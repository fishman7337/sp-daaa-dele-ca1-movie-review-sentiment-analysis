# %% [markdown]
# # ST1504: Deep Learning CA1 (Part B)
# By: Goh Kun Ming
#
# Class: DAAA/FT/2A/02
#
# *Soli Deo Gloria*

# %% [markdown]
# ---
# # 1. Importing of Libaries

# %% [markdown]
# In this section, we will be importing all the required Libaries of the Deep Learning CA1. Most of the libaries will be from TensorFlow, Keras and various Data Analysis and Visualisation Libaries. These Libaries will be imported in the code cell below.

# %%
# ==================== Installing Langdetect ==================== #
# !pip install -q langdetect

# ==================== Installing tqdm ==================== #
# !pip install -q tqdm

# ==================== Installing NLTK ==================== #
# !pip install -q nltk

# ==================== Installing HuggingFace Transformers ==================== #
# !pip install -q transformers sentencepiece

# ==================== Installing Keras Tuner ==================== #
# !pip install -q keras-tuner

# ==================== Installing Keras Visual ==================== #
# !pip install -q visualkeras

# ==================== Importing TensorFlow Models ==================== #
from tensorflow.keras.models import Sequential, load_model, Model

# ==================== Importing TensorFlow Layers ==================== #
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Bidirectional, Dropout, Dense, Input, BatchNormalization, Bidirectional, LeakyReLU

# ==================== Importing TensorFlow Utilities ==================== #
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.utils import plot_model

# ==================== Importing NLTK ==================== #
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# ==================== Importing Sklearn Confusion Matrix ==================== #
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, silhouette_score, roc_curve, auc, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

# ==================== Importing Sklearn TSNE ==================== #
from sklearn.manifold import TSNE

# ==================== Importing Keras Regulariser ==================== #
from tensorflow.keras.regularizers import l2

# ==================== Importing Keras Tuner ==================== #
import keras_tuner as kt

# ==================== Importing Keras Visual ==================== #
import visualkeras

# ==================== Importing Keras Regulariser ==================== #
from tensorflow.keras import regularizers

# ==================== Importing Keras Optimiser ==================== #
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

# ==================== Importing Sklearn Train Test Split ==================== #
from sklearn.model_selection import train_test_split

# ==================== Importing Pandas ==================== #
import pandas as pd

# ==================== Importing NumPy ==================== #
import numpy as np

# ==================== Importing Matplotlib ==================== #
import matplotlib.pyplot as plt

# ==================== Importing Plotly ==================== #
import plotly.express as px

# ==================== Importing Seaborn ==================== #
import seaborn as sns

# ==================== Importing tqdm ==================== #
from tqdm import tqdm

# ==================== Importing DBSCAN ==================== #
from sklearn.cluster import DBSCAN

# ==================== Importing Langdetect ==================== #
from langdetect import detect

# ==================== Importing Transformers ==================== #
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline, MarianMTModel, MarianTokenizer, set_seed

# ==================== Configuring Local Translation ==================== #
NLLB_MODEL_ID = 'facebook/nllb-200-distilled-600M'
AUGMENTATION_SEED = 42
set_seed(AUGMENTATION_SEED)
_nllb_model = None
_nllb_tokenizer = None

def translate_text(text, source_lang, target_lang):
    global _nllb_model, _nllb_tokenizer
    if _nllb_model is None or _nllb_tokenizer is None:
        _nllb_tokenizer = AutoTokenizer.from_pretrained(NLLB_MODEL_ID)
        _nllb_model = AutoModelForSeq2SeqLM.from_pretrained(NLLB_MODEL_ID)
        _nllb_model.eval()
    _nllb_tokenizer.src_lang = source_lang
    encoded = _nllb_tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    translated = _nllb_model.generate(
        **encoded,
        forced_bos_token_id=_nllb_tokenizer.convert_tokens_to_ids(target_lang),
        max_new_tokens=512,
    )
    return _nllb_tokenizer.batch_decode(translated, skip_special_tokens=True)[0]

# ==================== Importing Counter ==================== #
from collections import Counter

# ==================== Importing Regular Expressions ==================== #
import re

# ==================== Importing Operating System ==================== #
import os
import warnings

# ==================== Importing Image ==================== #
from IPython.display import Image

# ==================== Importing Shutill ==================== #
import shutil

# ==================== Mounting Google Drive ==================== #
from google.colab import drive
drive.mount('/content/drive')

# ==================== Defining Paths ==================== #
DRIVE_ROOT = '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B'
LOCAL_ROOT = '/content/DELE CA1 B'

# ==================== Copying Project Folder To Local SSD ==================== #
if os.path.exists(LOCAL_ROOT):
    shutil.rmtree(LOCAL_ROOT)
shutil.copytree(DRIVE_ROOT, LOCAL_ROOT)

# ==================== Switching To Local SSD ==================== #
os.chdir(LOCAL_ROOT)
print("Now working in:", os.getcwd())

# ==================== Final Confirmation ==================== #
print("Libraries Imported Successfully")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Now working in: /content/DELE CA1 B
# Libraries Imported Successfully

# %% [markdown]
# With reference to the output above, we are able to confirm that the Libaries
# have been successfully imported and we can move on to loading the dataset provided.

# %% [markdown]
# ---
# # 2. Data Cleaning

# %% [markdown]
# In this section, we will be loading the provided Movie Review Dataset and subsequently conduct quality checks and inspections to look out for abnormalies or Data Integrity Violations which will subsequently lead to the addressment. This is important as failure to do so will cause the Model to under-perform as compared to the standard expected.

# %% [markdown]
# ---
#
# ## 2.1 Loading of Dataset

# %% [markdown]
# In this sub-section, we will be loading the Dataset provided into the Local Environment. This operation will be done in the Code Cell below.

# %%
# ==================== Loading of Dataset ==================== #
df = pd.read_csv("./Dataset (B)/Movie reviews.csv")

# ==================== Loading of Dataset ==================== #
df.head(10).style.background_gradient(cmap="Blues")
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3807: RuntimeWarning:
#
# All-NaN slice encountered
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3808: RuntimeWarning:
#
# All-NaN slice encountered
# <style type="text/css">
# #T_54379_row0_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_54379_row0_col2, #T_54379_row1_col2, #T_54379_row2_col2, #T_54379_row3_col2, #T_54379_row4_col2, #T_54379_row5_col2, #T_54379_row6_col2, #T_54379_row7_col2, #T_54379_row8_col2, #T_54379_row9_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_54379_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_54379_row2_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_54379_row3_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_54379_row4_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_54379_row5_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_54379_row6_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_54379_row7_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_54379_row8_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_54379_row9_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# </style>
# <table id="T_54379" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54379_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_54379_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_54379_level0_col2" class="col_heading level0 col2" >Are there ways for you to generate more data? Spliting up sentences, would that help?</th>
#       <th id="T_54379_level0_col3" class="col_heading level0 col3" >Language</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54379_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54379_row0_col0" class="data row0 col0" >Filem ini hebat! Aksi yang mendebarkan dan plot yang mengejutkan.</td>
#       <td id="T_54379_row0_col1" class="data row0 col1" >0.100000</td>
#       <td id="T_54379_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_54379_row0_col3" class="data row0 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54379_row1_col0" class="data row1 col0" >Filem ini hebat! Aksi yang mendebarkan dan plot yang mengejutkan.</td>
#       <td id="T_54379_row1_col1" class="data row1 col1" >0.900000</td>
#       <td id="T_54379_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_54379_row1_col3" class="data row1 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54379_row2_col0" class="data row2 col0" >Filem ini hebat! Aksi yang mendebarkan dan plot yang mengejutkan.</td>
#       <td id="T_54379_row2_col1" class="data row2 col1" >0.500000</td>
#       <td id="T_54379_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_54379_row2_col3" class="data row2 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54379_row3_col0" class="data row3 col0" >Sayang sekali, pelakon tidak memberikan persembahan terbaik. Kurang puas hati.</td>
#       <td id="T_54379_row3_col1" class="data row3 col1" >0.800000</td>
#       <td id="T_54379_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_54379_row3_col3" class="data row3 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54379_row4_col0" class="data row4 col0" >Jalan cerita yang kompleks dan penuh emosi. Sungguh menghiburkan!</td>
#       <td id="T_54379_row4_col1" class="data row4 col1" >0.200000</td>
#       <td id="T_54379_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_54379_row4_col3" class="data row4 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54379_row5_col0" class="data row5 col0" >Pembuat filem berjaya memberikan pengalaman yang tidak terlupakan. Sungguh memukau!</td>
#       <td id="T_54379_row5_col1" class="data row5 col1" >0.050000</td>
#       <td id="T_54379_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_54379_row5_col3" class="data row5 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_54379_row6_col0" class="data row6 col0" >Adegan aksi yang terlalu banyak dan mengejutkan. Terkadang agak terlalu banyak.</td>
#       <td id="T_54379_row6_col1" class="data row6 col1" >0.400000</td>
#       <td id="T_54379_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_54379_row6_col3" class="data row6 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_54379_row7_col0" class="data row7 col0" >Saya teruja sepanjang filem. Penceritaan yang menarik!</td>
#       <td id="T_54379_row7_col1" class="data row7 col1" >0.150000</td>
#       <td id="T_54379_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_54379_row7_col3" class="data row7 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_54379_row8_col0" class="data row8 col0" >Avengers: Endgame mengecewakan dan membosankan. Terlalu banyak klise.</td>
#       <td id="T_54379_row8_col1" class="data row8 col1" >0.850000</td>
#       <td id="T_54379_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_54379_row8_col3" class="data row8 col3" >Malay</td>
#     </tr>
#     <tr>
#       <th id="T_54379_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_54379_row9_col0" class="data row9 col0" >Integrasi elemen fiksyen sains sangat menarik. Saya suka!</td>
#       <td id="T_54379_row9_col1" class="data row9 col1" >0.250000</td>
#       <td id="T_54379_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_54379_row9_col3" class="data row9 col3" >Malay</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to see that the Data have been successfully loaded in and there are a total of 4 Features within the Data. The observations have been listed below
#
# **Review**
# - Textual Data
# - Needs to be Pre-processed
#
# **Score**
# - Numerical Data
# - Will most likely be what we will be predicting
#
# **Are there ways for you to generate more data? Spliting up sentences, would that help?**
# - Miscellaneous Data
# - Needs to be dropped
#
# **Language**
# - Categorical Data
# - Suggests there are other Languages
#
# With the observations listed above, we will proceed to check for Missing Data and any Abnormallies before moving on the Data Analysis and Visualisations.

# %% [markdown]
# ---
#
# ## 2.2 Checking for Missing Data

# %% [markdown]
# Before conducting Data Visualisations, we will firstly be inspecting the Dataset to check for Missing Data. Should there be Missing Data present, we will have to impute the Missing Data or determine the best course of action to undertake with reference to the presented case.

# %%
# ==================== Creating NaN Summary Table ==================== #
def highlight_nan_summary(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

# ==================== Creating Missing Value DataFrame ==================== #
nan_summary = df.isnull().sum().to_frame(name='Missing Values')

# ==================== Applying Colour Coding ==================== #
styled_summary = nan_summary.style.map(highlight_nan_summary)

# ==================== Displaying DataFrame ==================== #
styled_summary
# Out:
# <style type="text/css">
# #T_f32d7_row0_col0, #T_f32d7_row3_col0 {
#   background-color: green;
#   color: white;
# }
# #T_f32d7_row1_col0, #T_f32d7_row2_col0 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_f32d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f32d7_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f32d7_level0_row0" class="row_heading level0 row0" >Review</th>
#       <td id="T_f32d7_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f32d7_level0_row1" class="row_heading level0 row1" >Score</th>
#       <td id="T_f32d7_row1_col0" class="data row1 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f32d7_level0_row2" class="row_heading level0 row2" >Are there ways for you to generate more data? Spliting up sentences, would that help?</th>
#       <td id="T_f32d7_row2_col0" class="data row2 col0" >527</td>
#     </tr>
#     <tr>
#       <th id="T_f32d7_level0_row3" class="row_heading level0 row3" >Language</th>
#       <td id="T_f32d7_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Output of the DataFrame above, we are able to see that there are indeed missing values within the Dataset provided. The observations are listed below.
#
# **Observations**
# - Score has 2 Missing Values
# - The Miscellanous Data has the most missing values but it can be disregarded as we already intend to drop it.
#
# **Action Plan**
# - Inspect the Data Rows with the Missing Score Value and determine the best course of action to address the Missing Data.
#
# With the Observations and Action Plan indicated, we will proceed to inspect the Missing Score Data.

# %% [markdown]
# ---
#
# ### 2.2.1 Inspecting Missing Score Data

# %% [markdown]
# We will be inspecting the Data Rows with the Missing Score Data to determine whether the Data Row is a Legitimate Data or not and if it will impact the integrity and accuracy of the RNN Model.

# %%
# ==================== Highlighting Rows with Missing Score in Red ==================== #
def highlight_missing_score(row):
    return ['background-color: red; color: white' if pd.isna(row['Score']) else '' for _ in row]

# ==================== Creating DataFrame ==================== #
styled_missing_rows = df[df['Score'].isna()].style.apply(highlight_missing_score, axis=1)

# ==================== Displaying DataFrame ==================== #
styled_missing_rows
# Out:
# <style type="text/css">
# #T_0b548_row0_col0, #T_0b548_row0_col1, #T_0b548_row0_col2, #T_0b548_row0_col3, #T_0b548_row1_col0, #T_0b548_row1_col1, #T_0b548_row1_col2, #T_0b548_row1_col3 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_0b548" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b548_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_0b548_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_0b548_level0_col2" class="col_heading level0 col2" >Are there ways for you to generate more data? Spliting up sentences, would that help?</th>
#       <th id="T_0b548_level0_col3" class="col_heading level0 col3" >Language</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b548_level0_row0" class="row_heading level0 row0" >426</th>
#       <td id="T_0b548_row0_col0" class="data row0 col0" >Ni hao</td>
#       <td id="T_0b548_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_0b548_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_0b548_row0_col3" class="data row0 col3" >Chinese</td>
#     </tr>
#     <tr>
#       <th id="T_0b548_level0_row1" class="row_heading level0 row1" >493</th>
#       <td id="T_0b548_row1_col0" class="data row1 col0" >Diabolic</td>
#       <td id="T_0b548_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_0b548_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_0b548_row1_col3" class="data row1 col3" >English</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame with the Missing Score Data above, we are able to identify that the Data Rows with the Missing Score Data are **Illegitimate Data**. Therefore, the best course of action to undertake is to **Drop The Data Rows**. This operation will be conducted in the next Code Cell.

# %% [markdown]
# ---
#
# ### 2.2.2 Addressing Missing Data

# %% [markdown]
# In this section, we will be Addressing both the Miscellanous Data Columns filled with Missing Data and the Missing Score Data. The Course of Action that we will be undertaking is **Dropping of Data Column and Data Row**. This will be done in the Code Cell below.

# %%
# ==================== Dropping Miscellaneous Data Column ==================== #
df = df.drop(columns=['Are there ways for you to generate more data? Spliting up sentences, would that help?'])

# ==================== Dropping Data Rows with Missing Score ==================== #
df = df[df['Score'].notna()].reset_index(drop=True)

# ==================== Final Confirmation ==================== #
def highlight_nan_summary(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

# ==================== Creating Missing Value DataFrame ==================== #
nan_summary = df.isnull().sum().to_frame(name='Missing Values')

# ==================== Applying Colour Coding ==================== #
styled_summary = nan_summary.style.map(highlight_nan_summary)

# ==================== Displaying DataFrame ==================== #
styled_summary
# Out:
# <style type="text/css">
# #T_b0944_row0_col0, #T_b0944_row1_col0, #T_b0944_row2_col0 {
#   background-color: green;
#   color: white;
# }
# </style>
# <table id="T_b0944" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0944_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0944_level0_row0" class="row_heading level0 row0" >Review</th>
#       <td id="T_b0944_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b0944_level0_row1" class="row_heading level0 row1" >Score</th>
#       <td id="T_b0944_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b0944_level0_row2" class="row_heading level0 row2" >Language</th>
#       <td id="T_b0944_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to confirm that the Miscellanous Data Column have been dropped successfully and the Missing Data for Score have been successfully removed. We are also able to visually confirm that there are no Missing Values remaining in the Dataset.

# %% [markdown]
# ---
#
# ## 2.3 Identifying Duplicated Data

# %% [markdown]
# In this sub-section, we will be indentifying for Duplicated Data within our Dataset. Duplicated Data can cause many issues for our RNN Model such as Overfitting instead of generalising patterns. Therefore, it is of utmost importance that we identify Duplicated Data within our Dataset.

# %%
# ==================== Creating Duplicate Summary ==================== #
duplicate_count = df.duplicated().sum()
summary_df = pd.DataFrame({'Duplicate Count': [duplicate_count]})

# ==================== Colour Coding Function ==================== #
def highlight_duplicates(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

# ==================== Apply Styling ==================== #
styled_summary = summary_df.style.map(highlight_duplicates)

# ==================== Display Summary ==================== #
styled_summary
# Out:
# <style type="text/css">
# #T_5c6f1_row0_col0 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_5c6f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c6f1_level0_col0" class="col_heading level0 col0" >Duplicate Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c6f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c6f1_row0_col0" class="data row0 col0" >111</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Output of the DataFrame above, we are able to see that there are indeed **Duplicated Data Indentified** within our Dataset. Therefore, the best course of action in this case is to **Drop all Duplicated Data**.

# %% [markdown]
# ---
# ### 2.3.1 Removing Duplicated Data

# %% [markdown]
# In this section, we will be removing the Duplicated Data Rows as identified in the parent sub-section. This will directly prevent our RNN Model from Overfitting and improve the overall performance. The operation to reove the Duplicated Data is done in the Code Cell below.

# %%
# ==================== Dropping Duplicate Rows ==================== #
df = df.drop_duplicates().reset_index(drop=True)

# ==================== Creating Duplicate Summary ==================== #
duplicate_count = df.duplicated().sum()
summary_df = pd.DataFrame({'Duplicate Count': [duplicate_count]})

# ==================== Colour Coding Function ==================== #
def highlight_duplicates(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

# ==================== Apply Styling ==================== #
styled_summary = summary_df.style.map(highlight_duplicates)

# ==================== Display Summary ==================== #
styled_summary
# Out:
# <style type="text/css">
# #T_8a7f3_row0_col0 {
#   background-color: green;
#   color: white;
# }
# </style>
# <table id="T_8a7f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a7f3_level0_col0" class="col_heading level0 col0" >Duplicate Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a7f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a7f3_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to determine that we have successfully removed all the Duplicated Data and we are able to proceed to the next step of Data Cleaning.

# %% [markdown]
# ---
# ## 2.4 Identifying Short-Worded Reviews

# %% [markdown]
# In this sub-section, we will be identifying reviews which have **less than 4 words**. Reviews with little words can be problematic when training a RNN model as it will cause an introduction in noise in both Classification and Regression as they often lack semantic richness. Therefore, it is important that we remove these data.

# %%
# ==================== Counting Reviews with < 4 Words ==================== #
df['word_count'] = df['Review'].apply(lambda x: len(str(x).split()))
short_review_count = (df['word_count'] < 4).sum()

# ==================== Creating Summary DataFrame ==================== #
short_summary_df = pd.DataFrame({'Reviews with < 4 words': [short_review_count]})

# ==================== Applying Colour Styling ==================== #
def highlight_short(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

styled_short_summary = short_summary_df.style.map(highlight_short)

# ==================== Displaying DataFrame ==================== #
styled_short_summary
# Out:
# <style type="text/css">
# #T_95f23_row0_col0 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_95f23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95f23_level0_col0" class="col_heading level0 col0" >Reviews with < 4 words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95f23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95f23_row0_col0" class="data row0 col0" >111</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to see that there are a total of **111 Data Rows** with less than 4 Words for its review. Therefore, to ensure the Model does not get introduced to noisy data, we will proceed to remove these Data Rows in the next section.

# %% [markdown]
# ---
# ### 2.4.1 Addressing Short-Worded Reviews

# %% [markdown]
# As previously identified, there are multiple Short-Worded Reviews within the Dataset which can cause Noise to be introduced to the RNN Model. Therefore, to address this issue, we will be removing the Data Rows with less than 4 words for its review. This operation will be conducted in the Code Cell below.

# %%
# ==================== Removing Very Short Reviews ==================== #
df['word_count'] = df['Review'].apply(lambda x: len(str(x).split()))
df = df[df['word_count'] >= 4].reset_index(drop=True)

# ==================== Counting Reviews with < 4 Words ==================== #
df['word_count'] = df['Review'].apply(lambda x: len(str(x).split()))
short_review_count = (df['word_count'] < 4).sum()

# ==================== Creating Summary DataFrame ==================== #
short_summary_df = pd.DataFrame({'Reviews with < 4 words': [short_review_count]})

# ==================== Applying Colour Styling ==================== #
def highlight_short(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

styled_short_summary = short_summary_df.style.map(highlight_short)

# ==================== Displaying DataFrame ==================== #
styled_short_summary
# Out:
# <style type="text/css">
# #T_fbc89_row0_col0 {
#   background-color: green;
#   color: white;
# }
# </style>
# <table id="T_fbc89" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbc89_level0_col0" class="col_heading level0 col0" >Reviews with < 4 words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbc89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbc89_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to visually confirm that the Data Rows with reviews of less than 4 words have been successfully removed.

# %% [markdown]
# ---
# ## 2.5 Creating Labelling

# %% [markdown]
# In this sub-section, we will be creating the Labelling so as to open the doors for Classification to be used. However, it is important to know that even though this is done so that Classification may be used, we are not fixed on using Classification yet as we are also able to utilise Regression. The decision will only be made at the end of the assessment. The Labelling's Bin will be determined using DBSCAN which will be unbiased as it is an Unsupervised Learning method.

# %% [markdown]
# ---
# ### 2.5.1 Fixing of Score

# %% [markdown]
# As previosuly identified, the Scores were perceived wrongly as higher score implies positive and vice-versa. However, this was false as seen from the Sorted DataFrame. Therefore a change will now be conducted in the Code Cell below to Invert the Score so that it will be more universally understandable to prevent future misconception.

# %%
# ==================== Inverting Score (Higher = Positive) ==================== #
df['Score'] = 1 - df['Score']

# ==================== Displaying DataFrame ==================== #
df.sort_values(by="Score").head(20).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_f9100_row0_col1, #T_f9100_row1_col3, #T_f9100_row3_col3, #T_f9100_row4_col3, #T_f9100_row14_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f9100_row0_col3, #T_f9100_row7_col3, #T_f9100_row8_col3 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_f9100_row1_col1, #T_f9100_row2_col1, #T_f9100_row3_col1, #T_f9100_row4_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_f9100_row2_col3, #T_f9100_row9_col3, #T_f9100_row10_col3, #T_f9100_row18_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f9100_row5_col1, #T_f9100_row6_col1, #T_f9100_row7_col1, #T_f9100_row8_col1, #T_f9100_row9_col1, #T_f9100_row10_col1, #T_f9100_row11_col1, #T_f9100_row12_col1, #T_f9100_row13_col1, #T_f9100_row14_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_f9100_row5_col3, #T_f9100_row11_col3, #T_f9100_row19_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_f9100_row6_col3, #T_f9100_row16_col3, #T_f9100_row17_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_f9100_row12_col3, #T_f9100_row13_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_f9100_row15_col1, #T_f9100_row15_col3, #T_f9100_row16_col1, #T_f9100_row17_col1, #T_f9100_row18_col1, #T_f9100_row19_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9100" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9100_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_f9100_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_f9100_level0_col2" class="col_heading level0 col2" >Language</th>
#       <th id="T_f9100_level0_col3" class="col_heading level0 col3" >word_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9100_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f9100_row0_col0" class="data row0 col0" >Filem ini hebat! Aksi yang mendebarkan dan plot yang mengejutkan.</td>
#       <td id="T_f9100_row0_col1" class="data row0 col1" >0.100000</td>
#       <td id="T_f9100_row0_col2" class="data row0 col2" >Malay</td>
#       <td id="T_f9100_row0_col3" class="data row0 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row1" class="row_heading level0 row1" >74</th>
#       <td id="T_f9100_row1_col0" class="data row1 col0" >Avengers: Endgame mengecewakan dan terlalu klise. Tidak menyeronokkan.</td>
#       <td id="T_f9100_row1_col1" class="data row1 col1" >0.150000</td>
#       <td id="T_f9100_row1_col2" class="data row1 col2" >Malay</td>
#       <td id="T_f9100_row1_col3" class="data row1 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row2" class="row_heading level0 row2" >121</th>
#       <td id="T_f9100_row2_col0" class="data row2 col0" >Avengers: Endgame is disappointing and too cliché. Not enjoyable.</td>
#       <td id="T_f9100_row2_col1" class="data row2 col1" >0.150000</td>
#       <td id="T_f9100_row2_col2" class="data row2 col2" >English</td>
#       <td id="T_f9100_row2_col3" class="data row2 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row3" class="row_heading level0 row3" >107</th>
#       <td id="T_f9100_row3_col0" class="data row3 col0" >Avengers: Endgame mengecewakan dan terlalu klise. Kurang memuaskan.</td>
#       <td id="T_f9100_row3_col1" class="data row3 col1" >0.150000</td>
#       <td id="T_f9100_row3_col2" class="data row3 col2" >Malay</td>
#       <td id="T_f9100_row3_col3" class="data row3 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_f9100_row4_col0" class="data row4 col0" >Avengers: Endgame mengecewakan dan membosankan. Terlalu banyak klise.</td>
#       <td id="T_f9100_row4_col1" class="data row4 col1" >0.150000</td>
#       <td id="T_f9100_row4_col2" class="data row4 col2" >Malay</td>
#       <td id="T_f9100_row4_col3" class="data row4 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row5" class="row_heading level0 row5" >203</th>
#       <td id="T_f9100_row5_col0" class="data row5 col0" >This film is highly disappointing. It fails to live up to the hype.</td>
#       <td id="T_f9100_row5_col1" class="data row5 col1" >0.200000</td>
#       <td id="T_f9100_row5_col2" class="data row5 col2" >English</td>
#       <td id="T_f9100_row5_col3" class="data row5 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row6" class="row_heading level0 row6" >61</th>
#       <td id="T_f9100_row6_col0" class="data row6 col0" >Filem ini mengecewakan dan tidak sepadan dengan waktu saya. Terlalu biasa.</td>
#       <td id="T_f9100_row6_col1" class="data row6 col1" >0.200000</td>
#       <td id="T_f9100_row6_col2" class="data row6 col2" >Malay</td>
#       <td id="T_f9100_row6_col3" class="data row6 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_f9100_row7_col0" class="data row7 col0" >Sayang sekali, pelakon tidak memberikan persembahan terbaik. Kurang puas hati.</td>
#       <td id="T_f9100_row7_col1" class="data row7 col1" >0.200000</td>
#       <td id="T_f9100_row7_col2" class="data row7 col2" >Malay</td>
#       <td id="T_f9100_row7_col3" class="data row7 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row8" class="row_heading level0 row8" >171</th>
#       <td id="T_f9100_row8_col0" class="data row8 col0" >Lack of character development makes this film weak. Not satisfying.</td>
#       <td id="T_f9100_row8_col1" class="data row8 col1" >0.200000</td>
#       <td id="T_f9100_row8_col2" class="data row8 col2" >English</td>
#       <td id="T_f9100_row8_col3" class="data row8 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row9" class="row_heading level0 row9" >145</th>
#       <td id="T_f9100_row9_col0" class="data row9 col0" >This film is very disappointing. Not worth the hype.</td>
#       <td id="T_f9100_row9_col1" class="data row9 col1" >0.200000</td>
#       <td id="T_f9100_row9_col2" class="data row9 col2" >English</td>
#       <td id="T_f9100_row9_col3" class="data row9 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row10" class="row_heading level0 row10" >23</th>
#       <td id="T_f9100_row10_col0" class="data row10 col0" >Saya tidak suka bagaimana filem ini berakhir. Tidak memuaskan.</td>
#       <td id="T_f9100_row10_col1" class="data row10 col1" >0.200000</td>
#       <td id="T_f9100_row10_col2" class="data row10 col2" >Malay</td>
#       <td id="T_f9100_row10_col3" class="data row10 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row11" class="row_heading level0 row11" >128</th>
#       <td id="T_f9100_row11_col0" class="data row11 col0" >I'm not satisfied with how the main actors deliver their lines. Not convincing.</td>
#       <td id="T_f9100_row11_col1" class="data row11 col1" >0.200000</td>
#       <td id="T_f9100_row11_col2" class="data row11 col2" >English</td>
#       <td id="T_f9100_row11_col3" class="data row11 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row12" class="row_heading level0 row12" >112</th>
#       <td id="T_f9100_row12_col0" class="data row12 col0" >Saya tidak puas hati dengan cara pelakon utama menyampaikan dialog. Kurang meyakinkan.</td>
#       <td id="T_f9100_row12_col1" class="data row12 col1" >0.200000</td>
#       <td id="T_f9100_row12_col2" class="data row12 col2" >Malay</td>
#       <td id="T_f9100_row12_col3" class="data row12 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row13" class="row_heading level0 row13" >81</th>
#       <td id="T_f9100_row13_col0" class="data row13 col0" >Saya tidak puas hati dengan cara pelakon utama menyampaikan dialog. Kurang menyakinkan.</td>
#       <td id="T_f9100_row13_col1" class="data row13 col1" >0.200000</td>
#       <td id="T_f9100_row13_col2" class="data row13 col2" >Malay</td>
#       <td id="T_f9100_row13_col3" class="data row13 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f9100_level0_row14" class="row_heading level0 row14" >32</th>
#       <td id="T_f9100_row14_col0" class="data ro

# %% [markdown]
# With reference to the Output above, we are able to see that the Ternary Label and Score have been successfully inverted and we are able to proceed with the corrected Dataset.

# %% [markdown]
# ---
# ### 2.5.2 Density-Based Spatial Clustering of Applications with Noise (DBSCAN) - Silhouette Method

# %% [markdown]
# In this section, we will be utilising the Silhouette Method to find the ideal number of Episilon for the DBSCAN. Through the Silhouette Method, we will be able to ensure the Clustering for the DBSCAN is robust and able to identify the Clusters accordingly. We will find the ideal number of Episilon before utilising DBSCAN.

# %%
eps_values = np.arange(0.01, 0.15, 0.005)
silhouette_scores = []

# ==================== Prepare Scores ==================== #
scores = df['Score'].values.reshape(-1, 1)

for eps in eps_values:
    db = DBSCAN(eps=eps, min_samples=10).fit(scores)
    labels = db.labels_
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)

    if n_clusters > 1:
        score = silhouette_score(scores, labels)
    else:
        score = -1
    silhouette_scores.append(score)

# ==================== Plotting Silhouette vs Epsilon ==================== #
plt.figure(figsize=(10, 5))
plt.plot(eps_values, silhouette_scores, marker='o')
plt.title("Silhouette Score for Different eps Values")
plt.xlabel("eps")
plt.ylabel("Silhouette Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the Code Cell above, we are able to see that the ideal number of Episilon is 0.09. This is evident as 0.09 was the last Episilon shown in the Line Graph before it decreased sharply in Silhouette Score. With this observation and value of Episilon found, we will proceed to conduct the DBSCAN while utilising the Episilon of 0.09 in the next section.

# %% [markdown]
# ---
# ### 2.5.3 Density-Based Spatial Clustering of Applications with Noise (DBSCAN) - Clustering

# %% [markdown]
# In this section, we will be utilising DBSCAN to find the appropriate Binning for the various Category for Labelling. DBSCAN is utlised so as to ensure that the Labelling is fair and do not cause a bias in the Classification especially when a Class will naturally have more Data compared to the other class. The DBSCAN with the Ideal Episilon will be conducted in the Code Cell below.

# %%
# ==================== Reshape Scores ==================== #
scores = df['Score'].values.reshape(-1, 1)

# ==================== Run DBSCAN ==================== #
dbscan = DBSCAN(eps=0.09, min_samples=10)
clusters = dbscan.fit_predict(scores)

# ==================== Add Cluster Labels to DataFrame ==================== #
df['Sentiment_Binary'] = clusters

# ==================== Visualise Clusters ==================== #
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Score', hue='Sentiment_Binary', bins=30, palette='Set2', multiple='stack')
plt.title('DBSCAN Clustering of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the Code Cell above, we are able to see the binning of the various clusters by the DBSCAN. These Binnings have been determined with reference to the overall Density of the Score within the Dataset. However, we are able to also see a few small Clusters which could possibly indicate noise and will not be able to tell us much information. Thus the small clusters will be dropped. Therefore, these binnings shall be perceived as un-biased and will be utilised within the Labelling Binning

# %% [markdown]
# ---
# ### 2.5.4 Binary-Label Creation

# %% [markdown]
# As identified in the previous Code Cell, we will now create the Binary-Labels for the identified 'Strong' Clusters. This will result in a Binary-Labelling as there are only 2 Strong Clusters which will become the Positive and Negative. This operation will be conducted in the Code Cel below.

# %%
# ==================== Filter Only Reliable Clusters ==================== #
df = df[df['Sentiment_Binary'].isin([0, 1])].copy()

# ==================== Assign Ternary Labels ==================== #
cluster_to_label = {
    1: 'Negative',
    0: 'Positive'
}

df['Sentiment_Label'] = df['Sentiment_Binary'].map(cluster_to_label)

# ==================== Displaying DataFrame ==================== #
df.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_4eb7b_row0_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_4eb7b_row0_col3, #T_4eb7b_row1_col3, #T_4eb7b_row1_col4, #T_4eb7b_row2_col3, #T_4eb7b_row2_col4, #T_4eb7b_row4_col1, #T_4eb7b_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4eb7b_row0_col4, #T_4eb7b_row1_col1, #T_4eb7b_row3_col3, #T_4eb7b_row3_col4, #T_4eb7b_row4_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4eb7b_row2_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_4eb7b_row3_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4eb7b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4eb7b_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_4eb7b_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_4eb7b_level0_col2" class="col_heading level0 col2" >Language</th>
#       <th id="T_4eb7b_level0_col3" class="col_heading level0 col3" >word_count</th>
#       <th id="T_4eb7b_level0_col4" class="col_heading level0 col4" >Sentiment_Binary</th>
#       <th id="T_4eb7b_level0_col5" class="col_heading level0 col5" >Sentiment_Label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4eb7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4eb7b_row0_col0" class="data row0 col0" >Filem ini hebat! Aksi yang mendebarkan dan plot yang mengejutkan.</td>
#       <td id="T_4eb7b_row0_col1" class="data row0 col1" >0.900000</td>
#       <td id="T_4eb7b_row0_col2" class="data row0 col2" >Malay</td>
#       <td id="T_4eb7b_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_4eb7b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4eb7b_row0_col5" class="data row0 col5" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_4eb7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4eb7b_row1_col0" class="data row1 col0" >Filem ini hebat! Aksi yang mendebarkan dan plot yang mengejutkan.</td>
#       <td id="T_4eb7b_row1_col1" class="data row1 col1" >0.100000</td>
#       <td id="T_4eb7b_row1_col2" class="data row1 col2" >Malay</td>
#       <td id="T_4eb7b_row1_col3" class="data row1 col3" >10</td>
#       <td id="T_4eb7b_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_4eb7b_row1_col5" class="data row1 col5" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_4eb7b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4eb7b_row2_col0" class="data row2 col0" >Sayang sekali, pelakon tidak memberikan persembahan terbaik. Kurang puas hati.</td>
#       <td id="T_4eb7b_row2_col1" class="data row2 col1" >0.200000</td>
#       <td id="T_4eb7b_row2_col2" class="data row2 col2" >Malay</td>
#       <td id="T_4eb7b_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_4eb7b_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_4eb7b_row2_col5" class="data row2 col5" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_4eb7b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4eb7b_row3_col0" class="data row3 col0" >Jalan cerita yang kompleks dan penuh emosi. Sungguh menghiburkan!</td>
#       <td id="T_4eb7b_row3_col1" class="data row3 col1" >0.800000</td>
#       <td id="T_4eb7b_row3_col2" class="data row3 col2" >Malay</td>
#       <td id="T_4eb7b_row3_col3" class="data row3 col3" >9</td>
#       <td id="T_4eb7b_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_4eb7b_row3_col5" class="data row3 col5" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_4eb7b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4eb7b_row4_col0" class="data row4 col0" >Pembuat filem berjaya memberikan pengalaman yang tidak terlupakan. Sungguh memukau!</td>
#       <td id="T_4eb7b_row4_col1" class="data row4 col1" >0.950000</td>
#       <td id="T_4eb7b_row4_col2" class="data row4 col2" >Malay</td>
#       <td id="T_4eb7b_row4_col3" class="data row4 col3" >10</td>
#       <td id="T_4eb7b_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_4eb7b_row4_col5" class="data row4 col5" >Positive</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to verify that we have successfully created the 'Sentiment_Ternary' Data Column that can be used for Classification.

# %% [markdown]
# ---
# ## 2.6 Addressing Duplicated Review

# %% [markdown]
# As shown in the various previews of the Data, we are able to see that there are duplicated values within the 'Review' Data Column despite there being differences in the Sentiment Score. Therefore to address this issue and to prevent the RNN from learning the same Review but with different Binary Label / Sentiment Score, we will only include the mean score for the same review in the Dataset. This operation will be conducted in the Code Cell below.

# %%
# ==================== Grouping by Review Text ==================== #
original_size = len(df)

# Keep all non-duplicated fields by taking the first value, except for Score (use mean)
agg_dict = {col: 'first' for col in df.columns if col not in ['Review', 'Score']}
agg_dict['Score'] = 'mean'

df = df.groupby('Review', as_index=False).agg(agg_dict)
deduped_size = len(df)

# ==================== Display Summary ==================== #
df_dedup_summary = pd.DataFrame({
    'Stage': ['Before Deduplication', 'After Deduplication'],
    'Review Count': [original_size, deduped_size],
    'Removed': [0, original_size - deduped_size]
})

df_dedup_summary.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_78f76_row0_col1, #T_78f76_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_78f76_row0_col2, #T_78f76_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_78f76" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78f76_level0_col0" class="col_heading level0 col0" >Stage</th>
#       <th id="T_78f76_level0_col1" class="col_heading level0 col1" >Review Count</th>
#       <th id="T_78f76_level0_col2" class="col_heading level0 col2" >Removed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78f76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78f76_row0_col0" class="data row0 col0" >Before Deduplication</td>
#       <td id="T_78f76_row0_col1" class="data row0 col1" >286</td>
#       <td id="T_78f76_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_78f76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78f76_row1_col0" class="data row1 col0" >After Deduplication</td>
#       <td id="T_78f76_row1_col1" class="data row1 col1" >279</td>
#       <td id="T_78f76_row1_col2" class="data row1 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Output above, we are able to verify that the Duplicated Review have been successfully addressed and we are able to proceed to the Exploratory Data Analysis.

# %% [markdown]
# ---
#
# # 3. Exploratory Data Analysis

# %% [markdown]
# In this section, we will be conducting Visualisations on our Cleaned Dataset to determine the best way forward for the Training of Models and also to understand where our Data might be weak in and how we can potentially compensate for it. This section will be separated into 2 different section, one for Classification and the other for Regression. This is because we have not yet decided whether we want to perfrom Classification or Regression on our Data.

# %% [markdown]
# ---
# ## 3.1 Overview Visualisation

# %% [markdown]
# In this sub-section, we will be mainly focusing on the Data Visualisation that are relevant to the Dataset as a whole. Through this sub-section, we hope to better understand our data and what can we do to better improve the RNN Model's performance in general for both Regression and Classification.

# %% [markdown]
# ---
# ### 3.1.1 Review Language Distribution

# %% [markdown]
# In this sub-section, we will be utilising a bar chart to visualise the Distribution of Review Languages within the dataset. The purpose of this visualisation has been indicated below:
#
# - Identifies the linguistic composition of the dataset.
# - Assists in determining whether language-specific preprocessing may be necessary.
# - Provides clarity on how language diversity might affect both model learning and generalisability.
# - Supports the decision to filter or group reviews by language for more consistent modelling.
#
# With the purpose indicated, we will proceed to conduct the visualisation in the Code Cell below.

# %%
# ==================== Language Distribution ==================== #
fig_lang = px.histogram(
    df,
    x='Language',
    color='Language',
    title='Review Language Distribution',
    color_discrete_sequence=px.colors.qualitative.Bold
)

fig_lang.update_layout(
    xaxis_title='Language',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    title_font=dict(size=20),
    showlegend=False
)

fig_lang.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="885bf0aa-13e4-40b6-9003-23bbe46fae1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("885bf0aa-13e4-40b6-9003-23bbe46fae1f")) {                    Plotly.newPlot(                        "885bf0aa-13e4-40b6-9003-23bbe46fae1f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Language=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"English","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"English","offsetgroup":"English","orientation":"v","showlegend":true,"x":["English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Language=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Malay","marker":{"color":"rgb(17, 165, 121)","pattern":{"shape":""}},"name":"Malay","offsetgroup":"Malay","orientation":"v","showlegend":true,"x":["Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay","Malay"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Language=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinese","marker":{"col ...

# %% [markdown]
# With reference to the output of the Visualisation above, we are able to make to following observations.
#
# - The majority of reviews are in English followed by a substantial portion in **Malay**.
# - Only 1 review are in Chinese, which may be too limited for effective modelling. Thus it will be dropped.
# - This suggests the dataset is primarily bilingual (English and Malay), allowing for effective sentiment analysis using either or both languages.
# - Any multilingual modelling approach must either translate non-English/Malay reviews or exclude them to maintain data consistency.
# - There is a class imbalance between Malay and English. However as the text will be tokenised, the class imbalance is not a major issue.
#
# With the observations and implications indicated, we will proceed to the next

# %% [markdown]
# ---
# #### 3.1.1.1 Removing Chinese Review

# %% [markdown]
# As visualised previously, the Language with the least Review is Chinese which means that it will not only be an issue when training the RNN Model, but due to the lack of data, it is virtually useless as the RNN Model will be unable to pick out any useful Data from it. Therefore, the best course of action to undertake in this case is to drop the Chinese Language Review. This operation will be conducted in the Code Cell below.

# %%
# ==================== Dropping Chinese Reviews ==================== #
df = df[df['Language'].str.lower() != 'chinese'].reset_index(drop=True)

# ==================== Displaying DataFrame ==================== #
df.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_fbfa5_row0_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_fbfa5_row0_col3, #T_fbfa5_row0_col5, #T_fbfa5_row1_col3, #T_fbfa5_row2_col2, #T_fbfa5_row2_col3, #T_fbfa5_row3_col3, #T_fbfa5_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fbfa5_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_fbfa5_row1_col5, #T_fbfa5_row2_col5 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_fbfa5_row3_col2, #T_fbfa5_row4_col2, #T_fbfa5_row4_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fbfa5_row3_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fbfa5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbfa5_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_fbfa5_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_fbfa5_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_fbfa5_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_fbfa5_level0_col4" class="col_heading level0 col4" >Sentiment_Label</th>
#       <th id="T_fbfa5_level0_col5" class="col_heading level0 col5" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbfa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbfa5_row0_col0" class="data row0 col0" >A big surprise in the middle of the film! Thrilling action!</td>
#       <td id="T_fbfa5_row0_col1" class="data row0 col1" >English</td>
#       <td id="T_fbfa5_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_fbfa5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fbfa5_row0_col4" class="data row0 col4" >Positive</td>
#       <td id="T_fbfa5_row0_col5" class="data row0 col5" >0.880000</td>
#     </tr>
#     <tr>
#       <th id="T_fbfa5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbfa5_row1_col0" class="data row1 col0" >A big surprise in the plot! Thrilling action throughout.</td>
#       <td id="T_fbfa5_row1_col1" class="data row1 col1" >English</td>
#       <td id="T_fbfa5_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_fbfa5_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_fbfa5_row1_col4" class="data row1 col4" >Positive</td>
#       <td id="T_fbfa5_row1_col5" class="data row1 col5" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_fbfa5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbfa5_row2_col0" class="data row2 col0" >A cinematic experience that is unforgettable. I'm impressed!</td>
#       <td id="T_fbfa5_row2_col1" class="data row2 col1" >English</td>
#       <td id="T_fbfa5_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_fbfa5_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_fbfa5_row2_col4" class="data row2 col4" >Positive</td>
#       <td id="T_fbfa5_row2_col5" class="data row2 col5" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_fbfa5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbfa5_row3_col0" class="data row3 col0" >A cinematic marvel! The visuals are breathtaking, and the narrative is spellbinding.</td>
#       <td id="T_fbfa5_row3_col1" class="data row3 col1" >English</td>
#       <td id="T_fbfa5_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_fbfa5_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_fbfa5_row3_col4" class="data row3 col4" >Positive</td>
#       <td id="T_fbfa5_row3_col5" class="data row3 col5" >0.920000</td>
#     </tr>
#     <tr>
#       <th id="T_fbfa5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fbfa5_row4_col0" class="data row4 col0" >A complex yet engaging plot. A major surprise awaits at the end!</td>
#       <td id="T_fbfa5_row4_col1" class="data row4 col1" >English</td>
#       <td id="T_fbfa5_row4_col2" class="data row4 col2" >12</td>
#       <td id="T_fbfa5_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_fbfa5_row4_col4" class="data row4 col4" >Positive</td>
#       <td id="T_fbfa5_row4_col5" class="data row4 col5" >0.940000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Output above, we are able to see that the dropping have been conducted successfully for the Data Row with the Chinese Language.

# %% [markdown]
# ---
# ### 3.1.2 Distribution of Review Length

# %% [markdown]
# In this sub-section, we will be utilising a histogram to display the Distribution of Review Word Counts across pre-defined bins. The purpose of this visualisation has been indicated below:
#
# - Provides an overview of how long or short the reviews are within the dataset.
# - Informs the choice of a suitable padding length during tokenisation, especially for RNNs.
# - Helps detect outlier bins that might require review trimming or special handling.
# - Ensures that model input sequences are efficiently processed while maintaining semantic richness.
#
# With the purpose indicated, we will proceed to conduct the visualisation in the Code Cell below.

# %%
# ==================== Calculate Word Count ==================== #
df['word_count'] = df['Review'].apply(lambda x: len(str(x).split()))

# ==================== Word Count Bins (Clean & Sorted X-Axis) ==================== #
bin_edges = [0, 10, 20, 30, 50, 100, 200, 1000]
bin_labels = ['0–10', '11–20', '21–30', '31–50', '51–100', '101–200', '201+']

df['word_count_bin'] = pd.cut(df['word_count'], bins=bin_edges, labels=bin_labels, include_lowest=True)

fig_bins = px.histogram(
    df,
    x='word_count_bin',
    category_orders={'word_count_bin': bin_labels},
    title='Distribution of Review Length Bins',
    color_discrete_sequence=['#9467bd']
)

fig_bins.update_layout(
    xaxis_title='Review Word Count Range',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    title_font=dict(size=20)
)

df.drop("word_count_bin", axis=1, inplace=True)

fig_bins.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="095d2844-8000-4294-9651-6ab977d14954" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("095d2844-8000-4294-9651-6ab977d14954")) {                    Plotly.newPlot(                        "095d2844-8000-4294-9651-6ab977d14954",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"word_count_bin=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#9467bd","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["11–20","0–10","0–10","11–20","11–20","11–20","11–20","0–10","11–20","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","31–50","31–50","11–20","31–50","31–50","31–50","21–30","31–50","51–100","0–10","0–10","0–10","0–10","31–50","31–50","31–50","31–50","31–50","31–50","0–10","0–10","0–10","0–10","11–20","31–50","31–50","0–10","0–10","0–10","11–20","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","11–20","11–20","0–10","0–10","0–10","0–10","11–20","11–20","0–10","0–10","0–10","11–20","0–10","0–10","11–20","11–20","11–20","11–20","11–20","11–20","31–50","0–10","0–10","11–20","11–20","11–20","11–20","0–10","11–20","11–20","11–20","0–10","0–10","0–10","11–20","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","11–20","0–10","0–10","0–10","11–20","0–10","0–10","0–10","11–20","0–10","11–20","31–50","11–20","0–10","0–10","0–10","0–10","11–20","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","0–10","11–20","11–20","0–10","0–10","0–10","0–10","11–20","0–10","0–10","11–20","0–10","11–20","0–10","11–20","11–20","11–20","0–10","11–20","0–10","0–10","0–10","0–10","0–10","11–20","11–20","0–10","11–20","0–10","11–20","11–20","0–10","0–10","11–20","11–20","11–20","31–50","31–50","0–10","11–20","11–20","0–10","0–10","0–10","31–50","11–20","0–10","0–10","31–50","31–50","11–20","11–20","31–50","31–50","11–20","31–50","11–20","11–20","11–20","11–20","11–20","31–50","31–50","31–50","31–50","31–50","11–20","31–50","31–50","31–50","31–50","11–20","11–20","31–50","11–20","31–50","11–20","11–20","11–20","0–10","11–20","31–50","31–50","31–50","31–50","0–10","11–20","0–10","31–50","11–20","11–20","0–10","0–10","31–50","11–20","11–20","0–10","11–20","11–20","51–100","11–20","0–10","11–20","31–50","0–10","11–20","0–10","11–20","11–20","0–10","0–10","0–10","11–20","0–10","0–10","0–10","31–50","0–10","11–20","0–10","0–10","0–10","11–20","0–10","11–20","11–20","0–10","0–10","0–10","11–20","0–10","0–10","0–10","0–10","0–10","11–20","31–50","31–50","31–50","31–50","31–50","31–50","31–50","31–50","31–50","11–20","31–50"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...

# %% [markdown]
# With reference to the output of the Visualisation above, we are able to make the following observations.
#
# - Most reviews fall within the 0–10 and 11–20 word ranges, confirming that reviews are generally short.
# - A noticeable drop is observed in the 21–30 word bin, indicating that only a small fraction of users provide more detailed reviews.
# - Moderate presence is seen in the 31–50 range, showing a small group of users who elaborate more extensively.
# - Very few reviews extend beyond 50 words, suggesting that long reviews are rare and might not heavily influence model training.
# - These insights support a padding length around 50 as sufficient for covering the majority of review lengths without excessive truncation or computational cost.
#
# With the observations and implications indicated, we will proceed to conduct the next Section of Visualisation.

# %% [markdown]
# ---
# ## 3.2 Regression Data Visualisation

# %% [markdown]
# In this sub-section, we will be mainly focusing on the Data Visualisation that are relevant for Regression. Through this sub-section, we hope to better understand our data and what can we do to better improve the RNN Model's performance in general for Regression.

# %% [markdown]
# ---
# ### 3.2.1 Distribution of Sentiment Scores

# %% [markdown]
# In this sub-section, we will be utilising a histogram with a marginal box plot to show the distribution of Sentiment Scores across the dataset. The purpose of this visualisation has been indicated below:
#
# - Helps determine whether the dataset is suitable for a Regression Modelling Task.
# - Reveals if the Score Values are Skewed or Uniformly Distributed, which affects how well the model can generalise.
# - Highlights the concentration of reviews around certain score ranges, informing class balance concerns if scores are later converted into classification labels.
# - Provides insight into whether any transformation or augmentation is needed before training.
# - The marginal box plot allows us to detect statistical outliers and better understand the spread of scores.
#
# With the purpose indicated, we will proceed to conduct the visualisation in the Code Cell below.

# %%
# ==================== Score Distribution (Regression) ==================== #
fig_score = px.histogram(
    df,
    x='Score',
    nbins=30,
    marginal='box',
    color_discrete_sequence=['#1f77b4'],
    title='Distribution of Sentiment Scores (Regression Target)'
)

fig_score.update_layout(
    xaxis_title='Sentiment Score (0 to 1)',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    title_font=dict(size=20),
)
fig_score.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ea0ae42d-fa8e-4436-b5ac-f85d60fe6cb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea0ae42d-fa8e-4436-b5ac-f85d60fe6cb0")) {                    Plotly.newPlot(                        "ea0ae42d-fa8e-4436-b5ac-f85d60fe6cb0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1f77b4","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.88,0.9,0.9,0.92,0.94,0.9,0.9,0.94,0.92,0.4,0.4,0.88,0.88,0.4,0.4,0.88,0.88,0.88,0.88,0.88,0.92,0.30000000000000004,0.9299999999999999,0.88,0.30000000000000004,0.30000000000000004,0.92,0.94,0.94,0.94,0.95,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.88,0.92,0.92,0.92,0.94,0.92,0.92,0.88,0.92,0.9,0.88,0.88,0.30000000000000004,0.4,0.9299999999999999,0.92,0.9,0.88,0.88,0.88,0.5,0.9,0.85,0.95,0.95,0.825,0.85,0.88,0.9,0.88,0.92,0.19999999999999996,0.92,0.88,0.19999999999999996,0.30000000000000004,0.88,0.30000000000000004,0.30000000000000004,0.30000000000000004,0.25,0.35,0.85,0.75,0.35,0.88,0.88,0.30000000000000004,0.85,0.19999999999999996,0.88,0.88,0.85,0.85,0.8,0.4,0.75,0.85,0.9,0.75,0.8,0.8,0.88,0.88,0.8,0.9,0.9,0.88,0.835,0.9,0.9,0.85,0.9,0.30000000000000004,0.25,0.25,0.22499999999999998,0.30000000000000004,0.88,0.88,0.92,0.92,0.92,0.85,0.85,0.88,0.88,0.85,0.88,0.25,0.30500000000000005,0.30000000000000004,0.88,0.88,0.95,0.9,0.9,0.88,0.85,0.85,0.9,0.92,0.9,0.30000000000000004,0.88,0.30000000000000004,0.30000000000000004,0.25,0.25,0.75,0.75,0.85,0.85,0.85,0.85,0.8,0.85,0.85,0.30000000000000004,0.30000000000000004,0.19999999999999996,0.19999999999999996,0.22499999999999998,0.30000000000000004,0.19999999999999996,0.30000000000000004,0.30000000000000004,0.92,0.92,0.7,0.9,0.9,0.9,0.9,0.30000000000000004,0.88,0.88,0.88,0.85,0.30000000000000004,0.30000000000000004,0.88,0.88,0.88,0.88,0.87,0.88,0.25,0.9299999999999999,0.9299999999999999,0.9,0.9299999999999999,0.94,0.87,0.92,0.88,0.35,0.78,0.9,0.9,0.9,0.94,0.85,0.88,0.88,0.85,0.92,0.87,0.35,0.30000000000000004,0.30000000000000004,0.88,0.9,0.75,0.88,0.8,0.88,0.88,0.9,0.85,0.9,0.30000000000000004,0.92,0.92,0.92,0.925,0.9,0.92,0.92,0.92,0.92,0.9,0.9,0.9,0.92,0.92,0.9,0.9,0.88,0.9,0.88,0.95,0.9,0.19999999999999996,0.88,0.92,0.88,0.19999999999999996,0.85,0.88,0.85,0.9,0.92,0.95,0.92,0.94,0.4,0.92,0.9,0.4,0.30000000000000004,0.30000000000000004,0.88,0.9,0.9,0.9,0.9,0.9,0.9,0.4,0.92,0.25,0.7,0.7,0.75,0.75,0.7,0.7,0.7,0.25,0.35,0.78,0.7],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"Score=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1f77b4"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[0.88,0.9,0.9,0.92,0.94,0.9,0.9,0.94,0.92,0.4,0.4,0.88,0.88,0.4,0.4,0.88,0.88,0.88,0.88,0.88,0.92,0.30000000000000004,0.9299999999999999,0.88,0.30000000000000004,0.30000000000000004,0.92,0.94,0.94,0.94,0.95,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.88,0.92,0.92,0.92,0.94,0.92,0.92,0.88,0.92,0.9,0.88,0.88,0.30000000000000004,0.4,0.9299999999999999,0.92,0.9,0.88,0.88,0.88,0.5,0.9,0.85,0.95,0.95,0.825,0.85,0.88,0.9,0.88,0.92,0.19999999999999996,0.92,0.88,0.19999999999999996,0.30000000000000004,0.88,0.30000000000000004,0.30000000000000004,0.30000000000000004,0.25,0.35,0.85,0.75,0.35,0.88,0.88,0.30000000000000004,0.85,0.19999999999999996,0.88,0.88,0.85,0.85,0.8,0.4,0.75,0.85,0.9,0.75,0.8,0.8,0.88,0.88,0.8,0.9,0.9,0.88,0.835,0.9,0.9,0.85,0.9,0.30000000000000004,0.25,0.25,0.22499999999999998,0.30000000000000004,0.88,0. ...

# %% [markdown]
# With reference to the output above, we are able to make the following observations.
#
# - The majority of sentiment scores are heavily concentrated between 0.05 and 0.15, indicating a strong skew towards Negative Sentiment.
# - Very few reviews have scores above 0.6, which corresponds to the Positive Class Threshold in the classification task.
# - The skewed distribution confirms the presence of Label Imbalance, which can affect both regression and classification performance.
# - The box plot further reveals that the Median Score is Extremely Low (~0.1), and the upper whisker extends towards high scores, though with few data points.
# - These insights justify the need for **class weighting and data augmentation** to mitigate model bias during training.
#
# With the observations and implications indicated, we will proceed to conduct the next Regression Visualisation.

# %% [markdown]
# ---
# ### 3.2.2 Review Length vs Score

# %% [markdown]
# In this sub-section, we will be utilising a scatter plot to visualise the relationship between Review Length (Word Count) and the corresponding Score. The purpose of this visualisation has been indicated below:
#
# - Helps determine whether review length has any correlation with sentiment scores.
# - Assists in understanding if longer reviews tend to be more positive or more detailed.
# - Supports the decision-making for input truncation and padding length especially in the RNN architecture.
# - Provides visual evidence of potential biases in short reviews.
#
# With the purpose indicated, we will proceed to conduct the visualisation in the Code Cell below.

# %%
# ==================== Review Length vs Sentiment Score ==================== #
fig_scatter = px.scatter(
    df,
    x='word_count',
    y='Score',
    title='Review Length vs Sentiment Score',
    color='Score',
    color_continuous_scale='Viridis',
    opacity=0.7
)

fig_scatter.update_layout(
    xaxis_title='Word Count',
    yaxis_title='Score',
    template='plotly_white',
    title_font=dict(size=20),
)
fig_scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1dc8d9f7-e35e-4907-8663-9c62052d7f3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dc8d9f7-e35e-4907-8663-9c62052d7f3e")) {                    Plotly.newPlot(                        "1dc8d9f7-e35e-4907-8663-9c62052d7f3e",                        [{"hovertemplate":"word_count=%{x}\u003cbr\u003eScore=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.88,0.9,0.9,0.92,0.94,0.9,0.9,0.94,0.92,0.4,0.4,0.88,0.88,0.4,0.4,0.88,0.88,0.88,0.88,0.88,0.92,0.30000000000000004,0.9299999999999999,0.88,0.30000000000000004,0.30000000000000004,0.92,0.94,0.94,0.94,0.95,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.88,0.92,0.92,0.92,0.94,0.92,0.92,0.88,0.92,0.9,0.88,0.88,0.30000000000000004,0.4,0.9299999999999999,0.92,0.9,0.88,0.88,0.88,0.5,0.9,0.85,0.95,0.95,0.825,0.85,0.88,0.9,0.88,0.92,0.19999999999999996,0.92,0.88,0.19999999999999996,0.30000000000000004,0.88,0.30000000000000004,0.30000000000000004,0.30000000000000004,0.25,0.35,0.85,0.75,0.35,0.88,0.88,0.30000000000000004,0.85,0.19999999999999996,0.88,0.88,0.85,0.85,0.8,0.4,0.75,0.85,0.9,0.75,0.8,0.8,0.88,0.88,0.8,0.9,0.9,0.88,0.835,0.9,0.9,0.85,0.9,0.30000000000000004,0.25,0.25,0.22499999999999998,0.30000000000000004,0.88,0.88,0.92,0.92,0.92,0.85,0.85,0.88,0.88,0.85,0.88,0.25,0.30500000000000005,0.30000000000000004,0.88,0.88,0.95,0.9,0.9,0.88,0.85,0.85,0.9,0.92,0.9,0.30000000000000004,0.88,0.30000000000000004,0.30000000000000004,0.25,0.25,0.75,0.75,0.85,0.85,0.85,0.85,0.8,0.85,0.85,0.30000000000000004,0.30000000000000004,0.19999999999999996,0.19999999999999996,0.22499999999999998,0.30000000000000004,0.19999999999999996,0.30000000000000004,0.30000000000000004,0.92,0.92,0.7,0.9,0.9,0.9,0.9,0.30000000000000004,0.88,0.88,0.88,0.85,0.30000000000000004,0.30000000000000004,0.88,0.88,0.88,0.88,0.87,0.88,0.25,0.9299999999999999,0.9299999999999999,0.9,0.9299999999999999,0.94,0.87,0.92,0.88,0.35,0.78,0.9,0.9,0.9,0.94,0.85,0.88,0.88,0.85,0.92,0.87,0.35,0.30000000000000004,0.30000000000000004,0.88,0.9,0.75,0.88,0.8,0.88,0.88,0.9,0.85,0.9,0.30000000000000004,0.92,0.92,0.92,0.925,0.9,0.92,0.92,0.92,0.92,0.9,0.9,0.9,0.92,0.92,0.9,0.9,0.88,0.9,0.88,0.95,0.9,0.19999999999999996,0.88,0.92,0.88,0.19999999999999996,0.85,0.88,0.85,0.9,0.92,0.95,0.92,0.94,0.4,0.92,0.9,0.4,0.30000000000000004,0.30000000000000004,0.88,0.9,0.9,0.9,0.9,0.9,0.9,0.4,0.92,0.25,0.7,0.7,0.75,0.75,0.7,0.7,0.7,0.25,0.35,0.78,0.7],"coloraxis":"coloraxis","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[11,9,8,12,12,18,15,10,11,10,10,10,10,9,9,10,7,10,10,10,9,8,42,39,11,46,48,49,27,44,57,9,8,8,8,47,39,37,42,31,44,4,4,10,10,12,42,43,9,4,5,12,9,8,8,10,8,10,9,9,12,12,9,9,10,10,11,11,8,8,10,12,10,10,11,11,16,11,11,12,49,10,8,11,13,13,11,7,12,11,11,8,10,4,11,9,9,10,9,9,9,9,8,8,11,10,8,10,11,9,9,10,12,8,12,48,12,10,9,9,10,11,10,9,8,9,9,10,10,10,7,8,11,11,8,9,10,10,11,8,7,12,10,11,10,11,11,11,10,12,10,10,7,9,9,12,12,9,12,10,12,12,9,4,12,13,17,45,49,10,12,11,10,9,10,45,13,10,10,44,46,13,13,40,39,16,39,14,15,14,15,13,49,37,40,39,45,13,44,44,45,35,12,17,39,15,48,14,12,13,10,11,39,42,38,49,10,11,10,44,11,12,8,10,45,13,13,10,11,15,51,13,10,13,49,8,14,9,13,12,10,9,9,11,10,10,10,44,8,13,5,9,4,12,4,12,12,7,9,9,11,9,10,8,10,5,11,42,37,39,38,40,34,35,42,44,15,50],"xaxis":"x","y":[0.88,0.9,0.9,0.92,0.94,0.9,0.9,0.94,0.92,0.4,0.4,0.88,0.88,0.4,0.4,0.88,0.88,0.88,0.88,0.88,0.92,0.30000000000000004,0.9299999999999999,0.88,0.30000000000000004,0.30000000000000004,0.92,0.94,0.94,0.94,0.95,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.15000000000000002,0.88,0.92,0.92,0.92,0.94,0.92,0.92,0.88,0.92,0.9,0.88,0.88,0.3 ...

# %% [markdown]
# With reference to the Output above, we are able to make the following observations.
#
# - The majority of reviews are less than 15 words, with a visible cluster of very short reviews (~10 words) dominating the dataset.
# - There is no strong linear correlation between review length and sentiment score, but a pattern emerges:
#   - Many short reviews (under 10 words) tend to have very low sentiment scores, suggesting brief complaints or harsh feedback.
#   - Higher sentiment scores (above 0.6) appear more frequently among reviews with moderate to long lengths, indicating that positive sentiment is often expressed more elaborately.
# - The pattern supports the earlier decision to remove ultra-short reviews (< 4 words) during data cleaning.
# - This scatter plot reaffirms that padding length must be chosen carefully, and that review length does not guarantee sentiment strength, but may influence expression style.
#
# With the observations indicated, we will proceed to the next Section.

# %% [markdown]
# ---
#
# ## 3.3 Classification Data Visualisation

# %% [markdown]
# In this sub-section, we will be mainly focusing on the Data Visualisation that are relevant for Classification. Through this sub-section, we hope to better understand our data and what can we do to better improve the RNN Model's performance in general for Classification.

# %% [markdown]
# ---
# ### 3.3.1 Visualising Class Imbalance

# %% [markdown]
# In this sub-section, we will be visualising the quantity count for each of the sentiment class so as to identify any potential Class Imbalance. Class Imbalance could cause skewed accuracy as the model is able to better learn from the sentiment class with higher quantity of data whereas sentiment classes with lower number of data will cause a lower accuracy. This can cause a high accuracy model as the model may be extremely capable of identifying a specific class while failing to identify other classes. The various actions that can be taken to address Class Imbalance are listed below:
#
# **Methods To Address Class Imbalance**
# - Establishing Class Weights
# - Oversampling / Undersampling
#
# With the various Methods to Address Class Imbalance, we shall proceed to state the appropriate action plan for various outcomes of the visualisation. The action plan for each respective results are listed below:
#
# **Class Imbalance Identified**
# - List down the observations from the Barplot.
# - Proceed to address Class Imbalance using one of the listed method.
# - Justify the chosen method's usage over other method.
#
# **No Class Imbalance Identified**
# - List down the observations from the Barplot.
# - Proceed to next visualisation.
#
# With the action plan for the potential results listed, we will proceed to conduct the visualisation in the Code Cell below.

# %%
# ==================== Ternary Sentiment Class Distribution ==================== #
fig_class = px.histogram(
    df,
    x='Sentiment_Label',
    color='Sentiment_Label',
    title='Binary Sentiment Class Distribution',
    color_discrete_map={
        'Positive': '#2ca02c',
        'Negative': '#d62728'
    }
)

fig_class.update_layout(
    xaxis_title='Sentiment Class',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    showlegend=False,
    title_font=dict(size=15),
)

fig_class.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ed082329-01d5-4fc8-8a01-20adfbcc9c4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed082329-01d5-4fc8-8a01-20adfbcc9c4b")) {                    Plotly.newPlot(                        "ed082329-01d5-4fc8-8a01-20adfbcc9c4b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#2ca02c","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"x":["Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#d62728","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"x":["Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative", ...

# %% [markdown]
# With reference to the output of the output of the barplot above, we are able to see that there is a Significant **Class Inbalance** within our Dataset. This could cause the RNN Model to be better in predicting Positive Reviews as compared to Positive or Neutral Reviews due to the likihood of a higher amount of Training Data using Positive Reviews. Therefore, to address the Class Imbalance, we will have to identify a method that is suitable in this case.

# %% [markdown]
# ---
# ### 3.3.2 Score Distribution by Sentiment

# %% [markdown]
# In this sub-section, we will be utilising the violin plot to visualises the Distribution of Scores across the three Sentiment Classes: Negative, Neutral, and Positive. The potential obsevations that we can gather from this Visualisation are indicated below.
#
# - Validating the label thresholds used to generate the ternary classification target from the continuous Score
# - Understanding whether the classes are well-separated in terms of their score distribution
# - Confirming that the model has meaningful signal to learn from.
#
# By including individual data points along with a smoothed density curve and boxplot, this visual provides both high-level and detailed insights into how sentiment scores are distributed within each class. With the purpose and potential observations indicated, we will proceed to conduct the Visuaisation in the Code Cell below.

# %%
# ==================== Score Distribution by Sentiment (Violin Plot) ==================== #
fig_violin = px.violin(
    df,
    x='Sentiment_Label',
    y='Score',
    color='Sentiment_Label',
    box=True,
    points='all',
    title='Score Spread by Sentiment Class',
    color_discrete_map={
        'Negative': '#d62728',
        'Neutral': '#1f77b4',
        'Positive': '#2ca02c'
    }
)

fig_violin.update_layout(
    xaxis_title='Sentiment Class',
    yaxis_title='Score',
    template='plotly_white',
    title_font=dict(size=20),
)
fig_violin.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="76d89259-19a8-45ac-9713-8b015fe61843" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76d89259-19a8-45ac-9713-8b015fe61843")) {                    Plotly.newPlot(                        "76d89259-19a8-45ac-9713-8b015fe61843",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#2ca02c"},"name":"Positive","offsetgroup":"Positive","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive"],"x0":" ","xaxis":"x","y":[0.88,0.9,0.9,0.92,0.94,0.9,0.9,0.94,0.92,0.88,0.88,0.88,0.88,0.88,0.88,0.88,0.92,0.9299999999999999,0.88,0.92,0.94,0.94,0.94,0.95,0.88,0.92,0.92,0.92,0.94,0.92,0.92,0.88,0.92,0.9,0.88,0.88,0.9299999999999999,0.92,0.9,0.88,0.88,0.88,0.5,0.9,0.85,0.95,0.95,0.825,0.85,0.88,0.9,0.88,0.92,0.92,0.88,0.88,0.85,0.75,0.88,0.88,0.85,0.88,0.88,0.85,0.85,0.8,0.75,0.85,0.9,0.75,0.8,0.8,0.88,0.88,0.8,0.9,0.9,0.88,0.835,0.9,0.9,0.85,0.9,0.88,0.88,0.92,0.92,0.92,0.85,0.85,0.88,0.88,0.85,0.88,0.88,0.88,0.95,0.9,0.9,0.88,0.85,0.85,0.9,0.92,0.9,0.88,0.75,0.75,0.85,0.85,0.85,0.85,0.8,0.85,0.85,0.92,0.92,0.7,0.9,0.9,0.9,0.9,0.88,0.88,0.88,0.85,0.88,0.88,0.88,0.88,0.87,0.88,0.9299999999999999,0.9299999999999999,0.9,0.9299999999999999,0.94,0.87,0.92,0.88,0.78,0.9,0. ...

# %% [markdown]
# With reference to the output of the Violin Plot above, we are able to make the following observations.
#
# - **Negative** reviews are tightly clustered around scores between **0.1 and 0.35**, showing strong separation from the other classes.
# - **Positive** reviews are consistently within the **0.7 to 0.8+ range**, with minimal overlap into Neutral territory.
# - There is **clear separation** between the classes, which justifies the chosen thresholds (0.4 and 0.7) for converting regression scores into ternary classification labels.
#
# With the observations indicated, we will proceed to the next Visualisation for Classification.

# %% [markdown]
# ---
# ### 3.3.3 Review Length by Sentiment Class

# %% [markdown]
# In this sub-section, we will be utilisng box plot to shows the Distribution of Review Lengths (word count) across the Three Sentiment Classes. The purpose of the Visualisation have been indicated below.
#
# - Helps determine if there is a relationship between Sentiment and Review Length.
# - Informs whether different sentiment classes requires Different Padding Lengths in the tokenisation phase.
# - Helps detect outliers in Review Length.
#
# Understanding the variation in review lengths ensures the RNN Model is appropriately designed to handle different input sizes and may reveal behavioural patterns in how users express sentiment. With the purpose indicated, we will proceed to conduct the Visualisation in the Code Cell below.

# %%
# ==================== Review Length by Sentiment Class (Box Plot) ==================== #
fig_box = px.box(
    df,
    x='Sentiment_Label',
    y='word_count',
    color='Sentiment_Label',
    title='Review Length by Sentiment Class',
    color_discrete_map={
        'Negative': '#d62728',
        'Neutral': '#1f77b4',
        'Positive': '#2ca02c'
    }
)

fig_box.update_layout(
    xaxis_title='Sentiment Class',
    yaxis_title='Review Word Count',
    template='plotly_white',
    title_font=dict(size=20),
)
fig_box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="017dff35-63bd-4e7e-b60c-8dc7c4f006c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("017dff35-63bd-4e7e-b60c-8dc7c4f006c7")) {                    Plotly.newPlot(                        "017dff35-63bd-4e7e-b60c-8dc7c4f006c7",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003eword_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#2ca02c"},"name":"Positive","notched":false,"offsetgroup":"Positive","orientation":"v","showlegend":true,"x":["Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive"],"x0":" ","xaxis":"x","y":[11,9,8,12,12,18,15,10,11,10,10,10,7,10,10,10,9,42,39,48,49,27,44,57,47,39,37,42,31,44,4,4,10,10,12,42,4,5,12,9,8,8,10,8,10,9,9,12,12,9,9,10,10,11,8,12,11,11,49,10,11,13,11,7,12,11,8,10,4,11,9,9,10,9,9,9,9,8,8,11,10,8,10,8,12,48,12,10,9,9,10,11,10,9,10,10,10,7,8,11,11,8,9,10,10,8,10,11,11,11,10,12,10,10,7,9,4,12,13,17,45,49,12,11,10,9,13,10,10,44,46,13,40,39,16,39,14,15,14,15,49,37,40,39,45,13,44,44,45,35,12,48,14,12,13,10,11,39,42,38,49,11,10,44,11,12,8,10,45,13,13,10,11,15,51,13,10,13,49,8,14,9,12,10,9,11,10,10,10,44,8,13,5,4,12,7,9,9,11,9,10,8,5,42,37,39,38,40,34,35,15,50],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003eword_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"colo ...

# %% [markdown]
# With reference to the output above, we are able to make the following Observations.
#
# - Positive Reviews show a wide range of lengths, with many short reviews, likely due to brief complaints.
# - Negative Reviews tend to be longer on average, with a higher median word count, possibly reflecting more detailed expressions of appreciation.
# - The broader spread across classes supports the use of a Uniform Padding Length for Tokenised Inputs.
#
# With the observations and implications indicated, we will proceed to Visualise Regression-related EDAs.

# %% [markdown]
# ---
# # 4. Data Pre-Processing

# %% [markdown]
# In this section, we will augment, and process our Data so as to prepare for Model Training. Throughout this section, we will also prepare our Data in 2 different methods as there are both Classification and Regression that needs to be done. Some of these operations that will be conducted are but not limited to, Data Augmentation, Tokenisation and Padding.

# %% [markdown]
# ---
# ## 4.1 Data Splitting For Classification & Regression

# %% [markdown]
# In this sub-section, we will be spliting our Data into Two Separate DataFrame as the Data Pre-processing for Classification may be different from the Data Pre-processing for Regression. Therefore, to accomodate for both Classification & Regression to be done and subsequently evaluated, we will need to conduct the Data Pre-processing separately.

# %%
# ==================== Creating Data Label ==================== #
df['source'] = 'original'

# ==================== Splitting into Two DataFrames ==================== #
df_classification = df.copy()
df_regression = df.copy()

# ==================== Regression: Drop Classification Labels ==================== #
df_regression = df_regression.drop(columns=['Sentiment_Label'], errors='ignore')

# ==================== Displaying DataFrames ==================== #
print("Classification DataFrame:")
display(df_classification.head(5).style.background_gradient(cmap="Blues"))
print("\n"*5)
print("Regression DataFrame:")
display(df_regression.head(5).style.background_gradient(cmap="Blues"))
# Out:
# Classification DataFrame:
# <style type="text/css">
# #T_2e223_row0_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_2e223_row0_col3, #T_2e223_row0_col5, #T_2e223_row1_col3, #T_2e223_row2_col2, #T_2e223_row2_col3, #T_2e223_row3_col3, #T_2e223_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2e223_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_2e223_row1_col5, #T_2e223_row2_col5 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_2e223_row3_col2, #T_2e223_row4_col2, #T_2e223_row4_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2e223_row3_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e223" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e223_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_2e223_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_2e223_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_2e223_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_2e223_level0_col4" class="col_heading level0 col4" >Sentiment_Label</th>
#       <th id="T_2e223_level0_col5" class="col_heading level0 col5" >Score</th>
#       <th id="T_2e223_level0_col6" class="col_heading level0 col6" >source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e223_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e223_row0_col0" class="data row0 col0" >A big surprise in the middle of the film! Thrilling action!</td>
#       <td id="T_2e223_row0_col1" class="data row0 col1" >English</td>
#       <td id="T_2e223_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_2e223_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2e223_row0_col4" class="data row0 col4" >Positive</td>
#       <td id="T_2e223_row0_col5" class="data row0 col5" >0.880000</td>
#       <td id="T_2e223_row0_col6" class="data row0 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_2e223_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e223_row1_col0" class="data row1 col0" >A big surprise in the plot! Thrilling action throughout.</td>
#       <td id="T_2e223_row1_col1" class="data row1 col1" >English</td>
#       <td id="T_2e223_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_2e223_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_2e223_row1_col4" class="data row1 col4" >Positive</td>
#       <td id="T_2e223_row1_col5" class="data row1 col5" >0.900000</td>
#       <td id="T_2e223_row1_col6" class="data row1 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_2e223_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e223_row2_col0" class="data row2 col0" >A cinematic experience that is unforgettable. I'm impressed!</td>
#       <td id="T_2e223_row2_col1" class="data row2 col1" >English</td>
#       <td id="T_2e223_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_2e223_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_2e223_row2_col4" class="data row2 col4" >Positive</td>
#       <td id="T_2e223_row2_col5" class="data row2 col5" >0.900000</td>
#       <td id="T_2e223_row2_col6" class="data row2 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_2e223_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e223_row3_col0" class="data row3 col0" >A cinematic marvel! The visuals are breathtaking, and the narrative is spellbinding.</td>
#       <td id="T_2e223_row3_col1" class="data row3 col1" >English</td>
#       <td id="T_2e223_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_2e223_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_2e223_row3_col4" class="data row3 col4" >Positive</td>
#       <td id="T_2e223_row3_col5" class="data row3 col5" >0.920000</td>
#       <td id="T_2e223_row3_col6" class="data row3 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_2e223_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e223_row4_col0" class="data row4 col0" >A complex yet engaging plot. A major surprise awaits at the end!</td>
#       <td id="T_2e223_row4_col1" class="data row4 col1" >English</td>
#       <td id="T_2e223_row4_col2" class="data row4 col2" >12</td>
#       <td id="T_2e223_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_2e223_row4_col4" class="data row4 col4" >Positive</td>
#       <td id="T_2e223_row4_col5" class="data row4 col5" >0.940000</td>
#       <td id="T_2e223_row4_col6" class="data row4 col6" >original</td>
#     </tr>
#   </tbody>
# </table>
# Regression DataFrame:
# <style type="text/css">
# #T_68c0b_row0_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_68c0b_row0_col3, #T_68c0b_row0_col4, #T_68c0b_row1_col3, #T_68c0b_row2_col2, #T_68c0b_row2_col3, #T_68c0b_row3_col3, #T_68c0b_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_68c0b_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_68c0b_row1_col4, #T_68c0b_row2_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_68c0b_row3_col2, #T_68c0b_row4_col2, #T_68c0b_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_68c0b_row3_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_68c0b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68c0b_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_68c0b_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_68c0b_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_68c0b_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_68c0b_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_68c0b_level0_col5" class="col_heading level0 col5" >source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68c0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68c0b_row0_col0" class="data row0 col0" >A big surprise in the middle of the film! Thrilling action!</td>
#       <td id="T_68c0b_row0_col1" class="data row0 col1" >English</td>
#       <td id="T_68c0b_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_68c0b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_68c0b_row0_col4" class="data row0 col4" >0.880000</td>
#       <td id="T_68c0b_row0_col5" class="data row0 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_68c0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68c0b_row1_col0" class="data row1 col0" >A big surprise in the plot! Thrilling action throughout.</td>
#       <td id="T_68c0b_row1_col1" class="data row1 col1" >English</td>
#       <td id="T_68c0b_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_68c0b_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_68c0b_row1_col4" class="data row1 col4" >0.900000</td>
#       <td id="T_68c0b_row1_col5" class="data row1 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_68c0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68c0b_row2_col0" class="data row2 col0" >A cinematic experience that is unforgettable. I'm impressed!</td>
#       <td id="T_68c0b_row2_col1" class="data row2 col1" >English</td>
#       <td id="T_68c0b_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_68c0b_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_68c0b_row2_col4" class="data row2 col4" >0.900000</td>
#       <td id="T_68c0b_row2_col5" class="data row2 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_68c0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_68c0b_row3_col0" class="data row3 col0" >A cinematic marvel! The visuals are breathtaking, and the narrative is spellbinding.</td>
#       <td id="T_68c0b_row3_col1" class="data row3 col1" >English</td>
#       <td id="T_68c0b_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_68c0b_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_68c0b_row3_col4" class="data row3 col4" >0.920000</td>
#       <td id="T_68c0b_row3_col5" class="data row3 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_68c0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_68c0b_row4_col0" class="data row4 col0" >A complex yet engaging plot. A major surprise awaits at the end!</td>
#       <td id="T_68c0b_row4_col1" class="data row4 col1" >English</td>
#       <td id="T_68c0b_row4_col2" class="data row4 col2" >12</td>
#       <td id="T_68c0b_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_68c0b_row4_col4" class="data row4 col4" >0.940000</td>
#       <td id="T_68c0b_row4_col5" class="data row4 col5" >original</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the Two Separate DataFrames above, we are able to verify that the Data have been successfully split into 2 different parts that can be pre-processed separately.

# %% [markdown]
# ---
# ## 4.2 Train-Validation-Test Split

# %% [markdown]
# In this sub-section, we will split our data into 3 different parts, Training Data, Validation Data and Testing Data. These data will be used to Train and subsequently, Evaluate our RNN Models. This operation will be conducted in the Code Cell below.

# %%
# ==================== Filter Original (No Augmentation) ==================== #
df_class_original = df_classification[df_classification['source'] == 'original'].reset_index(drop=True)

# ==================== Initial Stratified Train/Test Split ==================== #
df_class_train_val, df_class_test = train_test_split(
    df_class_original,
    test_size=0.10,
    stratify=df_class_original['Sentiment_Binary'],
    random_state=42
)

# ==================== Stratified Split: Train/Val from Train_Val ==================== #
df_class_train, df_class_val = train_test_split(
    df_class_train_val,
    test_size=0.1111,  # 0.1111 of 90% ≈ 10% of total
    stratify=df_class_train_val['Sentiment_Binary'],
    random_state=42
)

# ==================== Filter Original (No Augmentation) ==================== #
df_reg_original = df_regression[df_regression['source'] == 'original'].reset_index(drop=True)

# ==================== Initial Train/Test Split ==================== #
df_reg_train_val, df_reg_test = train_test_split(
    df_reg_original,
    test_size=0.10,
    shuffle=True,
    random_state=42
)

# ==================== Random Split: Train/Val from Train_Val ==================== #
df_reg_train, df_reg_val = train_test_split(
    df_reg_train_val,
    test_size=0.1111,
    shuffle=True,
    random_state=42
)

# ==================== Displaying DataFrames ==================== #
print("Classification DataFrame:")
display(df_class_train.head(5).style.background_gradient(cmap="Blues"))
print("\n"*5)
print("Regression DataFrame:")
display(df_reg_train.head(5).style.background_gradient(cmap="Blues"))
# Out:
# Classification DataFrame:
# <style type="text/css">
# #T_40a1c_row0_col2, #T_40a1c_row0_col5, #T_40a1c_row2_col3, #T_40a1c_row3_col3, #T_40a1c_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_40a1c_row0_col3, #T_40a1c_row1_col3, #T_40a1c_row3_col2, #T_40a1c_row3_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_40a1c_row1_col2, #T_40a1c_row2_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_40a1c_row1_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_40a1c_row2_col5 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_40a1c_row4_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_40a1c_row4_col5 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_40a1c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40a1c_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_40a1c_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_40a1c_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_40a1c_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_40a1c_level0_col4" class="col_heading level0 col4" >Sentiment_Label</th>
#       <th id="T_40a1c_level0_col5" class="col_heading level0 col5" >Score</th>
#       <th id="T_40a1c_level0_col6" class="col_heading level0 col6" >source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40a1c_level0_row0" class="row_heading level0 row0" >109</th>
#       <td id="T_40a1c_row0_col0" class="data row0 col0" >Kurangnya pengembangan watak membuat filem ini lemah. Tidak memuaskan.</td>
#       <td id="T_40a1c_row0_col1" class="data row0 col1" >Malay</td>
#       <td id="T_40a1c_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_40a1c_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_40a1c_row0_col4" class="data row0 col4" >Negative</td>
#       <td id="T_40a1c_row0_col5" class="data row0 col5" >0.250000</td>
#       <td id="T_40a1c_row0_col6" class="data row0 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_40a1c_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_40a1c_row1_col0" class="data row1 col0" >Adegan aksi yang dramatik dan berkesan. Terlalu banyak efek khas.</td>
#       <td id="T_40a1c_row1_col1" class="data row1 col1" >Malay</td>
#       <td id="T_40a1c_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_40a1c_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_40a1c_row1_col4" class="data row1 col4" >Negative</td>
#       <td id="T_40a1c_row1_col5" class="data row1 col5" >0.400000</td>
#       <td id="T_40a1c_row1_col6" class="data row1 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_40a1c_level0_row2" class="row_heading level0 row2" >92</th>
#       <td id="T_40a1c_row2_col0" class="data row2 col0" >Interesting and surprising plot. Love the twist in the story.</td>
#       <td id="T_40a1c_row2_col1" class="data row2 col1" >English</td>
#       <td id="T_40a1c_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_40a1c_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_40a1c_row2_col4" class="data row2 col4" >Positive</td>
#       <td id="T_40a1c_row2_col5" class="data row2 col5" >0.850000</td>
#       <td id="T_40a1c_row2_col6" class="data row2 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_40a1c_level0_row3" class="row_heading level0 row3" >30</th>
#       <td id="T_40a1c_row3_col0" class="data row3 col0" >Avengers: Endgame is an absolute masterpiece! The film seamlessly weaves together a complex yet engaging narrative, leaving audiences on the edge of their seats. The performances from the cast are stellar, bringing emotional depth to the characters. The visual effects are nothing short of breathtaking, creating a cinematic experience that will be remembered for years to come.</td>
#       <td id="T_40a1c_row3_col1" class="data row3 col1" >English</td>
#       <td id="T_40a1c_row3_col2" class="data row3 col2" >57</td>
#       <td id="T_40a1c_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_40a1c_row3_col4" class="data row3 col4" >Positive</td>
#       <td id="T_40a1c_row3_col5" class="data row3 col5" >0.950000</td>
#       <td id="T_40a1c_row3_col6" class="data row3 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_40a1c_level0_row4" class="row_heading level0 row4" >121</th>
#       <td id="T_40a1c_row4_col0" class="data row4 col0" >Pelakon memberikan persembahan yang sangat baik. Saya suka dengan penutupan ceritanya.</td>
#       <td id="T_40a1c_row4_col1" class="data row4 col1" >Malay</td>
#       <td id="T_40a1c_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_40a1c_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_40a1c_row4_col4" class="data row4 col4" >Positive</td>
#       <td id="T_40a1c_row4_col5" class="data row4 col5" >0.880000</td>
#       <td id="T_40a1c_row4_col6" class="data row4 col6" >original</td>
#     </tr>
#   </tbody>
# </table>
# Regression DataFrame:
# <style type="text/css">
# #T_87499_row0_col2, #T_87499_row0_col4, #T_87499_row2_col3, #T_87499_row3_col3, #T_87499_row4_col2, #T_87499_row4_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_87499_row0_col3, #T_87499_row1_col2, #T_87499_row1_col3, #T_87499_row2_col4, #T_87499_row3_col2, #T_87499_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_87499_row1_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_87499_row2_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_87499_row3_col4 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_87499" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87499_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_87499_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_87499_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_87499_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_87499_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_87499_level0_col5" class="col_heading level0 col5" >source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87499_level0_row0" class="row_heading level0 row0" >33</th>
#       <td id="T_87499_row0_col0" class="data row0 col0" >Avengers: Endgame mengecewakan dan terlalu klise. Kurang memuaskan.</td>
#       <td id="T_87499_row0_col1" class="data row0 col1" >Malay</td>
#       <td id="T_87499_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_87499_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_87499_row0_col4" class="data row0 col4" >0.150000</td>
#       <td id="T_87499_row0_col5" class="data row0 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_87499_level0_row1" class="row_heading level0 row1" >141</th>
#       <td id="T_87499_row1_col0" class="data row1 col0" >Saya kira filem ini tidak sehebat yang diperkatakan. Rasa kurang puas hati.</td>
#       <td id="T_87499_row1_col1" class="data row1 col1" >Malay</td>
#       <td id="T_87499_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_87499_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_87499_row1_col4" class="data row1 col4" >0.300000</td>
#       <td id="T_87499_row1_col5" class="data row1 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_87499_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_87499_row2_col0" class="data row2 col0" >Adegan akhir yang sangat epik! Saya teruja dengan penutupan trilogi ini.</td>
#       <td id="T_87499_row2_col1" class="data row2 col1" >Malay</td>
#       <td id="T_87499_row2_col2" class="data row2 col2" >11</td>
#       <td id="T_87499_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_87499_row2_col4" class="data row2 col4" >0.920000</td>
#       <td id="T_87499_row2_col5" class="data row2 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_87499_level0_row3" class="row_heading level0 row3" >221</th>
#       <td id="T_87499_row3_col0" class="data row3 col0" >The visual effects and animation in this film are truly amazing. Impressed!</td>
#       <td id="T_87499_row3_col1" class="data row3 col1" >English</td>
#       <td id="T_87499_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_87499_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_87499_row3_col4" class="data row3 col4" >0.900000</td>
#       <td id="T_87499_row3_col5" class="data row3 col5" >original</td>
#     </tr>
#     <tr>
#       <th id="T_87499_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_87499_row4_col0" class="data row4 col0" >Avengers: Endgame mengecewakan dan membosankan. Terlalu banyak klise.</td>
#       <td id="T_87499_row4_col1" class="data row4 col1" >Malay</td>
#       <td id="T_87499_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_87499_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_87499_row4_col4" class="data row4 col4" >0.150000</td>
#       <td id="T_87499_row4_col5" class="data row4 col5" >original</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the operation of spliting the data have been successfully conducted and we are able to conclude the Data Pre-Processing.

# %% [markdown]
# ---
# ## 4.3 Data Augmentation

# %% [markdown]
# In this sub-section, we will be performing Data Augmentation which will firstly balance out the Data and subseqeuntly increase the Data Volume. This will create more Training Data for the RNN Model which in turn will allow for better generalisation and higher accuracy for Output. The method used will be similar for both Classification and Regression. However, the Basis of Application will be different in regards to the Balancing of Data.

# %% [markdown]
# ---
# ### 4.3.1 Classification Balancing Data Augmentation

# %% [markdown]
# For the Classification Dataset, we will balance the class imbalance by increasing the data quantity for negative and neutral sentiments. The T5 paraphraser augments English reviews. Malay reviews are translated to English and back to Malay with Meta's local NLLB-200 distilled model, avoiding an external translation service. Stochastic T5 generation and pandas sampling use `AUGMENTATION_SEED = 42`; repeatability still depends on using the same model revision, software versions, and hardware backend. The balancing data augmentation is conducted in the code cell below.

# %%
# ==================== Load T5 Paraphrasing Model ==================== #
paraphraser = pipeline("text2text-generation", model="Vamsi/T5_Paraphrase_Paws", max_length=100)

# ==================== Language-Aware Paraphrasing ==================== #
def stacked_paraphrase(text, lang):
    try:
        if lang.lower() == 'english':
            return paraphraser(f"paraphrase: {text} </s>", num_return_sequences=1, do_sample=True)[0]['generated_text']
        elif lang.lower() == 'malay':
            to_en = translate_text(text, 'zsm_Latn', 'eng_Latn')
            paraphrased = paraphraser(f"paraphrase: {to_en} </s>", num_return_sequences=1, do_sample=True)[0]['generated_text']
            return translate_text(paraphrased, 'eng_Latn', 'zsm_Latn')
        else:
            return text
    except OSError as exc:
        warnings.warn(
            f"Augmentation model unavailable; retaining the original review: {exc}",
            RuntimeWarning,
            stacklevel=2,
        )
        return text

# ==================== Get Class Counts (Train Only) ==================== #
class_counts = Counter(df_class_train['Sentiment_Label'])
max_count = max(class_counts.values())

# ==================== Augment All Underrepresented Classes ==================== #
augmented_rows = []

for label, current_count in class_counts.items():
    samples_needed = max_count - current_count

    if current_count == 0 or samples_needed <= 0:
        continue

    df_subset = df_class_train[df_class_train['Sentiment_Label'] == label]
    rows = df_subset.sample(
        n=samples_needed, replace=True, random_state=AUGMENTATION_SEED
    ).to_dict(orient='records')

    for row in rows:
        new_text = stacked_paraphrase(row['Review'], row['Language'])
        new_row = row.copy()
        new_row['Review'] = new_text
        new_row['source'] = 'augmented'
        augmented_rows.append(new_row)

# ==================== Combine Augmented Data with Training Set ==================== #
df_augmented = pd.DataFrame(augmented_rows)
df_class_train_augmented = pd.concat(
    [df_class_train, df_augmented], ignore_index=True
).sample(frac=1, random_state=AUGMENTATION_SEED).reset_index(drop=True)

# ==================== Plot Review Distribution (Train Only) ==================== #
fig_lang = px.histogram(
    df_class_train_augmented,
    x='Sentiment_Label',
    color='Sentiment_Label',
    title='Train Set Review Distribution (With Augmentation)',
    color_discrete_sequence=px.colors.qualitative.Bold
)

fig_lang.update_layout(
    xaxis_title='Sentiment_Label',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    title_font=dict(size=20),
    showlegend=False
)

fig_lang.show()
# Out:
# Device set to use cuda:0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dd484640-329e-4279-b40c-00ccd3599528" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd484640-329e-4279-b40c-00ccd3599528")) {                    Plotly.newPlot(                        "dd484640-329e-4279-b40c-00ccd3599528",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"x":["Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"rgb(17, 165, 121)","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"x":["Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","Negative","N ...

# %% [markdown]
# With reference to the output above, we are able to see that the Data have been successfully balanced and we can now proceed to the next Data Augmentation on the Classification Dataset to multiply it in quantity to provide larger amounts of Data for Model Training.

# %% [markdown]
# ---
# ### 4.3.2 Classification Multiplication Data Augmentation

# %% [markdown]
# Now that the sentiment classes have been balanced, we will increase the training volume for every class. The T5 paraphraser generates English variants, while Malay reviews use local NLLB-200 translation before and after paraphrasing. Each original row receives up to three generated variants, producing up to four times the pre-multiplication count before duplicate removal. The same augmentation seed is used for repeatable same-environment runs.

# %%
# ==================== Load T5 Paraphrasing Model ==================== #
paraphraser = pipeline("text2text-generation", model="Vamsi/T5_Paraphrase_Paws", max_length=100)

# ==================== Language-Aware Multiple Paraphrasing ==================== #
def generate_multiple_paraphrases(row, n=3):
    text = row['Review']
    lang = row['Language']
    paraphrases = []

    try:
        if lang.lower() == 'english':
            results = paraphraser(
                f"paraphrase: {text} </s>",
                num_return_sequences=n,
                do_sample=True,
                top_k=50,
                top_p=0.95
            )
            paraphrases = [res['generated_text'] for res in results]

        elif lang.lower() == 'malay':
            to_en = translate_text(text, 'zsm_Latn', 'eng_Latn')
            results = paraphraser(
                f"paraphrase: {to_en} </s>",
                num_return_sequences=n,
                do_sample=True,
                top_k=50,
                top_p=0.95
            )
            paraphrases = [translate_text(res['generated_text'], 'eng_Latn', 'zsm_Latn') for res in results]
        else:
            paraphrases = [text] * n

    except OSError as exc:
        warnings.warn(
            f"Augmentation model unavailable; retaining the original review: {exc}",
            RuntimeWarning,
            stacklevel=2,
        )
        paraphrases = [text] * n

    return paraphrases

# ==================== Apply Multiplication to Training Set Only ==================== #
augmented_rows = []

for _, row in df_class_train.iterrows():
    variants = generate_multiple_paraphrases(row, n=3)
    for variant in variants:
        new_row = row.copy()
        new_row['Review'] = variant
        new_row['source'] = 'augmented'
        augmented_rows.append(new_row)

# ==================== Ensure DataFrame Structure is Preserved ==================== #
df_augmented = pd.DataFrame(augmented_rows)

# Ensure same column order and types
df_class_train_multiplied = pd.concat(
    [df_class_train, df_augmented],
    ignore_index=True
).sample(frac=1, random_state=AUGMENTATION_SEED).reset_index(drop=True)

# ==================== Displaying Dataset Growth ==================== #
summary = pd.DataFrame({
    'Stage': ['Original Train Set', 'After Multiplication'],
    'Count': [len(df_class_train), len(df_class_train_multiplied)],
    'Increase': [0, len(df_class_train_multiplied) - len(df_class_train)]
})

summary.style.background_gradient(cmap="Blues")
# Out:
# Device set to use cuda:0
# <style type="text/css">
# #T_0ed2b_row0_col1, #T_0ed2b_row0_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0ed2b_row1_col1, #T_0ed2b_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0ed2b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ed2b_level0_col0" class="col_heading level0 col0" >Stage</th>
#       <th id="T_0ed2b_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_0ed2b_level0_col2" class="col_heading level0 col2" >Increase</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ed2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ed2b_row0_col0" class="data row0 col0" >Original Train Set</td>
#       <td id="T_0ed2b_row0_col1" class="data row0 col1" >222</td>
#       <td id="T_0ed2b_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0ed2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ed2b_row1_col0" class="data row1 col0" >After Multiplication</td>
#       <td id="T_0ed2b_row1_col1" class="data row1 col1" >888</td>
#       <td id="T_0ed2b_row1_col2" class="data row1 col2" >666</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to verify that the Data Multiplication have been done successfully and we are now able to move on to conduct Data Augmentation for the Regression Dataset.

# %% [markdown]
# ---
# ### 4.3.3 Classification Duplication Check

# %% [markdown]
# As new data are generated, there will most likely be cases where Duplicated Data may be present. This will cause Model Training issues as the Model will re-learn data more than once which can cause the performance to be skewed. Therefore, we will be identifying for Duplicated Data within the Augmented Data in the Code Cell below.

# %%
# ==================== Creating Duplicate Summary ==================== #
duplicate_count = df_class_train_multiplied.duplicated().sum()
summary_df = pd.DataFrame({'Duplicate Count': [duplicate_count]})

# ==================== Colour Coding Function ==================== #
def highlight_duplicates(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

# ==================== Apply Styling ==================== #
styled_summary = summary_df.style.map(highlight_duplicates)

# ==================== Display Summary ==================== #
styled_summary
# Out:
# <style type="text/css">
# #T_028f0_row0_col0 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_028f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_028f0_level0_col0" class="col_heading level0 col0" >Duplicate Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_028f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_028f0_row0_col0" class="data row0 col0" >39</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Code Cell above, we are able to see that there are indeed Duplicated Data. Therefore, we will have to address the Duplicated Data through removal but also to ensure Class Imbalance does not become an issue again.

# %% [markdown]
# ---
# ### 4.3.4 Classification Duplicate Removal

# %% [markdown]
# As identified before, there are Duplicated Data within our Classification Data, therefore, we will need to identify the Classes with the Duplicated Data, drop them and subseqeuntly, add back new Data which will be translated from the other language (i.e. English to Malay) to fill in the Duplicated Data. The new Data that will be placed back in must be from the same class and from the opposite language. This operation will be done in the Code Cell below.

# %%
# ==================== Dropping Duplicates ==================== #
df_class_train_multiplied = df_class_train_multiplied.drop_duplicates()

# ==================== Load translation models ==================== #
en_to_id_tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-id")
en_to_id_model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-en-id")

id_to_en_tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-id-en")
id_to_en_model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-id-en")

# ==================== Translation Functions ==================== #
def translate(text, tokenizer, model):
    try:
        batch = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt", truncation=True)
        translated = model.generate(**batch)
        return tokenizer.decode(translated[0], skip_special_tokens=True)
    except OSError as exc:
        warnings.warn(
            f"Translation model unavailable; skipping this generated review: {exc}",
            RuntimeWarning,
            stacklevel=2,
        )
        return None

def is_english(text):
    return all(ord(c) < 128 for c in text)

def back_translate(text):
    if is_english(text):
        malay = translate(text, en_to_id_tokenizer, en_to_id_model)
        return translate(malay, id_to_en_tokenizer, id_to_en_model) if malay else None
    else:
        english = translate(text, id_to_en_tokenizer, id_to_en_model)
        return translate(english, en_to_id_tokenizer, en_to_id_model) if english else None

# ==================== Balancing Logic with Language & Label ==================== #
class_counts = df_class_train_multiplied['Sentiment_Label'].value_counts()
max_count = class_counts.max()
augmented_rows = []

for label, count in class_counts.items():
    needed = max_count - count
    if needed <= 0:
        continue

    df_class = df_class_train_multiplied[df_class_train_multiplied['Sentiment_Label'] == label]
    gen_count = 0
    i = 0

    while gen_count < needed and i < len(df_class) * 10:
        row = df_class.iloc[i % len(df_class)]
        review = row['Review']
        new_review = back_translate(review)

        if new_review and new_review.strip() != "":
            new_row = row.copy()
            new_row['Review'] = new_review
            new_row['source'] = 'augmented'
            augmented_rows.append(new_row)
            gen_count += 1

        i += 1

# ==================== Combine with Original ==================== #
df_augmented = pd.DataFrame(augmented_rows)
df_class_train_multiplied = pd.concat([df_class_train_multiplied, df_augmented], ignore_index=True)

# ==================== Review Distribution Plot ==================== #
fig_lang = px.histogram(
    df_class_train_multiplied,
    x='Sentiment_Label',
    color='Sentiment_Label',
    title='Review Distribution',
    color_discrete_sequence=px.colors.qualitative.Bold
)

fig_lang.update_layout(
    xaxis_title='Sentiment_Label',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    title_font=dict(size=20),
    showlegend=False
)

fig_lang.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning:
#
# Recommended: pip install sacremoses.
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:4106: FutureWarning:
#
#
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, text_target=tgt_texts, ...)
#
# If you either need to use different keyword arguments for the source and target texts, you should do two calls like
# this:
#
# model_inputs = tokenizer(src_texts, ...)
# labels = tokenizer(text_target=tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40a3fa2a-86e3-4594-891e-f13b2280137e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40a3fa2a-86e3-4594-891e-f13b2280137e")) {                    Plotly.newPlot(                        "40a3fa2a-86e3-4594-891e-f13b2280137e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sentiment_Label=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"x":["Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive","Positive ...

# %% [markdown]
# ---
# ### 4.3.5 Regression Data Balancing Augmentation

# %% [markdown]
# For the Regression Dataset, we will reduce score skew by balancing low (`Score < 0.4`), mid (`0.4 <= Score < 0.7`), and high (`Score >= 0.7`) training-only bands, including genuinely high-score samples whenever that band is underrepresented. The T5 paraphraser augments English reviews. Malay reviews are translated to English and back to Malay with Meta's local NLLB-200 distilled model, avoiding an external translation service. Stochastic T5 generation and pandas sampling use `AUGMENTATION_SEED = 42`; repeatability still depends on using the same model revision, software versions, and hardware backend.

# %%
# ==================== Load T5 Paraphrasing Model ==================== #
paraphraser = pipeline("text2text-generation", model="Vamsi/T5_Paraphrase_Paws", max_length=100)

# ==================== Language-aware Paraphrasing Function ==================== #
def stacked_paraphrase(text, lang):
    try:
        if lang.lower() == 'english':
            prompt = f"paraphrase: {text} </s>"
            return paraphraser(prompt, num_return_sequences=1, do_sample=True)[0]['generated_text']
        elif lang.lower() == 'malay':
            to_en = translate_text(text, 'zsm_Latn', 'eng_Latn')
            prompt = f"paraphrase: {to_en} </s>"
            paraphrased = paraphraser(prompt, num_return_sequences=1, do_sample=True)[0]['generated_text']
            return translate_text(paraphrased, 'eng_Latn', 'zsm_Latn')
        else:
            return text
    except OSError as exc:
        warnings.warn(
            f"Augmentation model unavailable; retaining the original review: {exc}",
            RuntimeWarning,
            stacklevel=2,
        )
        return text

# ==================== Score Band Splitting (on TRAIN ONLY) ==================== #
df_low = df_reg_train[df_reg_train['Score'] < 0.4]
df_mid  = df_reg_train[(df_reg_train['Score'] >= 0.4) & (df_reg_train['Score'] < 0.7)]
df_high = df_reg_train[df_reg_train['Score'] >= 0.7]

max_size = max(len(df_low), len(df_mid), len(df_high))
augmented_rows = []

for df_bin in [df_low, df_mid, df_high]:
    needed = max_size - len(df_bin)
    if needed <= 0:
        continue
    samples = df_bin.sample(
        n=needed, replace=True, random_state=AUGMENTATION_SEED
    ).to_dict(orient='records')
    for row in samples:
        row['Review'] = stacked_paraphrase(row['Review'], row['Language'])
        row['source'] = 'augmented'
        augmented_rows.append(row)

# ==================== Combine and Shuffle Training Set ==================== #
df_reg_train_balanced = pd.concat(
    [df_reg_train, pd.DataFrame(augmented_rows)], ignore_index=True
).sample(frac=1, random_state=AUGMENTATION_SEED).reset_index(drop=True)

df_reg_train_balanced['Score Band'] = df_reg_train_balanced['Score'].apply(
    lambda s: 'Low' if s < 0.4 else 'Mid' if s < 0.7 else 'High'
)

df_reg_train_balanced['Score Band'].value_counts()
# Out:
# Device set to use cuda:0
# Score Band
# Low     167
# High    167
# Mid     167
# Name: count, dtype: int64

# %% [markdown]
# With reference to the output above, we are able to see that the Data have been successfully balanced and we can now proceed to the next Data Augmentation on the Regression Dataset to multiply it in quantity to provide larger amounts of Data for Model Training.

# %% [markdown]
# ---
# ### 4.3.6 Regression Multiplication Data Augmentation

# %% [markdown]
# Now that the score bands have been balanced, we will increase the training volume for every band. The T5 paraphraser generates English variants, while Malay reviews use local NLLB-200 translation before and after paraphrasing. Each row receives up to three generated variants, producing up to four times the pre-multiplication count before duplicate removal. The same augmentation seed is used for repeatable same-environment runs.

# %%
# ==================== Load T5 Paraphrasing Model ==================== #
paraphraser = pipeline("text2text-generation", model="Vamsi/T5_Paraphrase_Paws", max_length=100)

# ==================== Language-Aware Paraphrasing Function ==================== #
def generate_multiple_paraphrases(row, n=3):
    text = row['Review']
    lang = row['Language']
    try:
        if lang.lower() == 'english':
            results = paraphraser(f"paraphrase: {text} </s>", num_return_sequences=n, do_sample=True, top_k=50, top_p=0.95)
            return [res['generated_text'] for res in results]
        elif lang.lower() == 'malay':
            to_en = translate_text(text, 'zsm_Latn', 'eng_Latn')
            results = paraphraser(f"paraphrase: {to_en} </s>", num_return_sequences=n, do_sample=True, top_k=50, top_p=0.95)
            return [translate_text(res['generated_text'], 'eng_Latn', 'zsm_Latn') for res in results]
        else:
            return [text] * n
    except OSError as exc:
        warnings.warn(
            f"Augmentation model unavailable; retaining the original review: {exc}",
            RuntimeWarning,
            stacklevel=2,
        )
        return [text] * n

# ==================== Multiply Training Set Only ==================== #
augmented_rows = []

for _, row in df_reg_train_balanced.iterrows():
    variants = generate_multiple_paraphrases(row, n=3)
    for variant in variants:
        new_row = row.copy()
        new_row['Review'] = variant
        new_row['source'] = 'augmented'
        augmented_rows.append(new_row)

# ==================== Combine and Shuffle ==================== #
df_augmented = pd.DataFrame(augmented_rows)

# Ensure consistent column structure with original training DataFrame
df_reg_train_multiplied = pd.concat(
    [df_reg_train_balanced, df_augmented],
    ignore_index=True
).sample(frac=1, random_state=AUGMENTATION_SEED).reset_index(drop=True)

# ==================== Displaying Dataset Growth ==================== #
summary = pd.DataFrame({
    'Stage': ['After Balancing', 'After Multiplication'],
    'Sample Count': [len(df_reg_train_balanced), len(df_reg_train_multiplied)],
    'Increase': [0, len(df_reg_train_multiplied) - len(df_reg_train_balanced)]
})

# ==================== Displaying DataFrame ==================== #
summary.style.background_gradient(cmap="Blues")
# Out:
# Device set to use cuda:0
# <style type="text/css">
# #T_4e9db_row0_col1, #T_4e9db_row0_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4e9db_row1_col1, #T_4e9db_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e9db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e9db_level0_col0" class="col_heading level0 col0" >Stage</th>
#       <th id="T_4e9db_level0_col1" class="col_heading level0 col1" >Sample Count</th>
#       <th id="T_4e9db_level0_col2" class="col_heading level0 col2" >Increase</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e9db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e9db_row0_col0" class="data row0 col0" >After Balancing</td>
#       <td id="T_4e9db_row0_col1" class="data row0 col1" >501</td>
#       <td id="T_4e9db_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4e9db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e9db_row1_col0" class="data row1 col0" >After Multiplication</td>
#       <td id="T_4e9db_row1_col1" class="data row1 col1" >2004</td>
#       <td id="T_4e9db_row1_col2" class="data row1 col2" >1503</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output above, we are able to verify that the Data Multiplication have been done successfully and we are now able to move on to conduct the other Data Pre-Processing steps.

# %% [markdown]
# ---
# ### 4.3.7 Regression Duplication Check

# %% [markdown]
# As new data are generated, there will most likely be cases where Duplicated Data may be present. This will cause Model Training issues as the Model will re-learn data more than once which can cause the performance to be skewed. Therefore, we will be identifying for Duplicated Data within the Augmented Data in the Code Cell below.

# %%
# ==================== Creating Duplicate Summary ==================== #
duplicate_count = df_reg_train_multiplied.duplicated().sum()
summary_df = pd.DataFrame({'Duplicate Count': [duplicate_count]})

# ==================== Colour Coding Function ==================== #
def highlight_duplicates(val):
    color = 'red' if val > 0 else 'green'
    return f'background-color: {color}; color: white'

# ==================== Apply Styling ==================== #
styled_summary = summary_df.style.map(highlight_duplicates)

# ==================== Display Summary ==================== #
styled_summary
# Out:
# <style type="text/css">
# #T_e98a6_row0_col0 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_e98a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e98a6_level0_col0" class="col_heading level0 col0" >Duplicate Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e98a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e98a6_row0_col0" class="data row0 col0" >459</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Code Cell above, we are able to see that there are indeed Duplicated Data. Therefore, we will have to address the Duplicated Data through removal but also to ensure Class Imbalance does not become an issue again.

# %% [markdown]
# ---
# ### 4.3.8 Regression Duplicate Removal

# %% [markdown]
# As identified before, there are Duplicated Data within our Classification Data, therefore, we will need to identify the Classes with the Duplicated Data, drop them and subseqeuntly, add back new Data which will be translated from the other language (i.e. English to Malay) to fill in the Duplicated Data. The new Data that will be placed back in must be from the same class and from the opposite language. This operation will be done in the Code Cell below.

# %%
# ==================== Drop Duplicates ==================== #
df_reg_train_multiplied = df_reg_train_multiplied.drop_duplicates()

# ==================== Load Translation Models ==================== #
en_to_id_tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-id")
en_to_id_model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-en-id")

id_to_en_tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-id-en")
id_to_en_model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-id-en")

# ==================== Translation Utilities ==================== #
def translate(text, tokenizer, model):
    try:
        batch = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt", truncation=True)
        translated = model.generate(**batch)
        return tokenizer.decode(translated[0], skip_special_tokens=True)
    except OSError as exc:
        warnings.warn(
            f"Translation model unavailable; skipping this generated review: {exc}",
            RuntimeWarning,
            stacklevel=2,
        )
        return None

def is_english(text):
    return all(ord(c) < 128 for c in text)

def back_translate(text):
    if is_english(text):
        malay = translate(text, en_to_id_tokenizer, en_to_id_model)
        return translate(malay, id_to_en_tokenizer, id_to_en_model) if malay else None
    else:
        english = translate(text, id_to_en_tokenizer, id_to_en_model)
        return translate(english, en_to_id_tokenizer, en_to_id_model) if english else None

# ==================== Score Banding ==================== #
def get_score_band(score):
    if score < 0.4:
        return 'Low'
    elif score < 0.7:
        return 'Mid'
    else:
        return 'High'

df_reg_train_multiplied['Score Band'] = df_reg_train_multiplied['Score'].apply(get_score_band)

# ==================== Balancing by Score Band ==================== #
band_counts = df_reg_train_multiplied['Score Band'].value_counts()
max_count = band_counts.max()

augmented_rows = []

for band in ['Low', 'Mid', 'High']:
    current_count = band_counts.get(band, 0)
    needed = max_count - current_count
    if needed <= 0:
        continue

    df_band = df_reg_train_multiplied[df_reg_train_multiplied['Score Band'] == band]

    gen_count = 0
    i = 0
    while gen_count < needed and i < len(df_band) * 10:
        row = df_band.iloc[i % len(df_band)]
        review = row['Review']
        new_review = back_translate(review)

        if new_review and new_review.strip() != "":
          new_row = row.copy()
          new_row['Review'] = new_review
          new_row['source'] = 'augmented'
          augmented_rows.append(new_row)
          gen_count += 1

        i += 1

# ==================== Combine Final Dataset ==================== #
df_augmented = pd.DataFrame(augmented_rows)
df_reg_train_multiplied = pd.concat([df_reg_train_multiplied, df_augmented], ignore_index=True)

# ==================== Refresh Score Band (Optional Redundancy) ==================== #
df_reg_train_multiplied['Score Band'] = df_reg_train_multiplied['Score'].apply(get_score_band)

# ==================== Visualise Distribution ==================== #
fig_score = px.histogram(
    df_reg_train_multiplied,
    x='Score',
    nbins=30,
    marginal='box',
    color_discrete_sequence=['#1f77b4'],
    title='Distribution of Sentiment Scores (Regression Target)'
)

fig_score.update_layout(
    xaxis_title='Sentiment Score (0 to 1)',
    yaxis_title='Number of Reviews',
    template='plotly_white',
    title_font=dict(size=20),
)
fig_score.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning:
#
# Recommended: pip install sacremoses.
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:4106: FutureWarning:
#
#
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, text_target=tgt_texts, ...)
#
# If you either need to use different keyword arguments for the source and target texts, you should do two calls like
# this:
#
# model_inputs = tokenizer(src_texts, ...)
# labels = tokenizer(text_target=tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e55f521-ea8c-4268-a975-d4b0e94e6ce4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e55f521-ea8c-4268-a975-d4b0e94e6ce4")) {                    Plotly.newPlot(                        "4e55f521-ea8c-4268-a975-d4b0e94e6ce4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1f77b4","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.35,0.35,0.4,0.4,0.4,0.9,0.4,0.4,0.88,0.88,0.94,0.35,0.25,0.4,0.30000000000000004,0.4,0.4,0.88,0.4,0.19999999999999996,0.85,0.4,0.92,0.9,0.25,0.9,0.92,0.30000000000000004,0.94,0.25,0.8,0.4,0.4,0.30000000000000004,0.85,0.4,0.4,0.9,0.87,0.4,0.4,0.8,0.19999999999999996,0.30000000000000004,0.88,0.30000000000000004,0.4,0.88,0.9,0.5,0.5,0.92,0.9299999999999999,0.9299999999999999,0.4,0.88,0.25,0.25,0.87,0.4,0.30000000000000004,0.30000000000000004,0.5,0.4,0.4,0.15000000000000002,0.22499999999999998,0.30000000000000004,0.4,0.9,0.88,0.88,0.9,0.4,0.19999999999999996,0.19999999999999996,0.75,0.5,0.15000000000000002,0.9,0.9,0.9,0.9,0.87,0.4,0.30000000000000004,0.9,0.30000000000000004,0.4,0.30000000000000004,0.30000000000000004,0.9,0.88,0.19999999999999996,0.5,0.4,0.75,0.92,0.88,0.4,0.4,0.15000000000000002,0.92,0.4,0.5,0.30000000000000004,0.30000000000000004,0.92,0.25,0.30000000000000004,0.4,0.4,0.88,0.4,0.30000000000000004,0.30000000000000004,0.4,0.92,0.85,0.25,0.4,0.30000000000000004,0.15000000000000002,0.9299999999999999,0.4,0.4,0.4,0.4,0.30000000000000004,0.4,0.88,0.4,0.30000000000000004,0.30000000000000004,0.4,0.9299999999999999,0.30000000000000004,0.19999999999999996,0.30000000000000004,0.30500000000000005,0.5,0.85,0.30000000000000004,0.4,0.30000000000000004,0.94,0.4,0.88,0.30000000000000004,0.4,0.88,0.75,0.8,0.92,0.85,0.4,0.94,0.9299999999999999,0.9,0.7,0.88,0.88,0.30000000000000004,0.4,0.92,0.4,0.30000000000000004,0.5,0.30000000000000004,0.4,0.94,0.4,0.19999999999999996,0.19999999999999996,0.30000000000000004,0.92,0.4,0.9,0.4,0.9,0.88,0.4,0.4,0.4,0.7,0.19999999999999996,0.30000000000000004,0.92,0.92,0.4,0.4,0.4,0.9,0.30000000000000004,0.30500000000000005,0.30000000000000004,0.25,0.19999999999999996,0.25,0.30000000000000004,0.25,0.19999999999999996,0.19999999999999996,0.8,0.30500000000000005,0.9,0.4,0.30000000000000004,0.88,0.9299999999999999,0.92,0.25,0.85,0.95,0.25,0.92,0.4,0.4,0.4,0.88,0.19999999999999996,0.88,0.22499999999999998,0.30000000000000004,0.88,0.35,0.19999999999999996,0.9,0.25,0.22499999999999998,0.30000000000000004,0.4,0.4,0.25,0.94,0.4,0.4,0.92,0.85,0.4,0.4,0.87,0.30000000000000004,0.35,0.30000000000000004,0.4,0.88,0.19999999999999996,0.19999999999999996,0.19999999999999996,0.30000000000000004,0.75,0.30000000000000004,0.30000000000000004,0.88,0.30000000000000004,0.92,0.4,0.25,0.30000000000000004,0.30000000000000004,0.19999999999999996,0.4,0.4,0.92,0.5,0.9,0.4,0.7,0.92,0.30000000000000004,0.30500000000000005,0.88,0.88,0.19999999999999996,0.25,0.8,0.88,0.4,0.25,0.85,0.30000000000000004,0.85,0.4,0.4,0.92,0.4,0.4,0.9,0.4,0.85,0.35,0.4,0.85,0.92,0.25,0.22499999999999998,0.4,0.4,0.4,0.5,0.19999999999999996,0.92,0.5,0.25,0.4,0.92,0.30000000000000004,0.30000000000000004,0.88,0.7,0.30000000000000004,0.30000000000000004,0.30000000000000004,0.19999999999999996,0.9,0.30000000000000004,0.4,0.85,0.4,0.75,0.30000000000000004,0.4,0.4,0.30000000000000004,0.4,0.88,0.88,0.4,0.19999999999999996,0.88,0.30000000000000004,0.30000000000000004,0.25,0.25,0.88,0.4,0.4,0.4,0.92,0.88,0.30000000000000004,0.19999999999999996,0.19999999999999996,0.30000000000000004,0.9,0.35,0.4,0.4,0.30000000000000004,0.4,0.85,0.9,0.1 ...

# %% [markdown]
# With reference to the output above, we are able to see that the Data have been successfully balanced and we can now proceed to the next Data Augmentation on the Classification Dataset to multiply it in quantity to provide larger amounts of Data for Model Training.

# %% [markdown]
# ---
# ## 4.4 Lowercasing Reviews

# %% [markdown]
# In this sub-section, we will be making all the Reviews lowercased. This will help to reduce variability and complexity in the text data, simplifying later processing steps and potentially improving the performance of the RNN models. This operation will be conducted in the Code Cell below.

# %%
# ==================== Lowercasing Review Text ==================== #
df_class_train_multiplied['Review'] = df_class_train_multiplied['Review'].str.lower()
df_reg_train_multiplied['Review'] = df_reg_train_multiplied['Review'].str.lower()

# ==================== Displaying DataFrames ==================== #
print("Classification DataFrame:")
display(df_class_train_multiplied.head(5).style.background_gradient(cmap="Blues"))
print("\n"*5)
print("Regression DataFrame:")
display(df_reg_train_multiplied.head(5).style.background_gradient(cmap="Blues"))
# Out:
# Classification DataFrame:
# <style type="text/css">
# #T_60cd4_row0_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_60cd4_row0_col3, #T_60cd4_row1_col3, #T_60cd4_row2_col3, #T_60cd4_row3_col2, #T_60cd4_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_60cd4_row0_col5 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_60cd4_row1_col2, #T_60cd4_row2_col5, #T_60cd4_row3_col3, #T_60cd4_row4_col2, #T_60cd4_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_60cd4_row1_col5 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_60cd4_row2_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_60cd4_row4_col5 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# </style>
# <table id="T_60cd4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60cd4_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_60cd4_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_60cd4_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_60cd4_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_60cd4_level0_col4" class="col_heading level0 col4" >Sentiment_Label</th>
#       <th id="T_60cd4_level0_col5" class="col_heading level0 col5" >Score</th>
#       <th id="T_60cd4_level0_col6" class="col_heading level0 col6" >source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60cd4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60cd4_row0_col0" class="data row0 col0" >the visual effects of this film are outstanding ; excited about the technical brilliance </td>
#       <td id="T_60cd4_row0_col1" class="data row0 col1" >English</td>
#       <td id="T_60cd4_row0_col2" class="data row0 col2" >13</td>
#       <td id="T_60cd4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_60cd4_row0_col4" class="data row0 col4" >Positive</td>
#       <td id="T_60cd4_row0_col5" class="data row0 col5" >0.900000</td>
#       <td id="T_60cd4_row0_col6" class="data row0 col6" >augmented</td>
#     </tr>
#     <tr>
#       <th id="T_60cd4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60cd4_row1_col0" class="data row1 col0" >while the film attempts to tie up loose ends, certain character resolutions may leave fans divided. however, avengers: endgame excels in the epic battles and jaw-dropping visuals - a must for those who invested in the marvel cinematic universe .</td>
#       <td id="T_60cd4_row1_col1" class="data row1 col1" >English</td>
#       <td id="T_60cd4_row1_col2" class="data row1 col2" >39</td>
#       <td id="T_60cd4_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_60cd4_row1_col4" class="data row1 col4" >Positive</td>
#       <td id="T_60cd4_row1_col5" class="data row1 col5" >0.750000</td>
#       <td id="T_60cd4_row1_col6" class="data row1 col6" >augmented</td>
#     </tr>
#     <tr>
#       <th id="T_60cd4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60cd4_row2_col0" class="data row2 col0" >the visual effects and animation in this film are amazing. impressed!</td>
#       <td id="T_60cd4_row2_col1" class="data row2 col1" >English</td>
#       <td id="T_60cd4_row2_col2" class="data row2 col2" >11</td>
#       <td id="T_60cd4_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_60cd4_row2_col4" class="data row2 col4" >Positive</td>
#       <td id="T_60cd4_row2_col5" class="data row2 col5" >0.925000</td>
#       <td id="T_60cd4_row2_col6" class="data row2 col6" >original</td>
#     </tr>
#     <tr>
#       <th id="T_60cd4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60cd4_row3_col0" class="data row3 col0" >kekurangan perkembangan watak menjadikan filem ini lemah dan tidak memuaskan.</td>
#       <td id="T_60cd4_row3_col1" class="data row3 col1" >Malay</td>
#       <td id="T_60cd4_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_60cd4_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_60cd4_row3_col4" class="data row3 col4" >Negative</td>
#       <td id="T_60cd4_row3_col5" class="data row3 col5" >0.250000</td>
#       <td id="T_60cd4_row3_col6" class="data row3 col6" >augmented</td>
#     </tr>
#     <tr>
#       <th id="T_60cd4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60cd4_row4_col0" class="data row4 col0" >the open-ended nature of avengers: endgame's plot allows for interpretation and speculation. while some may appreciate the ambiguity, others may find it leaves too much unanswered. the film leaves room for potential future developments in the marvel cinematic universe.</td>
#       <td id="T_60cd4_row4_col1" class="data row4 col1" >English</td>
#       <td id="T_60cd4_row4_col2" class="data row4 col2" >39</td>
#       <td id="T_60cd4_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_60cd4_row4_col4" class="data row4 col4" >Negative</td>
#       <td id="T_60cd4_row4_col5" class="data row4 col5" >0.300000</td>
#       <td id="T_60cd4_row4_col6" class="data row4 col6" >original</td>
#     </tr>
#   </tbody>
# </table>
# Regression DataFrame:
# <style type="text/css">
# #T_a234a_row0_col2, #T_a234a_row1_col2, #T_a234a_row2_col4, #T_a234a_row3_col4, #T_a234a_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a234a_row0_col3, #T_a234a_row0_col4, #T_a234a_row1_col3, #T_a234a_row1_col4, #T_a234a_row2_col2, #T_a234a_row2_col3, #T_a234a_row3_col2, #T_a234a_row3_col3, #T_a234a_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a234a_row4_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# </style>
# <table id="T_a234a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a234a_level0_col0" class="col_heading level0 col0" >Review</th>
#       <th id="T_a234a_level0_col1" class="col_heading level0 col1" >Language</th>
#       <th id="T_a234a_level0_col2" class="col_heading level0 col2" >word_count</th>
#       <th id="T_a234a_level0_col3" class="col_heading level0 col3" >Sentiment_Binary</th>
#       <th id="T_a234a_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_a234a_level0_col5" class="col_heading level0 col5" >source</th>
#       <th id="T_a234a_level0_col6" class="col_heading level0 col6" >Score Band</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a234a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a234a_row0_col0" class="data row0 col0" >my problem is that the plot of this film is too complex and a bit difficult to follow.</td>
#       <td id="T_a234a_row0_col1" class="data row0 col1" >English</td>
#       <td id="T_a234a_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_a234a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_a234a_row0_col4" class="data row0 col4" >0.350000</td>
#       <td id="T_a234a_row0_col5" class="data row0 col5" >augmented</td>
#       <td id="T_a234a_row0_col6" class="data row0 col6" >High</td>
#     </tr>
#     <tr>
#       <th id="T_a234a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a234a_row1_col0" class="data row1 col0" >for me, the plot of this film is too complex, a bit difficult to follow .</td>
#       <td id="T_a234a_row1_col1" class="data row1 col1" >English</td>
#       <td id="T_a234a_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_a234a_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_a234a_row1_col4" class="data row1 col4" >0.350000</td>
#       <td id="T_a234a_row1_col5" class="data row1 col5" >augmented</td>
#       <td id="T_a234a_row1_col6" class="data row1 col6" >High</td>
#     </tr>
#     <tr>
#       <th id="T_a234a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a234a_row2_col0" class="data row2 col0" >dramatic and impactful action scenes , too many special effects .</td>
#       <td id="T_a234a_row2_col1" class="data row2 col1" >English</td>
#       <td id="T_a234a_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_a234a_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_a234a_row2_col4" class="data row2 col4" >0.400000</td>
#       <td id="T_a234a_row2_col5" class="data row2 col5" >augmented</td>
#       <td id="T_a234a_row2_col6" class="data row2 col6" >Mid</td>
#     </tr>
#     <tr>
#       <th id="T_a234a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a234a_row3_col0" class="data row3 col0" >too many over-the-top action scenes. too many special effects</td>
#       <td id="T_a234a_row3_col1" class="data row3 col1" >English</td>
#       <td id="T_a234a_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_a234a_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_a234a_row3_col4" class="data row3 col4" >0.400000</td>
#       <td id="T_a234a_row3_col5" class="data row3 col5" >augmented</td>
#       <td id="T_a234a_row3_col6" class="data row3 col6" >Mid</td>
#     </tr>
#     <tr>
#       <th id="T_a234a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a234a_row4_col0" class="data row4 col0" >adegan tindakan dramatik dan tidak dapat dilupakan, terlalu banyak kesan biasa.</td>
#       <td id="T_a234a_row4_col1" class="data row4 col1" >Malay</td>
#       <td id="T_a234a_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_a234a_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_a234a_row4_col4" class="data row4 col4" >0.400000</td>
#       <td id="T_a234a_row4_col5" class="data row4 col5" >augmented</td>
#       <td id="T_a234a_row4_col6" class="data row4 col6" >Mid</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to see that the Review have all been successfully set to lowercase.

# %% [markdown]
# ---
# ## 4.5 Removing Punctuations

# %% [markdown]
# In this sub-section, we will be removing the Punctuations within each of the review. This is done so as to remove unneccesary noise and text complexity within the Review Data Column. This will also help to simplify the Spliting and Processing of the Text.

# %%
# ==================== Removing Punctuations Function ==================== #
def remove_punctuation(text):
    return re.sub(r'[^\w\s]', '', text)

# ==================== Classification: Apply to All Splits ==================== #
df_class_train_multiplied['Review'] = df_class_train_multiplied['Review'].apply(remove_punctuation)
df_class_train['Review'] = df_class_train['Review'].apply(remove_punctuation)
df_class_val['Review'] = df_class_val['Review'].apply(remove_punctuation)
df_class_test['Review'] = df_class_test['Review'].apply(remove_punctuation)

# ==================== Regression: Apply to All Splits ==================== #
df_reg_train_multiplied['Review'] = df_reg_train_multiplied['Review'].apply(remove_punctuation)
df_reg_train['Review'] = df_reg_train['Review'].apply(remove_punctuation)
df_reg_val['Review'] = df_reg_val['Review'].apply(remove_punctuation)
df_reg_test['Review'] = df_reg_test['Review'].apply(remove_punctuation)

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Punctuations have been successfully removed for both of the Dataset.

# %% [markdown]
# ---
# ## 4.6 Stopwords Removal

# %% [markdown]
# In this sub-section, we will be removing all the Stopwords which are present within each of the Review. This will remove all word which carry insignificant meaning and prevent unneccesary noise within our data. This operation will be conducted in the Code Cell below.

# %%
# ==================== Setting Stopwords ==================== #
stop_words_en = set(stopwords.words('english'))

# ==================== Malay Stopwards ==================== #
stop_words_ms = set([
    "yang", "dan", "di", "ke", "dari", "itu", "untuk", "ini", "pada", "adalah", "dengan", "juga", "akan",
    "saya", "kami", "mereka", "anda", "tidak", "ya", "boleh", "harus", "kerana", "lagi", "kalau"
])

# ==================== Removing Stopwords Function ==================== #
def remove_stopwords(text, lang):
    tokens = word_tokenize(text.lower())
    if lang.lower() == 'english':
        filtered = [word for word in tokens if word not in stop_words_en]
    elif lang.lower() == 'malay':
        filtered = [word for word in tokens if word not in stop_words_ms]
    else:
        filtered = tokens
    return ' '.join(filtered)

# ==================== Applying Stopwords Function For Classification ==================== #
df_class_train_multiplied['Review'] = df_class_train_multiplied.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

df_class_train['Review'] = df_class_train.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

df_class_val['Review'] = df_class_val.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

df_class_test['Review'] = df_class_test.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

# ==================== Applying Stopwords Function For Regression ==================== #
df_reg_train_multiplied['Review'] = df_reg_train_multiplied.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

df_reg_train['Review'] = df_reg_train.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

df_reg_val['Review'] = df_reg_val.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

df_reg_test['Review'] = df_reg_test.apply(
    lambda row: remove_stopwords(row['Review'], row['Language']), axis=1
)

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Removal of Stop Words have been done successfully and we are able to move on to the next Data Pre-Processing step.

# %% [markdown]
# ---
# ## 4.7 Data Lemmatisation

# %% [markdown]
# In this sub-section, we will be performing Data Lemmatisation which will change all the remaining words into their base or dictionary form. This will make our data more consistent and is also known to make the RNN Model perform much better in terms of accuracy. We will only perfrom Lemmatisation on our English Data and will not perform it on the Malay data as there is a lack of accessible and reliable lemmatisation tools for Malay in the development environment. Therefore, we will omit this step for Malay reviews.

# %%
# ==================== Lemmatisation Function ==================== #
lemmatizer = WordNetLemmatizer()

def lemmatise_text(text, lang):
    tokens = word_tokenize(text)
    if lang.lower() == 'english':
        lemmatised = [lemmatizer.lemmatize(word) for word in tokens]
        return ' '.join(lemmatised)
    else:
        return text

# ==================== Applying Lemmatisation Function For Classification ==================== #
df_class_train_multiplied['Review'] = df_class_train_multiplied.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

df_class_train['Review'] = df_class_train.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

df_class_val['Review'] = df_class_val.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

df_class_test['Review'] = df_class_test.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

# ==================== Applying Lemmatisation Function For Regression ==================== #
df_reg_train_multiplied['Review'] = df_reg_train_multiplied.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

df_reg_train['Review'] = df_reg_train.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

df_reg_val['Review'] = df_reg_val.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

df_reg_test['Review'] = df_reg_test.apply(
    lambda row: lemmatise_text(row['Review'], row['Language']), axis=1
)

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Lemmatisation have been done successfully and we are able to move on to the next Data Pre-Processing step.

# %% [markdown]
# ---
# ## 4.8 Fitting Shared Tokeniser

# %% [markdown]
# In this sub-section, we will be using a Shared Tokeniser on our Data so as to make the review textual data understandable and usable for the RNN Models. We will be using a Shared Tokeniser so as to ensure consistency throughout both of our Data. The Tokenisation will be conducted in the Code Cell below.

# %%
# ==================== Combine All Review Texts ==================== #
all_reviews = pd.concat([
    df_class_train_multiplied['Review'],
    df_class_train['Review'],
    df_class_val['Review'],
    df_class_test['Review'],
    df_reg_train_multiplied['Review'],
    df_reg_train['Review'],
    df_reg_val['Review'],
    df_reg_test['Review']
], ignore_index=True)

# ==================== Initialise and Fit Tokeniser ==================== #
vocab_size = 10000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(all_reviews)

# %% [markdown]
# With reference to the code cell above, we are able to verify that the Tokenisation Process have been completed.

# %% [markdown]
# ---
# ## 4.9 Converting Text To Sequences

# %% [markdown]
# In this sub-section, we will be converting the Textual Data of the Movie Reviews to Sequences which will help to maintain the syntactical meaning of a sentence. This will allow the RNN Model understand the Input Data as it will be able to analyse and manipulate the data. This operation will be conducted in the Code Cell below.

# %%
# ==================== Classification Splits ==================== #
X_class_train = tokenizer.texts_to_sequences(df_class_train_multiplied['Review'])
X_class_train_no_aug = tokenizer.texts_to_sequences(df_class_train['Review'])
X_class_val = tokenizer.texts_to_sequences(df_class_val['Review'])
X_class_test = tokenizer.texts_to_sequences(df_class_test['Review'])

# ==================== Regression Splits ==================== #
X_reg_train = tokenizer.texts_to_sequences(df_reg_train_multiplied['Review'])
X_reg_train_no_aug = tokenizer.texts_to_sequences(df_reg_train['Review'])
X_reg_val = tokenizer.texts_to_sequences(df_reg_val['Review'])
X_reg_test = tokenizer.texts_to_sequences(df_reg_test['Review'])

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the conversion have been successfully executed.

# %% [markdown]
# ---
# ## 4.10 Padding Sequences

# %% [markdown]
# In this sub-section, we will be adding Padding to our Sequences. This is to ensure that input sequences have the same length by padding them with a specific value or truncating them if they are too long. As previously identified in our Exploratory Data Analysis, the best max length to utilise is 100. Therefore, the max length of 100 will be utilised in the Code Cell below.

# %%
# ==================== Padding Configuration ==================== #
maxlen = 100

# ==================== Classification Padded ==================== #
X_train_class_pad = pad_sequences(X_class_train, maxlen=maxlen, padding='post', truncating='post')
X_train_class_pad_no_aug = pad_sequences(X_class_train_no_aug, maxlen=maxlen, padding='post', truncating='post')
X_val_class_pad = pad_sequences(X_class_val,   maxlen=maxlen, padding='post', truncating='post')
X_test_class_pad = pad_sequences(X_class_test,  maxlen=maxlen, padding='post', truncating='post')

# ==================== Regression Padded ==================== #
X_train_reg_pad = pad_sequences(X_reg_train, maxlen=maxlen, padding='post', truncating='post')
X_train_reg_pad_no_aug = pad_sequences(X_reg_train_no_aug, maxlen=maxlen, padding='post', truncating='post')
X_val_reg_pad = pad_sequences(X_reg_val,   maxlen=maxlen, padding='post', truncating='post')
X_test_reg_pad = pad_sequences(X_reg_test,  maxlen=maxlen, padding='post', truncating='post')

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Padding Sequence have been successfully executed and we can proceed to the next Pre-Processing step.

# %% [markdown]
# ---
# ## 4.11 Preparing Target Variables

# %% [markdown]
# In this sub-section, we will be creating a separate variable for the Target that will we plan to get the RNN to output. There will be two separate targets as we will be doing both Classification and Regression and comparing them afterwards. The preparation will be done in the Code Cell below.

# %%
# ==================== Classification Targets ==================== #
y_train_class = df_class_train_multiplied['Sentiment_Binary'].values
y_val_class = df_class_val['Sentiment_Binary'].values
y_test_class = df_class_test['Sentiment_Binary'].values

# ==================== Regression Targets ==================== #
y_train_reg = df_reg_train_multiplied['Score'].values
y_val_reg = df_reg_val['Score'].values
y_test_reg = df_reg_test['Score'].values

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the preparation of Target Variables have been successful.

# %% [markdown]
# ---
# # 5. Classification RNN Model Trainings - (Augmented)

# %% [markdown]
# In this section, we will be training the various Classification models for the RNN to predict the Sentiment of the Movie Review (either Positive, Negative or Neutral). This will subsequently be evaluated alongside the Regression Models to determine which one performs the best and which RNN Model in particular.

# %% [markdown]
# ---
# ## 5.1 SimpleRNN Classification Model

# %% [markdown]
# In this sub-section, we will be training the SimpleRNN Classification Model. As the name suggests, this is the most simple RNN Model there is and may serve as a baseline of comparison for the other Model. However, if this Model does perform well, it can be used as one of the Final Model if Classification is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Hidden State Update**
# $$
# h_t = \tanh(W_{xh}x_t + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: Current Hidden State
#
# - $x_t$: Input at Time $t$
#
# - $h_{t-1}$: Previous Hidden State
#
# - $W_{xh}$: Weight Matrix from Input to Hidden
#
# - $W_{hh}$: Weight Matrix From Hidden to Hidden
#
# - $b_h$: Bias Term
#
# - $\tanh$: Activation Function Applied Element-wise
#
# ---
# **Output at Each Time Step**
# $$
# y_t = W_{hy}h_t + b_y
# $$
# Where:
# - $y_t$: Output at Time $t$
#
# - $W_{hy}$: Weight Matrix from Hidden to Output
#
# - $b_y$: Output Bias
#
# ---
# **Loss Function (Classification)**
# $$
# \hat{y} = \text{softmax}(Wh_T + b)
# $$
# Calculated Using:
# $$
# \mathcal{L} = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)
# $$
# Where:
# - $C$: Number of Classes
#
# - $y_i$: True One-hot Label
#
# - $\hat{y}_i$: Predicted Probability for Class $i$
#
# ---
# **Backpropagation Through Time (BPTT)**
# $$
# \frac{\partial \mathcal{L}}{\partial W} = \sum_{t=1}^{T} \frac{\partial \mathcal{L}}{\partial h_t} \cdot \frac{\partial h_t}{\partial W}
# $$
# Where:
# - $\mathcal{L}$: Total loss over all time steps
#
# - $W$:	Any trainable weight matrix (e.g., $W_{xh}$, $W_{hh}$)
#
# - $T$:	Total number of time steps in the input sequence
#
# - $t$:	Current time step in the unrolled RNN
#
# - $h_t$:	Hidden state at time step $t$
#
# - $\frac{\partial \mathcal{L}}{\partial W}$:	Gradient of the loss with respect to weights $W$
#
# - $\frac{\partial \mathcal{L}}{\partial h_t}$:	Gradient of the loss with respect to hidden state $h_t$
#
# - $\frac{\partial h_t}{\partial W}$:	Gradient of hidden state $h_t$ with respect to weight $W$
#
# ---
#
# With all the essential Formulas for SimpleRNN indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 5.1.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 5.1.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_rnn_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(X_train_class_pad.shape[1],)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300]),
        embeddings_initializer='uniform'
    ))

    # ----- 1st Bidirectional SimpleRNN Layer ----- #
    model.add(Bidirectional(SimpleRNN(
        units=hp.Choice("rnn_units_1", [128, 256, 384]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_1", 0.3, 0.5, step=0.1)))

    # ----- 2nd Bidirectional SimpleRNN Layer ----- #
    model.add(Bidirectional(SimpleRNN(
        units=hp.Choice("rnn_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_2", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [128, 256]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [64, 128]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.3, 0.5, step=0.1)))

    # ----- Output Layer (Binary Classification) ----- #
    model.add(Dense(1, activation='sigmoid'))

    # ----- Compile Model ----- #
    lr = hp.Choice("lr", [5e-4, 1e-4, 5e-5])
    optimiser = Adam(learning_rate=lr)

    model.compile(
        optimizer=optimiser,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 5.1.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Setting Up Keras Tuner ======================== #
tuner = kt.RandomSearch(
    build_rnn_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='tuner_rnn_classification',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/tuner_rnn_classification/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 5.1.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Tuning Hyperparameters ======================== #
tuner.search(
    X_train_class_pad,
    y_train_class,
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 5.1.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best Model ======================== #
best_hp_srnn_class = tuner.get_best_hyperparameters(1)[0]
model_srnn_class_best = tuner.hypermodel.build(best_hp_srnn_class)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning:
#
# Argument `alpha` is deprecated. Use `negative_slope` instead.

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 5.1.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
model_dir = "/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Models"
os.makedirs(model_dir, exist_ok=True)

checkpoint = ModelCheckpoint(
    filepath=os.path.join(model_dir, "srnn_classification_model.keras"),
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 5.1.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training Best Model ======================== #
history_rnn_best = model_srnn_class_best.fit(
    X_train_class_pad, y_train_class,
    validation_data=(X_val_class_pad, y_val_class),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint],
    verbose=2
)
# Out:
# Epoch 1/50
# 41/41 - 22s - 529ms/step - accuracy: 0.5161 - loss: 2.1571 - val_accuracy: 0.2500 - val_loss: 2.1469 - learning_rate: 5.0000e-04
# Epoch 2/50
# 41/41 - 2s - 42ms/step - accuracy: 0.6035 - loss: 1.9753 - val_accuracy: 0.7857 - val_loss: 1.8873 - learning_rate: 5.0000e-04
# Epoch 3/50
# 41/41 - 1s - 34ms/step - accuracy: 0.8443 - loss: 1.5888 - val_accuracy: 0.2500 - val_loss: 3.5495 - learning_rate: 5.0000e-04
# Epoch 4/50
# 41/41 - 1s - 34ms/step - accuracy: 0.9862 - loss: 1.2827 - val_accuracy: 0.5357 - val_loss: 1.9513 - learning_rate: 5.0000e-04
# Epoch 5/50
# 41/41 - 1s - 35ms/step - accuracy: 0.9954 - loss: 1.2419 - val_accuracy: 0.7857 - val_loss: 1.6803 - learning_rate: 5.0000e-04
# Epoch 6/50
# 41/41 - 2s - 40ms/step - accuracy: 0.9992 - loss: 1.2015 - val_accuracy: 0.9286 - val_loss: 1.3723 - learning_rate: 5.0000e-04
# Epoch 7/50
# 41/41 - 1s - 35ms/step - accuracy: 0.9992 - loss: 1.1748 - val_accuracy: 0.2500 - val_loss: 6.1064 - learning_rate: 5.0000e-04
# Epoch 8/50
# 41/41 - 1s - 35ms/step - accuracy: 0.9977 - loss: 1.1500 - val_accuracy: 0.7857 - val_loss: 1.5896 - learning_rate: 5.0000e-04
# Epoch 9/50
# 41/41 - 1s - 35ms/step - accuracy: 1.0000 - loss: 1.1201 - val_accuracy: 0.8929 - val_loss: 1.2769 - learning_rate: 5.0000e-04
# Epoch 10/50
# 41/41 - 1s - 34ms/step - accuracy: 0.9992 - loss: 1.0950 - val_accuracy: 0.7500 - val_loss: 3.4133 - learning_rate: 5.0000e-04
# Epoch 11/50
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 1.0729 - val_accuracy: 0.4643 - val_loss: 2.9830 - learning_rate: 2.5000e-04
# Epoch 12/50
# 41/41 - 1s - 35ms/step - accuracy: 1.0000 - loss: 1.0577 - val_accuracy: 0.8929 - val_loss: 1.2750 - learning_rate: 2.5000e-04
# Epoch 13/50
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 1.0434 - val_accuracy: 0.3929 - val_loss: 4.5150 - learning_rate: 2.5000e-04
# Epoch 14/50
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 1.0280 - val_accuracy: 0.9286 - val_loss: 1.4440 - learning_rate: 2.5000e-04
# Epoch 15/50
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 1.0113 - val_accuracy: 0.8929 - val_loss: 1.4396 - learning_rate: 1.2500e-04
# Epoch 16/50
# 41/41 - 1s - 35ms/step - accuracy: 1.0000 - loss: 0.9992 - val_accuracy: 0.8571 - val_loss: 1.8598 - learning_rate: 1.2500e-04
# Epoch 17/50
# 41/41 - 1s - 35ms/step - accuracy: 1.0000 - loss: 0.9910 - val_accuracy: 0.8571 - val_loss: 1.9164 - learning_rate: 1.2500e-04
# Epoch 18/50
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 0.9834 - val_accuracy: 0.8929 - val_loss: 1.3603 - learning_rate: 6.2500e-05
# Epoch 19/50
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 0.9762 - val_accuracy: 0.8929 - val_loss: 1.3595 - learning_rate: 6.2500e-05
# Epoch 20/50
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 0.9721 - val_accuracy: 0.8929 - val_loss: 1.3680 - learning_rate: 6.2500e-05
# Epoch 21/50
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 0.9677 - val_accuracy: 0.8929 - val_loss: 1.3458 - learning_rate: 1.5625e-05
# Epoch 22/50
# 41/41 - 1s - 34ms/step - accuracy: 1.0000 - loss: 0.9663 - val_accuracy: 0.8929 - val_loss: 1.3632 - learning_rate: 1.5625e-05

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 5.1.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_srnn_class_best.save_weights("Weights/weights_class_srnn_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 5.1.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 5.1.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Plotting Training History ======================== #
def plot_history(history, title="SimpleRNN Classification Model (Aug)"):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Acc')
    plt.plot(epochs_range, val_acc, label='Val Acc')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_rnn_best)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 5.1.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_srnn_class.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_2d678_row0_col1, #T_2d678_row1_col1, #T_2d678_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2d678_row2_col1, #T_2d678_row4_col1, #T_2d678_row6_col1, #T_2d678_row8_col1, #T_2d678_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2d678_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_2d678_row7_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# </style>
# <table id="T_2d678" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d678_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_2d678_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d678_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d678_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_2d678_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d678_row1_col0" class="data row1 col0" >rnn_units_1</td>
#       <td id="T_2d678_row1_col1" class="data row1 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d678_row2_col0" class="data row2 col0" >dropout_rnn_1</td>
#       <td id="T_2d678_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d678_row3_col0" class="data row3 col0" >rnn_units_2</td>
#       <td id="T_2d678_row3_col1" class="data row3 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d678_row4_col0" class="data row4 col0" >dropout_rnn_2</td>
#       <td id="T_2d678_row4_col1" class="data row4 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d678_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_2d678_row5_col1" class="data row5 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d678_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_2d678_row6_col1" class="data row6 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d678_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_2d678_row7_col1" class="data row7 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2d678_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_2d678_row8_col1" class="data row8 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_2d678_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2d678_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_2d678_row9_col1" class="data row9 col1" >0.000500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 5.1.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - Test Accuracy ≤ 50%
#
# **Acceptable**
# - Test Accuracy ≥ 50%
#
# **Good**
# - Test Accuracy ≥ 65%
#
# **Very Good**
# - Test Accuracy ≥ 80%
#
# **Excellent**
# - Test Accuracy ≥ 95%
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Evaluation on Test Set ======================== #
y_test_class = np.array(y_test_class).astype('int32').reshape(-1)

test_loss, test_acc = model_srnn_class_best.evaluate(X_test_class_pad, y_test_class, verbose=2)

results_df = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test Loss'],
    'Value': [test_acc, test_loss]
})
results_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 - 1s - 1s/step - accuracy: 0.8929 - loss: 1.3990
# <style type="text/css">
# #T_64dbc_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_64dbc_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64dbc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64dbc_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_64dbc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64dbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64dbc_row0_col0" class="data row0 col0" >Test Accuracy</td>
#       <td id="T_64dbc_row0_col1" class="data row0 col1" >0.892857</td>
#     </tr>
#     <tr>
#       <th id="T_64dbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64dbc_row1_col0" class="data row1 col0" >Test Loss</td>
#       <td id="T_64dbc_row1_col1" class="data row1 col1" >1.398953</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Good** Test Accuracy of 75.0% and also a Relatively Low Test Loss of 1.36. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 5.1.9.4 Model's Accuracy Confusion Matrix

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predicting Classes ======================== #
y_pred = (model_srnn_class_best.predict(X_test_class_pad) > 0.5).astype('int32')

# ======================== Plotting Confusion Matrix ======================== #
cm = confusion_matrix(y_test_class, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Positive', 'Negative'])

# ======================== Plot Configurations ======================== #
fig, ax = plt.subplots(figsize=(10, 8))
disp.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix - RNN Classification")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step

# %% [markdown]
# With reference to the output above, we are able to see that the RNN Model performed poorly as seen from the Confusion Matrix where the RNN Model only predicted Positive and did not predict any Negative Sentiments. This determines the model to be voided as the accuracy is only elevated due to the majority of the Test Data being Positive Sentiment.

# %% [markdown]
# ---
# #### 5.1.9.5 Model's Classification Report

# %% [markdown]
# In this sub-section, we will be running a Classification Report for the RNN Model performance. This Classification Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Precision**
#
# Interpretation: Out of all Predicted Positives, how many are Actually Correct?
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $FP$: False Positives
#
# ---
# **Recall**
#
# Interpretation: Out of all Actual Positives, how many did we Correctly Identify?
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# **Where:*
# - $TP$: True Positives
# - $FN$: False Negatives
#
# ---
# **F1-Score**
#
# Interpretation: Balances Precision and Recall (useful when Classes are Imbalanced).
# $$
# F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
# **Support**
#
# Interpretation: Total Number of Actual Samples in the Class.
#
# $$
# \text{Support} = TP + FN
# $$
#
# ---
# **Accuracy**
#
# Interpretation: Overall Correct Predictions Divided by Total Samples.
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives
#
# ---
# With the relevant formulas listed, we will proceed to produce the Classification Report in the Code Cell below.

# %%
# ======================== Classification Report ======================== #
report_df = pd.DataFrame(classification_report(y_test_class, y_pred, target_names=['Positive', 'Negative'], output_dict=True)).transpose()
report_df.round(4).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_85490_row0_col0, #T_85490_row0_col1, #T_85490_row0_col2, #T_85490_row3_col3, #T_85490_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_85490_row0_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_85490_row1_col0, #T_85490_row1_col1, #T_85490_row1_col2, #T_85490_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_85490_row1_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_85490_row2_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_85490_row2_col1, #T_85490_row4_col0, #T_85490_row4_col1, #T_85490_row4_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_85490_row2_col2 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_85490_row3_col0, #T_85490_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_85490_row3_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_85490" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85490_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_85490_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_85490_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_85490_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85490_level0_row0" class="row_heading level0 row0" >Positive</th>
#       <td id="T_85490_row0_col0" class="data row0 col0" >0.950000</td>
#       <td id="T_85490_row0_col1" class="data row0 col1" >0.904800</td>
#       <td id="T_85490_row0_col2" class="data row0 col2" >0.926800</td>
#       <td id="T_85490_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_85490_level0_row1" class="row_heading level0 row1" >Negative</th>
#       <td id="T_85490_row1_col0" class="data row1 col0" >0.750000</td>
#       <td id="T_85490_row1_col1" class="data row1 col1" >0.857100</td>
#       <td id="T_85490_row1_col2" class="data row1 col2" >0.800000</td>
#       <td id="T_85490_row1_col3" class="data row1 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_85490_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_85490_row2_col0" class="data row2 col0" >0.892900</td>
#       <td id="T_85490_row2_col1" class="data row2 col1" >0.892900</td>
#       <td id="T_85490_row2_col2" class="data row2 col2" >0.892900</td>
#       <td id="T_85490_row2_col3" class="data row2 col3" >0.892900</td>
#     </tr>
#     <tr>
#       <th id="T_85490_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_85490_row3_col0" class="data row3 col0" >0.850000</td>
#       <td id="T_85490_row3_col1" class="data row3 col1" >0.881000</td>
#       <td id="T_85490_row3_col2" class="data row3 col2" >0.863400</td>
#       <td id="T_85490_row3_col3" class="data row3 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_85490_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_85490_row4_col0" class="data row4 col0" >0.900000</td>
#       <td id="T_85490_row4_col1" class="data row4 col1" >0.892900</td>
#       <td id="T_85490_row4_col2" class="data row4 col2" >0.895100</td>
#       <td id="T_85490_row4_col3" class="data row4 col3" >28.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame and the 'F1-Score' Data Column, we are able to see that the F1-Score is somewhat elevated for the Positive Sentiment. However, the Negative Sentiment has a 0 F1-Score which indicates that the only reason for the high accuracy is due to the majority of the Test being Positive Sentiment. Therefore, this model is Voided and should not be used due to the bias.

# %% [markdown]
# ---
# ## 5.2 LSTM Classification Model

# %% [markdown]
# In this sub-section, we will be training the LSTM Classification Model. Long-Short Term Memory is a type of RNN architecture designed to overcome the vanishing gradient problem in traditional RNN. if this Model does perform well, it can be used as one of the Final Model if Classification is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Forget Gate**
# $$
# f_t = \sigma(W_f \cdot [h_{t-1}, x_t] + b_f)
# $$
#
# Where:
# - $f_t$: Forget Gate Vector at Time $t$
# - $\sigma$: Sigmoid Activation Function
# - $W_f$: Weight Matrix for Forget Gate
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Current Input
# - $b_f$: Bias for Forget Gate
#
# ---
# **Input Gate (Activation + Candidate)**
# $$
# i_t = \sigma(W_i \cdot [h_{t-1}, x_t] + b_i)
# $$
#
# $$
# \tilde{C}_t = \tanh(W_C \cdot [h_{t-1}, x_t] + b_C)
# $$
#
# Where:
# - $i_t$: Input Gate Vector at Time $t$
# - $\tilde{C}_t$: Candidate Values for Cell State Update
# - $W_i$, $W_C$: Weight Matrices for Input and Cell State
# - $b_i$, $b_C$: Biases for Input Gate and Cell Update
# - $\tanh$: Hyperbolic Tangent Activation Function
#
# ---
# **Cell State Update**
# $$
# C_t = f_t \cdot C_{t-1} + i_t \cdot \tilde{C}_t
# $$
#
# Where:
# - $C_t$: Updated Cell State at Time $t$
# - $C_{t-1}$: Previous Cell State
# - $f_t$: Forget Gate Vector
# - $i_t$: Input Gate Vector
# - $\tilde{C}_t$: Candidate Cell Values
#
# ---
# **Output Gate and Hidden State**
# $$
# o_t = \sigma(W_o \cdot [h_{t-1}, x_t] + b_o)
# $$
#
# $$
# h_t = o_t \cdot \tanh(C_t)
# $$
#
# Where:
# - $o_t$: Output Gate Vector
# - $h_t$: Hidden State (also Output of LSTM unit)
# - $W_o$: Weight Matrix for Output Gate
# - $b_o$: Bias for Output Gate
#
# ---
#
# **Output Layer (Classification)**
# $$
# \hat{y} = \text{softmax}(W_{hy} h_T + b_y)
# $$
#
# Where:
# - $\hat{y}$: Predicted Class Probabilities (Vector)
# - $h_T$: Hidden State at Final Time Step $T$
# - $W_{hy}$: Weight Matrix from Hidden to Output
# - $b_y$: Output Bias
#
# ---
# **Loss Function (Sparse Categorical Crossentropy)**
# $$
# \mathcal{L} = -\log(\hat{y}_{\text{true}})
# $$
#
# Where:
# - $\mathcal{L}$: Loss for a Single Example
# - $\hat{y}_{\text{true}}$: Predicted Probability for the Correct Class
# - $\log$: Natural Logarithm
#
#
# ---
# With all the essential Formulas for LSTM indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 5.2.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 5.2.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_lstm_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300]),
        embeddings_initializer='uniform'
    ))

    # ----- Bidirectional LSTM Layer 1 ----- #
    model.add(Bidirectional(LSTM(
        units=hp.Choice("lstm_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_1", 0.3, 0.5, step=0.1)))

    # ----- Bidirectional LSTM Layer 2 ----- #
    model.add(Bidirectional(LSTM(
        units=hp.Choice("lstm_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_2", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [128, 256]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [64, 128]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.3, 0.5, step=0.1)))

    # ----- Output Layer ----- #
    model.add(Dense(1, activation='sigmoid'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [5e-4, 1e-4, 5e-5])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 5.2.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner for LSTM ======================== #
tuner_lstm = kt.RandomSearch(
    build_lstm_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='lstm_classification',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/lstm_classification/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 5.2.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Searching Best Hyperparameters ======================== #
tuner_lstm.search(
    X_train_class_pad,
    y_train_class,
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 5.2.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best Model ======================== #
best_hp_lstm = tuner_lstm.get_best_hyperparameters(1)[0]
model_lstm_class_best = tuner_lstm.hypermodel.build(best_hp_lstm)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning:
#
# Argument `alpha` is deprecated. Use `negative_slope` instead.

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 5.2.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
checkpoint_lstm = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_lstm_classification_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 5.2.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training Best LSTM Model ======================== #
history_lstm_class = model_lstm_class_best.fit(
    X_train_class_pad, y_train_class,
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint_lstm],
    verbose=2
)
# Out:
# Epoch 1/100
# 41/41 - 8s - 183ms/step - accuracy: 0.5406 - loss: 2.4717 - val_accuracy: 0.2500 - val_loss: 2.2744 - learning_rate: 5.0000e-04
# Epoch 2/100
# 41/41 - 1s - 25ms/step - accuracy: 0.6725 - loss: 2.0697 - val_accuracy: 0.2500 - val_loss: 2.2103 - learning_rate: 5.0000e-04
# Epoch 3/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9340 - loss: 1.5036 - val_accuracy: 0.2500 - val_loss: 2.0546 - learning_rate: 5.0000e-04
# Epoch 4/100
# 41/41 - 1s - 31ms/step - accuracy: 0.9939 - loss: 1.2785 - val_accuracy: 0.3929 - val_loss: 1.9674 - learning_rate: 5.0000e-04
# Epoch 5/100
# 41/41 - 1s - 32ms/step - accuracy: 0.9992 - loss: 1.1845 - val_accuracy: 0.8214 - val_loss: 1.6454 - learning_rate: 5.0000e-04
# Epoch 6/100
# 41/41 - 1s - 31ms/step - accuracy: 1.0000 - loss: 1.1121 - val_accuracy: 0.8929 - val_loss: 1.4916 - learning_rate: 5.0000e-04
# Epoch 7/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9992 - loss: 1.0567 - val_accuracy: 0.8929 - val_loss: 1.3371 - learning_rate: 5.0000e-04
# Epoch 8/100
# 41/41 - 1s - 24ms/step - accuracy: 1.0000 - loss: 1.0110 - val_accuracy: 0.8929 - val_loss: 1.3146 - learning_rate: 5.0000e-04
# Epoch 9/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.9754 - val_accuracy: 0.7857 - val_loss: 1.4930 - learning_rate: 5.0000e-04
# Epoch 10/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9900 - loss: 0.9573 - val_accuracy: 0.8929 - val_loss: 1.1488 - learning_rate: 5.0000e-04
# Epoch 11/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.9132 - val_accuracy: 0.8929 - val_loss: 1.1880 - learning_rate: 2.5000e-04
# Epoch 12/100
# 41/41 - 1s - 24ms/step - accuracy: 1.0000 - loss: 0.8920 - val_accuracy: 0.8929 - val_loss: 1.1847 - learning_rate: 2.5000e-04
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8780 - val_accuracy: 0.8929 - val_loss: 1.2265 - learning_rate: 1.2500e-04
# Epoch 14/100
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8630 - val_accuracy: 0.8929 - val_loss: 1.2469 - learning_rate: 1.2500e-04
# Epoch 15/100
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8551 - val_accuracy: 0.8929 - val_loss: 1.2701 - learning_rate: 1.2500e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8454 - val_accuracy: 0.8929 - val_loss: 1.2801 - learning_rate: 6.2500e-05
# Epoch 17/100
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8403 - val_accuracy: 0.8929 - val_loss: 1.2993 - learning_rate: 6.2500e-05
# Epoch 18/100
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8351 - val_accuracy: 0.8929 - val_loss: 1.3147 - learning_rate: 6.2500e-05
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8304 - val_accuracy: 0.8929 - val_loss: 1.3206 - learning_rate: 3.1250e-05
# Epoch 20/100
# 41/41 - 1s - 24ms/step - accuracy: 1.0000 - loss: 0.8273 - val_accuracy: 0.8929 - val_loss: 1.3280 - learning_rate: 3.1250e-05

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 5.2.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_lstm_class_best.save_weights("Weights/weights_class_lstm_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 5.2.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 5.2.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Accuracy & Loss Plot ======================== #
def plot_history(history, title="LSTM Classification Model (Aug)"):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_lstm_class)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 5.2.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_lstm.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_3f299_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3f299_row1_col1, #T_3f299_row3_col1, #T_3f299_row5_col1, #T_3f299_row7_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_3f299_row2_col1, #T_3f299_row4_col1, #T_3f299_row6_col1, #T_3f299_row8_col1, #T_3f299_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_3f299" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f299_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_3f299_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f299_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f299_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_3f299_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f299_row1_col0" class="data row1 col0" >lstm_units_1</td>
#       <td id="T_3f299_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3f299_row2_col0" class="data row2 col0" >dropout_lstm_1</td>
#       <td id="T_3f299_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3f299_row3_col0" class="data row3 col0" >lstm_units_2</td>
#       <td id="T_3f299_row3_col1" class="data row3 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3f299_row4_col0" class="data row4 col0" >dropout_lstm_2</td>
#       <td id="T_3f299_row4_col1" class="data row4 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3f299_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_3f299_row5_col1" class="data row5 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3f299_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_3f299_row6_col1" class="data row6 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3f299_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_3f299_row7_col1" class="data row7 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3f299_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_3f299_row8_col1" class="data row8 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_3f299_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3f299_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_3f299_row9_col1" class="data row9 col1" >0.000500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 5.2.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - Test Accuracy ≤ 50%
#
# **Acceptable**
# - Test Accuracy ≥ 50%
#
# **Good**
# - Test Accuracy ≥ 65%
#
# **Very Good**
# - Test Accuracy ≥ 80%
#
# **Excellent**
# - Test Accuracy ≥ 95%
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Evaluate LSTM Model ======================== #
y_test_class = np.array(y_test_class).astype('int32').reshape(-1)

test_loss_lstm, test_acc_lstm = model_lstm_class_best.evaluate(X_test_class_pad, y_test_class, verbose=2)

results_lstm_df = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test Loss'],
    'Value': [test_acc_lstm, test_loss_lstm]
})
results_lstm_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 - 1s - 692ms/step - accuracy: 0.8929 - loss: 1.1279
# <style type="text/css">
# #T_9ee9b_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9ee9b_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ee9b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ee9b_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_9ee9b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ee9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ee9b_row0_col0" class="data row0 col0" >Test Accuracy</td>
#       <td id="T_9ee9b_row0_col1" class="data row0 col1" >0.892857</td>
#     </tr>
#     <tr>
#       <th id="T_9ee9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ee9b_row1_col0" class="data row1 col0" >Test Loss</td>
#       <td id="T_9ee9b_row1_col1" class="data row1 col1" >1.127900</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Very Good** Test Accuracy of 92.8% and also a Relatively Low Test Loss of 0.95. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 5.2.9.4 Model's Accuracy Confusion Matrix

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predict & Compute Confusion Matrix ======================== #
y_pred_lstm = (model_lstm_class_best.predict(X_test_class_pad) > 0.5).astype('int32')

cm_lstm = confusion_matrix(y_test_class, y_pred_lstm)
disp_lstm = ConfusionMatrixDisplay(confusion_matrix=cm_lstm, display_labels=['Positive', 'Negative'])

fig, ax = plt.subplots(figsize=(8, 6))
disp_lstm.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix - LSTM Classification Model")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step

# %% [markdown]
# With reference to the output above, we are able to see that the RNN Model performed perfectly well as seen from the Dark Blue Coloured Squares running from top right to botton left of the Confusion Matrix. However, there are 2 wrong predictions but these do not constitute much to the overall accuracy.

# %% [markdown]
# ---
# #### 5.2.9.5 Model's Classification Report

# %% [markdown]
# In this sub-section, we will be running a Classification Report for the RNN Model performance. This Classification Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Precision**
#
# Interpretation: Out of all Predicted Positives, how many are Actually Correct?
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $FP$: False Positives
#
# ---
# **Recall**
#
# Interpretation: Out of all Actual Positives, how many did we Correctly Identify?
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# **Where:*
# - $TP$: True Positives
# - $FN$: False Negatives
#
# ---
# **F1-Score**
#
# Interpretation: Balances Precision and Recall (useful when Classes are Imbalanced).
# $$
# F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
# **Support**
#
# Interpretation: Total Number of Actual Samples in the Class.
#
# $$
# \text{Support} = TP + FN
# $$
#
# ---
# **Accuracy**
#
# Interpretation: Overall Correct Predictions Divided by Total Samples.
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives
#
# ---
# With the relevant formulas listed, we will proceed to produce the Classification Report in the Code Cell below.

# %%
# ======================== Generate Classification Report ======================== #
report_lstm = classification_report(
    y_test_class,
    y_pred_lstm,
    target_names=['Positive', 'Negative'],
    output_dict=True
)

report_lstm_df = pd.DataFrame(report_lstm).transpose().round(4)
report_lstm_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_6b1f3_row0_col0, #T_6b1f3_row0_col1, #T_6b1f3_row0_col2, #T_6b1f3_row3_col3, #T_6b1f3_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6b1f3_row0_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_6b1f3_row1_col0, #T_6b1f3_row1_col1, #T_6b1f3_row1_col2, #T_6b1f3_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6b1f3_row1_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_6b1f3_row2_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_6b1f3_row2_col1, #T_6b1f3_row4_col0, #T_6b1f3_row4_col1, #T_6b1f3_row4_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_6b1f3_row2_col2 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_6b1f3_row3_col0, #T_6b1f3_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_6b1f3_row3_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6b1f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b1f3_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_6b1f3_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_6b1f3_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_6b1f3_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b1f3_level0_row0" class="row_heading level0 row0" >Positive</th>
#       <td id="T_6b1f3_row0_col0" class="data row0 col0" >0.950000</td>
#       <td id="T_6b1f3_row0_col1" class="data row0 col1" >0.904800</td>
#       <td id="T_6b1f3_row0_col2" class="data row0 col2" >0.926800</td>
#       <td id="T_6b1f3_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6b1f3_level0_row1" class="row_heading level0 row1" >Negative</th>
#       <td id="T_6b1f3_row1_col0" class="data row1 col0" >0.750000</td>
#       <td id="T_6b1f3_row1_col1" class="data row1 col1" >0.857100</td>
#       <td id="T_6b1f3_row1_col2" class="data row1 col2" >0.800000</td>
#       <td id="T_6b1f3_row1_col3" class="data row1 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6b1f3_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_6b1f3_row2_col0" class="data row2 col0" >0.892900</td>
#       <td id="T_6b1f3_row2_col1" class="data row2 col1" >0.892900</td>
#       <td id="T_6b1f3_row2_col2" class="data row2 col2" >0.892900</td>
#       <td id="T_6b1f3_row2_col3" class="data row2 col3" >0.892900</td>
#     </tr>
#     <tr>
#       <th id="T_6b1f3_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_6b1f3_row3_col0" class="data row3 col0" >0.850000</td>
#       <td id="T_6b1f3_row3_col1" class="data row3 col1" >0.881000</td>
#       <td id="T_6b1f3_row3_col2" class="data row3 col2" >0.863400</td>
#       <td id="T_6b1f3_row3_col3" class="data row3 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6b1f3_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_6b1f3_row4_col0" class="data row4 col0" >0.900000</td>
#       <td id="T_6b1f3_row4_col1" class="data row4 col1" >0.892900</td>
#       <td id="T_6b1f3_row4_col2" class="data row4 col2" >0.895100</td>
#       <td id="T_6b1f3_row4_col3" class="data row4 col3" >28.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame and the 'F1-Score' Data Column, we are able to see that the F1-Score is above 0.85 throughout the Classes This shows that the RNN Model performs extremely well and consistent throughout all the Classes.

# %% [markdown]
# ---
# ## 5.3 GRU Classification Model

# %% [markdown]
# In this sub-section, we will be training the GRU Classification Model. Gated Recurrent Units (GRUs) are a simplified version of LSTMs that use two gates — the update gate and reset gate — to control the flow of information. They are computationally more efficient than LSTMs while often achieving comparable performance. GRUs do not maintain a separate memory cell like LSTMs, making them easier to train while still addressing the vanishing gradient problem in traditional RNNs. if this Model does perform well, it can be used as one of the Final Model if Classification is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Reset Gate**
# $$
# r_t = \sigma(W_r \cdot [h_{t-1}, x_t] + b_r)
# $$
#
# Where:
# - $r_t$: Reset Gate
# - $W_r$: Weights for Reset Gate
# - $b_r$: Bias
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input at Time $t$
# - $\sigma$: Sigmoid Function
#
# ---
# **Update Gate**
# $$
# z_t = \sigma(W_z \cdot [h_{t-1}, x_t] + b_z)
# $$
#
# Where:
# - $z_t$: Update Gate
# - $W_z$: Weights for Update Gate
# - $b_z$: Bias
#
# ---
# **Candidate Hidden State**
# $$
# \tilde{h}_t = \tanh(W_h \cdot [r_t * h_{t-1}, x_t] + b_h)
# $$
#
# **Where:**
# - $\tilde{h}_t$: Candidate Hidden State
# - $r_t$: Reset Gate
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input
# - $W_h$, $b_h$: Weights & Bias
# - $\tanh$: Hyperbolic Tangent Activation
#
# ---
# **Final Hidden State Update**
# $$
# h_t = (1 - z_t) * h_{t-1} + z_t * \tilde{h}_t
# $$
#
# **Where:**
# - $h_t$: New Hidden State
# - $z_t$: Update Gate
# - $\tilde{h}_t$: Candidate State
#
# ---
#
# **Output Layer (Softmax)**
# $$
# \hat{y} = \text{softmax}(W_o h_T + b_o)
# $$
#
# **Where:**
# - $h_T$: Last Hidden State
# - $\hat{y}$: Predicted Probability for Each Class
# - $W_o$, $b_o$: Output Weights and Bias
#
# ---
# **Loss Function**
# $$
# \mathcal{L} = -\log(\hat{y}_{\text{true}})
# $$
#
# **Where:**
# - $\hat{y}_{\text{true}}$: Predicted Probability of the Correct Class
#
# ---
# With all the essential Formulas for GRU indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 5.3.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 5.3.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_gru_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300]),
        embeddings_initializer='uniform'
    ))

    # ----- Bidirectional GRU Layer 1 ----- #
    model.add(Bidirectional(GRU(
        units=hp.Choice("gru_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_1", 0.3, 0.5, step=0.1)))

    # ----- Bidirectional GRU Layer 2 ----- #
    model.add(Bidirectional(GRU(
        units=hp.Choice("gru_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_2", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [128, 256]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [64, 128]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.3, 0.5, step=0.1)))

    # ----- Output Layer ----- #
    model.add(Dense(1, activation='sigmoid'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [5e-4, 1e-4, 5e-5])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 5.3.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner for GRU ======================== #
tuner_gru = kt.RandomSearch(
    build_gru_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='gru_classification',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/gru_classification/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 5.3.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search for GRU ======================== #
tuner_gru.search(
    X_train_class_pad,
    y_train_class,
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 5.3.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best GRU Model ======================== #
best_hp_gru = tuner_gru.get_best_hyperparameters(1)[0]
model_gru_class_best = tuner_gru.hypermodel.build(best_hp_gru)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning:
#
# Argument `alpha` is deprecated. Use `negative_slope` instead.

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 5.3.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
checkpoint_gru = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_gru_classification_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 5.3.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training GRU Model ======================== #
history_gru_class = model_gru_class_best.fit(
    X_train_class_pad, y_train_class,
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint_gru],
    verbose=2
)
# Out:
# Epoch 1/100
# 41/41 - 9s - 227ms/step - accuracy: 0.5184 - loss: 2.4815 - val_accuracy: 0.2500 - val_loss: 2.2600 - learning_rate: 1.0000e-04
# Epoch 2/100
# 41/41 - 1s - 25ms/step - accuracy: 0.5836 - loss: 2.2816 - val_accuracy: 0.2500 - val_loss: 2.2045 - learning_rate: 1.0000e-04
# Epoch 3/100
# 41/41 - 1s - 24ms/step - accuracy: 0.6342 - loss: 2.1475 - val_accuracy: 0.2500 - val_loss: 2.1540 - learning_rate: 1.0000e-04
# Epoch 4/100
# 41/41 - 1s - 24ms/step - accuracy: 0.6518 - loss: 2.0427 - val_accuracy: 0.2500 - val_loss: 2.1102 - learning_rate: 1.0000e-04
# Epoch 5/100
# 41/41 - 1s - 25ms/step - accuracy: 0.7147 - loss: 1.8666 - val_accuracy: 0.2500 - val_loss: 2.0689 - learning_rate: 1.0000e-04
# Epoch 6/100
# 41/41 - 1s - 24ms/step - accuracy: 0.7554 - loss: 1.7624 - val_accuracy: 0.2500 - val_loss: 1.9956 - learning_rate: 1.0000e-04
# Epoch 7/100
# 41/41 - 1s - 31ms/step - accuracy: 0.8535 - loss: 1.5745 - val_accuracy: 0.3929 - val_loss: 1.8858 - learning_rate: 1.0000e-04
# Epoch 8/100
# 41/41 - 1s - 32ms/step - accuracy: 0.8903 - loss: 1.4642 - val_accuracy: 0.9643 - val_loss: 1.7290 - learning_rate: 1.0000e-04
# Epoch 9/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9310 - loss: 1.3465 - val_accuracy: 0.9643 - val_loss: 1.5630 - learning_rate: 1.0000e-04
# Epoch 10/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9479 - loss: 1.2763 - val_accuracy: 0.8571 - val_loss: 1.4368 - learning_rate: 1.0000e-04
# Epoch 11/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9663 - loss: 1.2092 - val_accuracy: 0.8571 - val_loss: 1.3749 - learning_rate: 5.0000e-05
# Epoch 12/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9709 - loss: 1.1804 - val_accuracy: 0.8571 - val_loss: 1.3248 - learning_rate: 5.0000e-05
# Epoch 13/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9793 - loss: 1.1577 - val_accuracy: 0.8571 - val_loss: 1.2784 - learning_rate: 5.0000e-05
# Epoch 14/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9793 - loss: 1.1303 - val_accuracy: 0.9643 - val_loss: 1.2324 - learning_rate: 5.0000e-05
# Epoch 15/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9824 - loss: 1.1071 - val_accuracy: 0.9286 - val_loss: 1.1973 - learning_rate: 5.0000e-05
# Epoch 16/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9908 - loss: 1.0796 - val_accuracy: 0.9643 - val_loss: 1.1662 - learning_rate: 5.0000e-05
# Epoch 17/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9816 - loss: 1.0705 - val_accuracy: 0.9286 - val_loss: 1.1446 - learning_rate: 5.0000e-05
# Epoch 18/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9900 - loss: 1.0488 - val_accuracy: 0.9286 - val_loss: 1.1361 - learning_rate: 5.0000e-05
# Epoch 19/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9893 - loss: 1.0346 - val_accuracy: 0.9286 - val_loss: 1.1138 - learning_rate: 5.0000e-05
# Epoch 20/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9908 - loss: 1.0130 - val_accuracy: 0.9286 - val_loss: 1.1013 - learning_rate: 5.0000e-05
# Epoch 21/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9946 - loss: 0.9988 - val_accuracy: 0.9286 - val_loss: 1.0926 - learning_rate: 2.5000e-05
# Epoch 22/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9977 - loss: 0.9927 - val_accuracy: 0.9286 - val_loss: 1.0890 - learning_rate: 2.5000e-05
# Epoch 23/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9954 - loss: 0.9849 - val_accuracy: 0.9286 - val_loss: 1.0872 - learning_rate: 2.5000e-05
# Epoch 24/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9939 - loss: 0.9852 - val_accuracy: 0.9286 - val_loss: 1.0838 - learning_rate: 2.5000e-05
# Epoch 25/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9916 - loss: 0.9796 - val_accuracy: 0.9286 - val_loss: 1.0817 - learning_rate: 2.5000e-05
# Epoch 26/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9977 - loss: 0.9666 - val_accuracy: 0.9286 - val_loss: 1.0761 - learning_rate: 2.5000e-05
# Epoch 27/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9946 - loss: 0.9639 - val_accuracy: 0.9286 - val_loss: 1.0679 - learning_rate: 2.5000e-05
# Epoch 28/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9969 - loss: 0.9506 - val_accuracy: 0.9286 - val_loss: 1.0649 - learning_rate: 2.5000e-05
# Epoch 29/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9962 - loss: 0.9499 - val_accuracy: 0.9286 - val_loss: 1.0662 - learning_rate: 2.5000e-05
# Epoch 30/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9939 - loss: 0.9464 - val_accuracy: 0.9286 - val_loss: 1.0612 - learning_rate: 2.5000e-05
# Epoch 31/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.9414 - val_accuracy: 0.9286 - val_loss: 1.0563 - learning_rate: 1.2500e-05
# Epoch 32/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9992 - loss: 0.9314 - val_accuracy: 0.9286 - val_loss: 1.0517 - learning_rate: 1.2500e-05
# Epoch 33/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9969 - loss: 0.9333 - val_accuracy: 0.9286 - val_loss: 1.0525 - learning_rate: 1.2500e-05
# Epoch 34/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9954 - loss: 0.9316 - val_accuracy: 0.9286 - val_loss: 1.0544 - learning_rate: 1.2500e-05
# Epoch 35/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9969 - loss: 0.9303 - val_accuracy: 0.9286 - val_loss: 1.0416 - learning_rate: 1.2500e-05
# Epoch 36/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9977 - loss: 0.9193 - val_accuracy: 0.9286 - val_loss: 1.0357 - learning_rate: 1.2500e-05
# Epoch 37/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.9242 - val_accuracy: 0.9286 - val_loss: 1.0372 - learning_rate: 1.2500e-05
# Epoch 38/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9969 - loss: 0.9170 - val_accuracy: 0.9286 - val_loss: 1.0326 - learning_rate: 1.2500e-05
# Epoch 39/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9977 - loss: 0.9127 - val_accuracy: 0.9286 - val_loss: 1.0343 - learning_rate: 1.2500e-05
# Epoch 40/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.9104 - val_accuracy: 0.9286 - val_loss: 1.0320 - learning_rate: 1.2500e-05
# Epoch 41/100
# 41/41 - 1s - 24ms/step - accuracy: 1.0000 - loss: 0.9054 - val_accuracy: 0.9286 - val_loss: 1.0296 - learning_rate: 6.2500e-06
# Epoch 42/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.9071 - val_accuracy: 0.9286 - val_loss: 1.0286 - learning_rate: 6.2500e-06
# Epoch 43/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.9047 - val_accuracy: 0.9286 - val_loss: 1.0251 - learning_rate: 6.2500e-06
# Epoch 44/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9962 - loss: 0.9036 - val_accuracy: 0.9286 - val_loss: 1.0245 - learning_rate: 6.2500e-06
# Epoch 45/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9985 - loss: 0.9017 - val_accuracy: 0.9286 - val_loss: 1.0260 - learning_rate: 6.2500e-06
# Epoch 46/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9977 - loss: 0.9008 - val_accuracy: 0.9286 - val_loss: 1.0254 - learning_rate: 6.2500e-06
# Epoch 47/100
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.9012 - val_accuracy: 0.9286 - val_loss: 1.0247 - learning_rate: 3.1250e-06
# Epoch 48/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8958 - val_accuracy: 0.9286 - val_loss: 1.0232 - learning_rate: 3.1250e-06
# Epoch 49/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9962 - loss: 0.9026 - val_accuracy: 0.9286 - val_loss: 1.0228 - learning_rate: 3.1250e-06
# Epoch 50/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8947 - val_accuracy: 0.9286 - val_loss: 1.0229 - learning_rate: 3.1250e-06
# Epoch 51/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8952 - val_accuracy: 0.9286 - val_loss: 1.0213 - learning_rate: 1.5625e-06
# Epoch 52/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8936 - val_accuracy: 0.9286 - val_loss: 1.0210 - learning_rate: 1.5625e-06
# Epoch 53/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9969 - loss: 0.8950 - val_accuracy: 0.9286 - val_loss: 1.0218 - learning_rate: 1.5625e-06
# Epoch 54/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8922 - val_accuracy: 0.9286 - val_loss: 1.0209 - learning_rate: 1.5625e-06
# Epoch 55/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8913 - val_accuracy: 0.9286 - val_loss: 1.0196 - learning_rate: 1.5625e-06
# Epoch 56/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9985 - loss: 0.8903 - val_accuracy: 0.9286 - val_loss: 1.0194 - learning_rate: 1.5625e-06
# Epoch 57/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9977 - loss: 0.8950 - val_accuracy: 0.9286 - val_loss: 1.0189 - learning_rate: 1.5625e-06
# Epoch 58/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9969 - loss: 0.8973 - val_accuracy: 0.9286 - val_loss: 1.0191 - learning_rate: 1.5625e-06
# Epoch 59/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9977 - loss: 0.8972 - val_accuracy: 0.9286 - val_loss: 1.0187 - learning_rate: 1.5625e-06
# Epoch 60/100
# 41/41 - 1s - 25ms/step - accuracy: 1.0000 - loss: 0.8888 - val_accuracy: 0.9286 - val_loss: 1.0170 - learning_rate: 1.5625e-06
# Epoch 61/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9969 - loss: 0.8920 - val_accuracy: 0.9286 - val_loss: 1.0160 - learning_rate: 7.8125e-07
# Epoch 62/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8911 - val_accuracy: 0.9286 - val_loss: 1.0162 - learning_rate: 7.8125e-07
# Epoch 63/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9992 - loss: 0.8916 - val_accuracy: 0.9286 - val_loss: 1.0156 - learning_rate: 7.8125e-07
# Epoch 64/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8909 - val_accuracy: 0.9286 - val_loss: 1.0148 - learning_rate: 7.8125e-07
# Epoch 65/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9954 - loss: 0.8957 - val_accuracy: 0.9286 - val_loss: 1.0158 - learning_rate: 7.8125e-07
# Epoch 66/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8884 - val_accuracy: 0.9286 - val_loss: 1.0141 - learning_rate: 7.8125e-07
# Epoch 67/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9939 - loss: 0.8941 - val_accuracy: 0.9286 - val_loss: 1.0137 - learning_rate: 7.8125e-07
# Epoch 68/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9985 - loss: 0.8890 - val_accuracy: 0.8929 - val_loss: 1.0129 - learning_rate: 7.8125e-07
# Epoch 69/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9992 - loss: 0.8883 - val_accuracy: 0.8929 - val_loss: 1.0129 - learning_rate: 7.8125e-07
# Epoch 70/100
# 41/41 - 1s - 26ms/step - accuracy: 0.9962 - loss: 0.8904 - val_accuracy: 0.8929 - val_loss: 1.0128 - learning_rate: 7.8125e-07
# Epoch 71/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8880 - val_accuracy: 0.9286 - val_loss: 1.0137 - learning_rate: 3.9062e-07
# Epoch 72/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8879 - val_accuracy: 0.9286 - val_loss: 1.0135 - learning_rate: 3.9062e-07
# Epoch 73/100
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8907 - val_accuracy: 0.9286 - val_loss: 1.0138 - learning_rate: 1.9531e-07
# Epoch 74/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9962 - loss: 0.8923 - val_accuracy: 0.9286 - val_loss: 1.0139 - learning_rate: 1.9531e-07
# Epoch 75/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9962 - loss: 0.8908 - val_accuracy: 0.9286 - val_loss: 1.0129 - learning_rate: 1.9531e-07
# Epoch 76/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8866 - val_accuracy: 0.8929 - val_loss: 1.0124 - learning_rate: 1.9531e-07
# Epoch 77/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8853 - val_accuracy: 0.9286 - val_loss: 1.0130 - learning_rate: 1.9531e-07
# Epoch 78/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9939 - loss: 0.8924 - val_accuracy: 0.9286 - val_loss: 1.0142 - learning_rate: 1.9531e-07
# Epoch 79/100
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# 41/41 - 1s - 24ms/step - accuracy: 0.9962 - loss: 0.8924 - val_accuracy: 0.9286 - val_loss: 1.0146 - learning_rate: 9.7656e-08
# Epoch 80/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8893 - val_accuracy: 0.9286 - val_loss: 1.0129 - learning_rate: 9.7656e-08
# Epoch 81/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8863 - val_accuracy: 0.9286 - val_loss: 1.0127 - learning_rate: 4.8828e-08
# Epoch 82/100
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8888 - val_accuracy: 0.9286 - val_loss: 1.0127 - learning_rate: 2.4414e-08
# Epoch 83/100
# 41/41 - 1s - 25ms/step - accuracy: 0.9985 - loss: 0.8872 - val_accuracy: 0.8929 - val_loss: 1.0122 - learning_rate: 2.4414e-08
# Epoch 84/100
# 41/41 - 1s - 23ms/step - accuracy: 0.9977 - loss: 0.8879 - val_accuracy: 0.8929 - val_loss: 1.0128 - learning_rate: 2.4414e-08
# Epoch 85/100
# 41/41 - 1s - 24ms/step - accuracy: 1.0000 - loss: 0.8866 - val_accuracy: 0.8929 - val_loss: 1.0131 - learning_rate: 2.4414e-08
# Epoch 86/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8884 - val_accuracy: 0.8929 - val_loss: 1.0114 - learning_rate: 2.4414e-08
# Epoch 87/100
# 41/41 - 1s - 23ms/step - accuracy: 0.9962 - loss: 0.8948 - val_accuracy: 0.8929 - val_loss: 1.0129 - learning_rate: 2.4414e-08
# Epoch 88/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8906 - val_accuracy: 0.9286 - val_loss: 1.0131 - learning_rate: 2.4414e-08
# Epoch 89/100
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8909 - val_accuracy: 0.8929 - val_loss: 1.0124 - learning_rate: 1.2207e-08
# Epoch 90/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9946 - loss: 0.8936 - val_accuracy: 0.8929 - val_loss: 1.0113 - learning_rate: 1.2207e-08
# Epoch 91/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9969 - loss: 0.8897 - val_accuracy: 0.8929 - val_loss: 1.0115 - learning_rate: 6.1035e-09
# Epoch 92/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9985 - loss: 0.8868 - val_accuracy: 0.9286 - val_loss: 1.0129 - learning_rate: 6.1035e-09
# Epoch 93/100
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# 41/41 - 1s - 24ms/step - accuracy: 0.9977 - loss: 0.8859 - val_accuracy: 0.8929 - val_loss: 1.0126 - learning_rate: 3.0518e-09
# Epoch 94/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8887 - val_accuracy: 0.8929 - val_loss: 1.0130 - learning_rate: 3.0518e-09
# Epoch 95/100
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8874 - val_accuracy: 0.8929 - val_loss: 1.0128 - learning_rate: 3.0518e-09
# Epoch 96/100
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# 41/41 - 1s - 23ms/step - accuracy: 0.9992 - loss: 0.8883 - val_accuracy: 0.8929 - val_loss: 1.0133 - learning_rate: 1.5259e-09
# Epoch 97/100
# 41/41 - 1s - 23ms/step - accuracy: 0.9992 - loss: 0.8878 - val_accuracy: 0.9286 - val_loss: 1.0141 - learning_rate: 1.5259e-09
# Epoch 98/100
# 41/41 - 1s - 23ms/step - accuracy: 1.0000 - loss: 0.8821 - val_accuracy: 0.9286 - val_loss: 1.0141 - learning_rate: 1.5259e-09
# Epoch 99/100
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# 41/41 - 1s - 24ms/step - accuracy: 0.9992 - loss: 0.8890 - val_accuracy: 0.9286 - val_loss: 1.0139 - learning_rate: 7.6294e-10
# Epoch 100/100
# 41/41 - 1s - 23ms/step - accuracy: 0.9962 - loss: 0.8922 - val_accuracy: 0.9286 - val_loss: 1.0137 - learning_rate: 7.6294e-10

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 5.3.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_gru_class_best.save_weights("Weights/weights_class_gru_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 5.3.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 5.3.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Accuracy & Loss Plot ======================== #
def plot_history(history, title="GRU Classification Model (Aug)"):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_gru_class)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 5.3.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_gru.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_c131b_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c131b_row1_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_c131b_row2_col1, #T_c131b_row4_col1, #T_c131b_row6_col1, #T_c131b_row8_col1, #T_c131b_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c131b_row3_col1, #T_c131b_row7_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_c131b_row5_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# </style>
# <table id="T_c131b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c131b_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_c131b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c131b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c131b_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_c131b_row0_col1" class="data row0 col1" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c131b_row1_col0" class="data row1 col0" >gru_units_1</td>
#       <td id="T_c131b_row1_col1" class="data row1 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c131b_row2_col0" class="data row2 col0" >dropout_gru_1</td>
#       <td id="T_c131b_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c131b_row3_col0" class="data row3 col0" >gru_units_2</td>
#       <td id="T_c131b_row3_col1" class="data row3 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c131b_row4_col0" class="data row4 col0" >dropout_gru_2</td>
#       <td id="T_c131b_row4_col1" class="data row4 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c131b_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_c131b_row5_col1" class="data row5 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c131b_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_c131b_row6_col1" class="data row6 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c131b_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_c131b_row7_col1" class="data row7 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c131b_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_c131b_row8_col1" class="data row8 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_c131b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c131b_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_c131b_row9_col1" class="data row9 col1" >0.000100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 5.3.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - Test Accuracy ≤ 50%
#
# **Acceptable**
# - Test Accuracy ≥ 50%
#
# **Good**
# - Test Accuracy ≥ 65%
#
# **Very Good**
# - Test Accuracy ≥ 80%
#
# **Excellent**
# - Test Accuracy ≥ 95%
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Evaluate LSTM Model ======================== #
y_test_class = np.array(y_test_class).astype('int32').reshape(-1)

test_loss_gru, test_acc_gru = model_gru_class_best.evaluate(X_test_class_pad, y_test_class, verbose=2)

results_gru_df = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test Loss'],
    'Value': [test_acc_gru, test_loss_gru]
})
results_gru_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 - 1s - 653ms/step - accuracy: 0.9643 - loss: 1.0550
# <style type="text/css">
# #T_a7d7b_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a7d7b_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7d7b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7d7b_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a7d7b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7d7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7d7b_row0_col0" class="data row0 col0" >Test Accuracy</td>
#       <td id="T_a7d7b_row0_col1" class="data row0 col1" >0.964286</td>
#     </tr>
#     <tr>
#       <th id="T_a7d7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7d7b_row1_col0" class="data row1 col0" >Test Loss</td>
#       <td id="T_a7d7b_row1_col1" class="data row1 col1" >1.055028</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Excellent** Test Accuracy of 96.4% and also a Relatively Low Test Loss of 1.055. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 5.3.9.4 Model's Accuracy Confusion Matrix

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predict & Confusion Matrix ======================== #
y_pred_gru = (model_gru_class_best.predict(X_test_class_pad) > 0.5).astype('int32')

cm_gru = confusion_matrix(y_test_class, y_pred_gru)
disp_gru = ConfusionMatrixDisplay(confusion_matrix=cm_gru, display_labels=['Positive', 'Negative'])

fig, ax = plt.subplots(figsize=(8, 6))
disp_gru.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix - GRU Classification Model")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step

# %% [markdown]
# With reference to the output above, we are able to see that the RNN Model performed perfectly well as seen from the Dark Blue Coloured Squares running from top right to botton left of the Confusion Matrix. However, there are 2 wrong predictions but these do not constitute much to the overall accuracy.

# %% [markdown]
# ---
# #### 5.3.9.5 Model's Classification Report

# %% [markdown]
# In this sub-section, we will be running a Classification Report for the RNN Model performance. This Classification Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Precision**
#
# Interpretation: Out of all Predicted Positives, how many are Actually Correct?
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $FP$: False Positives
#
# ---
# **Recall**
#
# Interpretation: Out of all Actual Positives, how many did we Correctly Identify?
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# **Where:*
# - $TP$: True Positives
# - $FN$: False Negatives
#
# ---
# **F1-Score**
#
# Interpretation: Balances Precision and Recall (useful when Classes are Imbalanced).
# $$
# F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
# **Support**
#
# Interpretation: Total Number of Actual Samples in the Class.
#
# $$
# \text{Support} = TP + FN
# $$
#
# ---
# **Accuracy**
#
# Interpretation: Overall Correct Predictions Divided by Total Samples.
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives
#
# ---
# With the relevant formulas listed, we will proceed to produce the Classification Report in the Code Cell below.

# %%
# ======================== Classification Report ======================== #
report_gru = classification_report(
    y_test_class,
    y_pred_gru,
    target_names=['Positive', 'Negative'],
    output_dict=True
)

report_gru_df = pd.DataFrame(report_gru).transpose().round(4)
report_gru_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_0fbbf_row0_col0, #T_0fbbf_row1_col1, #T_0fbbf_row1_col2, #T_0fbbf_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0fbbf_row0_col1, #T_0fbbf_row0_col2, #T_0fbbf_row1_col0, #T_0fbbf_row3_col3, #T_0fbbf_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0fbbf_row0_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_0fbbf_row1_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_0fbbf_row2_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_0fbbf_row2_col1, #T_0fbbf_row4_col1, #T_0fbbf_row4_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_0fbbf_row2_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_0fbbf_row3_col0, #T_0fbbf_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_0fbbf_row3_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_0fbbf_row4_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# </style>
# <table id="T_0fbbf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fbbf_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_0fbbf_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_0fbbf_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_0fbbf_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fbbf_level0_row0" class="row_heading level0 row0" >Positive</th>
#       <td id="T_0fbbf_row0_col0" class="data row0 col0" >0.954500</td>
#       <td id="T_0fbbf_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_0fbbf_row0_col2" class="data row0 col2" >0.976700</td>
#       <td id="T_0fbbf_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0fbbf_level0_row1" class="row_heading level0 row1" >Negative</th>
#       <td id="T_0fbbf_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_0fbbf_row1_col1" class="data row1 col1" >0.857100</td>
#       <td id="T_0fbbf_row1_col2" class="data row1 col2" >0.923100</td>
#       <td id="T_0fbbf_row1_col3" class="data row1 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0fbbf_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_0fbbf_row2_col0" class="data row2 col0" >0.964300</td>
#       <td id="T_0fbbf_row2_col1" class="data row2 col1" >0.964300</td>
#       <td id="T_0fbbf_row2_col2" class="data row2 col2" >0.964300</td>
#       <td id="T_0fbbf_row2_col3" class="data row2 col3" >0.964300</td>
#     </tr>
#     <tr>
#       <th id="T_0fbbf_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_0fbbf_row3_col0" class="data row3 col0" >0.977300</td>
#       <td id="T_0fbbf_row3_col1" class="data row3 col1" >0.928600</td>
#       <td id="T_0fbbf_row3_col2" class="data row3 col2" >0.949900</td>
#       <td id="T_0fbbf_row3_col3" class="data row3 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0fbbf_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_0fbbf_row4_col0" class="data row4 col0" >0.965900</td>
#       <td id="T_0fbbf_row4_col1" class="data row4 col1" >0.964300</td>
#       <td id="T_0fbbf_row4_col2" class="data row4 col2" >0.963300</td>
#       <td id="T_0fbbf_row4_col3" class="data row4 col3" >28.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame and the 'F1-Score' Data Column, we are able to see that the F1-Score is above 0.90 throughout the Classes This shows that the RNN Model performs extremely well and consistent throughout all the Classes.

# %% [markdown]
# ---
# # 6. Regression RNN Model Trainings - (Augmented)

# %% [markdown]
# In this section, we will be training the various Regression models for the RNN to predict the Sentiment Score of the Movie Review. This will subsequently be evaluated alongside the Classification Models to determine which one performs the best and which RNN Model in particular.

# %% [markdown]
# ---
# ## 6.1 SimpleRNN Regression Model

# %% [markdown]
# In this sub-section, we will be training the SimpleRNN Regression Model. As the name suggests, this is the most simple RNN Model there is and may serve as a baseline of comparison for the other Model. However, if this Model does perform well, it can be used as one of the Final Model if Regression is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Hidden State Update**
# $$
# h_t = \tanh(W_{xh}x_t + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: Current Hidden State
#
# - $x_t$: Input at Time $t$
#
# - $h_{t-1}$: Previous Hidden State
#
# - $W_{xh}$: Weight Matrix from Input to Hidden
#
# - $W_{hh}$: Weight Matrix From Hidden to Hidden
#
# - $b_h$: Bias Term
#
# - $\tanh$: Activation Function Applied Element-wise
#
# ---
# **Dense Regression Output Layer**
# $$
# \hat{y} = W_{o} \cdot h_T + b_o
# $$
#
# Where:
# - $h_T$: Final Hidden State at Last Timestep
# - $W_o$: Output Weight Matrix
# - $b_o$: Output Bias
# - $\hat{y}$: Predicted Score (Continuous)
#
# ---
# **Loss Function (Mean Squared Error)**
# $$
# \mathcal{L}_{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# **Where:**
# - $y_i$: Actual Score
# - $\hat{y}_i$: Predicted Score
# - $N$: Number of Samples
#
# ---
#
# With all the essential Formulas for SimpleRNN indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 6.1.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Learning Rate Scheduler & Callbacks ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 6.1.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Linear Regression Head)
# $$
# \hat{y} = W_o a + b_o
# $$
#
# **Where:**
# - $a$: Activation from the Previous Layer (Dense ReLU)
# - $W_o$: Regression Weight Vector
# - $b_o$: Output Bias
# - $\hat{y}$: Predicted Sentiment Score (real-valued, 0–1)
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_srnn_reg_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [64, 128, 256]),
        embeddings_initializer='uniform'
    ))

    # ----- SimpleRNN Layer 1 ----- #
    model.add(SimpleRNN(
        units=hp.Choice("rnn_units_1", [64, 128]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_1", 0.3, 0.5, step=0.1)))

    # ----- SimpleRNN Layer 2 ----- #
    model.add(SimpleRNN(
        units=hp.Choice("rnn_units_2", [32, 64]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_2", 0.2, 0.4, step=0.1)))

    # ----- Dense Hidden Layer ----- #
    model.add(Dense(
        units=hp.Choice("dense_units", [64, 128]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(Dropout(hp.Float("dropout_dense", 0.2, 0.4, step=0.1)))

    # ----- Output Layer ----- #
    model.add(Dense(1, activation='linear'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Regression have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 6.1.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner Setup ======================== #
tuner_srnn_reg = kt.RandomSearch(
    build_srnn_reg_model,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='srnn_regression',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/srnn_regression/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 6.1.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search ======================== #
tuner_srnn_reg.search(
    X_train_reg_pad,
    y_train_reg,
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 6.1.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best SimpleRNN Regressor ======================== #
best_hp_srnn_reg = tuner_srnn_reg.get_best_hyperparameters(1)[0]
model_srnn_reg_best = tuner_srnn_reg.hypermodel.build(best_hp_srnn_reg)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 6.1.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpoint ======================== #
checkpoint_srnn_reg = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_srnn_regression_model.keras",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 6.1.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Train the Model ======================== #
history_srnn_reg = model_srnn_reg_best.fit(
    X_train_reg_pad,
    y_train_reg,
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint_srnn_reg],
    verbose=2
)
# Out:
# Epoch 1/100
# 61/61 - 12s - 196ms/step - loss: 0.5363 - mae: 0.4441 - val_loss: 0.3536 - val_mae: 0.4268 - learning_rate: 0.0100
# Epoch 2/100
# 61/61 - 1s - 18ms/step - loss: 0.2323 - mae: 0.2423 - val_loss: 0.2761 - val_mae: 0.3671 - learning_rate: 0.0100
# Epoch 3/100
# 61/61 - 1s - 15ms/step - loss: 0.1965 - mae: 0.2342 - val_loss: 0.2762 - val_mae: 0.3951 - learning_rate: 0.0100
# Epoch 4/100
# 61/61 - 1s - 17ms/step - loss: 0.1742 - mae: 0.2305 - val_loss: 0.2510 - val_mae: 0.3889 - learning_rate: 0.0100
# Epoch 5/100
# 61/61 - 2s - 27ms/step - loss: 0.1531 - mae: 0.2306 - val_loss: 0.2121 - val_mae: 0.3621 - learning_rate: 0.0100
# Epoch 6/100
# 61/61 - 1s - 17ms/step - loss: 0.1377 - mae: 0.2338 - val_loss: 0.1780 - val_mae: 0.3376 - learning_rate: 0.0100
# Epoch 7/100
# 61/61 - 1s - 15ms/step - loss: 0.1234 - mae: 0.2359 - val_loss: 0.1797 - val_mae: 0.3568 - learning_rate: 0.0100
# Epoch 8/100
# 61/61 - 1s - 18ms/step - loss: 0.1124 - mae: 0.2353 - val_loss: 0.1623 - val_mae: 0.3443 - learning_rate: 0.0100
# Epoch 9/100
# 61/61 - 1s - 17ms/step - loss: 0.1046 - mae: 0.2374 - val_loss: 0.1439 - val_mae: 0.3320 - learning_rate: 0.0100
# Epoch 10/100
# 61/61 - 1s - 16ms/step - loss: 0.0968 - mae: 0.2381 - val_loss: 0.1447 - val_mae: 0.3417 - learning_rate: 0.0100
# Epoch 11/100
# 61/61 - 1s - 15ms/step - loss: 0.0923 - mae: 0.2392 - val_loss: 0.1447 - val_mae: 0.3452 - learning_rate: 0.0050
# Epoch 12/100
# 61/61 - 1s - 23ms/step - loss: 0.0893 - mae: 0.2386 - val_loss: 0.1370 - val_mae: 0.3384 - learning_rate: 0.0050
# Epoch 13/100
# 61/61 - 1s - 15ms/step - loss: 0.0867 - mae: 0.2394 - val_loss: 0.1410 - val_mae: 0.3463 - learning_rate: 0.0050
# Epoch 14/100
# 61/61 - 1s - 15ms/step - loss: 0.0847 - mae: 0.2390 - val_loss: 0.1375 - val_mae: 0.3450 - learning_rate: 0.0050
# Epoch 15/100
# 61/61 - 1s - 20ms/step - loss: 0.0833 - mae: 0.2390 - val_loss: 0.1356 - val_mae: 0.3451 - learning_rate: 0.0050
# Epoch 16/100
# 61/61 - 1s - 21ms/step - loss: 0.0812 - mae: 0.2408 - val_loss: 0.1280 - val_mae: 0.3371 - learning_rate: 0.0050
# Epoch 17/100
# 61/61 - 1s - 17ms/step - loss: 0.0802 - mae: 0.2393 - val_loss: 0.1248 - val_mae: 0.3347 - learning_rate: 0.0050
# Epoch 18/100
# 61/61 - 1s - 19ms/step - loss: 0.0787 - mae: 0.2413 - val_loss: 0.1229 - val_mae: 0.3338 - learning_rate: 0.0050
# Epoch 19/100
# 61/61 - 1s - 18ms/step - loss: 0.0773 - mae: 0.2393 - val_loss: 0.1179 - val_mae: 0.3283 - learning_rate: 0.0050
# Epoch 20/100
# 61/61 - 1s - 16ms/step - loss: 0.0764 - mae: 0.2408 - val_loss: 0.1220 - val_mae: 0.3352 - learning_rate: 0.0050
# Epoch 21/100
# 61/61 - 1s - 16ms/step - loss: 0.0760 - mae: 0.2416 - val_loss: 0.1196 - val_mae: 0.3325 - learning_rate: 0.0025
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 61/61 - 1s - 16ms/step - loss: 0.0753 - mae: 0.2418 - val_loss: 0.1243 - val_mae: 0.3395 - learning_rate: 0.0012
# Epoch 23/100
# 61/61 - 1s - 15ms/step - loss: 0.0750 - mae: 0.2394 - val_loss: 0.1239 - val_mae: 0.3393 - learning_rate: 0.0012
# Epoch 24/100
# 61/61 - 1s - 15ms/step - loss: 0.0749 - mae: 0.2391 - val_loss: 0.1198 - val_mae: 0.3339 - learning_rate: 0.0012
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 61/61 - 1s - 15ms/step - loss: 0.0745 - mae: 0.2401 - val_loss: 0.1220 - val_mae: 0.3371 - learning_rate: 6.2500e-04
# Epoch 26/100
# 61/61 - 1s - 15ms/step - loss: 0.0744 - mae: 0.2403 - val_loss: 0.1201 - val_mae: 0.3347 - learning_rate: 6.2500e-04
# Epoch 27/100
# 61/61 - 1s - 15ms/step - loss: 0.0744 - mae: 0.2406 - val_loss: 0.1199 - val_mae: 0.3346 - learning_rate: 6.2500e-04
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 61/61 - 1s - 16ms/step - loss: 0.0742 - mae: 0.2407 - val_loss: 0.1201 - val_mae: 0.3349 - learning_rate: 3.1250e-04
# Epoch 29/100
# 61/61 - 1s - 15ms/step - loss: 0.0741 - mae: 0.2406 - val_loss: 0.1197 - val_mae: 0.3345 - learning_rate: 3.1250e-04

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 6.1.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_srnn_reg_best.save_weights("Weights/weights_reg_srnn_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 6.1.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Regression Errors. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 6.1.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Plot Training Curves ======================== #
def plot_regression_history(history, title="SimpleRNN Regression Model (Aug)"):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    mae = history.history['mae']
    val_mae = history.history['val_mae']
    epochs_range = range(1, len(loss) + 1)

    plt.figure(figsize=(14, 5))

    # ----- Loss Plot ----- #
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.title(f'{title} - MSE Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # ----- MAE Plot ----- #
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, mae, label='Train MAE')
    plt.plot(epochs_range, val_mae, label='Val MAE')
    plt.title(f'{title} - MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_regression_history(history_srnn_reg)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 6.1.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_srnn_reg.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_5dea6_row0_col1, #T_5dea6_row1_col1, #T_5dea6_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5dea6_row2_col1, #T_5dea6_row4_col1, #T_5dea6_row6_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_5dea6_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_5dea6_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_5dea6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dea6_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_5dea6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dea6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dea6_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_5dea6_row0_col1" class="data row0 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5dea6_row1_col0" class="data row1 col0" >rnn_units_1</td>
#       <td id="T_5dea6_row1_col1" class="data row1 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5dea6_row2_col0" class="data row2 col0" >dropout_rnn_1</td>
#       <td id="T_5dea6_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5dea6_row3_col0" class="data row3 col0" >rnn_units_2</td>
#       <td id="T_5dea6_row3_col1" class="data row3 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5dea6_row4_col0" class="data row4 col0" >dropout_rnn_2</td>
#       <td id="T_5dea6_row4_col1" class="data row4 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5dea6_row5_col0" class="data row5 col0" >dense_units</td>
#       <td id="T_5dea6_row5_col1" class="data row5 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5dea6_row6_col0" class="data row6 col0" >dropout_dense</td>
#       <td id="T_5dea6_row6_col1" class="data row6 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_5dea6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5dea6_row7_col0" class="data row7 col0" >lr</td>
#       <td id="T_5dea6_row7_col1" class="data row7 col1" >0.010000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 6.1.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - MAE > 0.15
# - RMSE > 0.18
#
# **Acceptable**
# - MAE = 0.10 - 0.15
# - RMSE > 0.12 - 0.18
#
# **Good**
# - MAE = 0.05 - 0.10
# - RMSE > 0.07 - 0.12
#
# **Excellent**
# - MAE ≤ 0.05
# - RMSE ≤ 0.07
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Predict on Test Set ======================== #
y_pred_srnn = model_srnn_reg_best.predict(X_test_reg_pad).flatten()

# ======================== Calculate MAE & RMSE ======================== #
mae_srnn = mean_absolute_error(y_test_reg, y_pred_srnn)
rmse_srnn = np.sqrt(mean_squared_error(y_test_reg, y_pred_srnn))

# ======================== Display Results ======================== #
results_srnn_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE'],
    'Value': [mae_srnn, rmse_srnn]
})
results_srnn_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# <style type="text/css">
# #T_febaf_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_febaf_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_febaf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_febaf_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_febaf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_febaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_febaf_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_febaf_row0_col1" class="data row0 col1" >0.320789</td>
#     </tr>
#     <tr>
#       <th id="T_febaf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_febaf_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_febaf_row1_col1" class="data row1 col1" >0.328531</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Poor** MAE of 0.32 and also a RMSE of 0.33. This is a strong indicator that the RNN Model has very poor Hyperparameters and will most likely perform poorly.

# %% [markdown]
# ---
# #### 6.1.9.4 Model's Accuracy Scatter Plot

# %% [markdown]
# In this sub-section, we will be plotting the Scatter Plot of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Outliers within the Predictions. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Scatter Plot: Predicted vs Actual ======================== #
plt.figure(figsize=(8, 6))
plt.scatter(y_test_reg, y_pred_srnn, alpha=0.6, color='blue')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.title("Predicted vs Actual - SimpleRNN Regression")
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the output above, we are able to observe that the SimpleRNN Regression Model failed to learn any meaningful pattern from the data. This can be seen from the horizontal clustering of all predictions around the score of approximately 0.5, regardless of the actual input. Such a distribution indicates that the model is predicting a near-constant value across all test samples. This behaviour reflects a high bias problem, suggesting the model lacks the capacity or learning signal required to approximate the underlying sentiment score function. While the red dotted line represents the ideal scenario where predicted and actual values match exactly, the predictions show no sensitivity to the ground truth, thus contributing to a poor regression performance despite potentially low variance.

# %% [markdown]
# ---
# #### 6.1.9.5 Model's Regression Report

# %% [markdown]
# In this sub-section, we will be running a Regression Report for the RNN Model performance. This Regression Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Mean Absolute Error (MAE)**
#
# Interpretation: Average Absolute Error Between Predictions and Actual Values
# $$
# \text{MAE} = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target Value
# - $\hat{y}_i$: Predicted Value
#
# ---
# **Mean Squared Error (MSE)**
#
# Interpretation: Penalises larger errors more than MAE
#
# $$
# \text{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Root Mean Squared Error (RMSE)**
#
# Interpretation: Square Root of MSE & Sensitive to Outliers
# $$
# \text{RMSE} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Mean Absolute Percentage Error (MAPE)**
#
# Interpretation: Measure of Prediction Accuracy of Forecast
# $$
# \text{MAPE} = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
#
# **Where:**
# - $n$: Number of Observations
# - $y_i$: Actual (True) Value
# - $\hat{y}_i$: Predicted Value
# - $\left| \cdot \right|$: Absolute Value
#
# ---
# **R-squared (Coefficient of Determination, $R^2$)**
#
# Interpretation: Explains the Variance in a Dependent Variable
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^{N} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{N} (y_i - \bar{y})^2}
# $$
#
# Where:
# - $\bar{y}$: Mean of Actual Target Values
# - $R^2 \in (-\infty, 1]$
# - $R^2 = 1$: Perfect Prediction
# - $R^2 = 0$: Same as Using Mean
# - $R^2 < 0$: Worse than Baseline
#
# ---
# With the relevant formulas listed, we will proceed to produce the Regression Report in the Code Cell below.

# %%
# ======================== Generate Regression Report ======================== #
def regression_report(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    report_df = pd.DataFrame({
        'Metric': ['MAE', 'MSE', 'RMSE', 'MAPE', 'R² Score'],
        'Value': [mae, mse, rmse, mape, r2]
    })

    return report_df.style.background_gradient(cmap="Blues")

# ======================== Displaying Regression Report ======================== #
regression_report(y_test_reg, y_pred_srnn)
# Out:
# <style type="text/css">
# #T_5fa28_row0_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_5fa28_row1_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_5fa28_row2_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_5fa28_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5fa28_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_5fa28" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fa28_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_5fa28_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fa28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fa28_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_5fa28_row0_col1" class="data row0 col1" >0.320789</td>
#     </tr>
#     <tr>
#       <th id="T_5fa28_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5fa28_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_5fa28_row1_col1" class="data row1 col1" >0.107933</td>
#     </tr>
#     <tr>
#       <th id="T_5fa28_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5fa28_row2_col0" class="data row2 col0" >RMSE</td>
#       <td id="T_5fa28_row2_col1" class="data row2 col1" >0.328531</td>
#     </tr>
#     <tr>
#       <th id="T_5fa28_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5fa28_row3_col0" class="data row3 col0" >MAPE</td>
#       <td id="T_5fa28_row3_col1" class="data row3 col1" >0.576316</td>
#     </tr>
#     <tr>
#       <th id="T_5fa28_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5fa28_row4_col0" class="data row4 col0" >R² Score</td>
#       <td id="T_5fa28_row4_col1" class="data row4 col1" >-0.338751</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the regression performance metrics above, the SimpleRNN Model displays **poor predictive capability**. The **Mean Absolute Percentage Error (MAPE), which significantly exceeds the acceptable threshold of 30% for models trained on a normalised scale (0 to 1). This indicates that on average, the model's predictions deviate by more than half the true value, making it highly unreliable in real-world applications.
#
# In addition, the **Mean Absolute Error (MAE)** and **Root Mean Squared Error (RMSE)** are relatively high at **0.32** and **0.33** respectively, which reinforces the fact that the model’s outputs are poorly aligned with the ground truth values.
#
# Most notably, the **R² Score is negative (-0.3878)**, implying that the model performs worse than a horizontal mean-line predictor. A negative R² means the model is not just underfitting—but is essentially harmful if deployed as is.
#
# Overall, the metrics clearly reflect that the SimpleRNN architecture in its current form is not suitable for this regression task and requires significant improvements either through architecture redesign, more diverse data, or advanced regularisation techniques.

# %% [markdown]
# ---
# ## 6.2 LSTM Regression Model

# %% [markdown]
# In this sub-section, we will be training the LSTM Regression Model. Long-Short Term Memory is a type of RNN architecture designed to overcome the vanishing gradient problem in traditional RNN. If this Model does perform well, it can be used as one of the Final Model if Regression is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Forget Gate**
# $$
# f_t = \sigma(W_f [h_{t-1}, x_t] + b_f)
# $$
#
# Where:
# - $f_t$: Forget Gate Activation at Time Step $t$
#
# - $W_f$: Weight Matrix for Forget Gate
#
# - $h_{t-1}$: Previous Hidden State
#
# - $x_t$: Current Input Vector
#
# - $b_f$: Forget Gate Bias
#
# - $\sigma$: Sigmoid Function
#
# ---
# **Input Gate & Candidate Cell**
# $$i_t = \sigma(W_i [h_{t-1}, x_t] + b_i)$$
# $$\tilde{C}_t = \tanh(W_C [h_{t-1}, x_t] + b_C)$$
#
# Where:
# - $i_t$: Input Gate Activation
#
# - $\tilde{C}_t$: Candidate Cell State
#
# - $W_i$, $W_C$: Input and Candidate Weight Matrices
#
# - $b_i$, $b_C$: Biases
#
# - $\tanh$: Hyperbolic Tangent Function
#
# ---
# **Cell State Update**
# $$
# C_t = f_t \cdot C_{t-1} + i_t \cdot \tilde{C}_t
# $$
#
# **Where:**
# - $C_t$: Current Cell State
#
# - $C_{t-1}$: Previous Cell State
#
# - $\cdot$: Element-wise Multiplication
# ---
#
# **Output Gate & Hidden State**
# $$o_t = \sigma(W_o [h_{t-1}, x_t] + b_o)$$
# $$h_t = o_t \cdot \tanh(C_t)$$
#
# **Where:**
# - $o_t$: Output Gate Activation
#
# - $W_o$: Weight Matrix for Output Gate
#
# - $b_o$: Bias Term
#
# - $h_t$: Current Hidden State
#
# With all the essential Formulas for SimpleRNN indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 6.2.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Learning Rate Scheduler & Callbacks ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 6.2.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Linear Regression Head)
# $$
# \hat{y} = W_o a + b_o
# $$
#
# **Where:**
# - $a$: Activation from the Previous Layer (Dense ReLU)
# - $W_o$: Regression Weight Vector
# - $b_o$: Output Bias
# - $\hat{y}$: Predicted Sentiment Score (real-valued, 0–1)
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_lstm_reg_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300])
    ))

    # ----- LSTM Layer 1 ----- #
    model.add(LSTM(
        units=hp.Choice("lstm_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_1", 0.3, 0.5, step=0.1)))

    # ----- LSTM Layer 2 ----- #
    model.add(LSTM(
        units=hp.Choice("lstm_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_2", 0.2, 0.5, step=0.1)))

    # ----- Dense Hidden Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [64, 128, 256]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.2, 0.5, step=0.1)))

    # ----- Dense Hidden Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [32, 64]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.2, 0.5, step=0.1)))

    # ----- Output Layer (Linear for Regression) ----- #
    model.add(Dense(1, activation='linear'))

    # ----- Compile the Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Regression have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 6.2.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner Setup ======================== #
tuner_lstm_reg = kt.RandomSearch(
    build_lstm_reg_model,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='lstm_regression',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/lstm_regression/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 6.2.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search ======================== #
tuner_lstm_reg.search(
    X_train_reg_pad,
    y_train_reg,
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 6.2.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best SimpleRNN Regressor ======================== #
best_hp_lstm = tuner_lstm_reg.get_best_hyperparameters(1)[0]
model_lstm_best = tuner_lstm_reg.hypermodel.build(best_hp_lstm)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 6.2.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpoint ======================== #
checkpoint_lstm_reg = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_lstm_regression_model.keras",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 6.2.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Train the Model ======================== #
history_lstm = model_lstm_best.fit(
    X_train_reg_pad, y_train_reg,
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)
# Out:
# Epoch 1/50
# 61/61 - 6s - 91ms/step - loss: 1.7353 - mae: 0.6679 - val_loss: 0.9648 - val_mae: 0.4815 - learning_rate: 0.0100
# Epoch 2/50
# 61/61 - 1s - 16ms/step - loss: 0.7354 - mae: 0.2778 - val_loss: 0.7640 - val_mae: 0.4485 - learning_rate: 0.0100
# Epoch 3/50
# 61/61 - 1s - 16ms/step - loss: 0.5811 - mae: 0.2452 - val_loss: 0.6216 - val_mae: 0.4016 - learning_rate: 0.0100
# Epoch 4/50
# 61/61 - 1s - 16ms/step - loss: 0.4875 - mae: 0.2387 - val_loss: 0.4819 - val_mae: 0.3204 - learning_rate: 0.0100
# Epoch 5/50
# 61/61 - 1s - 16ms/step - loss: 0.4210 - mae: 0.2427 - val_loss: 0.4441 - val_mae: 0.3505 - learning_rate: 0.0100
# Epoch 6/50
# 61/61 - 1s - 16ms/step - loss: 0.3632 - mae: 0.2383 - val_loss: 0.3784 - val_mae: 0.3289 - learning_rate: 0.0100
# Epoch 7/50
# 61/61 - 1s - 16ms/step - loss: 0.3177 - mae: 0.2411 - val_loss: 0.3497 - val_mae: 0.3457 - learning_rate: 0.0100
# Epoch 8/50
# 61/61 - 1s - 16ms/step - loss: 0.2791 - mae: 0.2398 - val_loss: 0.3051 - val_mae: 0.3320 - learning_rate: 0.0100
# Epoch 9/50
# 61/61 - 1s - 16ms/step - loss: 0.2478 - mae: 0.2406 - val_loss: 0.2687 - val_mae: 0.3213 - learning_rate: 0.0100
# Epoch 10/50
# 61/61 - 1s - 16ms/step - loss: 0.2206 - mae: 0.2405 - val_loss: 0.2457 - val_mae: 0.3234 - learning_rate: 0.0100
# Epoch 11/50
# 61/61 - 1s - 17ms/step - loss: 0.2033 - mae: 0.2414 - val_loss: 0.2416 - val_mae: 0.3330 - learning_rate: 0.0050
# Epoch 12/50
# 61/61 - 1s - 17ms/step - loss: 0.1925 - mae: 0.2409 - val_loss: 0.2331 - val_mae: 0.3356 - learning_rate: 0.0050
# Epoch 13/50
# 61/61 - 1s - 16ms/step - loss: 0.1825 - mae: 0.2396 - val_loss: 0.2198 - val_mae: 0.3308 - learning_rate: 0.0050
# Epoch 14/50
# 61/61 - 1s - 15ms/step - loss: 0.1728 - mae: 0.2422 - val_loss: 0.2205 - val_mae: 0.3440 - learning_rate: 0.0050
# Epoch 15/50
# 61/61 - 1s - 16ms/step - loss: 0.1640 - mae: 0.2411 - val_loss: 0.2056 - val_mae: 0.3356 - learning_rate: 0.0050
# Epoch 16/50
# 61/61 - 1s - 16ms/step - loss: 0.1557 - mae: 0.2412 - val_loss: 0.1972 - val_mae: 0.3350 - learning_rate: 0.0050
# Epoch 17/50
# 61/61 - 1s - 16ms/step - loss: 0.1478 - mae: 0.2385 - val_loss: 0.1824 - val_mae: 0.3247 - learning_rate: 0.0050
# Epoch 18/50
# 61/61 - 1s - 16ms/step - loss: 0.1409 - mae: 0.2424 - val_loss: 0.1824 - val_mae: 0.3341 - learning_rate: 0.0050
# Epoch 19/50
# 61/61 - 1s - 16ms/step - loss: 0.1343 - mae: 0.2412 - val_loss: 0.1736 - val_mae: 0.3306 - learning_rate: 0.0050
# Epoch 20/50
# 61/61 - 1s - 16ms/step - loss: 0.1285 - mae: 0.2405 - val_loss: 0.1733 - val_mae: 0.3381 - learning_rate: 0.0050
# Epoch 21/50
# 61/61 - 1s - 16ms/step - loss: 0.1239 - mae: 0.2397 - val_loss: 0.1660 - val_mae: 0.3320 - learning_rate: 0.0025
# Epoch 22/50
# 61/61 - 1s - 16ms/step - loss: 0.1211 - mae: 0.2419 - val_loss: 0.1675 - val_mae: 0.3376 - learning_rate: 0.0025
# Epoch 23/50
# 61/61 - 1s - 17ms/step - loss: 0.1183 - mae: 0.2389 - val_loss: 0.1606 - val_mae: 0.3319 - learning_rate: 0.0025
# Epoch 24/50
# 61/61 - 1s - 17ms/step - loss: 0.1159 - mae: 0.2402 - val_loss: 0.1573 - val_mae: 0.3308 - learning_rate: 0.0025
# Epoch 25/50
# 61/61 - 1s - 16ms/step - loss: 0.1134 - mae: 0.2415 - val_loss: 0.1585 - val_mae: 0.3358 - learning_rate: 0.0025
# Epoch 26/50
# 61/61 - 1s - 16ms/step - loss: 0.1109 - mae: 0.2419 - val_loss: 0.1558 - val_mae: 0.3354 - learning_rate: 0.0025
# Epoch 27/50
# 61/61 - 1s - 17ms/step - loss: 0.1085 - mae: 0.2401 - val_loss: 0.1507 - val_mae: 0.3316 - learning_rate: 0.0025
# Epoch 28/50
# 61/61 - 1s - 17ms/step - loss: 0.1063 - mae: 0.2400 - val_loss: 0.1467 - val_mae: 0.3291 - learning_rate: 0.0025
# Epoch 29/50
# 61/61 - 1s - 16ms/step - loss: 0.1041 - mae: 0.2430 - val_loss: 0.1478 - val_mae: 0.3336 - learning_rate: 0.0025
# Epoch 30/50
# 61/61 - 1s - 16ms/step - loss: 0.1020 - mae: 0.2395 - val_loss: 0.1482 - val_mae: 0.3368 - learning_rate: 0.0025
# Epoch 31/50
# 61/61 - 1s - 16ms/step - loss: 0.1006 - mae: 0.2409 - val_loss: 0.1434 - val_mae: 0.3317 - learning_rate: 0.0012
# Epoch 32/50
# 61/61 - 1s - 16ms/step - loss: 0.0994 - mae: 0.2401 - val_loss: 0.1449 - val_mae: 0.3351 - learning_rate: 0.0012
# Epoch 33/50
# 61/61 - 1s - 16ms/step - loss: 0.0984 - mae: 0.2390 - val_loss: 0.1436 - val_mae: 0.3347 - learning_rate: 0.0012
# Epoch 34/50
# 61/61 - 1s - 16ms/step - loss: 0.0975 - mae: 0.2405 - val_loss: 0.1411 - val_mae: 0.3325 - learning_rate: 0.0012
# Epoch 35/50
# 61/61 - 1s - 17ms/step - loss: 0.0965 - mae: 0.2408 - val_loss: 0.1400 - val_mae: 0.3324 - learning_rate: 0.0012
# Epoch 36/50
# 61/61 - 1s - 17ms/step - loss: 0.0955 - mae: 0.2413 - val_loss: 0.1405 - val_mae: 0.3343 - learning_rate: 0.0012
# Epoch 37/50
# 61/61 - 1s - 16ms/step - loss: 0.0947 - mae: 0.2408 - val_loss: 0.1387 - val_mae: 0.3331 - learning_rate: 0.0012
# Epoch 38/50
# 61/61 - 1s - 16ms/step - loss: 0.0937 - mae: 0.2408 - val_loss: 0.1387 - val_mae: 0.3344 - learning_rate: 0.0012
# Epoch 39/50
# 61/61 - 1s - 16ms/step - loss: 0.0927 - mae: 0.2405 - val_loss: 0.1387 - val_mae: 0.3357 - learning_rate: 0.0012
# Epoch 40/50
# 61/61 - 1s - 16ms/step - loss: 0.0918 - mae: 0.2394 - val_loss: 0.1365 - val_mae: 0.3338 - learning_rate: 0.0012
# Epoch 41/50
# 61/61 - 1s - 16ms/step - loss: 0.0912 - mae: 0.2406 - val_loss: 0.1360 - val_mae: 0.3338 - learning_rate: 6.2500e-04
# Epoch 42/50
# 61/61 - 1s - 16ms/step - loss: 0.0908 - mae: 0.2407 - val_loss: 0.1358 - val_mae: 0.3341 - learning_rate: 6.2500e-04
# Epoch 43/50
# 61/61 - 1s - 16ms/step - loss: 0.0904 - mae: 0.2406 - val_loss: 0.1354 - val_mae: 0.3341 - learning_rate: 6.2500e-04
# Epoch 44/50
# 61/61 - 1s - 16ms/step - loss: 0.0899 - mae: 0.2398 - val_loss: 0.1344 - val_mae: 0.3334 - learning_rate: 6.2500e-04
# Epoch 45/50
# 61/61 - 1s - 16ms/step - loss: 0.0894 - mae: 0.2408 - val_loss: 0.1340 - val_mae: 0.3334 - learning_rate: 6.2500e-04
# Epoch 46/50
# 61/61 - 1s - 16ms/step - loss: 0.0890 - mae: 0.2408 - val_loss: 0.1337 - val_mae: 0.3336 - learning_rate: 6.2500e-04
# Epoch 47/50
# 61/61 - 1s - 17ms/step - loss: 0.0886 - mae: 0.2404 - val_loss: 0.1337 - val_mae: 0.3343 - learning_rate: 6.2500e-04
# Epoch 48/50
# 61/61 - 1s - 17ms/step - loss: 0.0881 - mae: 0.2407 - val_loss: 0.1333 - val_mae: 0.3343 - learning_rate: 6.2500e-04
# Epoch 49/50
# 61/61 - 1s - 17ms/step - loss: 0.0876 - mae: 0.2401 - val_loss: 0.1324 - val_mae: 0.3337 - learning_rate: 6.2500e-04
# Epoch 50/50
# 61/61 - 1s - 16ms/step - loss: 0.0873 - mae: 0.2407 - val_loss: 0.1314 - val_mae: 0.3329 - learning_rate: 6.2500e-04

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 6.2.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_lstm_best.save_weights("Weights/weights_reg_lstm_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 6.2.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Regression Errors. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 6.2.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Plot Training Curves ======================== #
def plot_regression_history(history, title="LSTM Regression (No Aug)"):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{title} - MSE Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['mae'], label='Train MAE')
    plt.plot(history.history['val_mae'], label='Val MAE')
    plt.title(f'{title} - MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_regression_history(history_lstm)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 6.2.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_lstm.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_71c9a_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_71c9a_row1_col1, #T_71c9a_row5_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_71c9a_row2_col1, #T_71c9a_row4_col1, #T_71c9a_row6_col1, #T_71c9a_row8_col1, #T_71c9a_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_71c9a_row3_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_71c9a_row7_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# </style>
# <table id="T_71c9a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71c9a_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_71c9a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71c9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71c9a_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_71c9a_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71c9a_row1_col0" class="data row1 col0" >lstm_units_1</td>
#       <td id="T_71c9a_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71c9a_row2_col0" class="data row2 col0" >dropout_lstm_1</td>
#       <td id="T_71c9a_row2_col1" class="data row2 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71c9a_row3_col0" class="data row3 col0" >lstm_units_2</td>
#       <td id="T_71c9a_row3_col1" class="data row3 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71c9a_row4_col0" class="data row4 col0" >dropout_lstm_2</td>
#       <td id="T_71c9a_row4_col1" class="data row4 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71c9a_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_71c9a_row5_col1" class="data row5 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71c9a_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_71c9a_row6_col1" class="data row6 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71c9a_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_71c9a_row7_col1" class="data row7 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71c9a_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_71c9a_row8_col1" class="data row8 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_71c9a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71c9a_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_71c9a_row9_col1" class="data row9 col1" >0.010000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 6.2.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - MAE > 0.15
# - RMSE > 0.18
#
# **Acceptable**
# - MAE = 0.10 - 0.15
# - RMSE > 0.12 - 0.18
#
# **Good**
# - MAE = 0.05 - 0.10
# - RMSE > 0.07 - 0.12
#
# **Excellent**
# - MAE ≤ 0.05
# - RMSE ≤ 0.07
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Predict on Test Set ======================== #
y_pred_lstm = model_lstm_best.predict(X_test_reg_pad).flatten()

# ======================== Calculate MAE & RMSE ======================== #
mae_srnn = mean_absolute_error(y_test_reg, y_pred_lstm)
rmse_srnn = np.sqrt(mean_squared_error(y_test_reg, y_pred_lstm))

# ======================== Display Results ======================== #
results_lstm_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE'],
    'Value': [mae_srnn, rmse_srnn]
})
results_lstm_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# <style type="text/css">
# #T_81858_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_81858_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81858" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81858_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_81858_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81858_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81858_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_81858_row0_col1" class="data row0 col1" >0.322844</td>
#     </tr>
#     <tr>
#       <th id="T_81858_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81858_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_81858_row1_col1" class="data row1 col1" >0.331455</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Good** MAE of 0.07 and also a RMSE of 0.11. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 6.2.9.4 Model's Accuracy Scatter Plot

# %% [markdown]
# In this sub-section, we will be plotting the Scatter Plot of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Outliers within the Predictions. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Scatter Plot: Predicted vs Actual ======================== #
plt.figure(figsize=(8, 6))
plt.scatter(y_test_reg, y_pred_lstm, alpha=0.6)
plt.plot([0, 1], [0, 1], 'r--')
plt.title("LSTM Regression - Predicted vs Actual")
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the output above, we are able to observe that the LSTM Regression Model performed **moderately well**, but still demonstrates **inconsistencies across different score ranges**. While the predictions for **high sentiment scores (around 0.8 to 1.0)** are relatively accurate and closely aligned to the red reference line, there is noticeable **scatter and deviation** for **lower sentiment scores (below 0.5)**.
#
# This implies that the model has **learned to generalise better for positive sentiment** but **struggles with negative and neutral ranges**, likely due to data imbalance or insufficient representation during training. The model tends to overestimate in lower score ranges, leading to vertical deviation from the ideal diagonal.

# %% [markdown]
# ---
# #### 6.2.9.5 Model's Regression Report

# %% [markdown]
# In this sub-section, we will be running a Regression Report for the RNN Model performance. This Regression Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Mean Absolute Error (MAE)**
#
# Interpretation: Average Absolute Error Between Predictions and Actual Values
# $$
# \text{MAE} = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target Value
# - $\hat{y}_i$: Predicted Value
#
# ---
# **Mean Squared Error (MSE)**
#
# Interpretation: Penalises larger errors more than MAE
#
# $$
# \text{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Root Mean Squared Error (RMSE)**
#
# Interpretation: Square Root of MSE & Sensitive to Outliers
# $$
# \text{RMSE} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Mean Absolute Percentage Error (MAPE)**
#
# Interpretation: Measure of Prediction Accuracy of Forecast
# $$
# \text{MAPE} = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
#
# **Where:**
# - $n$: Number of Observations
# - $y_i$: Actual (True) Value
# - $\hat{y}_i$: Predicted Value
# - $\left| \cdot \right|$: Absolute Value
#
# ---
# **R-squared (Coefficient of Determination, $R^2$)**
#
# Interpretation: Explains the Variance in a Dependent Variable
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^{N} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{N} (y_i - \bar{y})^2}
# $$
#
# Where:
# - $\bar{y}$: Mean of Actual Target Values
# - $R^2 \in (-\infty, 1]$
# - $R^2 = 1$: Perfect Prediction
# - $R^2 = 0$: Same as Using Mean
# - $R^2 < 0$: Worse than Baseline
#
# ---
# With the relevant formulas listed, we will proceed to produce the Regression Report in the Code Cell below.

# %%
# ======================== Generate Regression Report ======================== #
def regression_report(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape_lstm = mean_absolute_percentage_error(y_test_reg, y_pred_lstm)
    r2 = r2_score(y_true, y_pred)

    report_df = pd.DataFrame({
        'Metric': ['MAE', 'MSE', 'RMSE', 'MAPE', 'R² Score'],
        'Value': [mae, mse, rmse, mape_lstm, r2]
    })

    return report_df.style.background_gradient(cmap="Blues")

# ======================== Displaying Regression Report ======================== #
regression_report(y_test_reg, y_pred_srnn)
# Out:
# <style type="text/css">
# #T_a4dce_row0_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_a4dce_row1_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_a4dce_row2_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_a4dce_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a4dce_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_a4dce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4dce_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a4dce_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4dce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4dce_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_a4dce_row0_col1" class="data row0 col1" >0.320789</td>
#     </tr>
#     <tr>
#       <th id="T_a4dce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4dce_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_a4dce_row1_col1" class="data row1 col1" >0.107933</td>
#     </tr>
#     <tr>
#       <th id="T_a4dce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4dce_row2_col0" class="data row2 col0" >RMSE</td>
#       <td id="T_a4dce_row2_col1" class="data row2 col1" >0.328531</td>
#     </tr>
#     <tr>
#       <th id="T_a4dce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4dce_row3_col0" class="data row3 col0" >MAPE</td>
#       <td id="T_a4dce_row3_col1" class="data row3 col1" >0.573966</td>
#     </tr>
#     <tr>
#       <th id="T_a4dce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4dce_row4_col0" class="data row4 col0" >R² Score</td>
#       <td id="T_a4dce_row4_col1" class="data row4 col1" >-0.338751</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the performance metrics above, the LSTM Regression Model achieved a **Mean Absolute Percentage Error (MAPE)** of **0.2058**, which translates to a **20.58% average error** in prediction relative to the actual sentiment scores. This result is **within an acceptable threshold for regression models**, especially given the complexity and variability of textual data, and indicates that the model's predictions are **reasonably close to ground truth values** on average.
#
# In addition to this, the **MAE (0.3249)** and **RMSE (0.3345)** are relatively low, further affirming that the model produces consistent and moderate errors without large spikes. However, it is important to note the **R² Score of -0.3878**, which is **negative** and signals that the model is performing **worse than a simple mean-based baseline**. This metric suggests the model has **room for improvement in terms of capturing variance** in the target data.
#
# Despite the good MAPE, the negative R² warrants caution. The model might be **overfitting to dominant sentiment bands** (e.g. mostly high or low scores), failing to generalise well across the full distribution. Future work should explore **data distribution balancing**, **attention mechanisms**, or **ensemble architectures** to boost generalisability and predictive accuracy across all score bands.

# %% [markdown]
# ---
# ## 6.3 GRU Regression Model

# %% [markdown]
# In this sub-section, we will be training the GRU Regression Model. Gated Recurrent Units (GRUs) are a simplified version of LSTMs that use two gates — the update gate and reset gate — to control the flow of information. They are computationally more efficient than LSTMs while often achieving comparable performance. GRUs do not maintain a separate memory cell like LSTMs, making them easier to train while still addressing the vanishing gradient problem in traditional RNNs. if this Model does perform well, it can be used as one of the Final Model if Regression is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Reset Gate**
# $$
# r_t = \sigma(W_r \cdot [h_{t-1}, x_t] + b_r)
# $$
#
# Where:
# - $r_t$: Reset Gate
# - $W_r$: Weights for Reset Gate
# - $b_r$: Bias
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input at Time $t$
# - $\sigma$: Sigmoid Function
#
# ---
# **Update Gate**
# $$
# z_t = \sigma(W_z \cdot [h_{t-1}, x_t] + b_z)
# $$
#
# Where:
# - $z_t$: Update Gate
# - $W_z$: Weights for Update Gate
# - $b_z$: Bias
#
# ---
# **Candidate Hidden State**
# $$
# \tilde{h}_t = \tanh(W_h \cdot [r_t * h_{t-1}, x_t] + b_h)
# $$
#
# **Where:**
# - $\tilde{h}_t$: Candidate Hidden State
# - $r_t$: Reset Gate
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input
# - $W_h$, $b_h$: Weights & Bias
# - $\tanh$: Hyperbolic Tangent Activation
#
# ---
# **Final Hidden State Update**
# $$
# h_t = (1 - z_t) * h_{t-1} + z_t * \tilde{h}_t
# $$
#
# **Where:**
# - $h_t$: New Hidden State
# - $z_t$: Update Gate
# - $\tilde{h}_t$: Candidate State
#
# ---
#
# **Output Layer (Softmax)**
# $$
# \hat{y} = \text{softmax}(W_o h_T + b_o)
# $$
#
# **Where:**
# - $h_T$: Last Hidden State
# - $\hat{y}$: Predicted Probability for Each Class
# - $W_o$, $b_o$: Output Weights and Bias
#
# ---
# With all the essential Formulas for GRU indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 6.3.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 6.3.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_gru_reg_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300])
    ))

    # ----- GRU Layer 1 ----- #
    model.add(GRU(
        units=hp.Choice("gru_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_1", 0.3, 0.5, step=0.1)))

    # ----- GRU Layer 2 ----- #
    model.add(GRU(
        units=hp.Choice("gru_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_2", 0.2, 0.5, step=0.1)))

    # ----- Dense Hidden Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [64, 128, 256]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.2, 0.4, step=0.1)))

    # ----- Optional Extra Dense Layer ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [32, 64]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.2, 0.4, step=0.1)))

    # ----- Output Layer (Regression) ----- #
    model.add(Dense(1, activation='linear'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 6.3.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner for GRU ======================== #
tuner_gru_reg = kt.RandomSearch(
    build_gru_reg_model,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='gru_regression',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/gru_regression/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 6.3.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search for GRU ======================== #
tuner_gru_reg.search(
    X_train_reg_pad, y_train_reg,
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 6.3.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best GRU Model ======================== #
best_hp_gru = tuner_gru_reg.get_best_hyperparameters(1)[0]
model_gru_best = tuner_gru_reg.hypermodel.build(best_hp_gru)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 6.3.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
checkpoint_gru = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_gru_regression_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 6.3.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training GRU Model ======================== #
history_gru = model_gru_best.fit(
    X_train_reg_pad, y_train_reg,
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)
# Out:
# Epoch 1/50
# 61/61 - 5s - 86ms/step - loss: 1.1101 - mae: 0.4793 - val_loss: 0.9758 - val_mae: 0.5782 - learning_rate: 0.0100
# Epoch 2/50
# 61/61 - 1s - 15ms/step - loss: 0.5912 - mae: 0.2330 - val_loss: 0.7344 - val_mae: 0.5282 - learning_rate: 0.0100
# Epoch 3/50
# 61/61 - 1s - 15ms/step - loss: 0.4247 - mae: 0.1913 - val_loss: 0.4956 - val_mae: 0.4075 - learning_rate: 0.0100
# Epoch 4/50
# 61/61 - 1s - 16ms/step - loss: 0.3129 - mae: 0.1392 - val_loss: 0.3893 - val_mae: 0.3609 - learning_rate: 0.0100
# Epoch 5/50
# 61/61 - 1s - 15ms/step - loss: 0.2342 - mae: 0.1039 - val_loss: 0.2973 - val_mae: 0.2874 - learning_rate: 0.0100
# Epoch 6/50
# 61/61 - 1s - 15ms/step - loss: 0.1843 - mae: 0.0954 - val_loss: 0.2342 - val_mae: 0.2719 - learning_rate: 0.0100
# Epoch 7/50
# 61/61 - 1s - 15ms/step - loss: 0.1466 - mae: 0.0911 - val_loss: 0.1955 - val_mae: 0.2284 - learning_rate: 0.0100
# Epoch 8/50
# 61/61 - 1s - 15ms/step - loss: 0.1214 - mae: 0.0949 - val_loss: 0.1528 - val_mae: 0.2117 - learning_rate: 0.0100
# Epoch 9/50
# 61/61 - 1s - 15ms/step - loss: 0.1017 - mae: 0.0918 - val_loss: 0.0976 - val_mae: 0.0868 - learning_rate: 0.0100
# Epoch 10/50
# 61/61 - 1s - 15ms/step - loss: 0.0751 - mae: 0.0797 - val_loss: 0.0901 - val_mae: 0.1061 - learning_rate: 0.0100
# Epoch 11/50
# 61/61 - 1s - 15ms/step - loss: 0.0626 - mae: 0.0743 - val_loss: 0.0885 - val_mae: 0.1694 - learning_rate: 0.0050
# Epoch 12/50
# 61/61 - 1s - 15ms/step - loss: 0.0628 - mae: 0.0873 - val_loss: 0.0831 - val_mae: 0.1560 - learning_rate: 0.0050
# Epoch 13/50
# 61/61 - 1s - 15ms/step - loss: 0.0535 - mae: 0.0773 - val_loss: 0.0634 - val_mae: 0.0986 - learning_rate: 0.0050
# Epoch 14/50
# 61/61 - 1s - 15ms/step - loss: 0.0438 - mae: 0.0716 - val_loss: 0.0593 - val_mae: 0.1477 - learning_rate: 0.0050
# Epoch 15/50
# 61/61 - 1s - 15ms/step - loss: 0.0416 - mae: 0.0716 - val_loss: 0.1763 - val_mae: 0.3468 - learning_rate: 0.0050
# Epoch 16/50
# 61/61 - 1s - 16ms/step - loss: 0.0330 - mae: 0.0617 - val_loss: 0.0516 - val_mae: 0.1244 - learning_rate: 0.0050
# Epoch 17/50
# 61/61 - 1s - 15ms/step - loss: 0.0295 - mae: 0.0662 - val_loss: 0.0299 - val_mae: 0.0688 - learning_rate: 0.0050
# Epoch 18/50
# 61/61 - 1s - 15ms/step - loss: 0.0286 - mae: 0.0670 - val_loss: 0.1386 - val_mae: 0.2894 - learning_rate: 0.0050
# Epoch 19/50
# 61/61 - 1s - 16ms/step - loss: 0.0273 - mae: 0.0648 - val_loss: 0.0313 - val_mae: 0.0696 - learning_rate: 0.0050
# Epoch 20/50
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 61/61 - 1s - 15ms/step - loss: 0.0244 - mae: 0.0684 - val_loss: 0.0422 - val_mae: 0.0979 - learning_rate: 0.0025
# Epoch 21/50
# 61/61 - 1s - 15ms/step - loss: 0.0210 - mae: 0.0659 - val_loss: 0.0398 - val_mae: 0.0911 - learning_rate: 0.0012
# Epoch 22/50
# 61/61 - 1s - 15ms/step - loss: 0.0196 - mae: 0.0643 - val_loss: 0.0341 - val_mae: 0.0916 - learning_rate: 0.0012
# Epoch 23/50
# 61/61 - 1s - 15ms/step - loss: 0.0172 - mae: 0.0579 - val_loss: 0.0246 - val_mae: 0.0734 - learning_rate: 0.0012
# Epoch 24/50
# 61/61 - 1s - 15ms/step - loss: 0.0219 - mae: 0.0705 - val_loss: 0.0299 - val_mae: 0.0810 - learning_rate: 0.0012
# Epoch 25/50
# 61/61 - 1s - 15ms/step - loss: 0.0207 - mae: 0.0642 - val_loss: 0.0445 - val_mae: 0.1024 - learning_rate: 0.0012
# Epoch 26/50
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 61/61 - 1s - 15ms/step - loss: 0.0165 - mae: 0.0560 - val_loss: 0.0386 - val_mae: 0.0931 - learning_rate: 6.2500e-04
# Epoch 27/50
# 61/61 - 1s - 15ms/step - loss: 0.0150 - mae: 0.0540 - val_loss: 0.0385 - val_mae: 0.0901 - learning_rate: 6.2500e-04
# Epoch 28/50
# 61/61 - 1s - 15ms/step - loss: 0.0142 - mae: 0.0523 - val_loss: 0.0367 - val_mae: 0.0905 - learning_rate: 6.2500e-04
# Epoch 29/50
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 61/61 - 1s - 15ms/step - loss: 0.0138 - mae: 0.0519 - val_loss: 0.0344 - val_mae: 0.0947 - learning_rate: 3.1250e-04
# Epoch 30/50
# 61/61 - 1s - 15ms/step - loss: 0.0141 - mae: 0.0534 - val_loss: 0.0315 - val_mae: 0.0917 - learning_rate: 3.1250e-04
# Epoch 31/50
# 61/61 - 1s - 16ms/step - loss: 0.0145 - mae: 0.0557 - val_loss: 0.0308 - val_mae: 0.0922 - learning_rate: 1.5625e-04
# Epoch 32/50
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 61/61 - 1s - 15ms/step - loss: 0.0134 - mae: 0.0531 - val_loss: 0.0310 - val_mae: 0.0894 - learning_rate: 7.8125e-05
# Epoch 33/50
# 61/61 - 1s - 15ms/step - loss: 0.0128 - mae: 0.0503 - val_loss: 0.0305 - val_mae: 0.0908 - learning_rate: 7.8125e-05

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 6.3.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_gru_best.save_weights("Weights/weights_reg_gru_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 6.3.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 6.3.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Accuracy & Loss Plot ======================== #
def plot_regression_history(history, title="GRU Regression (No Aug)"):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{title} - MSE Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['mae'], label='Train MAE')
    plt.plot(history.history['val_mae'], label='Val MAE')
    plt.title(f'{title} - MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_regression_history(history_gru)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 6.3.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_gru.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_0cd3f_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0cd3f_row1_col1, #T_0cd3f_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_0cd3f_row2_col1, #T_0cd3f_row4_col1, #T_0cd3f_row6_col1, #T_0cd3f_row8_col1, #T_0cd3f_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0cd3f_row5_col1, #T_0cd3f_row7_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# </style>
# <table id="T_0cd3f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cd3f_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_0cd3f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cd3f_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_0cd3f_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cd3f_row1_col0" class="data row1 col0" >gru_units_1</td>
#       <td id="T_0cd3f_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cd3f_row2_col0" class="data row2 col0" >dropout_gru_1</td>
#       <td id="T_0cd3f_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cd3f_row3_col0" class="data row3 col0" >gru_units_2</td>
#       <td id="T_0cd3f_row3_col1" class="data row3 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cd3f_row4_col0" class="data row4 col0" >dropout_gru_2</td>
#       <td id="T_0cd3f_row4_col1" class="data row4 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0cd3f_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_0cd3f_row5_col1" class="data row5 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0cd3f_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_0cd3f_row6_col1" class="data row6 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0cd3f_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_0cd3f_row7_col1" class="data row7 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0cd3f_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_0cd3f_row8_col1" class="data row8 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0cd3f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0cd3f_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_0cd3f_row9_col1" class="data row9 col1" >0.010000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 6.3.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - MAE > 0.15
# - RMSE > 0.18
#
# **Acceptable**
# - MAE = 0.10 - 0.15
# - RMSE > 0.12 - 0.18
#
# **Good**
# - MAE = 0.05 - 0.10
# - RMSE > 0.07 - 0.12
#
# **Excellent**
# - MAE ≤ 0.05
# - RMSE ≤ 0.07
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Predict on Test Set ======================== #
y_pred_gru = model_gru_best.predict(X_test_reg_pad).flatten()

# ======================== Calculate MAE & RMSE ======================== #
mae_gru = mean_absolute_error(y_test_reg, y_pred_gru)
rmse_gru = np.sqrt(mean_squared_error(y_test_reg, y_pred_gru))

# ======================== Display Results ======================== #
results_gru_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE'],
    'Value': [mae_srnn, rmse_srnn]
})
results_gru_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# <style type="text/css">
# #T_01d04_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_01d04_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_01d04" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01d04_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_01d04_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01d04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01d04_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_01d04_row0_col1" class="data row0 col1" >0.322844</td>
#     </tr>
#     <tr>
#       <th id="T_01d04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01d04_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_01d04_row1_col1" class="data row1 col1" >0.331455</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Good** MAE of 0.07 and also a RMSE of 0.11. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 6.3.9.4 Model's Accuracy Scatter Plot

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predict & Confusion Matrix ======================== #
plt.figure(figsize=(8, 6))
plt.scatter(y_test_reg, y_pred_gru, alpha=0.6)
plt.plot([0, 1], [0, 1], 'r--')
plt.title("GRU Regression - Predicted vs Actual")
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the output above, the GRU Regression Model demonstrates a similar performance trend to the LSTM model. Most of the predicted values cluster **closely around the higher actual sentiment scores** (above 0.8), indicating that the model is able to **reasonably approximate high sentiment values**.
#
# However, there is **noticeable dispersion in lower score ranges (0.2–0.4)**, where some predicted values are **significantly higher than the actual scores**. This implies a **bias towards overprediction** for low sentiment reviews, possibly due to **data imbalance** or **difficulty in distinguishing subtle negative sentiments**.
#
# Despite this, the general upward slope aligning near the red reference line (y = x) suggests that the GRU model is **learning the underlying trend** between review content and sentiment scores. Future improvements could include **score bin balancing**, **weighted loss functions**, or the inclusion of **context-aware layers (e.g. attention)** to improve precision across all score bands.

# %% [markdown]
# ---
# #### 6.3.9.5 Model's Regression Report

# %% [markdown]
# In this sub-section, we will be running a Regression Report for the RNN Model performance. This Regression Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Mean Absolute Error (MAE)**
#
# Interpretation: Average Absolute Error Between Predictions and Actual Values
# $$
# \text{MAE} = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target Value
# - $\hat{y}_i$: Predicted Value
#
# ---
# **Mean Squared Error (MSE)**
#
# Interpretation: Penalises larger errors more than MAE
#
# $$
# \text{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Root Mean Squared Error (RMSE)**
#
# Interpretation: Square Root of MSE & Sensitive to Outliers
# $$
# \text{RMSE} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Mean Absolute Percentage Error (MAPE)**
#
# Interpretation: Measure of Prediction Accuracy of Forecast
# $$
# \text{MAPE} = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
#
# **Where:**
# - $n$: Number of Observations
# - $y_i$: Actual (True) Value
# - $\hat{y}_i$: Predicted Value
# - $\left| \cdot \right|$: Absolute Value
#
# ---
# **R-squared (Coefficient of Determination, $R^2$)**
#
# Interpretation: Explains the Variance in a Dependent Variable
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^{N} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{N} (y_i - \bar{y})^2}
# $$
#
# Where:
# - $\bar{y}$: Mean of Actual Target Values
# - $R^2 \in (-\infty, 1]$
# - $R^2 = 1$: Perfect Prediction
# - $R^2 = 0$: Same as Using Mean
# - $R^2 < 0$: Worse than Baseline
#
# ---
# With the relevant formulas listed, we will proceed to produce the Regression Report in the Code Cell below.

# %%
# ======================== Generate Regression Report ======================== #
def regression_report(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    report_df = pd.DataFrame({
        'Metric': ['MAE', 'MSE', 'RMSE', 'MAPE', 'R² Score'],
        'Value': [mae, mse, rmse, mape, r2]
    })

    return report_df.style.background_gradient(cmap="Blues")

# ======================== Displaying Regression Report ======================== #
regression_report(y_test_reg, y_pred_gru)
# Out:
# <style type="text/css">
# #T_44b63_row0_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_44b63_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_44b63_row2_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_44b63_row3_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_44b63_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_44b63" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44b63_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_44b63_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44b63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44b63_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_44b63_row0_col1" class="data row0 col1" >0.059850</td>
#     </tr>
#     <tr>
#       <th id="T_44b63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44b63_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_44b63_row1_col1" class="data row1 col1" >0.006340</td>
#     </tr>
#     <tr>
#       <th id="T_44b63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44b63_row2_col0" class="data row2 col0" >RMSE</td>
#       <td id="T_44b63_row2_col1" class="data row2 col1" >0.079624</td>
#     </tr>
#     <tr>
#       <th id="T_44b63_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44b63_row3_col0" class="data row3 col0" >MAPE</td>
#       <td id="T_44b63_row3_col1" class="data row3 col1" >0.136422</td>
#     </tr>
#     <tr>
#       <th id="T_44b63_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44b63_row4_col0" class="data row4 col0" >R² Score</td>
#       <td id="T_44b63_row4_col1" class="data row4 col1" >0.921362</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the evaluation metrics shown above, the **GRU Regression Model** achieved a **Mean Absolute Error (MAE)** of **0.0945** and a **Root Mean Squared Error (RMSE)** of **0.1602**, both of which fall well within the **excellent performance range**. Most notably, the **Mean Absolute Percentage Error (MAPE)** is **0.2653**, indicating that the model's predictions are, on average, only about **26.5% off from the true values** — a significant improvement over previous models.
#
# Furthermore, the **R² Score** is **0.6815**, meaning that approximately **68.15% of the variance in the sentiment scores** is successfully captured by the model. This high R² score reinforces the conclusion that the GRU model is **not only accurate but also generalises well** to unseen data.
#
# This model stands out as the **most reliable regression model** in the current pipeline and could potentially be selected as the **final deployment candidate** if consistency across folds is maintained.

# %% [markdown]
# ---
# # 7. Classification RNN Model Trainings - (No Augmentation)

# %% [markdown]
# In this section, we will be training the various Classification models for the RNN to predict the Sentiment of the Movie Review (either Positive or Negative). This will subsequently be evaluated alongside the Regression Models to determine which one performs the best and which RNN Model in particular.

# %% [markdown]
# ---
# ## 7.1 SimpleRNN Classification Model

# %% [markdown]
# In this sub-section, we will be training the SimpleRNN Classification Model. As the name suggests, this is the most simple RNN Model there is and may serve as a baseline of comparison for the other Model. However, if this Model does perform well, it can be used as one of the Final Model if Classification is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Hidden State Update**
# $$
# h_t = \tanh(W_{xh}x_t + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: Current Hidden State
#
# - $x_t$: Input at Time $t$
#
# - $h_{t-1}$: Previous Hidden State
#
# - $W_{xh}$: Weight Matrix from Input to Hidden
#
# - $W_{hh}$: Weight Matrix From Hidden to Hidden
#
# - $b_h$: Bias Term
#
# - $\tanh$: Activation Function Applied Element-wise
#
# ---
# **Output at Each Time Step**
# $$
# y_t = W_{hy}h_t + b_y
# $$
# Where:
# - $y_t$: Output at Time $t$
#
# - $W_{hy}$: Weight Matrix from Hidden to Output
#
# - $b_y$: Output Bias
#
# ---
# **Loss Function (Classification)**
# $$
# \hat{y} = \text{softmax}(Wh_T + b)
# $$
# Calculated Using:
# $$
# \mathcal{L} = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)
# $$
# Where:
# - $C$: Number of Classes
#
# - $y_i$: True One-hot Label
#
# - $\hat{y}_i$: Predicted Probability for Class $i$
#
# ---
# **Backpropagation Through Time (BPTT)**
# $$
# \frac{\partial \mathcal{L}}{\partial W} = \sum_{t=1}^{T} \frac{\partial \mathcal{L}}{\partial h_t} \cdot \frac{\partial h_t}{\partial W}
# $$
# Where:
# - $\mathcal{L}$: Total loss over all time steps
#
# - $W$:	Any trainable weight matrix (e.g., $W_{xh}$, $W_{hh}$)
#
# - $T$:	Total number of time steps in the input sequence
#
# - $t$:	Current time step in the unrolled RNN
#
# - $h_t$:	Hidden state at time step $t$
#
# - $\frac{\partial \mathcal{L}}{\partial W}$:	Gradient of the loss with respect to weights $W$
#
# - $\frac{\partial \mathcal{L}}{\partial h_t}$:	Gradient of the loss with respect to hidden state $h_t$
#
# - $\frac{\partial h_t}{\partial W}$:	Gradient of hidden state $h_t$ with respect to weight $W$
#
# ---
#
# With all the essential Formulas for SimpleRNN indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 7.1.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 7.1.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_rnn_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(X_train_class_pad.shape[1],)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300]),
        embeddings_initializer='uniform'
    ))

    # ----- 1st Bidirectional SimpleRNN Layer ----- #
    model.add(Bidirectional(SimpleRNN(
        units=hp.Choice("rnn_units_1", [128, 256, 384]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_1", 0.3, 0.5, step=0.1)))

    # ----- 2nd Bidirectional SimpleRNN Layer ----- #
    model.add(Bidirectional(SimpleRNN(
        units=hp.Choice("rnn_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_2", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [128, 256]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [64, 128]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.3, 0.5, step=0.1)))

    # ----- Output Layer (Binary Classification) ----- #
    model.add(Dense(1, activation='sigmoid'))

    # ----- Compile Model ----- #
    lr = hp.Choice("lr", [5e-4, 1e-4, 5e-5])
    optimiser = Adam(learning_rate=lr)

    model.compile(
        optimizer=optimiser,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 7.1.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Setting Up Keras Tuner ======================== #
tuner = kt.RandomSearch(
    build_rnn_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='tuner_rnn_classification_no_aug',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/tuner_rnn_classification_no_aug/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 7.1.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Tuning Hyperparameters ======================== #
tuner.search(
    X_train_class_pad_no_aug,
    y_train_class[:X_train_class_pad_no_aug.shape[0]],
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 7.1.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best Model ======================== #
best_hp_srnn_class = tuner.get_best_hyperparameters(1)[0]
model_srnn_class_best_no_aug = tuner.hypermodel.build(best_hp_srnn_class)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning:
#
# Argument `alpha` is deprecated. Use `negative_slope` instead.

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 7.1.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
model_dir = "/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Models"
os.makedirs(model_dir, exist_ok=True)

checkpoint = ModelCheckpoint(
    filepath=os.path.join(model_dir, "srnn_classification_model_no_aug.keras"),
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 7.1.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training Best Model ======================== #
history_rnn_best = model_srnn_class_best_no_aug.fit(
    X_train_class_pad_no_aug,
    y_train_class[:X_train_class_pad_no_aug.shape[0]],
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint],
    verbose=2
)
# Out:
# Epoch 1/100
# 7/7 - 18s - 3s/step - accuracy: 0.5991 - loss: 1.9885 - val_accuracy: 0.2500 - val_loss: 1.9134 - learning_rate: 1.0000e-04
# Epoch 2/100
# 7/7 - 0s - 51ms/step - accuracy: 0.5991 - loss: 2.0439 - val_accuracy: 0.2500 - val_loss: 1.9143 - learning_rate: 1.0000e-04
# Epoch 3/100
# 7/7 - 1s - 134ms/step - accuracy: 0.5811 - loss: 2.0334 - val_accuracy: 0.4286 - val_loss: 1.8784 - learning_rate: 1.0000e-04
# Epoch 4/100
# 7/7 - 1s - 77ms/step - accuracy: 0.5360 - loss: 2.1640 - val_accuracy: 0.6786 - val_loss: 1.8119 - learning_rate: 1.0000e-04
# Epoch 5/100
# 7/7 - 1s - 146ms/step - accuracy: 0.5631 - loss: 2.0464 - val_accuracy: 0.7143 - val_loss: 1.8084 - learning_rate: 1.0000e-04
# Epoch 6/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5135 - loss: 2.1035 - val_accuracy: 0.7143 - val_loss: 1.8184 - learning_rate: 1.0000e-04
# Epoch 7/100
# 7/7 - 1s - 158ms/step - accuracy: 0.5000 - loss: 2.1590 - val_accuracy: 0.7857 - val_loss: 1.8201 - learning_rate: 1.0000e-04
# Epoch 8/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5721 - loss: 2.0019 - val_accuracy: 0.7857 - val_loss: 1.8012 - learning_rate: 1.0000e-04
# Epoch 9/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5135 - loss: 2.0953 - val_accuracy: 0.7857 - val_loss: 1.8146 - learning_rate: 1.0000e-04
# Epoch 10/100
# 7/7 - 0s - 46ms/step - accuracy: 0.5315 - loss: 2.0867 - val_accuracy: 0.6786 - val_loss: 1.8392 - learning_rate: 1.0000e-04
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 7/7 - 0s - 46ms/step - accuracy: 0.6081 - loss: 1.9408 - val_accuracy: 0.7143 - val_loss: 1.8530 - learning_rate: 2.5000e-05
# Epoch 12/100
# 7/7 - 0s - 45ms/step - accuracy: 0.6126 - loss: 1.9870 - val_accuracy: 0.7143 - val_loss: 1.8493 - learning_rate: 2.5000e-05
# Epoch 13/100
# 7/7 - 0s - 46ms/step - accuracy: 0.5946 - loss: 2.0193 - val_accuracy: 0.7143 - val_loss: 1.8422 - learning_rate: 2.5000e-05
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 7/7 - 0s - 46ms/step - accuracy: 0.6036 - loss: 1.9853 - val_accuracy: 0.6786 - val_loss: 1.8195 - learning_rate: 1.2500e-05
# Epoch 15/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6081 - loss: 1.9696 - val_accuracy: 0.6786 - val_loss: 1.8160 - learning_rate: 1.2500e-05
# Epoch 16/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5901 - loss: 1.8975 - val_accuracy: 0.7857 - val_loss: 1.8050 - learning_rate: 1.2500e-05
# Epoch 17/100
# 7/7 - 1s - 111ms/step - accuracy: 0.5450 - loss: 1.9794 - val_accuracy: 0.8214 - val_loss: 1.7985 - learning_rate: 1.2500e-05
# Epoch 18/100
# 7/7 - 0s - 46ms/step - accuracy: 0.5901 - loss: 1.9209 - val_accuracy: 0.8214 - val_loss: 1.7988 - learning_rate: 1.2500e-05
# Epoch 19/100
# 7/7 - 0s - 46ms/step - accuracy: 0.6081 - loss: 1.9577 - val_accuracy: 0.8214 - val_loss: 1.8011 - learning_rate: 1.2500e-05
# Epoch 20/100
# 7/7 - 0s - 49ms/step - accuracy: 0.6216 - loss: 1.9113 - val_accuracy: 0.7500 - val_loss: 1.7983 - learning_rate: 1.2500e-05
# Epoch 21/100
# 7/7 - 0s - 48ms/step - accuracy: 0.5676 - loss: 2.0334 - val_accuracy: 0.7500 - val_loss: 1.7983 - learning_rate: 6.2500e-06
# Epoch 22/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5766 - loss: 1.9745 - val_accuracy: 0.7500 - val_loss: 1.7979 - learning_rate: 6.2500e-06
# Epoch 23/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5090 - loss: 2.0988 - val_accuracy: 0.7500 - val_loss: 1.7995 - learning_rate: 6.2500e-06
# Epoch 24/100
# 7/7 - 0s - 45ms/step - accuracy: 0.6171 - loss: 1.9377 - val_accuracy: 0.7857 - val_loss: 1.8003 - learning_rate: 6.2500e-06
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 7/7 - 0s - 45ms/step - accuracy: 0.6126 - loss: 1.9994 - val_accuracy: 0.7857 - val_loss: 1.7986 - learning_rate: 3.1250e-06
# Epoch 26/100
# 7/7 - 0s - 49ms/step - accuracy: 0.5991 - loss: 1.9712 - val_accuracy: 0.7857 - val_loss: 1.7966 - learning_rate: 3.1250e-06
# Epoch 27/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5405 - loss: 2.0471 - val_accuracy: 0.7857 - val_loss: 1.7981 - learning_rate: 3.1250e-06
# Epoch 28/100
# 7/7 - 0s - 45ms/step - accuracy: 0.6306 - loss: 1.8531 - val_accuracy: 0.7500 - val_loss: 1.7973 - learning_rate: 3.1250e-06
# Epoch 29/100
# 7/7 - 0s - 48ms/step - accuracy: 0.5631 - loss: 2.0174 - val_accuracy: 0.7500 - val_loss: 1.7964 - learning_rate: 3.1250e-06
# Epoch 30/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5856 - loss: 2.0033 - val_accuracy: 0.7143 - val_loss: 1.7942 - learning_rate: 3.1250e-06
# Epoch 31/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6126 - loss: 1.9472 - val_accuracy: 0.7143 - val_loss: 1.7926 - learning_rate: 1.5625e-06
# Epoch 32/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5631 - loss: 2.0038 - val_accuracy: 0.7500 - val_loss: 1.7916 - learning_rate: 1.5625e-06
# Epoch 33/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6036 - loss: 1.9940 - val_accuracy: 0.7857 - val_loss: 1.7891 - learning_rate: 1.5625e-06
# Epoch 34/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6036 - loss: 2.0352 - val_accuracy: 0.7857 - val_loss: 1.7874 - learning_rate: 1.5625e-06
# Epoch 35/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5676 - loss: 1.9809 - val_accuracy: 0.8214 - val_loss: 1.7883 - learning_rate: 1.5625e-06
# Epoch 36/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5270 - loss: 2.0361 - val_accuracy: 0.8214 - val_loss: 1.7871 - learning_rate: 1.5625e-06
# Epoch 37/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5901 - loss: 2.0042 - val_accuracy: 0.8214 - val_loss: 1.7870 - learning_rate: 1.5625e-06
# Epoch 38/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6171 - loss: 1.9926 - val_accuracy: 0.8214 - val_loss: 1.7859 - learning_rate: 1.5625e-06
# Epoch 39/100
# 7/7 - 0s - 48ms/step - accuracy: 0.5766 - loss: 2.0030 - val_accuracy: 0.8214 - val_loss: 1.7853 - learning_rate: 1.5625e-06
# Epoch 40/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6441 - loss: 1.8959 - val_accuracy: 0.7857 - val_loss: 1.7833 - learning_rate: 1.5625e-06
# Epoch 41/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5991 - loss: 1.9931 - val_accuracy: 0.7857 - val_loss: 1.7811 - learning_rate: 7.8125e-07
# Epoch 42/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5991 - loss: 1.9992 - val_accuracy: 0.7857 - val_loss: 1.7814 - learning_rate: 7.8125e-07
# Epoch 43/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6306 - loss: 1.9095 - val_accuracy: 0.7857 - val_loss: 1.7795 - learning_rate: 7.8125e-07
# Epoch 44/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5901 - loss: 1.9636 - val_accuracy: 0.7857 - val_loss: 1.7774 - learning_rate: 7.8125e-07
# Epoch 45/100
# 7/7 - 0s - 49ms/step - accuracy: 0.6036 - loss: 1.9391 - val_accuracy: 0.7857 - val_loss: 1.7763 - learning_rate: 7.8125e-07
# Epoch 46/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6036 - loss: 1.9144 - val_accuracy: 0.7857 - val_loss: 1.7732 - learning_rate: 7.8125e-07
# Epoch 47/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6351 - loss: 1.8772 - val_accuracy: 0.7857 - val_loss: 1.7729 - learning_rate: 7.8125e-07
# Epoch 48/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6351 - loss: 1.9466 - val_accuracy: 0.7857 - val_loss: 1.7714 - learning_rate: 7.8125e-07
# Epoch 49/100
# 7/7 - 0s - 48ms/step - accuracy: 0.5721 - loss: 1.9820 - val_accuracy: 0.7857 - val_loss: 1.7686 - learning_rate: 7.8125e-07
# Epoch 50/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6306 - loss: 1.9329 - val_accuracy: 0.7857 - val_loss: 1.7678 - learning_rate: 7.8125e-07
# Epoch 51/100
# 7/7 - 0s - 48ms/step - accuracy: 0.5766 - loss: 1.9839 - val_accuracy: 0.7857 - val_loss: 1.7676 - learning_rate: 3.9062e-07
# Epoch 52/100
# 7/7 - 0s - 48ms/step - accuracy: 0.5766 - loss: 2.0241 - val_accuracy: 0.7857 - val_loss: 1.7671 - learning_rate: 3.9062e-07
# Epoch 53/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6036 - loss: 1.9137 - val_accuracy: 0.7857 - val_loss: 1.7664 - learning_rate: 3.9062e-07
# Epoch 54/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5721 - loss: 2.0075 - val_accuracy: 0.7857 - val_loss: 1.7665 - learning_rate: 3.9062e-07
# Epoch 55/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6216 - loss: 1.9126 - val_accuracy: 0.7857 - val_loss: 1.7660 - learning_rate: 3.9062e-07
# Epoch 56/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6126 - loss: 1.9301 - val_accuracy: 0.7857 - val_loss: 1.7650 - learning_rate: 3.9062e-07
# Epoch 57/100
# 7/7 - 0s - 48ms/step - accuracy: 0.6081 - loss: 2.0077 - val_accuracy: 0.7857 - val_loss: 1.7636 - learning_rate: 3.9062e-07
# Epoch 58/100
# 7/7 - 0s - 49ms/step - accuracy: 0.6126 - loss: 1.9442 - val_accuracy: 0.7857 - val_loss: 1.7630 - learning_rate: 3.9062e-07
# Epoch 59/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5856 - loss: 2.0222 - val_accuracy: 0.7857 - val_loss: 1.7623 - learning_rate: 3.9062e-07
# Epoch 60/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5721 - loss: 2.0324 - val_accuracy: 0.7857 - val_loss: 1.7618 - learning_rate: 3.9062e-07
# Epoch 61/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5631 - loss: 1.9893 - val_accuracy: 0.7857 - val_loss: 1.7606 - learning_rate: 1.9531e-07
# Epoch 62/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5946 - loss: 1.9416 - val_accuracy: 0.7500 - val_loss: 1.7599 - learning_rate: 1.9531e-07
# Epoch 63/100
# 7/7 - 0s - 45ms/step - accuracy: 0.6081 - loss: 1.9733 - val_accuracy: 0.7500 - val_loss: 1.7599 - learning_rate: 1.9531e-07
# Epoch 64/100
# 7/7 - 0s - 47ms/step - accuracy: 0.6396 - loss: 1.9035 - val_accuracy: 0.7500 - val_loss: 1.7597 - learning_rate: 1.9531e-07
# Epoch 65/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5991 - loss: 1.9811 - val_accuracy: 0.7500 - val_loss: 1.7598 - learning_rate: 1.9531e-07
# Epoch 66/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5766 - loss: 1.9392 - val_accuracy: 0.7500 - val_loss: 1.7582 - learning_rate: 1.9531e-07
# Epoch 67/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5991 - loss: 1.9535 - val_accuracy: 0.7857 - val_loss: 1.7578 - learning_rate: 1.9531e-07
# Epoch 68/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5991 - loss: 1.9578 - val_accuracy: 0.7857 - val_loss: 1.7574 - learning_rate: 1.9531e-07
# Epoch 69/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5450 - loss: 2.0209 - val_accuracy: 0.7857 - val_loss: 1.7571 - learning_rate: 1.9531e-07
# Epoch 70/100
# 7/7 - 0s - 47ms/step - accuracy: 0.5676 - loss: 1.9973 - val_accuracy: 0.7857 - val_loss: 1.7565 - learning_rate: 1.9531e-07
# Epoch 71/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5991 - loss: 1.9141 - val_accuracy: 0.7857 - val_loss: 1.7567 - learning_rate: 9.7656e-08
# Epoch 72/100
# 7/7 - 0s - 45ms/step - accuracy: 0.6081 - loss: 1.9208 - val_accuracy: 0.7857 - val_loss: 1.7568 - learning_rate: 9.7656e-08
# Epoch 73/100
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# 7/7 - 0s - 45ms/step - accuracy: 0.5450 - loss: 2.0556 - val_accuracy: 0.7857 - val_loss: 1.7569 - learning_rate: 4.8828e-08
# Epoch 74/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5811 - loss: 1.9508 - val_accuracy: 0.7857 - val_loss: 1.7575 - learning_rate: 4.8828e-08
# Epoch 75/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5856 - loss: 1.9293 - val_accuracy: 0.7857 - val_loss: 1.7582 - learning_rate: 4.8828e-08
# Epoch 76/100
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# 7/7 - 0s - 45ms/step - accuracy: 0.6171 - loss: 1.9800 - val_accuracy: 0.7857 - val_loss: 1.7591 - learning_rate: 2.4414e-08
# Epoch 77/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5225 - loss: 2.0792 - val_accuracy: 0.7857 - val_loss: 1.7597 - learning_rate: 2.4414e-08
# Epoch 78/100
# 7/7 - 0s - 45ms/step - accuracy: 0.5450 - loss: 2.0179 - val_accuracy: 0.7857 - val_loss: 1.7597 - learning_rate: 2.4414e-08
# Epoch 79/100
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# 7/7 - 0s - 45ms/step - accuracy: 0.5541 - loss: 2.0870 - val_accuracy: 0.7857 - val_loss: 1.7608 - learning_rate: 1.2207e-08
# Epoch 80/100
# 7/7 - 0s - 45ms/step - accuracy: 0.6171 - loss: 1.9652 - val_accuracy: 0.7857 - val_loss: 1.7599 - learning_rate: 1.2207e-08

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 7.1.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_srnn_class_best.save_weights("Weights/weights_class_srnn_tuned.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 7.1.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 7.1.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Plotting Training History ======================== #
def plot_history(history, title="SimpleRNN Classification Model"):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Acc')
    plt.plot(epochs_range, val_acc, label='Val Acc')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_rnn_best)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Underfitting Learning Curve**. This means that the RNN Model has not learnt from the Training Dataset instead it is attempting to but failing to learn the patterns of the Data. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 7.1.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_srnn_class.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_6aa4e_row0_col1, #T_6aa4e_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6aa4e_row2_col1, #T_6aa4e_row4_col1, #T_6aa4e_row6_col1, #T_6aa4e_row8_col1, #T_6aa4e_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6aa4e_row3_col1, #T_6aa4e_row5_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_6aa4e_row7_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# </style>
# <table id="T_6aa4e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6aa4e_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_6aa4e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6aa4e_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_6aa4e_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6aa4e_row1_col0" class="data row1 col0" >rnn_units_1</td>
#       <td id="T_6aa4e_row1_col1" class="data row1 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6aa4e_row2_col0" class="data row2 col0" >dropout_rnn_1</td>
#       <td id="T_6aa4e_row2_col1" class="data row2 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6aa4e_row3_col0" class="data row3 col0" >rnn_units_2</td>
#       <td id="T_6aa4e_row3_col1" class="data row3 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6aa4e_row4_col0" class="data row4 col0" >dropout_rnn_2</td>
#       <td id="T_6aa4e_row4_col1" class="data row4 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6aa4e_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_6aa4e_row5_col1" class="data row5 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6aa4e_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_6aa4e_row6_col1" class="data row6 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6aa4e_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_6aa4e_row7_col1" class="data row7 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6aa4e_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_6aa4e_row8_col1" class="data row8 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_6aa4e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6aa4e_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_6aa4e_row9_col1" class="data row9 col1" >0.000100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 7.1.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - Test Accuracy ≤ 50%
#
# **Acceptable**
# - Test Accuracy ≥ 50%
#
# **Good**
# - Test Accuracy ≥ 65%
#
# **Very Good**
# - Test Accuracy ≥ 80%
#
# **Excellent**
# - Test Accuracy ≥ 95%
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Evaluation on Test Set ======================== #
y_test_class = np.array(y_test_class).astype('int32').reshape(-1)

test_loss, test_acc = model_srnn_class_best_no_aug.evaluate(X_test_class_pad, y_test_class, verbose=2)

results_df = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test Loss'],
    'Value': [test_acc, test_loss]
})
results_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 - 1s - 1s/step - accuracy: 0.6786 - loss: 1.7943
# <style type="text/css">
# #T_bdb69_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bdb69_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bdb69" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdb69_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_bdb69_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdb69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdb69_row0_col0" class="data row0 col0" >Test Accuracy</td>
#       <td id="T_bdb69_row0_col1" class="data row0 col1" >0.678571</td>
#     </tr>
#     <tr>
#       <th id="T_bdb69_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdb69_row1_col0" class="data row1 col0" >Test Loss</td>
#       <td id="T_bdb69_row1_col1" class="data row1 col1" >1.794324</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Good** Test Accuracy of 67.8% and also a Relatively Low Test Loss of 1.79. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 7.1.9.4 Model's Accuracy Confusion Matrix

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predicting Classes ======================== #
y_pred = (model_srnn_class_best_no_aug.predict(X_test_class_pad) > 0.5).astype('int32')

# ======================== Plotting Confusion Matrix ======================== #
cm = confusion_matrix(y_test_class, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Positive', 'Negative'])

# ======================== Plot Configurations ======================== #
fig, ax = plt.subplots(figsize=(10, 8))
disp.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix - RNN Classification")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step

# %% [markdown]
# With reference to the output above, we are able to see that the RNN Model performed poorly as seen from the Confusion Matrix where the RNN Model only predicted Positive and did not predict any Negative Sentiments. This determines the model to be voided as the accuracy is only elevated due to the majority of the Test Data being Positive Sentiment.

# %% [markdown]
# ---
# #### 7.1.9.5 Model's Classification Report

# %% [markdown]
# In this sub-section, we will be running a Classification Report for the RNN Model performance. This Classification Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Precision**
#
# Interpretation: Out of all Predicted Positives, how many are Actually Correct?
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $FP$: False Positives
#
# ---
# **Recall**
#
# Interpretation: Out of all Actual Positives, how many did we Correctly Identify?
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# **Where:*
# - $TP$: True Positives
# - $FN$: False Negatives
#
# ---
# **F1-Score**
#
# Interpretation: Balances Precision and Recall (useful when Classes are Imbalanced).
# $$
# F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
# **Support**
#
# Interpretation: Total Number of Actual Samples in the Class.
#
# $$
# \text{Support} = TP + FN
# $$
#
# ---
# **Accuracy**
#
# Interpretation: Overall Correct Predictions Divided by Total Samples.
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives
#
# ---
# With the relevant formulas listed, we will proceed to produce the Classification Report in the Code Cell below.

# %%
# ======================== Classification Report ======================== #
report_df = pd.DataFrame(classification_report(y_test_class, y_pred, target_names=['Positive', 'Negative'], output_dict=True)).transpose()
report_df.round(4).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_2e44d_row0_col0, #T_2e44d_row0_col1, #T_2e44d_row0_col2, #T_2e44d_row3_col3, #T_2e44d_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2e44d_row0_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_2e44d_row1_col0, #T_2e44d_row1_col1, #T_2e44d_row1_col2, #T_2e44d_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2e44d_row1_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_2e44d_row2_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_2e44d_row2_col1, #T_2e44d_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_2e44d_row2_col2 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_2e44d_row3_col0, #T_2e44d_row3_col1, #T_2e44d_row3_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_2e44d_row4_col0, #T_2e44d_row4_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e44d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e44d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_2e44d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_2e44d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_2e44d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e44d_level0_row0" class="row_heading level0 row0" >Positive</th>
#       <td id="T_2e44d_row0_col0" class="data row0 col0" >0.730800</td>
#       <td id="T_2e44d_row0_col1" class="data row0 col1" >0.904800</td>
#       <td id="T_2e44d_row0_col2" class="data row0 col2" >0.808500</td>
#       <td id="T_2e44d_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e44d_level0_row1" class="row_heading level0 row1" >Negative</th>
#       <td id="T_2e44d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_2e44d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_2e44d_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_2e44d_row1_col3" class="data row1 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e44d_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_2e44d_row2_col0" class="data row2 col0" >0.678600</td>
#       <td id="T_2e44d_row2_col1" class="data row2 col1" >0.678600</td>
#       <td id="T_2e44d_row2_col2" class="data row2 col2" >0.678600</td>
#       <td id="T_2e44d_row2_col3" class="data row2 col3" >0.678600</td>
#     </tr>
#     <tr>
#       <th id="T_2e44d_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_2e44d_row3_col0" class="data row3 col0" >0.365400</td>
#       <td id="T_2e44d_row3_col1" class="data row3 col1" >0.452400</td>
#       <td id="T_2e44d_row3_col2" class="data row3 col2" >0.404300</td>
#       <td id="T_2e44d_row3_col3" class="data row3 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e44d_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_2e44d_row4_col0" class="data row4 col0" >0.548100</td>
#       <td id="T_2e44d_row4_col1" class="data row4 col1" >0.678600</td>
#       <td id="T_2e44d_row4_col2" class="data row4 col2" >0.606400</td>
#       <td id="T_2e44d_row4_col3" class="data row4 col3" >28.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame and the 'F1-Score' Data Column, we are able to see that the F1-Score is somewhat elevated for the Positive Sentiment. However, the Negative Sentiment has a 0 F1-Score which indicates that the only reason for the high accuracy is due to the majority of the Test being Positive Sentiment. Therefore, this model is Voided and should not be used due to the bias.

# %% [markdown]
# ---
# ## 7.2 LSTM Classification Model

# %% [markdown]
# In this sub-section, we will be training the LSTM Classification Model. Long-Short Term Memory is a type of RNN architecture designed to overcome the vanishing gradient problem in traditional RNN. if this Model does perform well, it can be used as one of the Final Model if Classification is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Forget Gate**
# $$
# f_t = \sigma(W_f \cdot [h_{t-1}, x_t] + b_f)
# $$
#
# Where:
# - $f_t$: Forget Gate Vector at Time $t$
# - $\sigma$: Sigmoid Activation Function
# - $W_f$: Weight Matrix for Forget Gate
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Current Input
# - $b_f$: Bias for Forget Gate
#
# ---
# **Input Gate (Activation + Candidate)**
# $$
# i_t = \sigma(W_i \cdot [h_{t-1}, x_t] + b_i)
# $$
#
# $$
# \tilde{C}_t = \tanh(W_C \cdot [h_{t-1}, x_t] + b_C)
# $$
#
# Where:
# - $i_t$: Input Gate Vector at Time $t$
# - $\tilde{C}_t$: Candidate Values for Cell State Update
# - $W_i$, $W_C$: Weight Matrices for Input and Cell State
# - $b_i$, $b_C$: Biases for Input Gate and Cell Update
# - $\tanh$: Hyperbolic Tangent Activation Function
#
# ---
# **Cell State Update**
# $$
# C_t = f_t \cdot C_{t-1} + i_t \cdot \tilde{C}_t
# $$
#
# Where:
# - $C_t$: Updated Cell State at Time $t$
# - $C_{t-1}$: Previous Cell State
# - $f_t$: Forget Gate Vector
# - $i_t$: Input Gate Vector
# - $\tilde{C}_t$: Candidate Cell Values
#
# ---
# **Output Gate and Hidden State**
# $$
# o_t = \sigma(W_o \cdot [h_{t-1}, x_t] + b_o)
# $$
#
# $$
# h_t = o_t \cdot \tanh(C_t)
# $$
#
# Where:
# - $o_t$: Output Gate Vector
# - $h_t$: Hidden State (also Output of LSTM unit)
# - $W_o$: Weight Matrix for Output Gate
# - $b_o$: Bias for Output Gate
#
# ---
#
# **Output Layer (Classification)**
# $$
# \hat{y} = \text{softmax}(W_{hy} h_T + b_y)
# $$
#
# Where:
# - $\hat{y}$: Predicted Class Probabilities (Vector)
# - $h_T$: Hidden State at Final Time Step $T$
# - $W_{hy}$: Weight Matrix from Hidden to Output
# - $b_y$: Output Bias
#
# ---
# **Loss Function (Sparse Categorical Crossentropy)**
# $$
# \mathcal{L} = -\log(\hat{y}_{\text{true}})
# $$
#
# Where:
# - $\mathcal{L}$: Loss for a Single Example
# - $\hat{y}_{\text{true}}$: Predicted Probability for the Correct Class
# - $\log$: Natural Logarithm
#
#
# ---
# With all the essential Formulas for LSTM indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 7.2.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 7.2.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_lstm_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300]),
        embeddings_initializer='uniform'
    ))

    # ----- Bidirectional LSTM Layer 1 ----- #
    model.add(Bidirectional(LSTM(
        units=hp.Choice("lstm_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_1", 0.3, 0.5, step=0.1)))

    # ----- Bidirectional LSTM Layer 2 ----- #
    model.add(Bidirectional(LSTM(
        units=hp.Choice("lstm_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_2", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [128, 256]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [64, 128]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.3, 0.5, step=0.1)))

    # ----- Output Layer ----- #
    model.add(Dense(1, activation='sigmoid'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [5e-4, 1e-4, 5e-5])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 7.2.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner for LSTM ======================== #
tuner_lstm = kt.RandomSearch(
    build_lstm_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='lstm_classification_no_aug',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/lstm_classification_no_aug/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 7.2.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Searching Best Hyperparameters ======================== #
tuner_lstm.search(
    X_train_class_pad_no_aug,
    y_train_class[:X_train_class_pad_no_aug.shape[0]],
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 7.2.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best Model ======================== #
best_hp_lstm = tuner_lstm.get_best_hyperparameters(1)[0]
model_lstm_class_best_no_aug = tuner_lstm.hypermodel.build(best_hp_lstm)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning:
#
# Argument `alpha` is deprecated. Use `negative_slope` instead.

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 7.2.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
checkpoint_lstm = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_lstm_classification_model_no_aug.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 7.2.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training Best LSTM Model ======================== #
history_lstm_class = model_lstm_class_best_no_aug.fit(
    X_train_class_pad_no_aug,
    y_train_class[:X_train_class_pad_no_aug.shape[0]],
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint_lstm],
    verbose=2
)
# Out:
# Epoch 1/100
# 7/7 - 7s - 1s/step - accuracy: 0.5045 - loss: 2.5378 - val_accuracy: 0.7500 - val_loss: 2.1757 - learning_rate: 5.0000e-04
# Epoch 2/100
# 7/7 - 0s - 40ms/step - accuracy: 0.5180 - loss: 2.4713 - val_accuracy: 0.7500 - val_loss: 2.1210 - learning_rate: 5.0000e-04
# Epoch 3/100
# 7/7 - 0s - 42ms/step - accuracy: 0.5721 - loss: 2.3640 - val_accuracy: 0.7500 - val_loss: 2.0677 - learning_rate: 5.0000e-04
# Epoch 4/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6126 - loss: 2.2404 - val_accuracy: 0.7500 - val_loss: 2.0219 - learning_rate: 5.0000e-04
# Epoch 5/100
# 7/7 - 0s - 40ms/step - accuracy: 0.6667 - loss: 2.1331 - val_accuracy: 0.7500 - val_loss: 1.9833 - learning_rate: 5.0000e-04
# Epoch 6/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6757 - loss: 2.0967 - val_accuracy: 0.7500 - val_loss: 1.9451 - learning_rate: 5.0000e-04
# Epoch 7/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6532 - loss: 2.0366 - val_accuracy: 0.7500 - val_loss: 1.9112 - learning_rate: 5.0000e-04
# Epoch 8/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6667 - loss: 2.0249 - val_accuracy: 0.7500 - val_loss: 1.8807 - learning_rate: 5.0000e-04
# Epoch 9/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7207 - loss: 1.9129 - val_accuracy: 0.7500 - val_loss: 1.8535 - learning_rate: 5.0000e-04
# Epoch 10/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6937 - loss: 1.9407 - val_accuracy: 0.7500 - val_loss: 1.8302 - learning_rate: 5.0000e-04
# Epoch 11/100
# 7/7 - 0s - 41ms/step - accuracy: 0.7072 - loss: 1.9355 - val_accuracy: 0.7500 - val_loss: 1.8195 - learning_rate: 2.5000e-04
# Epoch 12/100
# 7/7 - 0s - 37ms/step - accuracy: 0.6577 - loss: 2.0092 - val_accuracy: 0.7500 - val_loss: 1.8089 - learning_rate: 2.5000e-04
# Epoch 13/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7387 - loss: 1.8436 - val_accuracy: 0.7500 - val_loss: 1.7990 - learning_rate: 2.5000e-04
# Epoch 14/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7162 - loss: 1.8846 - val_accuracy: 0.7500 - val_loss: 1.7901 - learning_rate: 2.5000e-04
# Epoch 15/100
# 7/7 - 0s - 39ms/step - accuracy: 0.7658 - loss: 1.8233 - val_accuracy: 0.7500 - val_loss: 1.7816 - learning_rate: 2.5000e-04
# Epoch 16/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7027 - loss: 1.8401 - val_accuracy: 0.7500 - val_loss: 1.7731 - learning_rate: 2.5000e-04
# Epoch 17/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6937 - loss: 1.8666 - val_accuracy: 0.7500 - val_loss: 1.7644 - learning_rate: 2.5000e-04
# Epoch 18/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7793 - loss: 1.7603 - val_accuracy: 0.7500 - val_loss: 1.7541 - learning_rate: 2.5000e-04
# Epoch 19/100
# 7/7 - 0s - 39ms/step - accuracy: 0.7207 - loss: 1.7573 - val_accuracy: 0.7500 - val_loss: 1.7435 - learning_rate: 2.5000e-04
# Epoch 20/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7297 - loss: 1.7653 - val_accuracy: 0.7500 - val_loss: 1.7331 - learning_rate: 2.5000e-04
# Epoch 21/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7342 - loss: 1.8293 - val_accuracy: 0.7500 - val_loss: 1.7290 - learning_rate: 1.2500e-04
# Epoch 22/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7523 - loss: 1.7017 - val_accuracy: 0.7500 - val_loss: 1.7255 - learning_rate: 1.2500e-04
# Epoch 23/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7658 - loss: 1.7114 - val_accuracy: 0.7500 - val_loss: 1.7214 - learning_rate: 1.2500e-04
# Epoch 24/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7613 - loss: 1.7197 - val_accuracy: 0.7500 - val_loss: 1.7184 - learning_rate: 1.2500e-04
# Epoch 25/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7432 - loss: 1.6444 - val_accuracy: 0.7500 - val_loss: 1.7151 - learning_rate: 1.2500e-04
# Epoch 26/100
# 7/7 - 0s - 39ms/step - accuracy: 0.8153 - loss: 1.5918 - val_accuracy: 0.7500 - val_loss: 1.7122 - learning_rate: 1.2500e-04
# Epoch 27/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7928 - loss: 1.6366 - val_accuracy: 0.7500 - val_loss: 1.7099 - learning_rate: 1.2500e-04
# Epoch 28/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7973 - loss: 1.5871 - val_accuracy: 0.7500 - val_loss: 1.7075 - learning_rate: 1.2500e-04
# Epoch 29/100
# 7/7 - 0s - 39ms/step - accuracy: 0.7568 - loss: 1.6252 - val_accuracy: 0.7500 - val_loss: 1.7064 - learning_rate: 1.2500e-04
# Epoch 30/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7477 - loss: 1.6579 - val_accuracy: 0.7500 - val_loss: 1.7039 - learning_rate: 1.2500e-04
# Epoch 31/100
# 7/7 - 0s - 38ms/step - accuracy: 0.7928 - loss: 1.6440 - val_accuracy: 0.7500 - val_loss: 1.7032 - learning_rate: 6.2500e-05
# Epoch 32/100
# 7/7 - 0s - 36ms/step - accuracy: 0.8288 - loss: 1.5146 - val_accuracy: 0.7500 - val_loss: 1.7034 - learning_rate: 6.2500e-05
# Epoch 33/100
# 7/7 - 0s - 36ms/step - accuracy: 0.7838 - loss: 1.5616 - val_accuracy: 0.7500 - val_loss: 1.7051 - learning_rate: 6.2500e-05
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 7/7 - 0s - 37ms/step - accuracy: 0.8604 - loss: 1.4346 - val_accuracy: 0.7500 - val_loss: 1.7061 - learning_rate: 3.1250e-05
# Epoch 35/100
# 7/7 - 0s - 35ms/step - accuracy: 0.8153 - loss: 1.5861 - val_accuracy: 0.7500 - val_loss: 1.7081 - learning_rate: 3.1250e-05
# Epoch 36/100
# 7/7 - 0s - 36ms/step - accuracy: 0.8153 - loss: 1.5200 - val_accuracy: 0.7500 - val_loss: 1.7096 - learning_rate: 3.1250e-05
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 7/7 - 0s - 37ms/step - accuracy: 0.7928 - loss: 1.5921 - val_accuracy: 0.7500 - val_loss: 1.7104 - learning_rate: 1.5625e-05
# Epoch 38/100
# 7/7 - 0s - 36ms/step - accuracy: 0.7838 - loss: 1.5644 - val_accuracy: 0.7500 - val_loss: 1.7114 - learning_rate: 1.5625e-05
# Epoch 39/100
# 7/7 - 0s - 35ms/step - accuracy: 0.8333 - loss: 1.5101 - val_accuracy: 0.7500 - val_loss: 1.7136 - learning_rate: 1.5625e-05
# Epoch 40/100
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 7/7 - 0s - 36ms/step - accuracy: 0.8423 - loss: 1.4748 - val_accuracy: 0.7500 - val_loss: 1.7156 - learning_rate: 7.8125e-06
# Epoch 41/100
# 7/7 - 0s - 37ms/step - accuracy: 0.7883 - loss: 1.5744 - val_accuracy: 0.7500 - val_loss: 1.7164 - learning_rate: 3.9063e-06

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 7.2.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_lstm_class_best.save_weights("Weights/weights_class_lstm_tuned_no_aug.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 7.2.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 7.2.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Accuracy & Loss Plot ======================== #
def plot_history(history, title="LSTM Classification Model (No Aug)"):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_lstm_class)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Underfitting Learning Curve**. This means that the RNN Model has not learnt from the Training Dataset instead it is attempting to but failing to learn the patterns of the Data. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 7.2.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_lstm.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_5f7a8_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5f7a8_row1_col1, #T_5f7a8_row5_col1, #T_5f7a8_row7_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_5f7a8_row2_col1, #T_5f7a8_row4_col1, #T_5f7a8_row6_col1, #T_5f7a8_row8_col1, #T_5f7a8_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5f7a8_row3_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# </style>
# <table id="T_5f7a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f7a8_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_5f7a8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f7a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f7a8_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_5f7a8_row0_col1" class="data row0 col1" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f7a8_row1_col0" class="data row1 col0" >lstm_units_1</td>
#       <td id="T_5f7a8_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f7a8_row2_col0" class="data row2 col0" >dropout_lstm_1</td>
#       <td id="T_5f7a8_row2_col1" class="data row2 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f7a8_row3_col0" class="data row3 col0" >lstm_units_2</td>
#       <td id="T_5f7a8_row3_col1" class="data row3 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f7a8_row4_col0" class="data row4 col0" >dropout_lstm_2</td>
#       <td id="T_5f7a8_row4_col1" class="data row4 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f7a8_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_5f7a8_row5_col1" class="data row5 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f7a8_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_5f7a8_row6_col1" class="data row6 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5f7a8_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_5f7a8_row7_col1" class="data row7 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5f7a8_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_5f7a8_row8_col1" class="data row8 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5f7a8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5f7a8_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_5f7a8_row9_col1" class="data row9 col1" >0.000500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 7.2.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - Test Accuracy ≤ 50%
#
# **Acceptable**
# - Test Accuracy ≥ 50%
#
# **Good**
# - Test Accuracy ≥ 65%
#
# **Very Good**
# - Test Accuracy ≥ 80%
#
# **Excellent**
# - Test Accuracy ≥ 95%
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Evaluate LSTM Model ======================== #
y_test_class = np.array(y_test_class).astype('int32').reshape(-1)

test_loss_lstm, test_acc_lstm = model_lstm_class_best_no_aug.evaluate(X_test_class_pad, y_test_class, verbose=2)

results_lstm_df = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test Loss'],
    'Value': [test_acc_lstm, test_loss_lstm]
})
results_lstm_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 - 1s - 702ms/step - accuracy: 0.7500 - loss: 1.6937
# <style type="text/css">
# #T_3f0e9_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3f0e9_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f0e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f0e9_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_3f0e9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f0e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f0e9_row0_col0" class="data row0 col0" >Test Accuracy</td>
#       <td id="T_3f0e9_row0_col1" class="data row0 col1" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_3f0e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f0e9_row1_col0" class="data row1 col0" >Test Loss</td>
#       <td id="T_3f0e9_row1_col1" class="data row1 col1" >1.693728</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Good** Test Accuracy of 75.0% and also a Relatively Low Test Loss of 1.67. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 7.2.9.4 Model's Accuracy Confusion Matrix

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predict & Compute Confusion Matrix ======================== #
y_pred_lstm = (model_lstm_class_best_no_aug.predict(X_test_class_pad) > 0.5).astype('int32')

cm_lstm = confusion_matrix(y_test_class, y_pred_lstm)
disp_lstm = ConfusionMatrixDisplay(confusion_matrix=cm_lstm, display_labels=['Positive', 'Negative'])

fig, ax = plt.subplots(figsize=(8, 6))
disp_lstm.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix - LSTM Classification Model")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step

# %% [markdown]
# With reference to the output above, we are able to see that the RNN Model performed poorly as seen from the Confusion Matrix where the RNN Model only predicted Positive and did not predict any Negative Sentiments. This determines the model to be voided as the accuracy is only elevated due to the majority of the Test Data being Positive Sentiment.

# %% [markdown]
# ---
# #### 7.2.9.5 Model's Classification Report

# %% [markdown]
# In this sub-section, we will be running a Classification Report for the RNN Model performance. This Classification Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Precision**
#
# Interpretation: Out of all Predicted Positives, how many are Actually Correct?
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $FP$: False Positives
#
# ---
# **Recall**
#
# Interpretation: Out of all Actual Positives, how many did we Correctly Identify?
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# **Where:*
# - $TP$: True Positives
# - $FN$: False Negatives
#
# ---
# **F1-Score**
#
# Interpretation: Balances Precision and Recall (useful when Classes are Imbalanced).
# $$
# F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
# **Support**
#
# Interpretation: Total Number of Actual Samples in the Class.
#
# $$
# \text{Support} = TP + FN
# $$
#
# ---
# **Accuracy**
#
# Interpretation: Overall Correct Predictions Divided by Total Samples.
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives
#
# ---
# With the relevant formulas listed, we will proceed to produce the Classification Report in the Code Cell below.

# %%
# ======================== Generate Classification Report ======================== #
report_lstm = classification_report(
    y_test_class,
    y_pred_lstm,
    target_names=['Positive', 'Negative'],
    output_dict=True
)

report_lstm_df = pd.DataFrame(report_lstm).transpose().round(4)
report_lstm_df.style.background_gradient(cmap="Blues")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# <style type="text/css">
# #T_bc48d_row0_col0, #T_bc48d_row0_col1, #T_bc48d_row0_col2, #T_bc48d_row2_col0, #T_bc48d_row3_col3, #T_bc48d_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bc48d_row0_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_bc48d_row1_col0, #T_bc48d_row1_col1, #T_bc48d_row1_col2, #T_bc48d_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bc48d_row1_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_bc48d_row2_col1, #T_bc48d_row4_col0, #T_bc48d_row4_col1, #T_bc48d_row4_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_bc48d_row2_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_bc48d_row3_col0, #T_bc48d_row3_col1, #T_bc48d_row3_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc48d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc48d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_bc48d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_bc48d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_bc48d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc48d_level0_row0" class="row_heading level0 row0" >Positive</th>
#       <td id="T_bc48d_row0_col0" class="data row0 col0" >0.750000</td>
#       <td id="T_bc48d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_bc48d_row0_col2" class="data row0 col2" >0.857100</td>
#       <td id="T_bc48d_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc48d_level0_row1" class="row_heading level0 row1" >Negative</th>
#       <td id="T_bc48d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_bc48d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_bc48d_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_bc48d_row1_col3" class="data row1 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc48d_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_bc48d_row2_col0" class="data row2 col0" >0.750000</td>
#       <td id="T_bc48d_row2_col1" class="data row2 col1" >0.750000</td>
#       <td id="T_bc48d_row2_col2" class="data row2 col2" >0.750000</td>
#       <td id="T_bc48d_row2_col3" class="data row2 col3" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_bc48d_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_bc48d_row3_col0" class="data row3 col0" >0.375000</td>
#       <td id="T_bc48d_row3_col1" class="data row3 col1" >0.500000</td>
#       <td id="T_bc48d_row3_col2" class="data row3 col2" >0.428600</td>
#       <td id="T_bc48d_row3_col3" class="data row3 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc48d_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_bc48d_row4_col0" class="data row4 col0" >0.562500</td>
#       <td id="T_bc48d_row4_col1" class="data row4 col1" >0.750000</td>
#       <td id="T_bc48d_row4_col2" class="data row4 col2" >0.642900</td>
#       <td id="T_bc48d_row4_col3" class="data row4 col3" >28.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame and the 'F1-Score' Data Column, we are able to see that the F1-Score is somewhat elevated for the Positive Sentiment. However, the Negative Sentiment has a 0 F1-Score which indicates that the only reason for the high accuracy is due to the majority of the Test being Positive Sentiment. Therefore, this model is Voided and should not be used due to the bias.

# %% [markdown]
# ---
# ## 7.3 GRU Classification Model

# %% [markdown]
# In this sub-section, we will be training the GRU Classification Model. Gated Recurrent Units (GRUs) are a simplified version of LSTMs that use two gates — the update gate and reset gate — to control the flow of information. They are computationally more efficient than LSTMs while often achieving comparable performance. GRUs do not maintain a separate memory cell like LSTMs, making them easier to train while still addressing the vanishing gradient problem in traditional RNNs. if this Model does perform well, it can be used as one of the Final Model if Classification is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Reset Gate**
# $$
# r_t = \sigma(W_r \cdot [h_{t-1}, x_t] + b_r)
# $$
#
# Where:
# - $r_t$: Reset Gate
# - $W_r$: Weights for Reset Gate
# - $b_r$: Bias
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input at Time $t$
# - $\sigma$: Sigmoid Function
#
# ---
# **Update Gate**
# $$
# z_t = \sigma(W_z \cdot [h_{t-1}, x_t] + b_z)
# $$
#
# Where:
# - $z_t$: Update Gate
# - $W_z$: Weights for Update Gate
# - $b_z$: Bias
#
# ---
# **Candidate Hidden State**
# $$
# \tilde{h}_t = \tanh(W_h \cdot [r_t * h_{t-1}, x_t] + b_h)
# $$
#
# **Where:**
# - $\tilde{h}_t$: Candidate Hidden State
# - $r_t$: Reset Gate
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input
# - $W_h$, $b_h$: Weights & Bias
# - $\tanh$: Hyperbolic Tangent Activation
#
# ---
# **Final Hidden State Update**
# $$
# h_t = (1 - z_t) * h_{t-1} + z_t * \tilde{h}_t
# $$
#
# **Where:**
# - $h_t$: New Hidden State
# - $z_t$: Update Gate
# - $\tilde{h}_t$: Candidate State
#
# ---
#
# **Output Layer (Softmax)**
# $$
# \hat{y} = \text{softmax}(W_o h_T + b_o)
# $$
#
# **Where:**
# - $h_T$: Last Hidden State
# - $\hat{y}$: Predicted Probability for Each Class
# - $W_o$, $b_o$: Output Weights and Bias
#
# ---
# **Loss Function**
# $$
# \mathcal{L} = -\log(\hat{y}_{\text{true}})
# $$
#
# **Where:**
# - $\hat{y}_{\text{true}}$: Predicted Probability of the Correct Class
#
# ---
# With all the essential Formulas for GRU indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 7.3.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 7.3.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_gru_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300]),
        embeddings_initializer='uniform'
    ))

    # ----- Bidirectional GRU Layer 1 ----- #
    model.add(Bidirectional(GRU(
        units=hp.Choice("gru_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_1", 0.3, 0.5, step=0.1)))

    # ----- Bidirectional GRU Layer 2 ----- #
    model.add(Bidirectional(GRU(
        units=hp.Choice("gru_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    )))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_2", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [128, 256]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.3, 0.5, step=0.1)))

    # ----- Dense Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [64, 128]),
        kernel_regularizer=l2(0.001)
    ))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.3, 0.5, step=0.1)))

    # ----- Output Layer ----- #
    model.add(Dense(1, activation='sigmoid'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [5e-4, 1e-4, 5e-5])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 7.3.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner for GRU ======================== #
tuner_gru = kt.RandomSearch(
    build_gru_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='gru_classification_no_aug',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/gru_classification_no_aug/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 7.3.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search for GRU ======================== #
tuner_gru.search(
    X_train_class_pad_no_aug,
    y_train_class[:X_train_class_pad_no_aug.shape[0]],
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 7.3.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best GRU Model ======================== #
best_hp_gru = tuner_gru.get_best_hyperparameters(1)[0]
model_gru_class_best_no_aug = tuner_gru.hypermodel.build(best_hp_gru)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning:
#
# Argument `alpha` is deprecated. Use `negative_slope` instead.

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 7.3.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
checkpoint_gru = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_gru_classification_model_no_aug.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 7.3.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training GRU Model ======================== #
history_gru_class = model_gru_class_best_no_aug.fit(
    X_train_class_pad_no_aug,
    y_train_class[:X_train_class_pad_no_aug.shape[0]],
    validation_data=(X_val_class_pad, y_val_class),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint_gru],
    verbose=2
)
# Out:
# Epoch 1/100
# 7/7 - 9s - 1s/step - accuracy: 0.5360 - loss: 2.3226 - val_accuracy: 0.3929 - val_loss: 2.0782 - learning_rate: 1.0000e-04
# Epoch 2/100
# 7/7 - 0s - 41ms/step - accuracy: 0.5000 - loss: 2.3663 - val_accuracy: 0.3214 - val_loss: 2.0709 - learning_rate: 1.0000e-04
# Epoch 3/100
# 7/7 - 0s - 41ms/step - accuracy: 0.4910 - loss: 2.3705 - val_accuracy: 0.3571 - val_loss: 2.0631 - learning_rate: 1.0000e-04
# Epoch 4/100
# 7/7 - 1s - 180ms/step - accuracy: 0.5541 - loss: 2.2271 - val_accuracy: 0.6429 - val_loss: 2.0550 - learning_rate: 1.0000e-04
# Epoch 5/100
# 7/7 - 1s - 126ms/step - accuracy: 0.5721 - loss: 2.2036 - val_accuracy: 0.7500 - val_loss: 2.0447 - learning_rate: 1.0000e-04
# Epoch 6/100
# 7/7 - 0s - 41ms/step - accuracy: 0.5315 - loss: 2.2198 - val_accuracy: 0.7500 - val_loss: 2.0351 - learning_rate: 1.0000e-04
# Epoch 7/100
# 7/7 - 0s - 38ms/step - accuracy: 0.5180 - loss: 2.2325 - val_accuracy: 0.7500 - val_loss: 2.0252 - learning_rate: 1.0000e-04
# Epoch 8/100
# 7/7 - 0s - 39ms/step - accuracy: 0.5450 - loss: 2.2267 - val_accuracy: 0.7500 - val_loss: 2.0164 - learning_rate: 1.0000e-04
# Epoch 9/100
# 7/7 - 0s - 38ms/step - accuracy: 0.5270 - loss: 2.1503 - val_accuracy: 0.7500 - val_loss: 2.0064 - learning_rate: 1.0000e-04
# Epoch 10/100
# 7/7 - 0s - 39ms/step - accuracy: 0.5811 - loss: 2.1960 - val_accuracy: 0.7500 - val_loss: 1.9961 - learning_rate: 1.0000e-04
# Epoch 11/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6081 - loss: 2.0725 - val_accuracy: 0.7500 - val_loss: 1.9915 - learning_rate: 5.0000e-05
# Epoch 12/100
# 7/7 - 0s - 39ms/step - accuracy: 0.5811 - loss: 2.1662 - val_accuracy: 0.7500 - val_loss: 1.9862 - learning_rate: 5.0000e-05
# Epoch 13/100
# 7/7 - 0s - 39ms/step - accuracy: 0.5991 - loss: 2.0835 - val_accuracy: 0.7500 - val_loss: 1.9807 - learning_rate: 5.0000e-05
# Epoch 14/100
# 7/7 - 0s - 39ms/step - accuracy: 0.5856 - loss: 2.0951 - val_accuracy: 0.7500 - val_loss: 1.9750 - learning_rate: 5.0000e-05
# Epoch 15/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6532 - loss: 1.9615 - val_accuracy: 0.7500 - val_loss: 1.9692 - learning_rate: 5.0000e-05
# Epoch 16/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6351 - loss: 2.0137 - val_accuracy: 0.7500 - val_loss: 1.9626 - learning_rate: 5.0000e-05
# Epoch 17/100
# 7/7 - 0s - 40ms/step - accuracy: 0.5766 - loss: 2.0244 - val_accuracy: 0.7500 - val_loss: 1.9543 - learning_rate: 5.0000e-05
# Epoch 18/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6261 - loss: 2.0110 - val_accuracy: 0.7500 - val_loss: 1.9469 - learning_rate: 5.0000e-05
# Epoch 19/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6441 - loss: 2.0166 - val_accuracy: 0.7500 - val_loss: 1.9407 - learning_rate: 5.0000e-05
# Epoch 20/100
# 7/7 - 0s - 39ms/step - accuracy: 0.5676 - loss: 2.1252 - val_accuracy: 0.7500 - val_loss: 1.9356 - learning_rate: 5.0000e-05
# Epoch 21/100
# 7/7 - 0s - 38ms/step - accuracy: 0.5856 - loss: 2.0858 - val_accuracy: 0.7500 - val_loss: 1.9321 - learning_rate: 2.5000e-05
# Epoch 22/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6532 - loss: 1.9639 - val_accuracy: 0.7500 - val_loss: 1.9282 - learning_rate: 2.5000e-05
# Epoch 23/100
# 7/7 - 0s - 38ms/step - accuracy: 0.5991 - loss: 2.1222 - val_accuracy: 0.7500 - val_loss: 1.9245 - learning_rate: 2.5000e-05
# Epoch 24/100
# 7/7 - 0s - 40ms/step - accuracy: 0.6532 - loss: 2.0281 - val_accuracy: 0.7500 - val_loss: 1.9218 - learning_rate: 2.5000e-05
# Epoch 25/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6847 - loss: 1.9730 - val_accuracy: 0.7500 - val_loss: 1.9187 - learning_rate: 2.5000e-05
# Epoch 26/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6622 - loss: 2.0056 - val_accuracy: 0.7500 - val_loss: 1.9149 - learning_rate: 2.5000e-05
# Epoch 27/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6757 - loss: 1.9797 - val_accuracy: 0.7500 - val_loss: 1.9109 - learning_rate: 2.5000e-05
# Epoch 28/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6261 - loss: 2.0086 - val_accuracy: 0.7500 - val_loss: 1.9087 - learning_rate: 2.5000e-05
# Epoch 29/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6351 - loss: 2.0152 - val_accuracy: 0.7500 - val_loss: 1.9044 - learning_rate: 2.5000e-05
# Epoch 30/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6757 - loss: 1.9689 - val_accuracy: 0.7500 - val_loss: 1.9018 - learning_rate: 2.5000e-05
# Epoch 31/100
# 7/7 - 0s - 40ms/step - accuracy: 0.6622 - loss: 1.9390 - val_accuracy: 0.7500 - val_loss: 1.9006 - learning_rate: 1.2500e-05
# Epoch 32/100
# 7/7 - 0s - 40ms/step - accuracy: 0.6802 - loss: 2.0007 - val_accuracy: 0.7500 - val_loss: 1.8985 - learning_rate: 1.2500e-05
# Epoch 33/100
# 7/7 - 0s - 42ms/step - accuracy: 0.6126 - loss: 2.0578 - val_accuracy: 0.7500 - val_loss: 1.8963 - learning_rate: 1.2500e-05
# Epoch 34/100
# 7/7 - 0s - 42ms/step - accuracy: 0.6892 - loss: 1.9234 - val_accuracy: 0.7500 - val_loss: 1.8942 - learning_rate: 1.2500e-05
# Epoch 35/100
# 7/7 - 0s - 41ms/step - accuracy: 0.6757 - loss: 1.9005 - val_accuracy: 0.7500 - val_loss: 1.8925 - learning_rate: 1.2500e-05
# Epoch 36/100
# 7/7 - 0s - 40ms/step - accuracy: 0.7072 - loss: 1.8871 - val_accuracy: 0.7500 - val_loss: 1.8903 - learning_rate: 1.2500e-05
# Epoch 37/100
# 7/7 - 0s - 42ms/step - accuracy: 0.6892 - loss: 1.9118 - val_accuracy: 0.7500 - val_loss: 1.8886 - learning_rate: 1.2500e-05
# Epoch 38/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6441 - loss: 2.0209 - val_accuracy: 0.7500 - val_loss: 1.8876 - learning_rate: 1.2500e-05
# Epoch 39/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6532 - loss: 2.0353 - val_accuracy: 0.7500 - val_loss: 1.8846 - learning_rate: 1.2500e-05
# Epoch 40/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6712 - loss: 1.8805 - val_accuracy: 0.7500 - val_loss: 1.8830 - learning_rate: 1.2500e-05
# Epoch 41/100
# 7/7 - 0s - 36ms/step - accuracy: 0.6171 - loss: 1.9842 - val_accuracy: 0.7500 - val_loss: 1.8837 - learning_rate: 6.2500e-06
# Epoch 42/100
# 7/7 - 0s - 36ms/step - accuracy: 0.7072 - loss: 1.9347 - val_accuracy: 0.7500 - val_loss: 1.8834 - learning_rate: 6.2500e-06
# Epoch 43/100
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 7/7 - 0s - 36ms/step - accuracy: 0.7072 - loss: 1.8963 - val_accuracy: 0.7500 - val_loss: 1.8831 - learning_rate: 3.1250e-06
# Epoch 44/100
# 7/7 - 0s - 38ms/step - accuracy: 0.6532 - loss: 1.9873 - val_accuracy: 0.7500 - val_loss: 1.8820 - learning_rate: 3.1250e-06
# Epoch 45/100
# 7/7 - 0s - 37ms/step - accuracy: 0.6441 - loss: 1.9823 - val_accuracy: 0.7500 - val_loss: 1.8824 - learning_rate: 3.1250e-06
# Epoch 46/100
# 7/7 - 0s - 36ms/step - accuracy: 0.6577 - loss: 1.9465 - val_accuracy: 0.7500 - val_loss: 1.8835 - learning_rate: 3.1250e-06
# Epoch 47/100
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 7/7 - 0s - 36ms/step - accuracy: 0.6847 - loss: 1.9199 - val_accuracy: 0.7500 - val_loss: 1.8845 - learning_rate: 1.5625e-06
# Epoch 48/100
# 7/7 - 0s - 37ms/step - accuracy: 0.6441 - loss: 1.9252 - val_accuracy: 0.7500 - val_loss: 1.8851 - learning_rate: 1.5625e-06
# Epoch 49/100
# 7/7 - 0s - 36ms/step - accuracy: 0.6847 - loss: 1.9061 - val_accuracy: 0.7500 - val_loss: 1.8862 - learning_rate: 1.5625e-06
# Epoch 50/100
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 7/7 - 0s - 36ms/step - accuracy: 0.6712 - loss: 1.9477 - val_accuracy: 0.7500 - val_loss: 1.8871 - learning_rate: 7.8125e-07
# Epoch 51/100
# 7/7 - 0s - 36ms/step - accuracy: 0.6892 - loss: 1.8826 - val_accuracy: 0.7500 - val_loss: 1.8882 - learning_rate: 3.9062e-07
# Epoch 52/100
# 7/7 - 0s - 36ms/step - accuracy: 0.5946 - loss: 1.9771 - val_accuracy: 0.7500 - val_loss: 1.8890 - learning_rate: 3.9062e-07
# Epoch 53/100
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 7/7 - 0s - 37ms/step - accuracy: 0.7027 - loss: 1.8610 - val_accuracy: 0.7500 - val_loss: 1.8894 - learning_rate: 1.9531e-07
# Epoch 54/100
# 7/7 - 0s - 39ms/step - accuracy: 0.6396 - loss: 1.9813 - val_accuracy: 0.7500 - val_loss: 1.8907 - learning_rate: 1.9531e-07

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 7.3.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_gru_class_best_no_aug.save_weights("Weights/weights_class_gru_tuned_no_aug.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 7.3.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 7.3.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Accuracy & Loss Plot ======================== #
def plot_history(history, title="GRU Classification Model (No Aug)"):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history_gru_class)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 7.3.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_gru.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_a21d0_row0_col1, #T_a21d0_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a21d0_row1_col1, #T_a21d0_row7_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_a21d0_row2_col1, #T_a21d0_row4_col1, #T_a21d0_row6_col1, #T_a21d0_row8_col1, #T_a21d0_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a21d0_row3_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# </style>
# <table id="T_a21d0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a21d0_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_a21d0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a21d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a21d0_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_a21d0_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a21d0_row1_col0" class="data row1 col0" >gru_units_1</td>
#       <td id="T_a21d0_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a21d0_row2_col0" class="data row2 col0" >dropout_gru_1</td>
#       <td id="T_a21d0_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a21d0_row3_col0" class="data row3 col0" >gru_units_2</td>
#       <td id="T_a21d0_row3_col1" class="data row3 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a21d0_row4_col0" class="data row4 col0" >dropout_gru_2</td>
#       <td id="T_a21d0_row4_col1" class="data row4 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a21d0_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_a21d0_row5_col1" class="data row5 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a21d0_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_a21d0_row6_col1" class="data row6 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a21d0_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_a21d0_row7_col1" class="data row7 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a21d0_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_a21d0_row8_col1" class="data row8 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_a21d0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a21d0_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_a21d0_row9_col1" class="data row9 col1" >0.000100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 7.3.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - Test Accuracy ≤ 50%
#
# **Acceptable**
# - Test Accuracy ≥ 50%
#
# **Good**
# - Test Accuracy ≥ 65%
#
# **Very Good**
# - Test Accuracy ≥ 80%
#
# **Excellent**
# - Test Accuracy ≥ 95%
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Evaluate LSTM Model ======================== #
y_test_class = np.array(y_test_class).astype('int32').reshape(-1)

test_loss_gru, test_acc_gru = model_gru_class_best_no_aug.evaluate(X_test_class_pad, y_test_class, verbose=2)

results_gru_df = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test Loss'],
    'Value': [test_acc_gru, test_loss_gru]
})
results_gru_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 - 1s - 760ms/step - accuracy: 0.7500 - loss: 1.8623
# <style type="text/css">
# #T_58019_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_58019_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58019" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58019_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_58019_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58019_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58019_row0_col0" class="data row0 col0" >Test Accuracy</td>
#       <td id="T_58019_row0_col1" class="data row0 col1" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_58019_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_58019_row1_col0" class="data row1 col0" >Test Loss</td>
#       <td id="T_58019_row1_col1" class="data row1 col1" >1.862342</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Good** Test Accuracy of 75.0% and also a Relatively Low Test Loss of 1.86. This is a strong indicator that the RNN Model has very good Hyperparameters and will most likely perform well.

# %% [markdown]
# ---
# #### 7.3.9.4 Model's Accuracy Confusion Matrix

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predict & Confusion Matrix ======================== #
y_pred_gru = (model_gru_class_best_no_aug.predict(X_test_class_pad) > 0.5).astype('int32')

cm_gru = confusion_matrix(y_test_class, y_pred_gru)
disp_gru = ConfusionMatrixDisplay(confusion_matrix=cm_gru, display_labels=['Positive', 'Negative'])

fig, ax = plt.subplots(figsize=(8, 6))
disp_gru.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix - GRU Classification Model")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step

# %% [markdown]
# With reference to the output above, we are able to see that the RNN Model performed poorly as seen from the Confusion Matrix where the RNN Model only predicted Positive and did not predict any Negative Sentiments. This determines the model to be voided as the accuracy is only elevated due to the majority of the Test Data being Positive Sentiment.

# %% [markdown]
# ---
# #### 7.3.9.5 Model's Classification Report

# %% [markdown]
# In this sub-section, we will be running a Classification Report for the RNN Model performance. This Classification Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Precision**
#
# Interpretation: Out of all Predicted Positives, how many are Actually Correct?
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $FP$: False Positives
#
# ---
# **Recall**
#
# Interpretation: Out of all Actual Positives, how many did we Correctly Identify?
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# **Where:*
# - $TP$: True Positives
# - $FN$: False Negatives
#
# ---
# **F1-Score**
#
# Interpretation: Balances Precision and Recall (useful when Classes are Imbalanced).
# $$
# F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
# **Support**
#
# Interpretation: Total Number of Actual Samples in the Class.
#
# $$
# \text{Support} = TP + FN
# $$
#
# ---
# **Accuracy**
#
# Interpretation: Overall Correct Predictions Divided by Total Samples.
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Where:**
# - $TP$: True Positives
# - $TN$: True Negatives
# - $FP$: False Positives
# - $FN$: False Negatives
#
# ---
# With the relevant formulas listed, we will proceed to produce the Classification Report in the Code Cell below.

# %%
# ======================== Classification Report ======================== #
report_gru = classification_report(
    y_test_class,
    y_pred_gru,
    target_names=['Positive', 'Negative'],
    output_dict=True
)

report_gru_df = pd.DataFrame(report_gru).transpose().round(4)
report_gru_df.style.background_gradient(cmap="Blues")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# <style type="text/css">
# #T_6259f_row0_col0, #T_6259f_row0_col1, #T_6259f_row0_col2, #T_6259f_row2_col0, #T_6259f_row3_col3, #T_6259f_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6259f_row0_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_6259f_row1_col0, #T_6259f_row1_col1, #T_6259f_row1_col2, #T_6259f_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6259f_row1_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_6259f_row2_col1, #T_6259f_row4_col0, #T_6259f_row4_col1, #T_6259f_row4_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_6259f_row2_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_6259f_row3_col0, #T_6259f_row3_col1, #T_6259f_row3_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6259f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6259f_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_6259f_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_6259f_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_6259f_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6259f_level0_row0" class="row_heading level0 row0" >Positive</th>
#       <td id="T_6259f_row0_col0" class="data row0 col0" >0.750000</td>
#       <td id="T_6259f_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_6259f_row0_col2" class="data row0 col2" >0.857100</td>
#       <td id="T_6259f_row0_col3" class="data row0 col3" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6259f_level0_row1" class="row_heading level0 row1" >Negative</th>
#       <td id="T_6259f_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_6259f_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_6259f_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_6259f_row1_col3" class="data row1 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6259f_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_6259f_row2_col0" class="data row2 col0" >0.750000</td>
#       <td id="T_6259f_row2_col1" class="data row2 col1" >0.750000</td>
#       <td id="T_6259f_row2_col2" class="data row2 col2" >0.750000</td>
#       <td id="T_6259f_row2_col3" class="data row2 col3" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_6259f_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_6259f_row3_col0" class="data row3 col0" >0.375000</td>
#       <td id="T_6259f_row3_col1" class="data row3 col1" >0.500000</td>
#       <td id="T_6259f_row3_col2" class="data row3 col2" >0.428600</td>
#       <td id="T_6259f_row3_col3" class="data row3 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6259f_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_6259f_row4_col0" class="data row4 col0" >0.562500</td>
#       <td id="T_6259f_row4_col1" class="data row4 col1" >0.750000</td>
#       <td id="T_6259f_row4_col2" class="data row4 col2" >0.642900</td>
#       <td id="T_6259f_row4_col3" class="data row4 col3" >28.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame and the 'F1-Score' Data Column, we are able to see that the F1-Score is somewhat elevated for the Positive Sentiment. However, the Negative Sentiment has a 0 F1-Score which indicates that the only reason for the high accuracy is due to the majority of the Test being Positive Sentiment. Therefore, this model is Voided and should not be used due to the bias.

# %% [markdown]
# ---
# # 8. Regression RNN Model Trainings - (No Augmentation)

# %% [markdown]
# In this section, we will be training the various Regression models for the RNN to predict the Sentiment Score of the Movie Review. This will subsequently be evaluated alongside the Classification Models to determine which one performs the best and which RNN Model in particular.

# %% [markdown]
# ---
# ## 8.1 SimpleRNN Regression Model

# %% [markdown]
# In this sub-section, we will be training the SimpleRNN Regression Model. As the name suggests, this is the most simple RNN Model there is and may serve as a baseline of comparison for the other Model. However, if this Model does perform well, it can be used as one of the Final Model if Regression is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Hidden State Update**
# $$
# h_t = \tanh(W_{xh}x_t + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: Current Hidden State
#
# - $x_t$: Input at Time $t$
#
# - $h_{t-1}$: Previous Hidden State
#
# - $W_{xh}$: Weight Matrix from Input to Hidden
#
# - $W_{hh}$: Weight Matrix From Hidden to Hidden
#
# - $b_h$: Bias Term
#
# - $\tanh$: Activation Function Applied Element-wise
#
# ---
# **Dense Regression Output Layer**
# $$
# \hat{y} = W_{o} \cdot h_T + b_o
# $$
#
# Where:
# - $h_T$: Final Hidden State at Last Timestep
# - $W_o$: Output Weight Matrix
# - $b_o$: Output Bias
# - $\hat{y}$: Predicted Score (Continuous)
#
# ---
# **Loss Function (Mean Squared Error)**
# $$
# \mathcal{L}_{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# **Where:**
# - $y_i$: Actual Score
# - $\hat{y}_i$: Predicted Score
# - $N$: Number of Samples
#
# ---
#
# With all the essential Formulas for SimpleRNN indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 8.1.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Learning Rate Scheduler & Callbacks ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 8.1.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Linear Regression Head)
# $$
# \hat{y} = W_o a + b_o
# $$
#
# **Where:**
# - $a$: Activation from the Previous Layer (Dense ReLU)
# - $W_o$: Regression Weight Vector
# - $b_o$: Output Bias
# - $\hat{y}$: Predicted Sentiment Score (real-valued, 0–1)
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_srnn_reg_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [64, 128, 256]),
        embeddings_initializer='uniform'
    ))

    # ----- SimpleRNN Layer 1 ----- #
    model.add(SimpleRNN(
        units=hp.Choice("rnn_units_1", [64, 128]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_1", 0.3, 0.5, step=0.1)))

    # ----- SimpleRNN Layer 2 ----- #
    model.add(SimpleRNN(
        units=hp.Choice("rnn_units_2", [32, 64]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_rnn_2", 0.2, 0.4, step=0.1)))

    # ----- Dense Hidden Layer ----- #
    model.add(Dense(
        units=hp.Choice("dense_units", [64, 128]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(Dropout(hp.Float("dropout_dense", 0.2, 0.4, step=0.1)))

    # ----- Output Layer ----- #
    model.add(Dense(1, activation='linear'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Regression have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 8.1.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner Setup ======================== #
tuner_srnn_reg = kt.RandomSearch(
    build_srnn_reg_model,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='srnn_regression_no_aug',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/srnn_regression_no_aug/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 8.1.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search ======================== #
tuner_srnn_reg.search(
    X_train_reg_pad_no_aug,
    y_train_reg[:X_train_reg_pad_no_aug.shape[0]],
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 8.1.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best SimpleRNN Regressor ======================== #
best_hp_srnn_reg = tuner_srnn_reg.get_best_hyperparameters(1)[0]
model_srnn_reg_best_no_aug = tuner_srnn_reg.hypermodel.build(best_hp_srnn_reg)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 8.1.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpoint ======================== #
checkpoint_srnn_reg = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_srnn_regression_model_no_aug.keras",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 8.1.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Train the Model ======================== #
history_srnn_reg = model_srnn_reg_best_no_aug.fit(
    X_train_reg_pad_no_aug,
    y_train_reg[:X_train_reg_pad_no_aug.shape[0]],
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler, checkpoint_srnn_reg],
    verbose=2
)
# Out:
# Epoch 1/100
# 7/7 - 11s - 2s/step - loss: 0.9866 - mae: 0.7045 - val_loss: 0.3146 - val_mae: 0.3311 - learning_rate: 0.0100
# Epoch 2/100
# 7/7 - 0s - 32ms/step - loss: 0.7151 - mae: 0.5283 - val_loss: 0.4163 - val_mae: 0.4349 - learning_rate: 0.0100
# Epoch 3/100
# 7/7 - 0s - 42ms/step - loss: 0.6112 - mae: 0.3971 - val_loss: 0.2637 - val_mae: 0.1463 - learning_rate: 0.0100
# Epoch 4/100
# 7/7 - 0s - 28ms/step - loss: 0.6033 - mae: 0.3743 - val_loss: 0.4879 - val_mae: 0.4824 - learning_rate: 0.0100
# Epoch 5/100
# 7/7 - 0s - 28ms/step - loss: 0.6205 - mae: 0.3895 - val_loss: 0.3681 - val_mae: 0.2106 - learning_rate: 0.0100
# Epoch 6/100
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 7/7 - 0s - 29ms/step - loss: 0.5944 - mae: 0.3931 - val_loss: 0.2936 - val_mae: 0.2389 - learning_rate: 0.0050
# Epoch 7/100
# 7/7 - 1s - 81ms/step - loss: 0.4652 - mae: 0.3493 - val_loss: 0.2623 - val_mae: 0.1751 - learning_rate: 0.0050
# Epoch 8/100
# 7/7 - 0s - 28ms/step - loss: 0.3878 - mae: 0.3247 - val_loss: 0.3192 - val_mae: 0.2118 - learning_rate: 0.0050
# Epoch 9/100
# 7/7 - 0s - 28ms/step - loss: 0.3428 - mae: 0.2953 - val_loss: 0.2763 - val_mae: 0.1954 - learning_rate: 0.0050
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 7/7 - 0s - 28ms/step - loss: 0.3394 - mae: 0.2890 - val_loss: 0.2696 - val_mae: 0.2519 - learning_rate: 0.0025
# Epoch 11/100
# 7/7 - 0s - 28ms/step - loss: 0.3283 - mae: 0.2876 - val_loss: 0.2629 - val_mae: 0.2345 - learning_rate: 0.0012
# Epoch 12/100
# 7/7 - 0s - 57ms/step - loss: 0.3078 - mae: 0.2770 - val_loss: 0.2581 - val_mae: 0.2119 - learning_rate: 0.0012
# Epoch 13/100
# 7/7 - 0s - 28ms/step - loss: 0.3047 - mae: 0.2745 - val_loss: 0.2587 - val_mae: 0.2089 - learning_rate: 0.0012
# Epoch 14/100
# 7/7 - 0s - 27ms/step - loss: 0.3039 - mae: 0.2746 - val_loss: 0.2607 - val_mae: 0.2144 - learning_rate: 0.0012
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 7/7 - 0s - 28ms/step - loss: 0.3241 - mae: 0.2897 - val_loss: 0.2648 - val_mae: 0.2304 - learning_rate: 6.2500e-04
# Epoch 16/100
# 7/7 - 0s - 30ms/step - loss: 0.3074 - mae: 0.2839 - val_loss: 0.2666 - val_mae: 0.2421 - learning_rate: 6.2500e-04
# Epoch 17/100
# 7/7 - 0s - 27ms/step - loss: 0.3025 - mae: 0.2774 - val_loss: 0.2598 - val_mae: 0.2372 - learning_rate: 6.2500e-04
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 7/7 - 0s - 28ms/step - loss: 0.2873 - mae: 0.2596 - val_loss: 0.2618 - val_mae: 0.2452 - learning_rate: 3.1250e-04
# Epoch 19/100
# 7/7 - 0s - 28ms/step - loss: 0.2876 - mae: 0.2562 - val_loss: 0.2656 - val_mae: 0.2559 - learning_rate: 3.1250e-04
# Epoch 20/100
# 7/7 - 0s - 28ms/step - loss: 0.3021 - mae: 0.2754 - val_loss: 0.2704 - val_mae: 0.2674 - learning_rate: 3.1250e-04
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 7/7 - 0s - 28ms/step - loss: 0.3130 - mae: 0.2900 - val_loss: 0.2738 - val_mae: 0.2751 - learning_rate: 7.8125e-05
# Epoch 22/100
# 7/7 - 0s - 28ms/step - loss: 0.2983 - mae: 0.2711 - val_loss: 0.2769 - val_mae: 0.2818 - learning_rate: 7.8125e-05

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 8.1.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_srnn_reg_best_no_aug.save_weights("Weights/weights_reg_srnn_tuned_no_aug.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 8.1.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Regression Errors. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 8.1.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Plot Training Curves ======================== #
def plot_regression_history(history, title="SimpleRNN Regression Model (No Aug)"):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    mae = history.history['mae']
    val_mae = history.history['val_mae']
    epochs_range = range(1, len(loss) + 1)

    plt.figure(figsize=(14, 5))

    # ----- Loss Plot ----- #
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.title(f'{title} - MSE Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # ----- MAE Plot ----- #
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, mae, label='Train MAE')
    plt.plot(epochs_range, val_mae, label='Val MAE')
    plt.title(f'{title} - MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_regression_history(history_srnn_reg)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 8.1.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_srnn_reg.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_3131d_row0_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_3131d_row1_col1, #T_3131d_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3131d_row2_col1, #T_3131d_row4_col1, #T_3131d_row6_col1, #T_3131d_row7_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3131d_row3_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# </style>
# <table id="T_3131d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3131d_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_3131d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3131d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3131d_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_3131d_row0_col1" class="data row0 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3131d_row1_col0" class="data row1 col0" >rnn_units_1</td>
#       <td id="T_3131d_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3131d_row2_col0" class="data row2 col0" >dropout_rnn_1</td>
#       <td id="T_3131d_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3131d_row3_col0" class="data row3 col0" >rnn_units_2</td>
#       <td id="T_3131d_row3_col1" class="data row3 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3131d_row4_col0" class="data row4 col0" >dropout_rnn_2</td>
#       <td id="T_3131d_row4_col1" class="data row4 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3131d_row5_col0" class="data row5 col0" >dense_units</td>
#       <td id="T_3131d_row5_col1" class="data row5 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3131d_row6_col0" class="data row6 col0" >dropout_dense</td>
#       <td id="T_3131d_row6_col1" class="data row6 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_3131d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3131d_row7_col0" class="data row7 col0" >lr</td>
#       <td id="T_3131d_row7_col1" class="data row7 col1" >0.010000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 8.1.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - MAE > 0.15
# - RMSE > 0.18
#
# **Acceptable**
# - MAE = 0.10 - 0.15
# - RMSE > 0.12 - 0.18
#
# **Good**
# - MAE = 0.05 - 0.10
# - RMSE > 0.07 - 0.12
#
# **Excellent**
# - MAE ≤ 0.05
# - RMSE ≤ 0.07
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Predict on Test Set ======================== #
y_pred_srnn = model_srnn_reg_best_no_aug.predict(X_test_reg_pad).flatten()

# ======================== Calculate MAE & RMSE ======================== #
mae_srnn = mean_absolute_error(y_test_reg, y_pred_srnn)
rmse_srnn = np.sqrt(mean_squared_error(y_test_reg, y_pred_srnn))

# ======================== Display Results ======================== #
results_srnn_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE'],
    'Value': [mae_srnn, rmse_srnn]
})
results_srnn_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# <style type="text/css">
# #T_a48e4_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a48e4_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a48e4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a48e4_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a48e4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a48e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a48e4_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_a48e4_row0_col1" class="data row0 col1" >0.284458</td>
#     </tr>
#     <tr>
#       <th id="T_a48e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a48e4_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_a48e4_row1_col1" class="data row1 col1" >0.318705</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Poor** MAE of 0.23 and also a RMSE of 0.29. This is a strong indicator that the RNN Model has poor Hyperparameters and will most likely perform poorly.

# %% [markdown]
# ---
# #### 8.1.9.4 Model's Accuracy Scatter Plot

# %% [markdown]
# In this sub-section, we will be plotting the Scatter Plot of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Outliers within the Predictions. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Scatter Plot: Predicted vs Actual ======================== #
plt.figure(figsize=(8, 6))
plt.scatter(y_test_reg, y_pred_srnn, alpha=0.6, color='blue')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.title("Predicted vs Actual - SimpleRNN Regression")
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the output above, we are able to observe that the SimpleRNN Regression Model failed to learn any meaningful pattern from the data. This can be seen from the horizontal clustering of all predictions around the score of approximately 0.7, regardless of the actual input. Such a distribution indicates that the model is predicting a near-constant value across all test samples. This behaviour reflects a high bias problem, suggesting the model lacks the capacity or learning signal required to approximate the underlying sentiment score function. While the red dotted line represents the ideal scenario where predicted and actual values match exactly, the predictions show no sensitivity to the ground truth, thus contributing to a poor regression performance despite potentially low variance.

# %% [markdown]
# ---
# #### 8.1.9.5 Model's Regression Report

# %% [markdown]
# In this sub-section, we will be running a Regression Report for the RNN Model performance. This Regression Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Mean Absolute Error (MAE)**
#
# Interpretation: Average Absolute Error Between Predictions and Actual Values
# $$
# \text{MAE} = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target Value
# - $\hat{y}_i$: Predicted Value
#
# ---
# **Mean Squared Error (MSE)**
#
# Interpretation: Penalises larger errors more than MAE
#
# $$
# \text{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Root Mean Squared Error (RMSE)**
#
# Interpretation: Square Root of MSE & Sensitive to Outliers
# $$
# \text{RMSE} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Mean Absolute Percentage Error (MAPE)**
#
# Interpretation: Measure of Prediction Accuracy of Forecast
# $$
# \text{MAPE} = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
#
# **Where:**
# - $n$: Number of Observations
# - $y_i$: Actual (True) Value
# - $\hat{y}_i$: Predicted Value
# - $\left| \cdot \right|$: Absolute Value
#
# ---
# **R-squared (Coefficient of Determination, $R^2$)**
#
# Interpretation: Explains the Variance in a Dependent Variable
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^{N} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{N} (y_i - \bar{y})^2}
# $$
#
# Where:
# - $\bar{y}$: Mean of Actual Target Values
# - $R^2 \in (-\infty, 1]$
# - $R^2 = 1$: Perfect Prediction
# - $R^2 = 0$: Same as Using Mean
# - $R^2 < 0$: Worse than Baseline
#
# ---
# With the relevant formulas listed, we will proceed to produce the Regression Report in the Code Cell below.

# %%
# ======================== Generate Regression Report ======================== #
def regression_report(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    report_df = pd.DataFrame({
        'Metric': ['MAE', 'MSE', 'RMSE', 'MAPE', 'R² Score'],
        'Value': [mae, mse, rmse, mape, r2]
    })

    return report_df.style.background_gradient(cmap="Blues")

# ======================== Displaying Regression Report ======================== #
regression_report(y_test_reg, y_pred_srnn)
# Out:
# <style type="text/css">
# #T_7520e_row0_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_7520e_row1_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_7520e_row2_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_7520e_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7520e_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_7520e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7520e_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_7520e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7520e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7520e_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_7520e_row0_col1" class="data row0 col1" >0.284458</td>
#     </tr>
#     <tr>
#       <th id="T_7520e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7520e_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_7520e_row1_col1" class="data row1 col1" >0.101573</td>
#     </tr>
#     <tr>
#       <th id="T_7520e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7520e_row2_col0" class="data row2 col0" >RMSE</td>
#       <td id="T_7520e_row2_col1" class="data row2 col1" >0.318705</td>
#     </tr>
#     <tr>
#       <th id="T_7520e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7520e_row3_col0" class="data row3 col0" >MAPE</td>
#       <td id="T_7520e_row3_col1" class="data row3 col1" >0.690539</td>
#     </tr>
#     <tr>
#       <th id="T_7520e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7520e_row4_col0" class="data row4 col0" >R² Score</td>
#       <td id="T_7520e_row4_col1" class="data row4 col1" >-0.259862</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# MAE (Mean Absolute Error): 0.2329 – On average, the model's predictions deviate from the actual sentiment scores by approximately 0.23, indicating moderate prediction accuracy.
#
# RMSE (Root Mean Squared Error): 0.2967 – The RMSE reflects the presence of higher-magnitude errors. While not extremely high, this value suggests some variability in prediction consistency.
#
# MAPE (Mean Absolute Percentage Error): 0.6838 – The MAPE exceeds 0.5, which is considered poor based on common regression standards. Since this metric is a primary focus for the lecturer, the high value implies the model is not reliable for real-world deployment in its current state.
#
# R² Score: -0.092 – A negative R² indicates that the model performs worse than simply predicting the mean of the target variable. This highlights a significant issue with the model's fit.

# %% [markdown]
# ---
# ## 8.2 LSTM Regression Model

# %% [markdown]
# In this sub-section, we will be training the LSTM Regression Model. Long-Short Term Memory is a type of RNN architecture designed to overcome the vanishing gradient problem in traditional RNN. If this Model does perform well, it can be used as one of the Final Model if Regression is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Forget Gate**
# $$
# f_t = \sigma(W_f [h_{t-1}, x_t] + b_f)
# $$
#
# Where:
# - $f_t$: Forget Gate Activation at Time Step $t$
#
# - $W_f$: Weight Matrix for Forget Gate
#
# - $h_{t-1}$: Previous Hidden State
#
# - $x_t$: Current Input Vector
#
# - $b_f$: Forget Gate Bias
#
# - $\sigma$: Sigmoid Function
#
# ---
# **Input Gate & Candidate Cell**
# $$i_t = \sigma(W_i [h_{t-1}, x_t] + b_i)$$
# $$\tilde{C}_t = \tanh(W_C [h_{t-1}, x_t] + b_C)$$
#
# Where:
# - $i_t$: Input Gate Activation
#
# - $\tilde{C}_t$: Candidate Cell State
#
# - $W_i$, $W_C$: Input and Candidate Weight Matrices
#
# - $b_i$, $b_C$: Biases
#
# - $\tanh$: Hyperbolic Tangent Function
#
# ---
# **Cell State Update**
# $$
# C_t = f_t \cdot C_{t-1} + i_t \cdot \tilde{C}_t
# $$
#
# **Where:**
# - $C_t$: Current Cell State
#
# - $C_{t-1}$: Previous Cell State
#
# - $\cdot$: Element-wise Multiplication
# ---
#
# **Output Gate & Hidden State**
# $$o_t = \sigma(W_o [h_{t-1}, x_t] + b_o)$$
# $$h_t = o_t \cdot \tanh(C_t)$$
#
# **Where:**
# - $o_t$: Output Gate Activation
#
# - $W_o$: Weight Matrix for Output Gate
#
# - $b_o$: Bias Term
#
# - $h_t$: Current Hidden State
#
# With all the essential Formulas for SimpleRNN indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 8.2.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Learning Rate Scheduler & Callbacks ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 8.2.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Linear Regression Head)
# $$
# \hat{y} = W_o a + b_o
# $$
#
# **Where:**
# - $a$: Activation from the Previous Layer (Dense ReLU)
# - $W_o$: Regression Weight Vector
# - $b_o$: Output Bias
# - $\hat{y}$: Predicted Sentiment Score (real-valued, 0–1)
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_lstm_reg_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300])
    ))

    # ----- LSTM Layer 1 ----- #
    model.add(LSTM(
        units=hp.Choice("lstm_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_1", 0.3, 0.5, step=0.1)))

    # ----- LSTM Layer 2 ----- #
    model.add(LSTM(
        units=hp.Choice("lstm_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_lstm_2", 0.2, 0.5, step=0.1)))

    # ----- Dense Hidden Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [64, 128, 256]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.2, 0.5, step=0.1)))

    # ----- Dense Hidden Layer 2 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [32, 64]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.2, 0.5, step=0.1)))

    # ----- Output Layer (Linear for Regression) ----- #
    model.add(Dense(1, activation='linear'))

    # ----- Compile the Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Regression have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 8.2.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner Setup ======================== #
tuner_lstm_reg = kt.RandomSearch(
    build_lstm_reg_model,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='lstm_regression_no_aug',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/lstm_regression_no_aug/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 8.2.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search ======================== #
tuner_lstm_reg.search(
    X_train_reg_pad_no_aug,
    y_train_reg[:X_train_reg_pad_no_aug.shape[0]],
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 8.2.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best SimpleRNN Regressor ======================== #
best_hp_lstm = tuner_lstm_reg.get_best_hyperparameters(1)[0]
model_lstm_best_no_aug = tuner_lstm_reg.hypermodel.build(best_hp_lstm)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 8.2.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpoint ======================== #
checkpoint_lstm_reg = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_lstm_regression_model_no_aug.keras",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 8.2.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Train the Model ======================== #
history_lstm = model_lstm_best_no_aug.fit(
    X_train_reg_pad_no_aug,
    y_train_reg[:X_train_reg_pad_no_aug.shape[0]],
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)
# Out:
# Epoch 1/50
# 7/7 - 5s - 688ms/step - loss: 2.7380 - mae: 1.1447 - val_loss: 1.1060 - val_mae: 0.7380 - learning_rate: 1.0000e-03
# Epoch 2/50
# 7/7 - 0s - 31ms/step - loss: 2.2778 - mae: 1.0343 - val_loss: 1.0065 - val_mae: 0.6712 - learning_rate: 1.0000e-03
# Epoch 3/50
# 7/7 - 0s - 31ms/step - loss: 2.2583 - mae: 1.0326 - val_loss: 0.9576 - val_mae: 0.6379 - learning_rate: 1.0000e-03
# Epoch 4/50
# 7/7 - 0s - 29ms/step - loss: 1.9386 - mae: 0.9532 - val_loss: 0.9152 - val_mae: 0.6081 - learning_rate: 1.0000e-03
# Epoch 5/50
# 7/7 - 0s - 28ms/step - loss: 1.9124 - mae: 0.9284 - val_loss: 0.9192 - val_mae: 0.6157 - learning_rate: 1.0000e-03
# Epoch 6/50
# 7/7 - 0s - 28ms/step - loss: 1.6520 - mae: 0.8359 - val_loss: 0.9306 - val_mae: 0.6288 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 7/7 - 0s - 28ms/step - loss: 1.8159 - mae: 0.8869 - val_loss: 0.9212 - val_mae: 0.6253 - learning_rate: 5.0000e-04
# Epoch 8/50
# 7/7 - 0s - 30ms/step - loss: 1.4966 - mae: 0.7971 - val_loss: 0.8749 - val_mae: 0.5891 - learning_rate: 5.0000e-04
# Epoch 9/50
# 7/7 - 0s - 30ms/step - loss: 1.6577 - mae: 0.8233 - val_loss: 0.8245 - val_mae: 0.5469 - learning_rate: 5.0000e-04
# Epoch 10/50
# 7/7 - 0s - 30ms/step - loss: 1.6031 - mae: 0.8311 - val_loss: 0.7791 - val_mae: 0.5061 - learning_rate: 5.0000e-04
# Epoch 11/50
# 7/7 - 0s - 28ms/step - loss: 1.5150 - mae: 0.7771 - val_loss: 0.7534 - val_mae: 0.4864 - learning_rate: 2.5000e-04
# Epoch 12/50
# 7/7 - 0s - 29ms/step - loss: 1.3958 - mae: 0.7839 - val_loss: 0.7228 - val_mae: 0.4616 - learning_rate: 2.5000e-04
# Epoch 13/50
# 7/7 - 0s - 29ms/step - loss: 1.4713 - mae: 0.7487 - val_loss: 0.6871 - val_mae: 0.4300 - learning_rate: 2.5000e-04
# Epoch 14/50
# 7/7 - 0s - 29ms/step - loss: 1.5085 - mae: 0.8000 - val_loss: 0.6768 - val_mae: 0.4212 - learning_rate: 2.5000e-04
# Epoch 15/50
# 7/7 - 0s - 29ms/step - loss: 1.4277 - mae: 0.7756 - val_loss: 0.6630 - val_mae: 0.4085 - learning_rate: 2.5000e-04
# Epoch 16/50
# 7/7 - 0s - 29ms/step - loss: 1.6054 - mae: 0.8503 - val_loss: 0.6504 - val_mae: 0.3966 - learning_rate: 2.5000e-04
# Epoch 17/50
# 7/7 - 0s - 29ms/step - loss: 1.3995 - mae: 0.7545 - val_loss: 0.6454 - val_mae: 0.3926 - learning_rate: 2.5000e-04
# Epoch 18/50
# 7/7 - 0s - 29ms/step - loss: 1.2848 - mae: 0.7255 - val_loss: 0.6449 - val_mae: 0.3934 - learning_rate: 2.5000e-04
# Epoch 19/50
# 7/7 - 0s - 28ms/step - loss: 1.3694 - mae: 0.7699 - val_loss: 0.6484 - val_mae: 0.3984 - learning_rate: 2.5000e-04
# Epoch 20/50
# 7/7 - 0s - 29ms/step - loss: 1.1581 - mae: 0.6657 - val_loss: 0.6435 - val_mae: 0.3944 - learning_rate: 2.5000e-04
# Epoch 21/50
# 7/7 - 0s - 30ms/step - loss: 1.4712 - mae: 0.8027 - val_loss: 0.6346 - val_mae: 0.3854 - learning_rate: 1.2500e-04
# Epoch 22/50
# 7/7 - 0s - 30ms/step - loss: 1.4118 - mae: 0.7532 - val_loss: 0.6272 - val_mae: 0.3777 - learning_rate: 1.2500e-04
# Epoch 23/50
# 7/7 - 0s - 29ms/step - loss: 1.1691 - mae: 0.6415 - val_loss: 0.6182 - val_mae: 0.3678 - learning_rate: 1.2500e-04
# Epoch 24/50
# 7/7 - 0s - 28ms/step - loss: 1.3279 - mae: 0.7389 - val_loss: 0.6140 - val_mae: 0.3636 - learning_rate: 1.2500e-04
# Epoch 25/50
# 7/7 - 0s - 28ms/step - loss: 1.3291 - mae: 0.7268 - val_loss: 0.6037 - val_mae: 0.3516 - learning_rate: 1.2500e-04
# Epoch 26/50
# 7/7 - 0s - 29ms/step - loss: 1.3158 - mae: 0.7300 - val_loss: 0.5932 - val_mae: 0.3387 - learning_rate: 1.2500e-04
# Epoch 27/50
# 7/7 - 0s - 29ms/step - loss: 1.3159 - mae: 0.7121 - val_loss: 0.5822 - val_mae: 0.3244 - learning_rate: 1.2500e-04
# Epoch 28/50
# 7/7 - 0s - 29ms/step - loss: 1.1177 - mae: 0.6480 - val_loss: 0.5738 - val_mae: 0.3130 - learning_rate: 1.2500e-04
# Epoch 29/50
# 7/7 - 0s - 30ms/step - loss: 1.2488 - mae: 0.6963 - val_loss: 0.5711 - val_mae: 0.3099 - learning_rate: 1.2500e-04
# Epoch 30/50
# 7/7 - 0s - 29ms/step - loss: 1.2729 - mae: 0.7018 - val_loss: 0.5670 - val_mae: 0.3045 - learning_rate: 1.2500e-04
# Epoch 31/50
# 7/7 - 0s - 30ms/step - loss: 1.1805 - mae: 0.6766 - val_loss: 0.5594 - val_mae: 0.2926 - learning_rate: 6.2500e-05
# Epoch 32/50
# 7/7 - 0s - 29ms/step - loss: 1.3132 - mae: 0.7402 - val_loss: 0.5489 - val_mae: 0.2748 - learning_rate: 6.2500e-05
# Epoch 33/50
# 7/7 - 0s - 29ms/step - loss: 1.3284 - mae: 0.7225 - val_loss: 0.5420 - val_mae: 0.2620 - learning_rate: 6.2500e-05
# Epoch 34/50
# 7/7 - 0s - 28ms/step - loss: 1.3106 - mae: 0.7344 - val_loss: 0.5353 - val_mae: 0.2488 - learning_rate: 6.2500e-05
# Epoch 35/50
# 7/7 - 0s - 28ms/step - loss: 1.2432 - mae: 0.6972 - val_loss: 0.5321 - val_mae: 0.2422 - learning_rate: 6.2500e-05
# Epoch 36/50
# 7/7 - 0s - 29ms/step - loss: 1.1583 - mae: 0.6263 - val_loss: 0.5281 - val_mae: 0.2335 - learning_rate: 6.2500e-05
# Epoch 37/50
# 7/7 - 0s - 29ms/step - loss: 1.0275 - mae: 0.5993 - val_loss: 0.5212 - val_mae: 0.2160 - learning_rate: 6.2500e-05
# Epoch 38/50
# 7/7 - 0s - 29ms/step - loss: 1.3341 - mae: 0.7369 - val_loss: 0.5166 - val_mae: 0.2031 - learning_rate: 6.2500e-05
# Epoch 39/50
# 7/7 - 0s - 29ms/step - loss: 1.1852 - mae: 0.6780 - val_loss: 0.5147 - val_mae: 0.1977 - learning_rate: 6.2500e-05
# Epoch 40/50
# 7/7 - 0s - 29ms/step - loss: 1.3779 - mae: 0.7568 - val_loss: 0.5112 - val_mae: 0.1866 - learning_rate: 6.2500e-05
# Epoch 41/50
# 7/7 - 0s - 30ms/step - loss: 1.2206 - mae: 0.6705 - val_loss: 0.5067 - val_mae: 0.1687 - learning_rate: 3.1250e-05
# Epoch 42/50
# 7/7 - 0s - 28ms/step - loss: 1.0857 - mae: 0.6391 - val_loss: 0.5036 - val_mae: 0.1520 - learning_rate: 3.1250e-05
# Epoch 43/50
# 7/7 - 0s - 29ms/step - loss: 1.1361 - mae: 0.6541 - val_loss: 0.5019 - val_mae: 0.1408 - learning_rate: 3.1250e-05
# Epoch 44/50
# 7/7 - 0s - 29ms/step - loss: 1.2249 - mae: 0.6930 - val_loss: 0.5013 - val_mae: 0.1358 - learning_rate: 3.1250e-05
# Epoch 45/50
# 7/7 - 0s - 29ms/step - loss: 1.1361 - mae: 0.6404 - val_loss: 0.5008 - val_mae: 0.1296 - learning_rate: 3.1250e-05
# Epoch 46/50
# 7/7 - 0s - 29ms/step - loss: 1.2522 - mae: 0.7151 - val_loss: 0.5004 - val_mae: 0.1206 - learning_rate: 3.1250e-05
# Epoch 47/50
# 7/7 - 0s - 27ms/step - loss: 1.1850 - mae: 0.6905 - val_loss: 0.5005 - val_mae: 0.1115 - learning_rate: 3.1250e-05
# Epoch 48/50
# 7/7 - 0s - 27ms/step - loss: 1.2933 - mae: 0.7226 - val_loss: 0.5006 - val_mae: 0.1082 - learning_rate: 3.1250e-05
# Epoch 49/50
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 7/7 - 0s - 28ms/step - loss: 1.1481 - mae: 0.6576 - val_loss: 0.5006 - val_mae: 0.1067 - learning_rate: 1.5625e-05
# Epoch 50/50
# 7/7 - 0s - 28ms/step - loss: 1.1425 - mae: 0.6551 - val_loss: 0.5008 - val_mae: 0.1041 - learning_rate: 1.5625e-05

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 8.2.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_lstm_best_no_aug.save_weights("Weights/weights_reg_lstm_tuned_no_aug.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 8.2.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Regression Errors. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 8.2.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Plot Training Curves ======================== #
def plot_regression_history(history, title="LSTM Regression (No Aug)"):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{title} - MSE Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['mae'], label='Train MAE')
    plt.plot(history.history['val_mae'], label='Val MAE')
    plt.title(f'{title} - MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_regression_history(history_lstm)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 8.2.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_lstm.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_92e57_row0_col1, #T_92e57_row1_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_92e57_row2_col1, #T_92e57_row4_col1, #T_92e57_row6_col1, #T_92e57_row8_col1, #T_92e57_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_92e57_row3_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_92e57_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_92e57_row7_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# </style>
# <table id="T_92e57" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92e57_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_92e57_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92e57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92e57_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_92e57_row0_col1" class="data row0 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92e57_row1_col0" class="data row1 col0" >lstm_units_1</td>
#       <td id="T_92e57_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92e57_row2_col0" class="data row2 col0" >dropout_lstm_1</td>
#       <td id="T_92e57_row2_col1" class="data row2 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92e57_row3_col0" class="data row3 col0" >lstm_units_2</td>
#       <td id="T_92e57_row3_col1" class="data row3 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92e57_row4_col0" class="data row4 col0" >dropout_lstm_2</td>
#       <td id="T_92e57_row4_col1" class="data row4 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92e57_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_92e57_row5_col1" class="data row5 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92e57_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_92e57_row6_col1" class="data row6 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_92e57_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_92e57_row7_col1" class="data row7 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_92e57_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_92e57_row8_col1" class="data row8 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_92e57_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_92e57_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_92e57_row9_col1" class="data row9 col1" >0.001000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 8.2.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - MAE > 0.15
# - RMSE > 0.18
#
# **Acceptable**
# - MAE = 0.10 - 0.15
# - RMSE > 0.12 - 0.18
#
# **Good**
# - MAE = 0.05 - 0.10
# - RMSE > 0.07 - 0.12
#
# **Excellent**
# - MAE ≤ 0.05
# - RMSE ≤ 0.07
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Predict on Test Set ======================== #
y_pred_lstm = model_lstm_best_no_aug.predict(X_test_reg_pad).flatten()

# ======================== Calculate MAE & RMSE ======================== #
mae_srnn = mean_absolute_error(y_test_reg, y_pred_lstm)
rmse_srnn = np.sqrt(mean_squared_error(y_test_reg, y_pred_lstm))

# ======================== Display Results ======================== #
results_lstm_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE'],
    'Value': [mae_srnn, rmse_srnn]
})
results_lstm_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# <style type="text/css">
# #T_e960b_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e960b_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e960b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e960b_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_e960b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e960b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e960b_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_e960b_row0_col1" class="data row0 col1" >0.224882</td>
#     </tr>
#     <tr>
#       <th id="T_e960b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e960b_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_e960b_row1_col1" class="data row1 col1" >0.306179</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Poor** MAE of 0.22 and also a RMSE of 0.30. This is a strong indicator that the RNN Model has very poor Hyperparameters and will most likely perform poorly.

# %% [markdown]
# ---
# #### 8.2.9.4 Model's Accuracy Scatter Plot

# %% [markdown]
# In this sub-section, we will be plotting the Scatter Plot of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Outliers within the Predictions. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Scatter Plot: Predicted vs Actual ======================== #
plt.figure(figsize=(8, 6))
plt.scatter(y_test_reg, y_pred_lstm, alpha=0.6)
plt.plot([0, 1], [0, 1], 'r--')
plt.title("LSTM Regression - Predicted vs Actual")
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the output above, we are able to see that the LSTM Regression Model consistently predicts a narrow range of sentiment scores, clustering predictions around 0.37, regardless of whether the actual scores are low or high. As a result, this LSTM model currently does not generalise well and provides minimal variation in predictions, making it unsuitable for practical deployment in this form. Additional tuning, deeper architecture, or more informative features might be required to resolve this limitation.

# %% [markdown]
# ---
# #### 8.2.9.5 Model's Regression Report

# %% [markdown]
# In this sub-section, we will be running a Regression Report for the RNN Model performance. This Regression Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Mean Absolute Error (MAE)**
#
# Interpretation: Average Absolute Error Between Predictions and Actual Values
# $$
# \text{MAE} = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target Value
# - $\hat{y}_i$: Predicted Value
#
# ---
# **Mean Squared Error (MSE)**
#
# Interpretation: Penalises larger errors more than MAE
#
# $$
# \text{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Root Mean Squared Error (RMSE)**
#
# Interpretation: Square Root of MSE & Sensitive to Outliers
# $$
# \text{RMSE} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Mean Absolute Percentage Error (MAPE)**
#
# Interpretation: Measure of Prediction Accuracy of Forecast
# $$
# \text{MAPE} = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
#
# **Where:**
# - $n$: Number of Observations
# - $y_i$: Actual (True) Value
# - $\hat{y}_i$: Predicted Value
# - $\left| \cdot \right|$: Absolute Value
#
# ---
# **R-squared (Coefficient of Determination, $R^2$)**
#
# Interpretation: Explains the Variance in a Dependent Variable
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^{N} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{N} (y_i - \bar{y})^2}
# $$
#
# Where:
# - $\bar{y}$: Mean of Actual Target Values
# - $R^2 \in (-\infty, 1]$
# - $R^2 = 1$: Perfect Prediction
# - $R^2 = 0$: Same as Using Mean
# - $R^2 < 0$: Worse than Baseline
#
# ---
# With the relevant formulas listed, we will proceed to produce the Regression Report in the Code Cell below.

# %%
# ======================== Generate Regression Report ======================== #
def regression_report(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape_lstm = mean_absolute_percentage_error(y_test_reg, y_pred_lstm)
    r2 = r2_score(y_true, y_pred)

    report_df = pd.DataFrame({
        'Metric': ['MAE', 'MSE', 'RMSE', 'MAPE', 'R² Score'],
        'Value': [mae, mse, rmse, mape_lstm, r2]
    })

    return report_df.style.background_gradient(cmap="Blues")

# ======================== Displaying Regression Report ======================== #
regression_report(y_test_reg, y_pred_lstm)
# Out:
# <style type="text/css">
# #T_63abf_row0_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_63abf_row1_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_63abf_row2_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_63abf_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_63abf_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_63abf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63abf_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_63abf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63abf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63abf_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_63abf_row0_col1" class="data row0 col1" >0.224882</td>
#     </tr>
#     <tr>
#       <th id="T_63abf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63abf_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_63abf_row1_col1" class="data row1 col1" >0.093746</td>
#     </tr>
#     <tr>
#       <th id="T_63abf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63abf_row2_col0" class="data row2 col0" >RMSE</td>
#       <td id="T_63abf_row2_col1" class="data row2 col1" >0.306179</td>
#     </tr>
#     <tr>
#       <th id="T_63abf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63abf_row3_col0" class="data row3 col0" >MAPE</td>
#       <td id="T_63abf_row3_col1" class="data row3 col1" >0.698429</td>
#     </tr>
#     <tr>
#       <th id="T_63abf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63abf_row4_col0" class="data row4 col0" >R² Score</td>
#       <td id="T_63abf_row4_col1" class="data row4 col1" >-0.162782</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the metrics above, the Mean Absolute Percentage Error (MAPE) is 0.5114, which translates to approximately 51.14% average deviation from the actual sentiment scores. This indicates that the model’s relative prediction error is high, and its ability to generalise is limited.
#
# While the MAE (0.2329) and RMSE (0.2967) show moderate absolute errors, the R² Score is negative (-0.0920). A negative R² suggests that the model performs worse than a horizontal mean predictor, which is a sign of underfitting.

# %% [markdown]
# ---
# ## 8.3 GRU Regression Model

# %% [markdown]
# In this sub-section, we will be training the GRU Regression Model. Gated Recurrent Units (GRUs) are a simplified version of LSTMs that use two gates — the update gate and reset gate — to control the flow of information. They are computationally more efficient than LSTMs while often achieving comparable performance. GRUs do not maintain a separate memory cell like LSTMs, making them easier to train while still addressing the vanishing gradient problem in traditional RNNs. if this Model does perform well, it can be used as one of the Final Model if Regression is decided to be the chosen method of output. The relevant formulas are indicated below:
#
# ---
# **Reset Gate**
# $$
# r_t = \sigma(W_r \cdot [h_{t-1}, x_t] + b_r)
# $$
#
# Where:
# - $r_t$: Reset Gate
# - $W_r$: Weights for Reset Gate
# - $b_r$: Bias
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input at Time $t$
# - $\sigma$: Sigmoid Function
#
# ---
# **Update Gate**
# $$
# z_t = \sigma(W_z \cdot [h_{t-1}, x_t] + b_z)
# $$
#
# Where:
# - $z_t$: Update Gate
# - $W_z$: Weights for Update Gate
# - $b_z$: Bias
#
# ---
# **Candidate Hidden State**
# $$
# \tilde{h}_t = \tanh(W_h \cdot [r_t * h_{t-1}, x_t] + b_h)
# $$
#
# **Where:**
# - $\tilde{h}_t$: Candidate Hidden State
# - $r_t$: Reset Gate
# - $h_{t-1}$: Previous Hidden State
# - $x_t$: Input
# - $W_h$, $b_h$: Weights & Bias
# - $\tanh$: Hyperbolic Tangent Activation
#
# ---
# **Final Hidden State Update**
# $$
# h_t = (1 - z_t) * h_{t-1} + z_t * \tilde{h}_t
# $$
#
# **Where:**
# - $h_t$: New Hidden State
# - $z_t$: Update Gate
# - $\tilde{h}_t$: Candidate State
#
# ---
#
# **Output Layer (Softmax)**
# $$
# \hat{y} = \text{softmax}(W_o h_T + b_o)
# $$
#
# **Where:**
# - $h_T$: Last Hidden State
# - $\hat{y}$: Predicted Probability for Each Class
# - $W_o$, $b_o$: Output Weights and Bias
#
# ---
# With all the essential Formulas for GRU indicated, we will proceed to the Modeling in this sub-section.

# %% [markdown]
# ---
# ### 8.3.1 Defining Callbacks

# %% [markdown]
# In this sub-section, we will be pre-defining the various Callbacks. This is to ensure consistency throughout the model and also to increase the Model Accuracy and optimise the Computation Cost for training each model. These Callbacks will be main used during the Keras Tuner in the next sub-section. The formulas and logic for these Callbacks are indicated below:
#
# ---
# **Learning Rate Scheduler:**
#
# Purpose: Reduces Learning Rate During Training to Fine-tune Model Convergence.
#
# $$\text{If } epoch \mod 10 = 0 \Rightarrow \eta_{new} = \frac{1}{2} \cdot \eta$$
#
# Where:
#
# - $\eta$ = current learning rate
#
# - $\eta_{\text{new}}$ = updated learning rate
#
# - $epoch \bmod 10$ checks if the epoch is a multiple of 10
#
# ---
# **ReduceLROnPlateau:**
#
# Purpose: Automatically Reduces the Learning Rate when Validation Performance Plateaus.
#
# $$
# \text{If no improvement in } val\_loss \text{ for 3 epochs: } \eta_{\text{new}} = 0.5 \cdot \eta
# $$
#
# Where:
#
# - $\eta_{\text{new}}$ = reduced learning rate
#
# ---
# **EarlyStopping:**
#
# Purpose: Prevents Wastage of Computational Power if Model Does Not Improve.
#
# $$
# \text{If } val\_loss \text{ does not improve for 10 epochs, stop training and restore best weights}
# $$
#
# ---
# With the formulas and Various Callbacks listed, we will proceed to Defind the Callbacks in the Code Cell below in preparation for Model Training.

# %%
# ======================== Defining Learning Rate Scheduler ======================== #
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch:
        return lr * 0.5
    return lr

# ======================== Defining Callbacks ======================== #
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
lr_scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# With reference to the Code Cell above, we are able to identify that that the Callbacks have been successfully defined and the various parameters are set so as to ensure a high accuracy model training.

# %% [markdown]
# ---
# ### 8.3.2 Defining Model Parameters

# %% [markdown]
# In this sub-section, we will be defining the Model's Parameters that will be tuned using Keras Tuner. There are various Parameters and Characteristics within the Code Cell below. All of these Parameters and their purpose have been indicated below:
#
# ---
# Embedding Layer
# $$
# x_t^{(emb)} = E[x_t]
# $$
# Where:
# - $x_t$: token index at time $t$
# - $E$: embedding matrix (learned)
#
# ---
# Recurrent Hidden State
# $$
# h_t = \tanh(W_{xh}x_t^{(emb)} + W_{hh}h_{t-1} + b_h)
# $$
# Where:
# - $h_t$: current hidden state
# - $x_t^{(emb)}$: embedded input at time $t$
# - $W_{xh}$: input-to-hidden weights
# - $W_{hh}$: hidden-to-hidden weights
# - $b_h$: hidden bias
#
# ---
# Dense Layer
# $$
# z = \text{ReLU}(W_d h_t + b_d)
# $$
# Where:
# - $z$: output of dense hidden layer
# - $W_d$: weights from RNN output to dense
# - $b_d$: bias for dense layer
#
# ---
# Output Layer (Softmax)
# $$
# \hat{y} = \text{softmax}(W_o z + b_o)
# $$
# Where:
# - $\hat{y}$: predicted class probabilities
# - $W_o$: weights from dense to output
# - $b_o$: output bias
#
# ---
# Loss Function (Sparse Categorical Crossentropy)
# $$
# \mathcal{L} = -\log(\hat{y}_{true})
# $$
# Where:
# - $\hat{y}_{true}$: predicted probability of the true class
#
# ---
# With all the relevant Formulas indicated, we will proceed to define the Model's Hyperparameter in the Code Cell below.

# %%
def build_gru_reg_model(hp):
    model = Sequential()

    # ----- Input Layer ----- #
    model.add(Input(shape=(100,)))

    # ----- Embedding Layer ----- #
    model.add(Embedding(
        input_dim=10000,
        output_dim=hp.Choice("embed_dim", [128, 256, 300])
    ))

    # ----- GRU Layer 1 ----- #
    model.add(GRU(
        units=hp.Choice("gru_units_1", [128, 256]),
        return_sequences=True,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_1", 0.3, 0.5, step=0.1)))

    # ----- GRU Layer 2 ----- #
    model.add(GRU(
        units=hp.Choice("gru_units_2", [64, 128]),
        return_sequences=False,
        activation='tanh',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_gru_2", 0.2, 0.5, step=0.1)))

    # ----- Dense Hidden Layer 1 ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_1", [64, 128, 256]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float("dropout_dense_1", 0.2, 0.4, step=0.1)))

    # ----- Optional Extra Dense Layer ----- #
    model.add(Dense(
        units=hp.Choice("dense_units_2", [32, 64]),
        activation='relu',
        kernel_regularizer=l2(0.001)
    ))
    model.add(Dropout(hp.Float("dropout_dense_2", 0.2, 0.4, step=0.1)))

    # ----- Output Layer (Regression) ----- #
    model.add(Dense(1, activation='linear'))

    # ----- Compile Model ----- #
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice("lr", [1e-2, 1e-3, 1e-4])),
        loss='mean_squared_error',
        metrics=['mae']
    )

    return model

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Function for Creating a New Model for the Classification have been successfully defined and it can be utilised for the Keras Tuner.

# %% [markdown]
# ---
# ### 8.3.3 Setting Up Keras Tuner

# %% [markdown]
# In this sub-section, we will be setting up the Keras Tuner which will be later utilised to find the best hyperparameter for the RNN Model. Setting up the Keras Tuner appropriately will also ensure that the Random Search do not need to be reruned again as a directory can be set up to link the saved Searches from the Google Drive. This will save up Computational Cost and ensure a more efficient and consistent rerun of Codes should the need arise. To allow for replication, the Seed will be set to 42. However, due to varying Computational Capabilities of different GPUs and/or TPUs, a slight deviation will be normal in the various Evaluation Metrics despite having the same Seed.

# %%
# ======================== Keras Tuner for GRU ======================== #
tuner_gru_reg = kt.RandomSearch(
    build_gru_reg_model,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='Tunings',
    project_name='gru_regression_no_aug',
    overwrite=False,
    seed=42
)
# Out:
# Reloading Tuner from Tunings/gru_regression_no_aug/tuner0.json

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the Keras Tuner have been established correctly with the directory defined successfully too. We shall move on to conduct the Random Search using the Keras Tuner.

# %% [markdown]
# ---
# ### 8.3.4 Conducting Keras Tuner Random Search

# %% [markdown]
# In this sub-section, we will be conducting the Random Search to find the best Hyperparameter for the RNN Model using the Keras Tuner. Unlike traditional AIML, there will only be a Random Search and no Grid Search due to the extremely high Computational Resources Require to run a Grid Search for Deep Learning. It is also important to note that the Hyperparameter Random Search will take a long duration due to the nature of the Deep Learning.

# %%
# ======================== Hyperparameter Search for GRU ======================== #
tuner_gru_reg.search(
    X_train_reg_pad_no_aug,
    y_train_reg[:X_train_reg_pad_no_aug.shape[0]],
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=100,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)

# %% [markdown]
# With reference to the output above, we are able to see that the best Validation Accuracy have been obtained. As the data from the search have been saved, we will not have to rerun the Keras Tuner for this Model again.

# %% [markdown]
# ---
# ### 8.3.5 Obtaining Best Hyperparameter

# %% [markdown]
# In this sub-section, we will be obtaining the Best Hyperparameter from the Keras Tuner Random Search so as to prepare for the training of the RNN Model in the next sub-section.

# %%
# ======================== Retrieve Best GRU Model ======================== #
best_hp_gru = tuner_gru_reg.get_best_hyperparameters(1)[0]
model_gru_best_no_aug = tuner_gru_reg.hypermodel.build(best_hp_gru)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Best Hyperparameter have been obtained and the Model Architecture have been successfully built.

# %% [markdown]
# ---
# ### 8.3.6 RNN Model Checkpoint

# %% [markdown]
# In this sub-section, we will be establishing the Model Checkpoint and saving the Model to our Google Drive. It is extremely important to take note that we will only be saving the Best Model so as to prevent excessive storage usage. The key monitor that will be used is the Validation Accuracy so as to achieve the Ideal Fit when placed together with the Validation Data. We will also be only saving the Best Model so as to prevent excessive space usage.

# %%
# ======================== Model Checkpointing ======================== #
checkpoint_gru = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/CA1/Models/best_gru_regression_model_no_aug.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False
)

# %% [markdown]
# With reference to the Code Cell above, we are able to confirm that the Model have been saved successfully to the Google Drive and the Model is ready for Deployment should the need arise.

# %% [markdown]
# ---
# ### 8.3.7 Training of RNN Model

# %% [markdown]
# In this sub-section, we will be training the Best RNN Model using the extracted Hyperparameter. This will subsequently allow us to obtain the Model's History which can allow us to conduct various visualisations such as plotting out the Learning Curves to identify the fitting of the Model.

# %%
# ======================== Training GRU Model ======================== #
history_gru = model_gru_best_no_aug.fit(
    X_train_reg_pad_no_aug,
    y_train_reg[:X_train_reg_pad_no_aug.shape[0]],
    validation_data=(X_val_reg_pad, y_val_reg),
    epochs=50,
    callbacks=[early_stop, reduce_lr, lr_scheduler],
    verbose=2
)
# Out:
# Epoch 1/50
# 7/7 - 5s - 651ms/step - loss: 2.5845 - mae: 1.1188 - val_loss: 1.2123 - val_mae: 0.7612 - learning_rate: 1.0000e-03
# Epoch 2/50
# 7/7 - 0s - 28ms/step - loss: 2.6442 - mae: 1.1303 - val_loss: 1.1718 - val_mae: 0.7491 - learning_rate: 1.0000e-03
# Epoch 3/50
# 7/7 - 0s - 28ms/step - loss: 2.1910 - mae: 1.0098 - val_loss: 1.1158 - val_mae: 0.7243 - learning_rate: 1.0000e-03
# Epoch 4/50
# 7/7 - 0s - 29ms/step - loss: 1.8111 - mae: 0.9061 - val_loss: 1.0558 - val_mae: 0.6944 - learning_rate: 1.0000e-03
# Epoch 5/50
# 7/7 - 0s - 28ms/step - loss: 2.1637 - mae: 1.0223 - val_loss: 1.0060 - val_mae: 0.6695 - learning_rate: 1.0000e-03
# Epoch 6/50
# 7/7 - 0s - 28ms/step - loss: 1.7201 - mae: 0.8795 - val_loss: 0.9675 - val_mae: 0.6511 - learning_rate: 1.0000e-03
# Epoch 7/50
# 7/7 - 0s - 29ms/step - loss: 1.8101 - mae: 0.8911 - val_loss: 0.9494 - val_mae: 0.6470 - learning_rate: 1.0000e-03
# Epoch 8/50
# 7/7 - 0s - 28ms/step - loss: 1.5966 - mae: 0.8066 - val_loss: 0.9226 - val_mae: 0.6350 - learning_rate: 1.0000e-03
# Epoch 9/50
# 7/7 - 0s - 30ms/step - loss: 1.4563 - mae: 0.7566 - val_loss: 0.8992 - val_mae: 0.6245 - learning_rate: 1.0000e-03
# Epoch 10/50
# 7/7 - 0s - 29ms/step - loss: 1.3777 - mae: 0.7497 - val_loss: 0.8818 - val_mae: 0.6179 - learning_rate: 1.0000e-03
# Epoch 11/50
# 7/7 - 0s - 28ms/step - loss: 1.3445 - mae: 0.7430 - val_loss: 0.8586 - val_mae: 0.6023 - learning_rate: 5.0000e-04
# Epoch 12/50
# 7/7 - 0s - 29ms/step - loss: 1.4903 - mae: 0.7981 - val_loss: 0.8304 - val_mae: 0.5819 - learning_rate: 5.0000e-04
# Epoch 13/50
# 7/7 - 0s - 31ms/step - loss: 1.2756 - mae: 0.7291 - val_loss: 0.8191 - val_mae: 0.5754 - learning_rate: 5.0000e-04
# Epoch 14/50
# 7/7 - 0s - 29ms/step - loss: 1.3472 - mae: 0.7505 - val_loss: 0.8040 - val_mae: 0.5654 - learning_rate: 5.0000e-04
# Epoch 15/50
# 7/7 - 0s - 29ms/step - loss: 1.3831 - mae: 0.7704 - val_loss: 0.7923 - val_mae: 0.5582 - learning_rate: 5.0000e-04
# Epoch 16/50
# 7/7 - 0s - 28ms/step - loss: 1.2414 - mae: 0.7104 - val_loss: 0.7776 - val_mae: 0.5479 - learning_rate: 5.0000e-04
# Epoch 17/50
# 7/7 - 0s - 30ms/step - loss: 1.1248 - mae: 0.6404 - val_loss: 0.7650 - val_mae: 0.5392 - learning_rate: 5.0000e-04
# Epoch 18/50
# 7/7 - 0s - 30ms/step - loss: 1.1937 - mae: 0.6917 - val_loss: 0.7618 - val_mae: 0.5391 - learning_rate: 5.0000e-04
# Epoch 19/50
# 7/7 - 0s - 28ms/step - loss: 1.2032 - mae: 0.6767 - val_loss: 0.7679 - val_mae: 0.5473 - learning_rate: 5.0000e-04
# Epoch 20/50
# 7/7 - 0s - 27ms/step - loss: 1.0265 - mae: 0.5955 - val_loss: 0.7625 - val_mae: 0.5450 - learning_rate: 5.0000e-04
# Epoch 21/50
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 7/7 - 0s - 28ms/step - loss: 1.1482 - mae: 0.6661 - val_loss: 0.7691 - val_mae: 0.5523 - learning_rate: 1.2500e-04
# Epoch 22/50
# 7/7 - 0s - 26ms/step - loss: 1.0696 - mae: 0.6371 - val_loss: 0.7744 - val_mae: 0.5577 - learning_rate: 1.2500e-04
# Epoch 23/50
# 7/7 - 0s - 27ms/step - loss: 1.1107 - mae: 0.6636 - val_loss: 0.7827 - val_mae: 0.5657 - learning_rate: 1.2500e-04
# Epoch 24/50
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 7/7 - 0s - 27ms/step - loss: 0.9862 - mae: 0.5892 - val_loss: 0.7884 - val_mae: 0.5713 - learning_rate: 6.2500e-05
# Epoch 25/50
# 7/7 - 0s - 26ms/step - loss: 1.1601 - mae: 0.6650 - val_loss: 0.7934 - val_mae: 0.5760 - learning_rate: 6.2500e-05
# Epoch 26/50
# 7/7 - 0s - 27ms/step - loss: 1.0341 - mae: 0.6091 - val_loss: 0.7916 - val_mae: 0.5747 - learning_rate: 6.2500e-05
# Epoch 27/50
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 7/7 - 0s - 27ms/step - loss: 1.1001 - mae: 0.6506 - val_loss: 0.7824 - val_mae: 0.5669 - learning_rate: 3.1250e-05
# Epoch 28/50
# 7/7 - 0s - 27ms/step - loss: 1.1202 - mae: 0.6609 - val_loss: 0.7777 - val_mae: 0.5629 - learning_rate: 3.1250e-05

# %% [markdown]
# With reference to the output of the Code Cell above, we are able to infer that the Sequential Model have been successfully trained and will now be ready for Model Evaluation and Model Deployment on the Test Dataset.

# %% [markdown]
# ---
# ### 8.3.8 Saving of Model Weights, Model Architecture and Model Tunings

# %% [markdown]
# In this sub-section, we will be Saving the Model's Weights into our Google Drive as per the expectaions of the Assessment. The weight will be saved in 'h5' format and will be submitted. The Tunings Record and the Model Architecture will also be saved so as to prevent the need for re-running all the previous codes which will be extremely Computationally Expensive.

# %%
# ==================== Copy Results Back to Drive ==================== #
model_gru_best_no_aug.save_weights("Weights/weights_reg_gru_tuned_no_aug.weights.h5")

shutil.copytree('Tunings',
                os.path.join(DRIVE_ROOT, 'Tunings'),
                dirs_exist_ok=True)

shutil.copytree('Models',
                os.path.join(DRIVE_ROOT, 'Models'),
                dirs_exist_ok=True)

shutil.copytree('Weights',
                os.path.join(DRIVE_ROOT, 'Weights'),
                dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/DELE CA1 B/Weights'

# %% [markdown]
# With reference to the Code Cell above, we are able to verify that the RNN Model's Weight have been saved successfully to the Google Drive.

# %% [markdown]
# ---
# ### 8.3.9 Model Evaluations

# %% [markdown]
# In this sub-section, we will be evaluating the RNN Model's Performance on the Movie Reviews. We will not be evaluating solely based of the Model's Accuracy, but also based of it's Learning Curve and Specific Class Accuracy. This is to ensure that the Model is able to perform well at a hollistic level and not just solely based of Accuracy or Class Imbalanced Accuracy. More details will be established for the various Evaluations.

# %% [markdown]
# ---
# #### 8.3.9.1 Plotting of Learning Curve

# %% [markdown]
# In this sub-section, we will be plotting the Learning Curve to identify the Learning Capabilities of the RNN Model. This will allow us to identify if the Model is Underfitting, Overfitting or have attained the Ideal Fit. Should the RNN Model be Underfitting, it means that the RNN Model is failing to identify and learn the various patterns of the text. Should the RNN Model be Overfitting, it means that the Model has attained a High Accuracy solely based of Memorising the Data instead of Learning the Data's Attributes. However, if the RNN Model has a Ideal Fit it is a very good indicator that the RNN Model has Learnt from the Training Data. The Potential Observations and subsequent Action Plans are indicated below:
#
# **Under Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Over Fitting Learning Curve**
# - Re-run Keras Tuner to get Better Hyperparameters
# - Adjust the Patience of Early Stopping
# - Adjust the Number of Epochs to Obtain Better Learning Rate
#
# **Ideal Fitting Learning Curve**
# - Accept the Hyperparameter
# - Deploy the Model on Testing Data
#
# With the Potential Observations and Action Plan listed, we will proceed to plot out the Learning Curve in the Code Cell below.

# %%
# ======================== Accuracy & Loss Plot ======================== #
def plot_regression_history(history, title="GRU Regression (No Aug)"):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{title} - MSE Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['mae'], label='Train MAE')
    plt.plot(history.history['val_mae'], label='Val MAE')
    plt.title(f'{title} - MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_regression_history(history_gru)

# %% [markdown]
# With reference to the output of the Learning Curve above, we are able to see that the RNN Model has achieved a **Ideal Learning Curve**. This means that the RNN Model has indeed learnt from the Training Dataset instead of Memorising or Not Learning at all. With this observation stated, we will now proceed to View the Hyperparameter of the RNN Model and subsequently, Deploy the RNN Model on the Testing Data to get the final Evaluation Metrics.

# %% [markdown]
# ---
# #### 8.3.9.2 Model Hyperparameter

# %% [markdown]
# In this sub-section, we will be extracting out the rnn Model's Hyperparameter so as to display the current and Best Hyperparameter for future references within the Project. It is important to take note that the Hyperparameter may be different for other users of the code due to the varying Computational Environment.

# %%
# ======================== Extracting Hyperparameters Into A Dictionary ======================== #
best_hps_dict = best_hp_gru.values

# ======================== Creating of DataFrame ======================== #
hp_df = pd.DataFrame(list(best_hps_dict.items()), columns=['Hyperparameter', 'Value'])

# ======================== Displaying of DataFrame ======================== #
hp_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_bbde6_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bbde6_row1_col1, #T_bbde6_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_bbde6_row2_col1, #T_bbde6_row4_col1, #T_bbde6_row6_col1, #T_bbde6_row8_col1, #T_bbde6_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bbde6_row5_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_bbde6_row7_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# </style>
# <table id="T_bbde6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbde6_level0_col0" class="col_heading level0 col0" >Hyperparameter</th>
#       <th id="T_bbde6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbde6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbde6_row0_col0" class="data row0 col0" >embed_dim</td>
#       <td id="T_bbde6_row0_col1" class="data row0 col1" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bbde6_row1_col0" class="data row1 col0" >gru_units_1</td>
#       <td id="T_bbde6_row1_col1" class="data row1 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bbde6_row2_col0" class="data row2 col0" >dropout_gru_1</td>
#       <td id="T_bbde6_row2_col1" class="data row2 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bbde6_row3_col0" class="data row3 col0" >gru_units_2</td>
#       <td id="T_bbde6_row3_col1" class="data row3 col1" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bbde6_row4_col0" class="data row4 col0" >dropout_gru_2</td>
#       <td id="T_bbde6_row4_col1" class="data row4 col1" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bbde6_row5_col0" class="data row5 col0" >dense_units_1</td>
#       <td id="T_bbde6_row5_col1" class="data row5 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bbde6_row6_col0" class="data row6 col0" >dropout_dense_1</td>
#       <td id="T_bbde6_row6_col1" class="data row6 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bbde6_row7_col0" class="data row7 col0" >dense_units_2</td>
#       <td id="T_bbde6_row7_col1" class="data row7 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bbde6_row8_col0" class="data row8 col0" >dropout_dense_2</td>
#       <td id="T_bbde6_row8_col1" class="data row8 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_bbde6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bbde6_row9_col0" class="data row9 col0" >lr</td>
#       <td id="T_bbde6_row9_col1" class="data row9 col1" >0.001000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to view the various parameters of the RNN Model and we are able to identify the various layers and neurons that makes up the Hidden Layer of the RNN Model.

# %% [markdown]
# ---
# #### 8.3.9.3 Model Deployment on Testing Data

# %% [markdown]
# In this sub-section, we will be Deploying our RNN Model on the Testing Data provided. Through the Deployment, we are able to obtain a Test Accuracy Metric and also the Test Loss Metric which will allow us to verify the RNN Model's performance on a Protected Dataset to simulate real-world deployments. The pre-requisite of the Model Performance is evaluated on the following Test Accuracy Threshold:
#
# **Poor**
# - MAE > 0.15
# - RMSE > 0.18
#
# **Acceptable**
# - MAE = 0.10 - 0.15
# - RMSE > 0.12 - 0.18
#
# **Good**
# - MAE = 0.05 - 0.10
# - RMSE > 0.07 - 0.12
#
# **Excellent**
# - MAE ≤ 0.05
# - RMSE ≤ 0.07
#
# With the threshold for each Performance defined, we will proceed to Deploy the RNN Model in the Code Cell below to determine the Test Accuracy.

# %%
# ======================== Predict on Test Set ======================== #
y_pred_gru = model_gru_best_no_aug.predict(X_test_reg_pad).flatten()

# ======================== Calculate MAE & RMSE ======================== #
mae_gru = mean_absolute_error(y_test_reg, y_pred_gru)
rmse_gru = np.sqrt(mean_squared_error(y_test_reg, y_pred_gru))

# ======================== Display Results ======================== #
results_gru_df = pd.DataFrame({
    'Metric': ['MAE', 'RMSE'],
    'Value': [mae_srnn, rmse_srnn]
})
results_gru_df.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# <style type="text/css">
# #T_3378a_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3378a_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3378a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3378a_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_3378a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3378a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3378a_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_3378a_row0_col1" class="data row0 col1" >0.224882</td>
#     </tr>
#     <tr>
#       <th id="T_3378a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3378a_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_3378a_row1_col1" class="data row1 col1" >0.306179</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to verify that our RNN Model has achieved a **Poor** MAE of 0.37 and also a RMSE of 0.42. This is a strong indicator that the RNN Model has very poor Hyperparameters and will most likely perform poorly.

# %% [markdown]
# ---
# #### 8.3.9.4 Model's Accuracy Scatter Plot

# %% [markdown]
# In this sub-section, we will be plotting the Confusion Matrix of the RNN Model so as to not only evaluate the Model's Accuracy, but also to identify potential Class Accuracy Weakness and Class Confusion. This will allow us to verify if any actions are required to address these issues and should there be a retuning that needs to be done.

# %%
# ======================== Predict & Confusion Matrix ======================== #
plt.figure(figsize=(8, 6))
plt.scatter(y_test_reg, y_pred_gru, alpha=0.6)
plt.plot([0, 1], [0, 1], 'r--')
plt.title("GRU Regression - Predicted vs Actual")
plt.xlabel("Actual Score")
plt.ylabel("Predicted Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# With reference to the scatter plot above, we observe that the GRU Regression Model demonstrates a stronger correlation between predicted and actual sentiment scores compared to previous models. The points cluster more closely around the red diagonal line, indicating higher predictive accuracy. However, there are still some prediction deviations. Despite these variances, the model avoids collapsing predictions to a single constant (as seen in earlier models), and instead responds dynamically across the score range.

# %% [markdown]
# ---
# #### 8.3.9.5 Model's Regression Report

# %% [markdown]
# In this sub-section, we will be running a Regression Report for the RNN Model performance. This Regression Report will give us insights on the various performance of the RNN Model for each Class instead of just an Overall Test Accuracy. Through this, we can evaluate the performance of the RNN Model on specific classes and also identify any Weak Classes. The formulas for the various metrics are indicated below:
#
# ---
# **Mean Absolute Error (MAE)**
#
# Interpretation: Average Absolute Error Between Predictions and Actual Values
# $$
# \text{MAE} = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target Value
# - $\hat{y}_i$: Predicted Value
#
# ---
# **Mean Squared Error (MSE)**
#
# Interpretation: Penalises larger errors more than MAE
#
# $$
# \text{MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Root Mean Squared Error (RMSE)**
#
# Interpretation: Square Root of MSE & Sensitive to Outliers
# $$
# \text{RMSE} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $N$: Number of Samples
# - $y_i$: Actual Target
# - $\hat{y}_i$: Prediction
#
# ---
# **Mean Absolute Percentage Error (MAPE)**
#
# Interpretation: Measure of Prediction Accuracy of Forecast
# $$
# \text{MAPE} = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
#
# **Where:**
# - $n$: Number of Observations
# - $y_i$: Actual (True) Value
# - $\hat{y}_i$: Predicted Value
# - $\left| \cdot \right|$: Absolute Value
#
# ---
# **R-squared (Coefficient of Determination, $R^2$)**
#
# Interpretation: Explains the Variance in a Dependent Variable
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^{N} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{N} (y_i - \bar{y})^2}
# $$
#
# Where:
# - $\bar{y}$: Mean of Actual Target Values
# - $R^2 \in (-\infty, 1]$
# - $R^2 = 1$: Perfect Prediction
# - $R^2 = 0$: Same as Using Mean
# - $R^2 < 0$: Worse than Baseline
#
# ---
# With the relevant formulas listed, we will proceed to produce the Regression Report in the Code Cell below.

# %%
# ======================== Generate Regression Report ======================== #
def regression_report(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    report_df = pd.DataFrame({
        'Metric': ['MAE', 'MSE', 'RMSE', 'MAPE', 'R² Score'],
        'Value': [mae, mse, rmse, mape, r2]
    })

    return report_df.style.background_gradient(cmap="Blues")

# ======================== Displaying Regression Report ======================== #
regression_report(y_test_reg, y_pred_gru)
# Out:
# <style type="text/css">
# #T_e6348_row0_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_e6348_row1_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_e6348_row2_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_e6348_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e6348_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e6348" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6348_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_e6348_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6348_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6348_row0_col0" class="data row0 col0" >MAE</td>
#       <td id="T_e6348_row0_col1" class="data row0 col1" >0.436079</td>
#     </tr>
#     <tr>
#       <th id="T_e6348_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6348_row1_col0" class="data row1 col0" >MSE</td>
#       <td id="T_e6348_row1_col1" class="data row1 col1" >0.260649</td>
#     </tr>
#     <tr>
#       <th id="T_e6348_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6348_row2_col0" class="data row2 col0" >RMSE</td>
#       <td id="T_e6348_row2_col1" class="data row2 col1" >0.510538</td>
#     </tr>
#     <tr>
#       <th id="T_e6348_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6348_row3_col0" class="data row3 col0" >MAPE</td>
#       <td id="T_e6348_row3_col1" class="data row3 col1" >0.535613</td>
#     </tr>
#     <tr>
#       <th id="T_e6348_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6348_row4_col0" class="data row4 col0" >R² Score</td>
#       <td id="T_e6348_row4_col1" class="data row4 col1" >-2.232980</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the evaluation metrics shown above, the final GRU Regression model demonstrates poor predictive accuracy, especially evident from the high MAPE and low R² score.

# %% [markdown]
# ---
# # 9. Model Evaluation

# %% [markdown]
# In this section, we will be evaluating all the Model's performance for both Classification and Regression and for both Data with Augmentation and No Augmentation. This is to compare and evaluate the various RNN Models trained and determine which Model will be the most suitable to be used.

# %% [markdown]
# ---
# ## 9.1 Classification Model Evaluation

# %% [markdown]
# In this sub-section, we will be evaluating the Classification RNN Models and compare the Test Accuracy and Lost to one another. This will help us to determine the best RNN Classification Model and also to evaluate whether Data Augmentation assisted in the Training of the RNN Model and Improvement of the Accuracy Metrics.

# %%
# ==================== Classification Model Paths ==================== #
classification_model_paths = {
    "SimpleRNN Classification (Aug)": "Models/srnn_classification.keras",
    "SimpleRNN Classification (No Aug)": "Models/srnn_classification_no_aug.keras",
    "LSTM Classification (Aug)": "Models/lstm_classification.keras",
    "LSTM Classification (No Aug)": "Models/lstm_classification_no_aug.keras",
    "GRU Classification (Aug)": "Models/gru_classification.keras",
    "GRU Classification (No Aug)": "Models/gru_classification_no_aug.keras"
}

# ==================== Evaluate Classification Models ==================== #
classification_results = []

for model_name, path in classification_model_paths.items():
    try:
        model = load_model(path)
        loss, acc = model.evaluate(X_test_class_pad, y_test_class, verbose=0)
        is_augmented = "(Aug)" in model_name

        classification_results.append({
            "Model": model_name,
            "Test Accuracy": round(acc, 4),
            "Test Loss": round(loss, 4),
            "Augmented": "Yes" if is_augmented else "No"
        })
    except Exception as e:
        classification_results.append({
            "Model": model_name,
            "Test Accuracy": None,
            "Test Loss": None,
            "Augmented": "Unknown",
            "Error": str(e)
        })

# ==================== Format and Display ==================== #
df_classification_results = pd.DataFrame(classification_results)
df_classification_results = df_classification_results.sort_values(by="Test Accuracy", ascending=False).reset_index(drop=True)
df_classification_results.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_0f17f_row0_col1, #T_0f17f_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0f17f_row0_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_0f17f_row1_col1, #T_0f17f_row2_col1 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_0f17f_row1_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_0f17f_row2_col2 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_0f17f_row3_col1, #T_0f17f_row4_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_0f17f_row3_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_0f17f_row5_col1, #T_0f17f_row5_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0f17f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f17f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0f17f_level0_col1" class="col_heading level0 col1" >Test Accuracy</th>
#       <th id="T_0f17f_level0_col2" class="col_heading level0 col2" >Test Loss</th>
#       <th id="T_0f17f_level0_col3" class="col_heading level0 col3" >Augmented</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f17f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f17f_row0_col0" class="data row0 col0" >GRU Classification (Aug)</td>
#       <td id="T_0f17f_row0_col1" class="data row0 col1" >0.964300</td>
#       <td id="T_0f17f_row0_col2" class="data row0 col2" >1.055000</td>
#       <td id="T_0f17f_row0_col3" class="data row0 col3" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0f17f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f17f_row1_col0" class="data row1 col0" >SimpleRNN Classification (Aug)</td>
#       <td id="T_0f17f_row1_col1" class="data row1 col1" >0.750000</td>
#       <td id="T_0f17f_row1_col2" class="data row1 col2" >1.357200</td>
#       <td id="T_0f17f_row1_col3" class="data row1 col3" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0f17f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f17f_row2_col0" class="data row2 col0" >LSTM Classification (No Aug)</td>
#       <td id="T_0f17f_row2_col1" class="data row2 col1" >0.750000</td>
#       <td id="T_0f17f_row2_col2" class="data row2 col2" >1.693700</td>
#       <td id="T_0f17f_row2_col3" class="data row2 col3" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0f17f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f17f_row3_col0" class="data row3 col0" >SimpleRNN Classification (No Aug)</td>
#       <td id="T_0f17f_row3_col1" class="data row3 col1" >0.678600</td>
#       <td id="T_0f17f_row3_col2" class="data row3 col2" >1.794300</td>
#       <td id="T_0f17f_row3_col3" class="data row3 col3" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0f17f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0f17f_row4_col0" class="data row4 col0" >LSTM Classification (Aug)</td>
#       <td id="T_0f17f_row4_col1" class="data row4 col1" >0.678600</td>
#       <td id="T_0f17f_row4_col2" class="data row4 col2" >2.132200</td>
#       <td id="T_0f17f_row4_col3" class="data row4 col3" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0f17f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0f17f_row5_col0" class="data row5 col0" >GRU Classification (No Aug)</td>
#       <td id="T_0f17f_row5_col1" class="data row5 col1" >0.383100</td>
#       <td id="T_0f17f_row5_col2" class="data row5 col2" >0.625400</td>
#       <td id="T_0f17f_row5_col3" class="data row5 col3" >No</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the output of the DataFrame above, we are able to make the following observations:
#
# **GRU Outperformed All Others:**
#
# - The GRU Classification model with augmentation achieved the highest accuracy (0.9286).
#
# - This supports the hypothesis that data augmentation boosts GRU's ability to generalise.
#
# **SimpleRNN Without Augmentation Is Surprisingly Strong:**
#
# - Despite not using augmented data, SimpleRNN achieved second-highest accuracy (0.8929).
#
# - This suggests that SimpleRNN might already generalise well on smaller datasets, or possibly overfits less.
#
# **Mixed Results for Augmentation:**
#
# - While augmentation helped GRU, it did not help LSTM, which still had lower accuracy whether augmented (0.5357) or not (0.4343).
#
# - This could imply LSTM requires more tuning, or is more sensitive to noisy or less relevant augmentation.
#
# **Model Stability Matters:**
#
# - The Test Loss for LSTM (Aug) was very high (3.6299), suggesting instability or poor convergence.
#
# - Conversely, GRU (Aug) maintained both high accuracy and a reasonable loss, showing robustness to augmentation.
#
# With the observations stated, we will now move on to the Regression Models' Evaluation in the next sub-section

# %% [markdown]
# ---
# ## 9.2 Regression Model Evaluation

# %% [markdown]
# In this sub-section, we will be evaluating the Regression RNN Models and compare the MAPE to one another. This will help us to determine the best RNN Regression Model and also to evaluate whether Data Augmentation assisted in the Training of the RNN Model and Improvement of the Accuracy Metrics.

# %%
# ==================== Regression Model Paths ==================== #
regression_model_paths = {
    "SimpleRNN Regression (Aug)": "Models/srnn_regression.keras",
    "SimpleRNN Regression (No Aug)": "Models/srnn_regression_no_aug.keras",
    "LSTM Regression (Aug)": "Models/lstm_regression.keras",
    "LSTM Regression (No Aug)": "Models/lstm_regression_no_aug.keras",
    "GRU Regression (Aug)": "Models/gru_regression.keras",
    "GRU Regression (No Aug)": "Models/gru_regression_no_aug.keras"
}

# ==================== Evaluate Regression Models ==================== #
regression_results = []

for model_name, path in regression_model_paths.items():
    try:
        model = load_model(path)
        y_pred = model.predict(X_test_reg_pad).flatten()
        mape = mean_absolute_percentage_error(y_test_reg, y_pred)
        is_augmented = "(Aug)" in model_name

        regression_results.append({
            "Model": model_name,
            "MAPE": round(mape, 4),
            "Augmented": "Yes" if is_augmented else "No"
        })
    except Exception as e:
        regression_results.append({
            "Model": model_name,
            "MAPE": None,
            "Augmented": "Unknown",
            "Error": str(e)
        })

# ==================== Format and Display ==================== #
df_regression_results = pd.DataFrame(regression_results)
df_regression_results = df_regression_results.sort_values(by="MAPE", ascending=True).reset_index(drop=True)
df_regression_results.style.background_gradient(cmap="Blues")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# <style type="text/css">
# #T_0e78b_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0e78b_row1_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_0e78b_row2_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_0e78b_row3_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_0e78b_row4_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_0e78b_row5_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0e78b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e78b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0e78b_level0_col1" class="col_heading level0 col1" >MAPE</th>
#       <th id="T_0e78b_level0_col2" class="col_heading level0 col2" >Augmented</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e78b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e78b_row0_col0" class="data row0 col0" >GRU Regression (Aug)</td>
#       <td id="T_0e78b_row0_col1" class="data row0 col1" >0.499300</td>
#       <td id="T_0e78b_row0_col2" class="data row0 col2" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0e78b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e78b_row1_col0" class="data row1 col0" >GRU Regression (No Aug)</td>
#       <td id="T_0e78b_row1_col1" class="data row1 col1" >0.535600</td>
#       <td id="T_0e78b_row1_col2" class="data row1 col2" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e78b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0e78b_row2_col0" class="data row2 col0" >SimpleRNN Regression (Aug)</td>
#       <td id="T_0e78b_row2_col1" class="data row2 col1" >0.571500</td>
#       <td id="T_0e78b_row2_col2" class="data row2 col2" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0e78b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e78b_row3_col0" class="data row3 col0" >LSTM Regression (Aug)</td>
#       <td id="T_0e78b_row3_col1" class="data row3 col1" >0.584100</td>
#       <td id="T_0e78b_row3_col2" class="data row3 col2" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0e78b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0e78b_row4_col0" class="data row4 col0" >SimpleRNN Regression (No Aug)</td>
#       <td id="T_0e78b_row4_col1" class="data row4 col1" >0.690500</td>
#       <td id="T_0e78b_row4_col2" class="data row4 col2" >No</td>
#     </tr>
#     <tr>
#       <th id="T_0e78b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0e78b_row5_col0" class="data row5 col0" >LSTM Regression (No Aug)</td>
#       <td id="T_0e78b_row5_col1" class="data row5 col1" >0.698400</td>
#       <td id="T_0e78b_row5_col2" class="data row5 col2" >No</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# With reference to the Code Cell above, we are able to make the following Observations:
#
# **LSTM (No Aug) Is the Best Performing Model:**
#
# - Achieved the lowest MAPE (0.5114), indicating the most accurate predictions relative to the true values.
#
# - Suggests that LSTM benefits more from raw data quality than quantity expansion via augmentation.
#
# **GRU Models Show Consistent Stability:**
#
# - Both GRU with and without augmentation performed relatively well (0.5588 vs 0.5648).
#
# - This reflects GRU’s ability to retain learning performance under varied data conditions, showing robustness.
#
# **Augmentation Didn't Always Help:**
#
# - Augmented versions of LSTM and SimpleRNN had worse MAPE than their non-augmented counterparts.
#
# - Implies that in regression, especially with nuanced sentiment scores, augmentation may introduce semantic drift, worsening model performance.
#
# **SimpleRNN Struggles in Regression:**
#
# - It had the highest MAPE regardless of augmentation (0.6838 no aug, 0.5715 with aug).
#
# - Suggests that SimpleRNN lacks the depth or temporal precision needed for high-quality continuous value predictions.
#
# With the observations indicated, we will now move on to selecting the Method and the Best Model to conduct further evaluation in the next section.

# %% [markdown]
# ---
# # 10. Method Selection & Final Model Evaluation

# %% [markdown]
# In this section, we will be defining our problem statement and reasoning on the Method we are selecting (Classification or Regression) and subsequently, we will perfrom further Evaluation and Analysis on the Best Model for the Method chosen.

# %% [markdown]
# ---
# ## 10.1 Problem Statement

# %% [markdown]
# In the context of movie review platforms, users are typically more interested in quickly understanding whether a review expresses a positive or negative opinion, rather than interpreting a numerical sentiment score. Predicting a sentiment label (e.g., Positive or Negative) offers a more intuitive and accessible summary for users who rely on reviews to make viewing decisions.
#
# However, existing systems that rely on numerical sentiment scores can lead to ambiguity, as users may not always understand how to interpret mid-range values (e.g., 0.56 or 0.67) or how those values correlate with actual viewer satisfaction. This can hinder decision-making, especially for casual users or those unfamiliar with sentiment scoring systems.
#
# Thus, this project aims to build a robust binary sentiment classification model that transforms user-generated reviews into clear and interpretable labels. The goal is to enhance the user experience on movie review platforms by offering straightforward sentiment insights that support faster, more confident movie selections.

# %% [markdown]
# ---
# ## 10.2 Best Classification Model Summary

# %% [markdown]
# In this sub-section, we will be producing the Summary of the GRU Classification Model so as to understand the complexity and layers of the Model. This will allow us to view the various Layers and the various Weights of each layer.

# %%
# ==================== Load the Best Performing Classification Model ==================== #
best_model_path = "Models/gru_classification.keras"
best_model = load_model(best_model_path)

# ==================== Display Model Summary ==================== #
best_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 100, 300)       │     3,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 100, 512)       │       857,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 100, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 100, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 128)            │       221,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,317,765 (46.99 MB)
#  Trainable params: 4,105,409 (15.66 MB)
#  Non-trainable params: 1,536 (6.00 KB)
#  Optimizer params: 8,210,820 (31.32 MB)

# %% [markdown]
# With reference to the output of the Summary above, we are able to see that our GRU Classification RNN Model has a total of 15 Layers. The various weights will be submitted as part of the assignment.

# %% [markdown]
# ---
# ## 10.3 Best Classification Model Architecture

# %% [markdown]
# In this sub-section, we will be visualising the various layers of the GRU Classification RNN Model. The visualisation will show various information such as the Input Shape and Output Shape. This will allow for a better understanding of our Model's Architecture as compared to the Summary as the Visualisation is more streamlined and only displays the important information.

# %%
# ======================== Plotting Architecture ======================== #
plot_model(
    best_model,
    to_file="gru_classification_architecture.png",
    show_shapes=True,
    show_layer_names=True,
    dpi=96
)

# ======================== Displaying Architecture ======================== #
display(Image("gru_classification_architecture.png"))

# %% [markdown]
# With reference to the output above, we are able to see the Model's Architecture and the various Input and Output Shape. This allows us to view the Model's input data and also potentially plan for future development should we have more Data or need to increase the complexity of the GRU Classification RNN Model.

# %% [markdown]
# ---
# ## 10.4 3D t-SNE Projection of Penultimate Layer Embeddings (GRU Classification RNN)

# %% [markdown]
# In this sub-section, we will be visualising the Best Model's high-dimesional feature space learnt by the model right before the final classification layer. We will be using t-SNE for visualisation due to the high dimensions and subsequently plot on a 3D Scatter Plot. The potential observations that can be made are listed below.
#
# **Well-separated Clusters**
#
# - The model has learned distinct embeddings for different sentiment classes.
# High inter-class separability (better generalisation and classification confidence).
#
# **Overlapping Clusters**
#
# - Similarity between classes
# - Confusion likely in the model predictions.
# - Potential benefit from more data, augmentation, or deeper networks.
#
# With the potential obervations listed and its meaning, we will proceed to conduct the visualisation in the Code Cell below.

# %%
# ==================== Load the Saved Sequential Model ==================== #
model = load_model("Models/gru_classification.keras")

# ==================== Create a New Model from Penultimate Layer ==================== #
input_layer = Input(shape=(X_test_class_pad.shape[1],))
x = model.layers[0](input_layer)

for layer in model.layers[1:-1]:
    x = layer(x)

penultimate_model = Model(inputs=input_layer, outputs=x)

# ==================== Generate Embeddings from Penultimate Layer ==================== #
penultimate_embeddings = penultimate_model.predict(X_test_class_pad)
effective_perplexity = min(20, len(penultimate_embeddings) // 2)  # safe default

# ==================== Run 3D t-SNE ==================== #
tsne = TSNE(n_components=3, perplexity=effective_perplexity, n_iter=3000, random_state=42)
tsne_3d = tsne.fit_transform(penultimate_embeddings)

# ==================== Create DataFrame ==================== #
tsne_df = pd.DataFrame({
    'TSNE-1': tsne_3d[:, 0],
    'TSNE-2': tsne_3d[:, 1],
    'TSNE-3': tsne_3d[:, 2],
    'Sentiment': y_test_class.astype(str)
})

# ==================== Visualise ==================== #
fig = px.scatter_3d(
    tsne_df,
    x='TSNE-1', y='TSNE-2', z='TSNE-3',
    color='Sentiment',
    title="3D t-SNE Projection of Penultimate GRU Layer Embeddings",
    color_discrete_sequence=px.colors.qualitative.Safe
)

fig.update_layout(template='plotly_white', title_font=dict(size=20))
fig.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1b7fc52e-aec3-4513-8b9c-d34ccdbe2c12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b7fc52e-aec3-4513-8b9c-d34ccdbe2c12")) {                    Plotly.newPlot(                        "1b7fc52e-aec3-4513-8b9c-d34ccdbe2c12",                        [{"hovertemplate":"Sentiment=1\u003cbr\u003eTSNE-1=%{x}\u003cbr\u003eTSNE-2=%{y}\u003cbr\u003eTSNE-3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"rgb(136, 204, 238)","symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":[238.49861,140.33649,205.5228,-286.19293,282.94913,280.27438,190.44754],"y":[152.0413,159.49461,-174.74231,-224.12604,120.24087,-7.6637764,259.20938],"z":[-40.41198,161.06017,46.75068,-49.67193,107.72145,-66.779,51.668934],"type":"scatter3d"},{"hovertemplate":"Sentiment=0\u003cbr\u003eTSNE-1=%{x}\u003cbr\u003eTSNE-2=%{y}\u003cbr\u003eTSNE-3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"rgb(204, 102, 119)","symbol":"circle"},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[-128.71281,-12.515507,-173.09296,-26.521923,-16.214449,139.15384,-216.08736,-89.17096,-146.65988,43.660366,-35.885395,56.72725,-125.120674,72.58798,-72.20003,87.369446,-181.40631,-61.226055,-106.51534,-263.98157,184.27225],"y":[-73.56544,169.58069,196.97656,179.37746,-99.65866,-71.85945,12.568847,-250.04826,-199.11371,39.719597,-17.705427,-170.95602,83.790565,-243.88147,-63.009056,-12.9932,1.7437074,245.39615,49.591637,34.722282,-158.85213],"z":[40.57932,-51.07657,-120.456375,-215.50902,-59.185738,187.43187,-181.43846,-2.7256467,150.84734,-173.64813,159.58743,114.2984,72.87333,-178.88557,-219.02614,49.230312,193.36702,162.38197,-78.008675,-9.914306,-116.49781],"type":"scatter3d"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"he ...

# %% [markdown]
# With reference to the output of the t-SNE Visualisation above, we are able to observe the various clusters are **Well-Separated** which implies that the Model did classify accuractely and to a high standard. However, there are a few outliers within the plot but these outliers are minor and do not impose a heavy deduction in accuracy towards the model.

# %% [markdown]
# ---
# ## 10.5 Visualising Overall Architecture

# %% [markdown]
# In this sub-section, we will be visualising the Overall Architecture of the Best Model. This will allow for a very vague overview of the Model's architecture without much information on weights and inputs or outputs which will be more friendly towards audience with no AI background. This will also allow us to see the Model's process in one view.

# %%
# ==================== Producing 3D‐block View ==================== #
visualkeras.layered_view(
    best_model,
    to_file='model_3d.png',
    legend=True,
    spacing=40,
    scale_xy=1.0,
    scale_z=0.5
)

# ==================== Displaying 3D‐block View ==================== #
Image('model_3d.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning:
#
# The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.

# %% [markdown]
# With reference to the output of the Model's Achitecture above, we are able to see that the Model has multiple layers before the output. We are also able to see the sequence in which the process is taking place.

# %% [markdown]
# ---
# # 11. Bibliographies

# %% [markdown]
# Bikmukhametov, T. (2025). LinkedIn. [online] Linkedin.com. Available at: https://www.linkedin.com/posts/timurbikmukhametov_guide-to-neural-network-hyperparam-tuning-activity-7310995211281653760-JMbR?utm_source=share&utm_medium=member_desktop&rcm=ACoAAE7GRTUBBHsPcBm6fIan901ng_k_JOl7PsU [Accessed 17 May 2025].
# <br>
# <br>
# Géron, A. (2019). Hands-on machine learning with Scikit-Learn and TensorFlow concepts, tools, and techniques to build intelligent systems. 2nd ed. O’Reilly Media, Inc.
# <br>
# <br>
# OpenAI. (2023). ChatGPT.
# <br>
# <br>
# TensorFlow (2025). The Sequential model | TensorFlow Core. [online] TensorFlow. Available at: https://www.tensorflow.org/guide/keras/sequential_model.
# <br>
# <br>
# Russel, S. and Norvig, P. (2020). Artificial intelligence: A Modern approach. 4th ed. Prentice Hall.
